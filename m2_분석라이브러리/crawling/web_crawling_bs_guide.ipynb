# %% [markdown]
# Beautiful Soup Documentation <br/>
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %%
html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<div></div>
<p class="title"><b>The Dormouse's story</b></p>
<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://naver.com" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
with open('wtest1.html','w') as f:
    f.write(html_doc)

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html_doc, 'html.parser')
soup
# Out:
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <div></div>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body></html>

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html_doc, 'html.parser')
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <div>
#   </div>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://naver.com" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
soup.title
# Out:
# <title>The Dormouse's story</title>

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.title.parent.name
# Out:
# 'head'

# %%
# p태그 첫번째 데이터
soup.p
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
# a태그 첫번째 데이터
soup.a
# Out:
# <a class="sister" href="http://naver.com" id="link1">Elsie</a>

# %%
soup.find('a')
# Out:
# <a class="sister" href="http://naver.com" id="link1">Elsie</a>

# %%
soup.a['class']
# Out:
# ['sister']

# %%
soup.find_all('a')
# Out:
# [<a class="sister" href="http://naver.com" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.find_all(class_="sister")
# Out:
# [<a class="sister" href="http://naver.com" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.find(id="link3")
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
soup.p['class']
# Out:
# ['title']

# %%
soup.find('p')
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
soup.find(class_='story')
# Out:
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://naver.com" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>

# %%
soup.find_all('p')
# Out:
# [<p class="title"><b>The Dormouse's story</b></p>,
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://naver.com" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  <p class="story">...</p>]

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# http://naver.com
# http://example.com/lacie
# http://example.com/tillie

# %%
soup.find_all()
# Out:
# [<html><head><title>The Dormouse's story</title></head>
#  <body>
#  <div></div>
#  <p class="title"><b>The Dormouse's story</b></p>
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://naver.com" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>
#  <p class="story">...</p>
#  </body></html>,
#  <head><title>The Dormouse's story</title></head>,
#  <title>The Dormouse's story</title>,
#  <body>
#  <div></div>
#  <p class="title"><b>The Dormouse's story</b></p>
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://naver.com" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>
#  <p class="story">...</p>
#  </body>,
#  <div></div>,
#  <p class="title"><b>The Dormouse's story</b></p>,
#  <b>The Dormouse's story</b>,
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://naver.com" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  <a class="sister" href="http://naver.com" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>,
#  <p class="story">...</p>]

# %% [markdown]
# #### string vs. get_text() vs. text
# - BeautifulSoup 객체에서 text 속성, get_text() 메서드, string 속성은 모두 HTML 또는 XML 문서에서 텍스트 데이터를 추출하는 데 사용
# - text 속성은 해당 태그에서 모든 텍스트 데이터를 가져오며,
# - get_text() 메서드도 동일한 결과를 반환합니다.
# - string 속성은 해당 태그에서 첫 번째로 발견된 문자열 데이터만 가져옵니다.

# %%
html = '''
<html>
<body>
<div>
Hello,world!
</div>
<div>
<p>
Hello,<b>world!</b>
</p>
</div>        
</body>
</html>
'''

# %%
with open('bt_test.html','w') as f:
    f.write(html)

# %%
with open('bt_test.html','r') as f:
    html = f.read()
    print(html)
# Out:
# <html>
# <body>
# <div>
# Hello,world!
# </div>
# <div>
# <p>
# Hello,<b>world!</b>
# </p>
# </div>
# </body>
# </html>

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html, 'html.parser')
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <div>
#    Hello,world!
#   </div>
#   <div>
#    <p>
#     Hello,
#     <b>
#      world!
#     </b>
#    </p>
#   </div>
#  </body>
# </html>

# %%
print(soup.div.text)
# Out:
# Hello,world!

# %%
print(soup.div.get_text())
# Out:
# Hello,world!

# %%
print(soup.div.string)
# Out:
# Hello,world!

# %%
# text 속성
print(soup.p.text)
# Out:
# Hello,world!

# %%
# get_text() 메서드
print(soup.p.get_text())
# Out:
# Hello,world!

# %%
# string 속성
print(soup.p.string)
print(soup.p.b.string)
# Out:
# None
# world!

# %%
soup.b.string
# Out:
# 'world!'

# %%
# body에 있는 모든 text 
import re
bs = soup.body.text
print(bs)
# Out:
# Hello,world!
#
#
#
# Hello,world!

# %%
# Q. 정규표현식을 사용하여 아래와 같이 출력하세요.
Hello,world!
Hello,world!

# %%
bs1 = re.finditer('.+', bs)
print(bs1)
for i in bs1:
    print(i.group())
# Out:
# <callable_iterator object at 0x0000029CE53C5A30>
# Hello,world!
# Hello,world!

# %%
texts = re.findall('[^\s]+',bs)
for t in texts:
    print(t)
# print(re.findall('[A-Za-z!]+',bs))
# Out:
# Hello,world!
# Hello,world!

# %%
# Q. 아래와 같이 출력하세요.
Hello,world! Hello,world!

# %%
text=re.findall('[^\s]+',bs)
for t in text:
    print(t,end=' ')
# Out:
# Hello,world! Hello,world!

# %%
bs = soup.body.text
bs = re.findall('.+',bs)
print(' '.join(bs))
# Out:
# Hello,world! Hello,world!

# %%
li = ''
for t in texts:
    li += t
    li += ' '
print(li)
# Out:
# Hello,world! Hello,world!

# %%
for t in texts:
    re.sub(r'\n','',t)
    print(t,end=' ')
# Out:
# Hello,world! Hello,world!

# %%
from bs4 import BeautifulSoup
html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<div></div>
<p class="title"><b>The Dormouse's story</b></p>
<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""
soup = BeautifulSoup(html_doc, 'html.parser')
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <div>
#   </div>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
bs = str(soup)
print(bs,type(bs))
# Out:
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <div></div>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body></html> <class 'str'>

# %%
# 영어 텍스트만 출력
p = re.findall('[a-zA-Z]+',bs) # 정규표현식
m = ' '.join(p)
m
# Out:
# 'html head title The Dormouse s story title head body div div p class title b The Dormouse s story b p p class story Once upon a time there were three little sisters and their names were a class sister href http example com elsie id link Elsie a a class sister href http example com lacie id link Lacie a and a class sister href http example com tillie id link Tillie a and they lived at the bottom of a well p p class story p body html'

# %%
print(type(soup))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
print(soup.get_text())
print(soup.text)
# Out:
# The Dormouse's story
#
#
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...
#
# The Dormouse's story
#
#
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...

# %%
texts = soup.find_all('body')
li = ''
for t in texts:
    li += t.text
li
# Out:
# "\n\nThe Dormouse's story\nOnce upon a time there were three little sisters; and their names were\nElsie,\nLacie and\nTillie;\nand they lived at the bottom of a well.\n...\n"

# %%
# 개행을 정규표현식으로 제거

re.sub('\n','',li)
# Out:
# "The Dormouse's storyOnce upon a time there were three little sisters; and their names wereElsie,Lacie andTillie;and they lived at the bottom of a well...."

# %%
# 개행을 정규표현식으로 제거
import re
texts = re.findall('[^\s]+', soup.text)
li =''
for text in texts:
    li += text
    li += ' '
print(li)
# Out:
# The Dormouse's story The Dormouse's story Once upon a time there were three little sisters; and their names were Elsie, Lacie and Tillie; and they lived at the bottom of a well. ...

# %%
soup.title
# Out:
# <title>The Dormouse's story</title>

# %%
print(soup.title.string)
# Out:
# The Dormouse's story

# %% [markdown]
# bs
#
# https://hi-guten-tag.tistory.com/8

# %% [markdown]
# #### html.parser vs. lxml
# - 파이썬에서 HTML 및 XML 문서를 파싱(parsing)하는 라이브러리
# - html.parser는 HTML 문서를 파싱하는 데에 적합한 파서. 파이썬의 기본 라이브러리로 제공되며 파이썬 내부적으로 구현되어 있으며, 외부 종속성이 없으므로 파이썬과 함께 설치되는 패키지만 사용할 수 있습니다.
# - lxml은 C 언어로 작성된 파이썬 외부 라이브러리로서 HTML 및 XML 문서를 파싱하는 데에 적합하며, 파서 성능이 매우 우수합니다.
# - HTML 문서를 파싱하는 경우에는 html.parser를 사용하는 것이 간단하고 편리하며, 대부분의 경우에는 충분한 성능을 제공합니다. 그러나 대용량의 XML 문서나 매우 복잡한 HTML 문서를 파싱해야 하는 경우에는 lxml을 사용하는 것이 더 효율적입니다.

# %% [markdown]
# #### urllib + bs

# %%
# lxml은 파이썬에서 XML과 HTML 문서를 파싱하고 조작하기 위한 빠르고 유연한 라이브러리
# !pip install lxml

# %%
import urllib.request as rq

url = 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100'
# html = rq.urlopen(url).read()
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'lxml')
print(bs)
# Out:
# <!DOCTYPE HTML>
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh"/>
# <meta content="width=1106" name="viewport"/>
# <meta content="정치 : 네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image"/>
# <meta content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="정치 : 네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
# <meta content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공" name="twitter:description"/>
# <title>정치 홈 : 네이버 뉴스	</title>
# <link href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/news.css" rel="stylesheet" type="text/css"/>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jindo.js" type="text/javascript"></script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jquery.js" type="text/javascript"></script>
# <script type="text/javascript">
# var _MAIN_NEWS_MENU_ID='shm';
# var _MAIN_NEWS_SECTION_ID='103';
# var ccsrv='cc.naver.com';
# var g_ssc='news.sec';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness = 3;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
#
# var gnb_timestamp = "Mon May 01 11:40:04 KST 2023";
# </script>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.service.js" type="text/javascript"></script>
# <script>
#
#     var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#     if (!isUnderIE10) {
#         var gladSDK = document.createElement("script");
#         gladSDK.async = true;
#         gladSDK.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#         document.head.appendChild(gladSDK);
#     }
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#
#     window.gladsdk.cmd.push(function () {
#         window.gladsdk.setGlobalConfig({enablePersistAd: true});
#         window.gladsdk.setHostMeta('theme', 'system');
#
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newsend',
#             adSlotElementId: 'glad_ad_newsend'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newslist',
#             adSlotElementId: 'glad_ad_newslist'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_sidebox',
#             adSlotElementId: 'glad_ad_sidebox'
#         });
#     })
# </script>
# </head>
# <body>
# <div id="wrap">
# <!-- 광고적용 태그 추가 -->
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
# <li><span class="snb_bdr"></span><a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">스포츠</a></li>
# <li><span class="snb_bdr"></span><a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">날씨</a></li>
# <li><span class="snb_bdr"></span><a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">프리미엄</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_both">
# <div class="lnb_left">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li><a class="nclicks(lnb.pcmedia)" href="/"><span class="tx">언론사별</span> </a></li>
# <li class="on"><a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
# <li><a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a></li>
# <li><a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹</span> </a></li>
# <li><a class="nclicks(lnb.paper)" href="/newspaper/home"><span class="tx">신문보기</span> </a></li>
# <li><a class="nclicks(lnb.opi)" href="/opinion/home"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(lnb.fact)" href="/main/factcheck/main.naver"><span class="tx">팩트체크</span> </a></li>
# </ul>
# </div>
# </div>
# <div class="lnb_right">
# <div class="lnb_extra">
# <div class="lnb_extra_menu">
# <ul class="lnb_extra_menu_list">
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(STA.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb">
# <span class="lnb_date"><strong>05</strong>.<strong>01</strong><span class="day">(월)</span></span>
# <ul class="lnb_side" tabindex="0">
# <li><a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li><a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li><a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# <hr/>
# <table cellpadding="0" cellspacing="0" class="container">
# <caption class="blind">기사목록</caption>
# <colgroup>
# <col class="col_snb"/>
# <col class="col_content"/>
# <col class="col_aside"/>
# </colgroup>
# <tr>
# <td class="snb">
# <div class="snb" id="snb">
# <h2 class="h2"><a class="nclicks(lmn_pol.home)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100">정치</a></h2>
# <ul class="nav">
# <li><a class="snb_s11 nclicks(lmn_pol.mnl,,1)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=264">대통령실 </a></li>
# <li><a class="snb_s12 nclicks(lmn_pol.mnl,,2)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=265">국회/정당 </a></li>
# <li><a class="snb_s13 nclicks(lmn_pol.mnl,,3)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=268">북한 </a></li>
# <li><a class="snb_s14 nclicks(lmn_pol.mnl,,4)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=266">행정 </a></li>
# <li><a class="snb_s15 nclicks(lmn_pol.mnl,,5)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=267">국방/외교 </a></li>
# <li><a class="snb_s16 nclicks(lmn_pol.mnl,,6)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=269">정치일반 </a></li>
# </ul>
# <div class="snb_banner">
# <a class="nclicks(lmn_pol.pmb,,1)" href="https://media.naver.com/channel/setting?back=main"><img alt="언론사 구독하기" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/01/14/142956425_144518244_%2525B8%2525F0%2525B9%2525D9%2525C0%2525CF%2525B8%2525DE%2525C0%2525CE.png" width="71"/></a>
# </div>
# <div class="snb_banner">
# <a class="nclicks(lmn_pol.pmb,,1)" href="https://contents.premium.naver.com/"><img alt="네이버 프리미엄콘텐츠" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71"/></a>
# </div>
# </div>
# </td>
# <td class="content">
# <div class="content" id="main_content">
# <div class="list_body section_index">
# <div class="cluster">
# <div class="cluster_title">
# <span class="cluster_title_inner"><a class="cluster_title_icon_link _news_cluster_layer_btn" href="#biF7L"><i class="cluster_title_icon">안내</i>헤드라인 뉴스</a></span>
# <div class="cluster_title_layer _news_cluster_layer is_hidden">
# <div class="cluster_title_layer_text">
#                             헤드라인 뉴스와 각 기사묶음 타이틀은 <br/> 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.
#                         </div>
# <div class="cluster_title_layer_image"></div>
# <button class="cluster_title_layer_close _news_cluster_layer_close_btn" type="button">닫기</button>
# </div>
# </div>
# </div>
# <div class="_persist">
# <div class="cluster">
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/014/0005005133?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/014/2023/05/01/5005133.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/014/0005005133?sid=100">'동맹 쐐기' 방미효과? 尹지지율, 4주 만에 반등했다</a>
# <div class="cluster_text_lede">최근 미국 국빈 방문을 마치고 귀국한 윤석열 대통령의 국정수행 지지도가 4주만에 반등했다는 여론조사 결과가 1일 발표됐다. 여론조사 전문기관 리얼미터가  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news014,0005005133',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">파이낸셜뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news658,0000039680',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">국제신문</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/658/0000039680?sid=100">尹 지지율 4주만에 반등..."美서 환대 받은 효과 나오나?"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news448,0000407097',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">TV조선</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/448/0000407097?sid=100">尹대통령 긍정평가 34.5%…4주 만에 소폭 반등</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006779685',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779685?sid=100">尹 지지율 34.5%, 4주 만에 1.9%p 상승…"방미 불안감 해소"</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010810_00000002&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=014&amp;aid=0005005133"><span class="cluster_foot_more_icon_num">37</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879472?sid=100">외교부, 中 한미회담 보도 반박..."타국 우려사항 아냐"</a>
# <div class="cluster_text_lede">외교부가 한미의 대북 확장억제 강화 방안을 담은 워싱턴 선언 내용을 비난하는 중국 언론 보도에 대해 타국이 우려를 가질 사항이 아니라고 반박했습니다. 외교부 당국자는 "북·중·러의 경고를 무시하면 보복에 직 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879472',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006779445',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779445?sid=100">정부, 워싱턴선언 비난 中관영매체에 "中정부의 北비핵화 역할 호소를"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news366,0000898012',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선비즈</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898012?sid=100">정부, 한미회담 비난 中 보도 반박… “다른 나라가 우려할 사안 아냐”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013913416',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013913416?sid=100">정부, 한미회담 비난 中보도 반박…"타국이 우려할 사항 아냐"</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304302240_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=052&amp;aid=0001879472"><span class="cluster_foot_more_icon_num">7</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779889?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/421/2023/05/01/6779889.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779889?sid=100">與 "尹 방미, 북핵대응·가치동맹 최대 성과…양국 새 이정표 수립"</a>
# <div class="cluster_text_lede">국민의힘은 1일 윤석열 대통령의 미국 국빈 방문에 대해 "한미 양국 관계의 새로운 이정표를 수립하는 계기를 마련했다"고 극찬했다. 김기현 대표는 이날 국 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006779889',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879511',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879511?sid=100">김기현 "尹 국빈 방미, 한미 새 이정표 수립 최대 성과"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013913728',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013913728?sid=100">김기현 "尹방미, 한미 양국관계 새 이정표 수립 최대 성과 거둬"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011833258',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011833258?sid=100">김기현, 尹 방미에 "한미관계 새로운 이정표 수립 계기 마련"</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010940_00000015&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=421&amp;aid=0006779889"><span class="cluster_foot_more_icon_num">15</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269869?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/214/2023/05/01/1269869.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269869?sid=100">'설화' 김재원 "심려끼쳐 대단히 죄송"‥한 달만 최고위 복귀</a>
# <div class="cluster_text_lede">잇따른 설화로 논란을 일으킨 김재원 국민의힘 최고위원이 한 달 만에 당 최고위원회의에 참석해 다시한번 사과의 뜻을 밝혔습니다. 김 최고위원은 '5·18  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news214,0001269869',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">MBC</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006779781',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779781?sid=100">한달만 최고위 출석 김재원 "대단히 죄송"…당은 징계절차 개시할듯</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news025,0003276991',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">중앙일보</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003276991?sid=100">김재원, 한 달만에 최고위 출석 "심려끼쳐 죄송, 열심히 하겠다"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879513',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879513?sid=100">'설화' 김재원, 한 달 만에 최고위 복귀..."심려 끼쳐 죄송"</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010930_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=214&amp;aid=0001269869"><span class="cluster_foot_more_icon_num">36</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779432?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/421/2023/04/30/6779432.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779432?sid=100">박광온 "尹, 국익·균형외교 원칙 지켰는지 면밀히 평가해야"</a>
# <div class="cluster_text_lede">박광온 더불어민주당 원내대표는 30일 미국 국빈 방문을 마치고 귀국한 윤석열 대통령의 한미 정상회담 성과에 대해서 "과연 (국익외교, 균형외교) 두 가지 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006779432',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898011?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/366/2023/04/30/898011.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898011?sid=100">박광온 “‘돈 봉투’ 논란 정면으로 맞서야… 대의원제 폐지 아직 안돼”</a>
# <div class="cluster_text_lede">박광온 더불어민주당 원내대표는 ‘2021년 전당대회 돈 봉투’ 의혹이 불거지며 당이 위기에 빠진 상황을 두고 “위기를 회피하려 해선 안 되고, 담담하게  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news366,0000898011',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선비즈</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304302210_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=421&amp;aid=0006779432"><span class="cluster_foot_more_icon_num">15</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185080?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/011/2023/04/30/4185080.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185080?sid=100">‘서지니형’ 왜 거기서 나와?…尹 대통령 "어떻게 오셨냐"</a>
# <div class="cluster_text_lede">미국을 국빈 방문한 윤석열 대통령이 세계적인 영상 콘텐츠 기업들을 만나 K-콘텐츠 수출 확대를 논의한 자리에 자리에 배우 이서진이 모습을 보였다. 윤 대 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004185080',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/005/0001605144?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/005/2023/05/01/1605144.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/005/0001605144?sid=100">‘서지니형’ 왜 여기에?…尹대통령 “어떻게 오셨냐”</a>
# <div class="cluster_text_lede">미국을 국빈 방문한 윤석열 대통령이 세계적인 영상 콘텐츠 기업들을 한자리에서 만나 K-콘텐츠 수출 확대를 논의한 자리에 배우 이서진이 등장해 화제가 되고 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news005,0001605144',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">국민일보</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304280850_00000028&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=011&amp;aid=0004185080"><span class="cluster_foot_more_icon_num">8</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269756?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/214/2023/04/30/1269756.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269756?sid=100">국민의힘 윤리위, 내일 첫 회의‥'김재원·태영호 중징계' 나오나</a>
# <div class="cluster_text_lede">국민의힘 중앙윤리위원회가 내일 오전 당사에서 첫 회의를 열고 새로 선임된 윤리위원들에게 임명장을 수여할 예정인 가운데, 잇단 설화로 물의를 빚은 김재원· …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news214,0001269756',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">MBC</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779241?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/421/2023/04/30/6779241.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779241?sid=100">野 "태영호·김재원 징계" 논평에 與 "위대한 정신승리 백미될 것"(종합)</a>
# <div class="cluster_text_lede">국민의힘은 30일 더불어민주당이 내달 1일 열릴 국민의힘 윤리위원회와 관련해 '태영호·김재원 최고위원에게 합당한 징계를 내리라'고 논평한 데 대해 "온갖 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006779241',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304281030_00001855&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=214&amp;aid=0001269756"><span class="cluster_foot_more_icon_num">46</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879485?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/052/2023/05/01/1879485.jpg?type=ofullfill132_90" width="132"/>
# <strong class="r_ico r_vod_medium">동영상기사</strong>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879485?sid=100"> 윤 대통령, 방미 마치고 귀국...여야, 엇갈린 평가[뉴스라이더]</a>
# <div class="cluster_text_lede">■ 진행 : 김대근 앵커, 안보라 앵커 ■ 출연 : 임경빈 시사 평론가 * 아래 텍스트는 실제 방송 내용과 차이가 있을 수 있으니 보다 정확한 내용은 방 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879485',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879411?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/052/2023/04/30/1879411.jpg?type=ofullfill132_90" width="132"/>
# <strong class="r_ico r_vod_medium">동영상기사</strong>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879411?sid=100">윤 대통령, 국빈 방미 마치고 귀국...여야, 방미 평가 ·간호법 대치</a>
# <div class="cluster_text_lede">■ 진행 : 이세나 앵커, 정성욱 앵커 ■ 출연 : 서성교 건국대 특임교수, 배종호 세한대 교수 * 아래 텍스트는 실제 방송 내용과 차이가 있을 수 있으 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879411',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304281620_00000245&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=052&amp;aid=0001879485"><span class="cluster_foot_more_icon_num">5</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054488?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/055/2023/05/01/1054488.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054488?sid=100">박광온 "국정운영 '사람 중심'으로 바꿔야…학부모 주 4일제 검토"</a>
# <div class="cluster_text_lede">박광온 민주당 원내대표는 "지금 윤석열 대통령과 정부가 해야 할 일은 분명하다. 국정운영 기조를 사람 중심으로 대전환해야 한다"고 강조했습니다. 박 원내 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news055,0001054488',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">SBS</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013913799?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2023/05/01/13913799.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013913799?sid=100">박광온 "사람 중심으로 국정운영 바꿔야…학부모 주4일제 검토"</a>
# <div class="cluster_text_lede">잔혹한 사회적 죽음 계속…초등 자녀 키우는 맞벌이 부부 대상 주4일제 준비" 더불어민주당 박광온 원내대표는 1일 "지금 윤석열 대통령과 정부가 해야 할  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013913799',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011000_00000003&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=055&amp;aid=0001054488"><span class="cluster_foot_more_icon_num">19</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879481?sid=100"> 민형배 "당내 비판? 늘 그래왔던 분들...자기 참모에 수류탄 터뜨리는 행위"[뉴스킹]</a>
# <div class="cluster_text_lede">YTN라디오(FM 94.5) [뉴스킹 박지훈입니다] □ 방송일시 : 2023년 5월 1일 (월) □ 진행 : 박지훈 변호사 □ 출연자 : 민형배 더불어민주당 의원 * 아래 텍스트는 실제 방송 내용과 차이가  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879481',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011475966?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/056/2023/05/01/11475966.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011475966?sid=100"> 김민석 “송영길 발언이 공천에 직결? 황당한 상상력”[최강시사]</a>
# <div class="cluster_text_lede">- 새 원내대표 박광온, 오랫동안 의원들 접촉해온 것 플러스 된 듯 - 돈봉투 의혹 진상조사는 한계 명료하다는 것이 대부분의 인식 - 대의원제 폐지하자는 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news056,0011475966',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">KBS</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010930_00000089&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=052&amp;aid=0001879481"><span class="cluster_foot_more_icon_num">4</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002137436?sid=100">‘워싱턴 선언’ 최대 성과...중·러 ‘강한 반발’ 부담</a>
# <div class="cluster_text_lede">윤석열 대통령의 5박7일 미국 국빈방문 최대 성과로는 무엇보다 ‘워싱턴 선언’이 꼽힌다. 고도화하는 북한의 핵·미사일 위협에 맞서 대북 확장억제(핵우산)를 획기적으로 강화하고 한미 간 안보 협력 수준을 대폭 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news016,0002137436',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">헤럴드경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002137245?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/016/2023/05/01/2137245.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002137245?sid=100">확장억제 강화 ‘워싱턴 선언’ 최대 성과…신냉전 구도 ‘숙제’ [국빈방미 결산]</a>
# <div class="cluster_text_lede">윤석열 대통령의 5박7일 미국 국빈방문 최대 성과로는 무엇보다 ‘워싱턴 선언’이 꼽힌다. 고도화하는 북한의 핵·미사일 위협에 맞서 대북 확장억제(핵우산) …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news016,0002137245',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">헤럴드경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304280010_00001014&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=016&amp;aid=0002137436"><span class="cluster_foot_more_icon_num">22</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/015/0004839333?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/015/2023/04/30/4839333.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/015/0004839333?sid=100">"尹 영어 연설 상상 초월"…'1세대 강사' 오성식 극찬한 까닭</a>
# <div class="cluster_text_lede">'1세대 영어 강사' 오성식 씨가 윤석열 대통령의 미 의회 연설에 대해 "윤 대통령이 영어뿐 아니라 스피치에도 일가견이 있다"고 평가했다. 오 씨는 80 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news015,0004839333',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">한국경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/057/0001739228?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/057/2023/05/01/1739228.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/057/0001739228?sid=100">'1세대 영어강사' 오성식 "윤 대통령 영어연설에 소름"</a>
# <div class="cluster_text_lede">80~90년대 '생활영어'로 명성을 얻은 '1세대 영어 강사' 오성식 씨가 윤석열 대통령의 미국 의회 연설에 대해 "이번 스피치는 정말 만점이었다"며 극 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news057,0001739228',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">MBN</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304301840_00000102&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=015&amp;aid=0004839333"><span class="cluster_foot_more_icon_num">12</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779977?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/421/2023/05/01/6779977.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779977?sid=100">尹 "한미동맹, 모든 면에서 확장…청년·미래세대 기회의 플랫폼 돼야"</a>
# <div class="cluster_text_lede">윤석열 대통령은 1일 조 바이든 미국 대통령과의 정상회담을 통해 한미동맹이 포괄적으로 강화했다고 평가하면서 "무엇보다 청년 미래 세대에게 기회의 플랫폼이 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006779977',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011476070?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/056/2023/05/01/11476070.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011476070?sid=100">윤 대통령 “업그레이드 한미동맹, 청년 기회의 플랫폼 돼야”</a>
# <div class="cluster_text_lede">윤석열 대통령이 한미정상회담 결과가 청년 미래 세대에게 기회의 플랫폼이 되도록 후속조치를 구체화해 달라고 지시했습니다. 윤 대통령은 오늘(1일) 용산 대 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news056,0011476070',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">KBS</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011110_00000003&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=421&amp;aid=0006779977"><span class="cluster_foot_more_icon_num">12</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879480?sid=100">이종섭 국방장관 "워싱턴 선언, 제2한미상호방위조약"</a>
# <div class="cluster_text_lede">이종섭 국방부 장관은 확장억제 강화를 골자로 한 '워싱턴 선언'에 대해 제2의 한미상호방위조약으로 불러도 될 정도로 의미가 크다고 평가했습니다. 이 장관은 언론 기고문에서 이번 선언은 재래식 무기를 기반으로 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879480',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/015/0004839320?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/015/2023/04/30/4839320.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/015/0004839320?sid=100">"워싱턴 선언은 제2 한·미 상호방위조약"</a>
# <div class="cluster_text_lede">윤석열 대통령은 지난 28일 한·미 정상이 채택한 ‘워싱턴 선언’의 의미에 대해 “재래식 무기에 기반한 한·미 상호방위조약에서 ‘핵이 포함된 상호방위 개 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news015,0004839320',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">한국경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304290630_00000003&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=052&amp;aid=0001879480"><span class="cluster_foot_more_icon_num">8</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011833230?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/05/01/11833230.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011833230?sid=100">박용진 "송영길 탈당…윤관석·이성만 선택지 많지 않아"</a>
# <div class="cluster_text_lede">기사내용 요약 "지도부가 책임있는 결정 내리면 따라야" "대의원제 개편, 소 잃고 외양간 부수기" [서울=뉴박용진 더불어민주당 의원은 1일 지난 2021 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011833230',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/018/0005476347?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/018/2023/05/01/5476347.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/018/0005476347?sid=100">박용진 "이재명, `돈 봉투` 의혹 칼 들고 당 정리·책임져야"</a>
# <div class="cluster_text_lede">박용진 더불어민주당 의원은 1일 지난 2021년 민주당 전당대회 ‘돈 봉투’ 의혹의 핵심 인물로 꼽히는 윤관석·이성만 민주당 의원에 대해 “송영길 전 대 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news018,0005476347',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">이데일리</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# ...
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/659/0000011136?ntype=RANKING&amp;sid=001">"부모 대부분 자녀들 마약 범죄 몰라".. 용돈으로 사고, …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=659"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/659/2022/01/19/logo_659_56_20220119141438.png" width="16"/></span>전주MBC</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/657/0000014464?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/657/2023/05/01/14464.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/657/0000014464?ntype=RANKING&amp;sid=001">[뉴스비하인드] 대구경북신공항, 새로운 하늘길인가? 꽉 막 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=657"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/657/2022/01/19/logo_657_56_20220119135625.png" width="16"/></span>대구MBC</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/661/0000024311?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/661/2023/05/01/24311.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/661/0000024311?ntype=RANKING&amp;sid=001">유급휴일 '근로자의 날'.."직장인 10명 중 3명  출근 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=661"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/661/2022/01/19/logo_661_56_20220119142145.png" width="16"/></span>JIBS</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/665/0000000882?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/665/2023/05/01/882.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/665/0000000882?ntype=RANKING&amp;sid=001">리버버스 김포~여의도 20분? 실제론 1시간 28분 [視리 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=665"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/665/2022/12/08/logo_665_56_20221208184224.png" width="16"/></span>더스쿠프</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018624?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/145/2023/05/01/18624.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018624?ntype=RANKING&amp;sid=001">적금 탔더니 그 돈으로 병원을 가네···5월 별자리 운세</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=145"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/145/2020/12/09/logo_145_56_20201209180915.png" width="16"/></span>레이디경향</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <button class="refresh_button nclicks('rig.renws2new') _refreshButton" type="button">더보기</button>
# </div>
# <script type="text/javascript">
#     var OfficeTopRankingManager = jindo.$Class({
#         $static: {
#             RANKING_INFO_BUTTON_SELECTOR: '._rankingInfoButton',
#             RANKING_INFO_LAYER_SELECTOR : '._rankingInfoLayer',
#             RANKING_INFO_BUTTON_CLOSE_SELECTOR : '._rankingInfoCloseButton',
#             REFRESH_BUTTON_SELECTOR : '._refreshButton',
#             RANKING_LIST_SELECTOR : '._rankingList'
#         },
#
#         $init: function(base) {
#             this._welBase = jindo.$Element(base);
#             this._rankingInfoLayer = jindo.$Element(this._welBase.query(this.constructor.RANKING_INFO_LAYER_SELECTOR));
#             this._rankingListArray = jindo.$ElementList(this._welBase.queryAll(this.constructor.RANKING_LIST_SELECTOR));
#
#             this._initEvent();
#         },
#
#         _initEvent: function() {
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_SELECTOR, jindo.$Fn(this._showRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_CLOSE_SELECTOR, jindo.$Fn(this._closeRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.REFRESH_BUTTON_SELECTOR, jindo.$Fn(this._refreshRankingList, this).bind());
#         },
#
#         _showRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.toggle();
#         },
#
#         _closeRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.hide();
#         },
#
#         _refreshRankingList: function(event) {
#             event.stopDefault();
#
#             for (var i=0 ; i<this._rankingListArray.length() ; i++) {
#                 var rankingList = this._rankingListArray.get(i);
#
#                 if (rankingList.visible() === true) {
#                     var nextIndex = i + 1;
#
#                     if (nextIndex === this._rankingListArray.length()) {
#                         nextIndex = 0;
#                     }
#
#                     var nextRankingList = this._rankingListArray.get(nextIndex);
#
#                     rankingList.hide();
#                     nextRankingList.show();
#
#                     break;
#                 }
#             }
#         }
#     });
#
#     window.addEventListener("load", function() {
#         var officeTopRanking = jindo.$$.getSingle("._officeTopRanking1087473");
#         if (officeTopRanking) {
#             new OfficeTopRankingManager(officeTopRanking);
#         }
#     });
# </script>
# <div class="side_ad" id="glad_ad_sidebox"></div>
# <div class="section" id="right_dailyList" style="margin-bottom:20px; white-space:nowrap;">
# <h4>분야별 주요뉴스</h4>
# <div class="classfy sd" style="display:block">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/055/0001054484?sid=100" title="'설화' 김재원 최고위 복귀…'자진사퇴'엔 &quot;아직 생각 안 해봐&quot;">'설화' 김재원 최고위 복귀…'자진사퇴'엔 "아직 생각 안 해봐"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/214/0001269875?sid=100" title="윤 대통령 지지율 1.9%p 오른 34.5%‥4주 만에 반등 [리얼미터]">윤 대통령 지지율 1.9%p 오른 34.5%‥4주 만에 반등 [리얼미터]</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/001/0013913799?sid=100" title='박광온 "사람 중심으로 국정운영 바꿔야…학부모 주4일제 검토"'>박광온 "사람 중심으로 국정운영 바꿔야…학부모 주4일제 검토"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/001/0013913648?sid=104" title="'中·대만 대리전' 파라과이 대선서 '親美·親대만' 페냐 당선(종합)">'中·대만 대리전' 파라과이 대선서 '親美·親대만' 페냐 당선(종합)</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/079/0003765136?sid=104" title="퍼스트리퍼블릭 붕괴 수순…Fed 고민 깊어져">퍼스트리퍼블릭 붕괴 수순…Fed 고민 깊어져</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/001/0013913873?sid=101" title="'41% 급감' 반도체에 수출 7개월째 감소…적자 3조원대로 좁혀져(종합)">'41% 급감' 반도체에 수출 7개월째 감소…적자 3조원대로 좁혀져(종합)</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/092/0002290751?sid=101" title="삼성전자, 5월 가정의 달 맞아 '2023형 TV 슈퍼빅세일' 진행">삼성전자, 5월 가정의 달 맞아 '2023형 TV 슈퍼빅세일' 진행</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/421/0006780047?sid=101" title="오늘 국회서 ‘전세사기 특별법’ 심사…지원대상 요건 조정 등에 이목 집중">오늘 국회서 ‘전세사기 특별법’ 심사…지원대상 요건 조정 등에 이목 집중</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/138/0002147587?sid=105" title="‘중간요금제’ 속속 출격…LTE→5G 전환 이끌어낼까">‘중간요금제’ 속속 출격…LTE→5G 전환 이끌어낼까</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/011/0004185262?sid=105" title="'노태북 열풍 이어갈까'…삼성, 인텔 13세대 기반 PC 3종 출시">'노태북 열풍 이어갈까'…삼성, 인텔 13세대 기반 PC 3종 출시</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/079/0003765126?sid=102" title="檢, '돈봉투 의혹' 송영길 캠프 지역본부장 등 추가 압수수색(종합)">檢, '돈봉투 의혹' 송영길 캠프 지역본부장 등 추가 압수수색(종합)</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/079/0003765120?sid=102" title="'강남 투신' 10대 만났던 20대 남성 입건…자살방조죄 적용">'강남 투신' 10대 만났던 20대 남성 입건…자살방조죄 적용</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/081/0003357755?sid=102" title="컵라면 먹던 초등생 ‘묻지마 폭행’ 10대 구속기소">컵라면 먹던 초등생 ‘묻지마 폭행’ 10대 구속기소</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011833398?sid=103" title="조계종, 전국 65개 사찰 관람료 4일부터 면제">조계종, 전국 65개 사찰 관람료 4일부터 면제</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/011/0004185244?sid=103" title='팰리세이드 5%·캐스퍼 70만원 할인…"현대차 SUV 사려면 5월에"'>팰리세이드 5%·캐스퍼 70만원 할인…"현대차 SUV 사려면 5월에"</a> </li>
# </ul>
# </ul>
# </ul>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://media.naver.com/channel/settings"> <img alt="네이버 메인에서 바로 보는 언론사 편집뉴스 지금 바로 구독해보세요!" src="https://imgnews.pstatic.net/image/upload/item/2018/11/27/174854048_PC_%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA_%25B1%25B8%25B5%25B6%25C8%25B0%25BC%25BA%25C8%25AD.png" width="300"/> </a>
# </div>
# </div>
# <div class="section">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/assembly/index.naver" target="_blank"> <img alt="내일을 여는 국민의 국회" border="0" class="banner" height="60" src="https://imgnews.pstatic.net/image/upload/item/2021/01/08/173235779_%25B1%25B9%25C8%25B8%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA.png" width="300"/> </a>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" target="_blank"> <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/183951086_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300"/> </a>
# </div>
# </div>
# <div class="section">
# <h4> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"> 서비스 안내 </a> </h4>
# <ul class="list_txt">
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb"> 고침 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb"> 정정·반론·추후 보도 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb"> 불공정 선거 보도 기사 모음 </a> </li>
# </ul>
# <a class="more_link nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"><span class="blind">서비스 안내</span>더보기</a>
# </div>
# <script>
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#
#         adSlot.setCustomParam("calp", 'shome');
#         window.gladsdk.displayAd(adSlot);
#     });
# </script>
# </div>
# </td>
# </tr>
# </table>
# </div>
# <hr/>
# <div class="index">
# <div class="index_inner">
# <div class="floating_btn">
# <div class="floating_inner">
# <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
# <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
# </div>
# </div>
# <div class="index_tab" id="index.press_category">
# <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content is_hidden" id="index.press.area"></div>
# <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content02 is_hidden" id="index.category.area"></div>
# </div>
# </div>
# </div>
# <hr/>
# <div id="footer">
# <ul>
# <li class="first"><a class="nclicks(fot.agreement)" href="http://www.naver.com/rules/service.html">이용약관</a></li>
# <li><a class="nclicks(fot.guide)" href="/main/ombudsman/index.naver">서비스 안내</a></li>
# <li><a class="nclicks(fot.editor)" href="/main/ombudsman/edit.naver?mid=omb">기사배열 원칙 책임자 : 유봉석</a></li>
# <li>청소년 보호 책임자 : 이희만</li>
# <li><strong><a class="nclicks(fot.privacy)" href="http://www.naver.com/rules/privacy.html">개인정보처리방침</a></strong></li>
# <li><a class="nclicks(fot.disclaimer)" href="http://www.naver.com/rules/disclaimer.html">책임의 한계와 법적고지</a></li>
# <li><a class="nclicks(fot.help)" href="#" onclick="news.external.OPS.helpNews(); return false;" title="새창">뉴스 고객센터</a></li>
# </ul>
# <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
# <address class="address_nhn">
# <a class="logo nclicks(fot.naver)" href="https://www.navercorp.com/" target="_blank"><span class="blind">NAVER</span></a>
# <em>Copyright ©</em>
# <a class="nclicks(fot.navercorp)" href="https://www.navercorp.com/" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# <!-- -->
# </div>
# <script type="text/javascript">
#
#
#
#
#
#
#
# var index_tab = new news.index.TabController('index.press_category');
# index_tab.add(new news.index.Tab('index.press.btn','stit','index.press.area','/main/ajax/bottomIndex/press.naver'));
# index_tab.add(new news.index.Tab('index.category.btn','stit2','index.category.area','/main/ajax/bottomIndex/category.naver'));
# jindo.$Fn(index_tab.toggle, index_tab).attach(index_tab.tabs.keys(), 'click');
#
#
# (function() {
# 	news.right.RightSideFloatingManager.init();
# })();
#
#
#
#     (function() {
#         news.right.TopDownFloatingManager.init();
#     })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ;(function(){
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jindo.$Fn(function(){
#
#
# 	lcs_do();
#
#     }).attach(window, eventType);
# })();
#
#
#
#
#
#
#
#
# news.startup();
#
#
# jindo.$Fn(function(){
#     var welSkip = jindo.$Element("u_skip");
#     if (welSkip === null) {
#         return;
#     }
#     welSkip.delegate("click", "a", function(weEvent){
#         weEvent.stopDefault();
#         var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#         oWebAccessibilityUtil.moveFocus(elTarget);
#     });
# }).attach(window, "load");
#
#
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
# </body>
# </html>

# %%
text1 = bs.find('p')
print(text1,'\n')
text2 = bs.find('p').string
print(text2,'\n')
text3 = bs.find('p').get_text()
print(text3)
# Out:
# <p class="airs_info_inner"><i class="airs_info_icon_airs">AiRS</i><span class="airs_info_text"><b>추천</b>으로 구성된 뉴스를 제공합니다.</span></p>
#
# None
#
# AiRS추천으로 구성된 뉴스를 제공합니다.

# %%
texts = bs.find_all('p')

for t in texts:
    print(t.text)
# Out:
# AiRS추천으로 구성된 뉴스를 제공합니다.
# 오전 10시~오전 11시까지 집계한 결과입니다.
# 본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.

# %% [markdown]
# bs4에서 headers는
#
# headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
# - HTTP 요청을 보낼 때 요청 헤더를 설정하는 데 사용됩니다.
# - 일반적으로 웹 사이트에서 데이터를 스크래핑하려면, 해당 웹 사이트에서 HTTP 요청을 받을 때 자신이 웹 브라우저인 것처럼 보이도록 요청 헤더를 설정해야 합니다.
# - 이를 통해 웹 사이트는 봇이나 크롤러와 같은 자동화된 스크래핑 도구에서 요청을 보내는 것으로 인식하는 것을 방지할 수 있습니다.

# %% [markdown]
#  #### 인코딩 에러를 해결
#  chardet.detect(response.content)['encoding']은 response.content의 인코딩 방식을 자동으로 감지하여 반환하며
#  이 값을 encoding 변수에 저장한 후, response.content를 이 encoding 방식으로 디코딩하여 html 변수에 저장하고 출력

# %%
import requests
import chardet

# HTTP 요청에서 사용될 헤더 정보를 설정합니다.
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}

# 웹사이트에서 스크래핑할 URL을 지정합니다.
url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100'

# 지정된 url에 HTTP GET 요청을 전달
response = requests.get(url, headers=headers)

# HTTP 요청이 성공적으로 전달되었다면, 웹사이트의 HTML 코드를 출력합니다.
if response.status_code == 200:
#     encoding = chardet.detect(response.content)['encoding']
#     print(response.content.decode(encoding)) # 웹사이트의 HTML 코드를 포함하는 이진(binary) 데이터를 반환
     print(response.text) # 웹사이트의 HTML 코드를 문자열 형태로 반환
else:
    print("HTTP request failed.")
# Out:
# <!DOCTYPE HTML>
# <html lang="ko">
# <head>
# <meta charset="euc-kr">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta name="referrer" contents="always">
# <meta http-equiv="refresh" content="600" />
# <meta name="viewport" content="width=1106" />
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <meta property="og:title"       content="정치 : 네이버 뉴스">
# <meta property="og:type"        content="website">
# <meta property="og:url"         content="https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100">
# <meta property="og:image"       content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png"/>
# <meta property="og:description" content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공">
# <meta property="og:article:author"	content="네이버"/>
#
# <meta name="twitter:card"		content="summary">
# <meta name="twitter:title"		content="정치 : 네이버 뉴스">
# <meta name="twitter:site"       content="네이버 뉴스">
# <meta name="twitter:creator"    content="네이버 뉴스">
# <meta name="twitter:image"		content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png">
# <meta name="twitter:description" content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공">
#
#
#
#
#
#
#
# <title>정치 홈 : 네이버 뉴스	</title>
# <link rel="shortcut icon" type="image/x-icon" href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico" />
#
#
#
#
#
#
#
#
#
#
# 		<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/common.css"/>
# 		<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/news.css"/>
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jindo.js" charset="euc-kr"></script>
#
#
#
#
# <script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jquery.js" charset="utf-8"></script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript">
# var _MAIN_NEWS_MENU_ID='shm';
# var _MAIN_NEWS_SECTION_ID='103';
# var ccsrv='cc.naver.com';
# var g_ssc='news.sec';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness = 3;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
#
# var gnb_timestamp = "Mon May 01 12:23:29 KST 2023";
# </script>
#
#
#
#
# <script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.service.js" charset="euc-kr"></script>
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script>
#
#     var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#     if (!isUnderIE10) {
#         var gladSDK = document.createElement("script");
#         gladSDK.async = true;
#         gladSDK.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#         document.head.appendChild(gladSDK);
#     }
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#
#     window.gladsdk.cmd.push(function () {
#         window.gladsdk.setGlobalConfig({enablePersistAd: true});
#         window.gladsdk.setHostMeta('theme', 'system');
#
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newsend',
#             adSlotElementId: 'glad_ad_newsend'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newslist',
#             adSlotElementId: 'glad_ad_newslist'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_sidebox',
#             adSlotElementId: 'glad_ad_sidebox'
#         });
#     })
# </script>
#
#
# </head>
#
# <body>
# 	<div id="wrap">
# 		<!-- 광고적용 태그 추가 -->
# 		<div id="da_base"></div>
# 		<div id="da_stake"></div>
#
#
#
# <div id="header" class="header">
#
# 	<div id="u_skip">
# 		<a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# 		<a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# 	</div>
#
#
# 	<div class="snb_area">
# 		<div class="snb_inner">
#
# <div class="gnb_area">
#    <div class="gnb_wrap">
#
#       <div id="gnb" class="gnb_dark_type2"></div>
#
#    </div>
#    <div class="gnb_search is_hidden _search_content">
#    </div>
#    <div id="gnb_search_tool" class="gnb_tool">
#       <a href="javascript:;" class="tool_button _search_content_toggle_btn nclicks(gnb.sch)"><span class="icon_search">검색</span></a>
#    </div>
# </div>
#
#
#
# <div id="snb_wrap">
#     <h1>
#         <a href="https://www.naver.com/" class="h_logo nclicks(gnb.naver)"><span class="blind">NAVER</span></a>
#         <a href="/" class="h_news nclicks(gnb.news)"><span class="blind">뉴스</span></a>
#     </h1>
#     <ul class="snb_related_service">
#         <li><span class="snb_bdr"></span><a href="https://entertain.naver.com/home" class="entertain nclicks(gnb.enter)">TV연예</a></li>
#         <li><span class="snb_bdr"></span><a href="https://sports.news.naver.com" class="sports nclicks(gnb.sports)">스포츠</a></li>
#         <li><span class="snb_bdr"></span><a href="https://weather.naver.com" class="weather nclicks(gnb.weather)">날씨</a></li>
#         <li><span class="snb_bdr"></span><a href="https://contents.premium.naver.com" class="premium nclicks(gnb.premium)">프리미엄</a></li>
#     </ul>
# </div>
# 		</div>
# 	</div>
# 	<div class="lnb_area">
# 		<div class="lnb_inner">
#
#
#
#
#
#
#
# <div class="lnb_both">
# 	<div class="lnb_left">
# 		<div id="lnb" class="lnb_menu">
# 			<ul>
# 				<li><a href="/" class="nclicks(lnb.pcmedia)"><span class="tx">언론사별</span> </a></li>
# 				<li class="on"><a href="/main/main.naver?mode=LSD&mid=shm&sid1=100" class="nclicks(lnb.pol)"><span class="tx">정치</span> <span class="blind">선택됨</span></a></li>
# 				<li><a href="/main/main.naver?mode=LSD&mid=shm&sid1=101" class="nclicks(lnb.eco)"><span class="tx">경제</span> </a></li>
# 				<li><a href="/main/main.naver?mode=LSD&mid=shm&sid1=102" class="nclicks(lnb.soc)"><span class="tx">사회</span> </a></li>
# 				<li><a href="/main/main.naver?mode=LSD&mid=shm&sid1=103" class="nclicks(lnb.lif)"><span class="tx">생활/문화</span> </a></li>
# 				<li><a href="/main/main.naver?mode=LSD&mid=shm&sid1=105" class="nclicks(lnb.sci)"><span class="tx">IT/과학</span> </a></li>
# 				<li><a href="/main/main.naver?mode=LSD&mid=shm&sid1=104" class="nclicks(lnb.wor)"><span class="tx">세계</span> </a></li>
# 				<li><a href="/main/ranking/popularDay.naver?mid=etc&sid1=111" class="nclicks(lnb.rankin)"><span class="tx">랭킹</span> </a></li>
# 				<li><a href="/newspaper/home" class="nclicks(lnb.paper)"><span class="tx">신문보기</span> </a></li>
# 				<li><a href="/opinion/home" class="nclicks(lnb.opi)"><span class="tx">오피니언</span> </a></li>
# 				<li><a href="/main/tv/index.naver?mid=tvh" class="nclicks(lnb.tv)"><span class="tx">TV</span> </a></li>
# 				<li><a href="/main/factcheck/main.naver" class="nclicks(lnb.fact)"><span class="tx">팩트체크</span> </a></li>
#
# 			</ul>
# 		</div>
# 	</div>
# 	<div class="lnb_right">
# 		<div class="lnb_extra">
#
#
# 			<div class="lnb_extra_menu">
# 				<ul class="lnb_extra_menu_list">
# 					<li class="lnb_extra_menu_item"><a href="https://news.naver.com/main/officeList.naver" class="lnb_extra_menu_link nclicks(nct.right3)" title="전체 언론사">전체 언론사</a></li>
# 					<li class="lnb_extra_menu_item"><a href="https://newsstand.naver.com/" class="lnb_extra_menu_link nclicks(STA.newsstand)" title="뉴스스탠드" target="_blank">뉴스스탠드</a></li>
# 					<li class="lnb_extra_menu_item"><a href="https://newslibrary.naver.com/search/searchByDate.nhn" class="lnb_extra_menu_link nclicks(nct.right4)" title="라이브러리" target="_blank">라이브러리</a></li>
# 				</ul>
# 			</div>
# 		</div>
# 	</div>
# </div>
#
# 		</div>
# 	</div>
#
#
#
#     <div class="lnb">
#
#
#
#
#         <span class="lnb_date"><strong>05</strong>.<strong>01</strong><span class="day">(월)</span></span>
#
#         <ul class="lnb_side" tabindex="0">
#             <li><a href="https://news.naver.com/main/officeList.naver" class="nclicks(slb.allmedia)" title="전체 언론사">전체 언론사</a></li>
#             <li><a href="https://newsstand.naver.com/" class="nclicks(slb.newsstand)" title="뉴스스탠드" target="_blank" >뉴스스탠드</a></li>
#             <li><a href="https://newslibrary.naver.com/search/searchByDate.nhn" class="nclicks(slb.library)" title="라이브러리" target="_blank">라이브러리</a></li>
#         </ul>
#     </div>
#
# </div>
# 		<hr>
#
# 		<table cellpadding="0" cellspacing="0" class="container">
# 			<caption class="blind">기사목록</caption>
# 			<colgroup>
# 				<col class="col_snb">
# 				<col class="col_content">
# 				<col class="col_aside">
# 			</colgroup>
# 			<tr>
# 				<td class="snb">
# 					<div id="snb" class="snb">
#
#
#
#
#
#
#
#
#
# <h2 class="h2"><a href="/main/main.naver?mode=LSD&mid=shm&sid1=100" class="nclicks(lmn_pol.home)">정치</a></h2>
# <ul class="nav">
#
#
# <li><a href="/main/list.naver?mode=LS2D&mid=shm&sid1=100&sid2=264" class="snb_s11 nclicks(lmn_pol.mnl,,1)">대통령실 </a></li>
# <li><a href="/main/list.naver?mode=LS2D&mid=shm&sid1=100&sid2=265" class="snb_s12 nclicks(lmn_pol.mnl,,2)">국회/정당 </a></li>
# <li><a href="/main/list.naver?mode=LS2D&mid=shm&sid1=100&sid2=268" class="snb_s13 nclicks(lmn_pol.mnl,,3)">북한 </a></li>
# <li><a href="/main/list.naver?mode=LS2D&mid=shm&sid1=100&sid2=266" class="snb_s14 nclicks(lmn_pol.mnl,,4)">행정 </a></li>
# <li><a href="/main/list.naver?mode=LS2D&mid=shm&sid1=100&sid2=267" class="snb_s15 nclicks(lmn_pol.mnl,,5)">국방/외교 </a></li>
# <li><a href="/main/list.naver?mode=LS2D&mid=shm&sid1=100&sid2=269" class="snb_s16 nclicks(lmn_pol.mnl,,6)">정치일반 </a></li>
# </ul>
#
#
#
# <div class="snb_banner">
#  <a href="https://media.naver.com/channel/setting?back=main" class="nclicks(lmn_pol.pmb,,1)"><img src="https://imgnews.pstatic.net/image/upload/item/2021/01/14/142956425_144518244_%2525B8%2525F0%2525B9%2525D9%2525C0%2525CF%2525B8%2525DE%2525C0%2525CE.png" width="71" height="74" alt="언론사 구독하기" /></a>
# </div>
# <div class="snb_banner">
#  <a href="https://contents.premium.naver.com/" class="nclicks(lmn_pol.pmb,,1)"><img src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71" height="74" alt="네이버 프리미엄콘텐츠" /></a>
# </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 					</div>
# 				</td>
# 				<td class="content">
# 					<div id="main_content" class="content">
# 						<div class="list_body section_index">
#
#         <div class="cluster">
#                 <div class="cluster_title">
#                     <span class="cluster_title_inner"><a href="#biF7L" class="cluster_title_icon_link _news_cluster_layer_btn "><i class="cluster_title_icon">안내</i>헤드라인 뉴스</a></span>
#
#                     <div class="cluster_title_layer _news_cluster_layer is_hidden">
#                         <div class="cluster_title_layer_text">
#                             헤드라인 뉴스와 각 기사묶음 타이틀은 <br> 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.
#                         </div>
#                         <div class="cluster_title_layer_image"></div>
#                         <button type="button" class="cluster_title_layer_close _news_cluster_layer_close_btn">닫기</button>
#                     </div>
#                 </div>
#         </div>
#
#
#             <div class="_persist">
#                 <div class="cluster">
#
#
#
#
#
#
#
#
#
#
#                                 <div class="cluster_group _cluster_content" >
#
#                                     <div class="cluster_body">
#                                         <ul class="cluster_list">
#
#
#
#
#                                                         <li class="cluster_item">
#
#
#
#                                                                 <div class="cluster_thumb">
#                                                                     <div class="cluster_thumb_inner">
#                                                                         <a href="https://n.news.naver.com/mnews/article/421/0006778647?sid=100" class="cluster_thumb_link nclicks(cls_pol.clsart)">
#
#                                                                             <img src="https://imgnews.pstatic.net/image/origin/421/2023/04/30/6778647.jpg?type=ofullfill132_90" width="132" height="90" alt="" onError="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;">
#
#                                                                         </a>
#                                                                     </div>
#                                                                 </div>
#
#                                                             <div class="cluster_text">
#                                                                 <a href="https://n.news.naver.com/mnews/article/421/0006778647?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">일본인 가네코·다쓰지 '5월 독립운동가'…대한민국 독립 헌신</a>
#                                                                 <div class="cluster_text_lede">국가보훈처가 일본인으로서 대한민국 독립에 헌신한 독립유공자 가네코 후미코 선생과 후세 다쓰지 선생을 각각 &#039;2023년 5월의 독립운동가&#039;로 선정했다고 3 …</div>
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006778647',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">뉴스1</div>
#                                                                 </div>
#                                                             </div>
#                                                         </li>
#
#
#
#
#
#
#
#
#                                                         <li class="cluster_item as_line">
#                                                             <div class="cluster_text">
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news028,0002637952',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">한겨레</div>
#                                                                 </div>
#                                                                 <a href="https://n.news.naver.com/mnews/article/028/0002637952?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">일본인 가네코 후미코·후세 다쓰지 ‘5월 독립운동가’</a>
#                                                             </div>
#                                                         </li>
#
#
#
#
#
#
#
#                                                         <li class="cluster_item as_line">
#                                                             <div class="cluster_text">
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011833590',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">뉴시스</div>
#                                                                 </div>
#                                                                 <a href="https://n.news.naver.com/mnews/article/003/0011833590?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">'박열의 그녀' 독립기념관 5월의 독립운동가 됐다</a>
#                                                             </div>
#                                                         </li>
#
#
#
#
#
#
#
#                                                         <li class="cluster_item as_line">
#                                                             <div class="cluster_text">
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004185042',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">서울경제</div>
#                                                                 </div>
#                                                                 <a href="https://n.news.naver.com/mnews/article/011/0004185042?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">'5월의 독립운동가'에 日가네코 후미코·후세 다쓰지 선정</a>
#                                                             </div>
#                                                         </li>
#
#
#
#                                         </ul>
#                                     </div>
#
#                                         <div class="cluster_foot">
#                                             <div class="cluster_foot_inner">
#                                                 <a href="/main/clusterArticles.naver?id=c_202304301020_00000001&mode=LSD&mid=shm&sid1=100&oid=421&aid=0006778647" class="cluster_foot_more nclicks(cls_pol.clstitle)"><span class="cluster_foot_more_icon_num">13</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
#                                             </div>
#                                         </div>
#
#                                 </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                 <div class="cluster_group _cluster_content" >
#
#                                     <div class="cluster_body">
#                                         <ul class="cluster_list">
#
#
#
#
#                                                         <li class="cluster_item">
#
#
#                                                             <div class="cluster_text">
#                                                                 <a href="https://n.news.naver.com/mnews/article/052/0001879481?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)"> 민형배 "당내 비판? 늘 그래왔던 분들...자기 참모에 수류탄 터뜨리는 행위"[뉴스킹]</a>
#                                                                 <div class="cluster_text_lede">YTN라디오(FM 94.5) [뉴스킹 박지훈입니다] □ 방송일시 : 2023년 5월 1일 (월) □ 진행 : 박지훈 변호사 □ 출연자 : 민형배 더불어민주당 의원 * 아래 텍스트는 실제 방송 내용과 차이가  …</div>
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879481',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">YTN</div>
#                                                                 </div>
#                                                             </div>
#                                                         </li>
#
#
#
#
#
#
#
#
#                                                         <li class="cluster_item as_line">
#                                                             <div class="cluster_text">
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news056,0011475966',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">KBS</div>
#                                                                 </div>
#                                                                 <a href="https://n.news.naver.com/mnews/article/056/0011475966?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)"> 김민석 “송영길 발언이 공천에 직결? 황당한 상상력”[최강시사]</a>
#                                                             </div>
#                                                         </li>
#
#
#
#
#
#
#
#                                                         <li class="cluster_item as_line">
#                                                             <div class="cluster_text">
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879526',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">YTN</div>
#                                                                 </div>
#                                                                 <a href="https://n.news.naver.com/mnews/article/052/0001879526?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)"> 방미 성과 엇갈리는 평가..여 "역사적 전환점" vs 야 "사기 외교"[뉴스라이브]</a>
#                                                             </div>
#                                                         </li>
#
#
#
#
#
#
#
#                                                         <li class="cluster_item as_line">
#                                                             <div class="cluster_text">
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879527',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">YTN</div>
#                                                                 </div>
#                                                                 <a href="https://n.news.naver.com/mnews/article/052/0001879527?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)"> 검찰, 캠프 관계자 등 추가 압수수색..송영길 "물극필반"[뉴스라이브]</a>
#                                                             </div>
#                                                         </li>
#
#
#
#                                         </ul>
#                                     </div>
#
#                                         <div class="cluster_foot">
#                                             <div class="cluster_foot_inner">
#                                                 <a href="/main/clusterArticles.naver?id=c_202305010930_00000089&mode=LSD&mid=shm&sid1=100&oid=052&aid=0001879481" class="cluster_foot_more nclicks(cls_pol.clstitle)"><span class="cluster_foot_more_icon_num">4</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
#                                             </div>
#                                         </div>
#
#                                 </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                 <div class="cluster_group _cluster_content" >
#
#                                     <div class="cluster_body">
#                                         <ul class="cluster_list">
#
#
#
#
#                                                         <li class="cluster_item">
#
#
#
#                                                                 <div class="cluster_thumb">
#                                                                     <div class="cluster_thumb_inner">
#                                                                         <a href="https://n.news.naver.com/mnews/article/023/0003760988?sid=100" class="cluster_thumb_link nclicks(cls_pol.clsart)">
#
#                                                                             <img src="https://imgnews.pstatic.net/image/origin/023/2023/05/01/3760988.jpg?type=ofullfill132_90" width="132" height="90" alt="" onError="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;">
#
#                                                                         </a>
#                                                                     </div>
#                                                                 </div>
#
#                                                             <div class="cluster_text">
#                                                                 <a href="https://n.news.naver.com/mnews/article/023/0003760988?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">“한미동맹은 미래 세대 위한 유산”</a>
#                                                                 <div class="cluster_text_lede">尹대통령, 귀국후 트위터에 올려 하버드대에선 “워싱턴 선언은 업그레이드된 제2의 방위조약” 윤석열 대통령이 5박 7일 미국 국빈 방문을 마치고 30일 서 …</div>
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news023,0003760988',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">조선일보</div>
#                                                                 </div>
#                                                             </div>
#                                                         </li>
#
#
#
#
#
#
#
#
#                                                         <li class="cluster_item as_line">
#                                                             <div class="cluster_text">
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news055,0001054275',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">SBS</div>
#                                                                 </div>
#                                                                 <a href="https://n.news.naver.com/mnews/article/055/0001054275?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">"워싱턴 선언, 핵 포함 상호방위 업그레이드"</a>
#                                                             </div>
#                                                         </li>
#
#
#
#
#
#
#
#                                                         <li class="cluster_item as_line">
#                                                             <div class="cluster_text">
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879480',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">YTN</div>
#                                                                 </div>
#                                                                 <a href="https://n.news.naver.com/mnews/article/052/0001879480?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">이종섭 국방장관 "워싱턴 선언, 제2한미상호방위조약"</a>
#                                                             </div>
#                                                         </li>
#
#
#
#
#
#
#
#                                                         <li class="cluster_item as_line">
#                                                             <div class="cluster_text">
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news088,0000811742',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">매일신문</div>
#                                                                 </div>
#                                                                 <a href="https://n.news.naver.com/mnews/article/088/0000811742?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">이종섭 국방장관 "워싱턴선언, 美확장억제 이행 강력한 의지 보여줘"</a>
#                                                             </div>
#                                                         </li>
#
#
#
#                                         </ul>
#                                     </div>
#
#                                         <div class="cluster_foot">
#                                             <div class="cluster_foot_inner">
#                                                 <a href="/main/clusterArticles.naver?id=c_202304290630_00000003&mode=LSD&mid=shm&sid1=100&oid=023&aid=0003760988" class="cluster_foot_more nclicks(cls_pol.clstitle)"><span class="cluster_foot_more_icon_num">9</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
#                                             </div>
#                                         </div>
#
#                                 </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                 <div class="cluster_group _cluster_content" >
#
#                                     <div class="cluster_body">
#                                         <ul class="cluster_list">
#
#
#
#
#                                                         <li class="cluster_item">
#
#
#                                                             <div class="cluster_text">
#                                                                 <a href="https://n.news.naver.com/mnews/article/052/0001879557?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">[속보] 與 윤리위, 김재원·태영호 징계 절차 개시 결정</a>
#                                                                 <div class="cluster_text_lede">與 윤리위, 김재원·태영호 최고위원 징계 절차 개시 향후 사실 확인·당사자 소명 등 거쳐 징계 수위 결정 당원권 정지 이상 중징계 경우 내년 총선 공천 영향 가능성 김재원·태영호, 잇단 설화로 당 안팎 징계 …</div>
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879557',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">YTN</div>
#                                                                 </div>
#                                                             </div>
#                                                         </li>
#
#
#
#
#
#
#
#
#                                                         <li class="cluster_item as_line">
#                                                             <div class="cluster_text">
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011833124',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">뉴시스</div>
#                                                                 </div>
#                                                                 <a href="https://n.news.naver.com/mnews/article/003/0011833124?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">여당 윤리위 공식 출범…김재원·태영호 징계 착수 전망</a>
#                                                             </div>
#                                                         </li>
#
#
#
#
#
#
#
#                                                         <li class="cluster_item as_line">
#                                                             <div class="cluster_text">
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news079,0003765077',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">노컷뉴스</div>
#                                                                 </div>
#                                                                 <a href="https://n.news.naver.com/mnews/article/079/0003765077?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">野 돈봉투 의혹에 차별화 나선 與, 오늘 첫 윤리위가 시험대</a>
#                                                             </div>
#                                                         </li>
#
#
#
#
#
#
#
#                                                         <li class="cluster_item as_line">
#                                                             <div class="cluster_text">
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news056,0011475807',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">KBS</div>
#                                                                 </div>
#                                                                 <a href="https://n.news.naver.com/mnews/article/056/0011475807?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">국민의힘 윤리위 첫 회의…‘5.18 발언 물의’ 김재원 징계하나</a>
#                                                             </div>
#                                                         </li>
#
#
#
#                                         </ul>
#                                     </div>
#
#                                         <div class="cluster_foot">
#                                             <div class="cluster_foot_inner">
#                                                 <a href="/main/clusterArticles.naver?id=c_202304281030_00001855&mode=LSD&mid=shm&sid1=100&oid=052&aid=0001879557" class="cluster_foot_more nclicks(cls_pol.clstitle)"><span class="cluster_foot_more_icon_num">50</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
#                                             </div>
#                                         </div>
#
#                                 </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                             <div class="cluster_group _cluster_content" >
#
#                                 <div class="cluster_body">
#                                     <ul class="cluster_list">
#
#
#                                         <li class="cluster_item">
#
#
#
#                                                 <div class="cluster_thumb">
#                                                     <div class="cluster_thumb_inner">
#                                                         <a href="https://n.news.naver.com/mnews/article/008/0004881806?sid=100" class="cluster_thumb_link nclicks(cls_pol.clsart)">
#
#                                                             <img src="https://imgnews.pstatic.net/image/origin/008/2023/05/01/4881806.jpg?type=ofullfill132_90" width="132" height="90" alt="" onError="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;">
#
#                                                         </a>
#                                                     </div>
#                                                 </div>
#
#                                             <div class="cluster_text">
#                                                 <a href="https://n.news.naver.com/mnews/article/008/0004881806?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">尹대통령 "업그레이드된 한미동맹, 청년세대 기회의 플랫폼 돼야"</a>
#                                                 <div class="cluster_text_lede">수석비서관회의 주재하고 &#034;동맹, 안보·산업·과학기술 등에서 확장…후속조치 구체화해 달라&#034; 윤석열 대통령이 1일 조 바이든 대통령과의 한미정상회담으로 한미 …</div>
#                     <div class="cluster_text_info _rcount"    data-comment="{gno:'news008,0004881806',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                     <div class="cluster_text_press">머니투데이</div>
#                                                 </div>
#                                             </div>
#                                         </li>
#
#
#                                         <li class="cluster_item">
#
#
#
#                                                 <div class="cluster_thumb">
#                                                     <div class="cluster_thumb_inner">
#                                                         <a href="https://n.news.naver.com/mnews/article/277/0005253026?sid=100" class="cluster_thumb_link nclicks(cls_pol.clsart)">
#
#                                                             <img src="https://imgnews.pstatic.net/image/origin/277/2023/05/01/5253026.jpg?type=ofullfill132_90" width="132" height="90" alt="" onError="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;">
#
#                                                         </a>
#                                                     </div>
#                                                 </div>
#
#                                             <div class="cluster_text">
#                                                 <a href="https://n.news.naver.com/mnews/article/277/0005253026?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">尹 "확장된 한미동맹, 미래세대 기회 플랫폼 돼야"</a>
#                                                 <div class="cluster_text_lede">윤석열 대통령은 1일 확장억제 강화·각 분야 협력 확대 등이 합의한 한미정상회담 결과와 관련해 &#034;청년 미래 세대에게 기회의 플랫폼이 되도록 후속 조치를  …</div>
#                     <div class="cluster_text_info _rcount"    data-comment="{gno:'news277,0005253026',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                     <div class="cluster_text_press">아시아경제</div>
#                                                 </div>
#                                             </div>
#                                         </li>
#
#                                     </ul>
#                                 </div>
#
#                                     <div class="cluster_foot">
#                                         <div class="cluster_foot_inner">
#                                             <a href="/main/clusterArticles.naver?id=c_202305011110_00000003&mode=LSD&mid=shm&sid1=100&oid=008&aid=0004881806" class="cluster_foot_more nclicks(cls_pol.clstitle)"><span class="cluster_foot_more_icon_num">15</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
#                                         </div>
#                                     </div>
#
#                             </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                             <div class="cluster_group _cluster_content" >
#
#                                 <div class="cluster_body">
#                                     <ul class="cluster_list">
#
#
#                                         <li class="cluster_item">
#
#
#
#                                                 <div class="cluster_thumb">
# ...
#
#                         </div>
#                     </div>
#                 </div>
#             </li>
#
#
#
#
#             <li>
#
#
#
#                         <a href="https://n.news.naver.com/mnews/ranking/article/661/0000024311?ntype=RANKING&sid=001" class="ranking_thumb nclicks('rig.renws2')">
#                             <img src="https://mimgnews.pstatic.net/image/origin/661/2023/05/01/24311.jpg?type=nf88_60" width="88" height="60" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';">
#
#                         </a>
#
#
#
#                 <div class="list_text_wrap">
#                     <div class="list_text">
#                         <div class="list_text_inner">
#                             <a href="https://n.news.naver.com/mnews/ranking/article/661/0000024311?ntype=RANKING&sid=001" class="list_tit nclicks('rig.renws2')">유급휴일 &#039;근로자의 날&#039;..&#034;직장인 10명 중 3명  출근 …</a>
#
#                                 <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=661"><span class="list_press_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/661/2022/01/19/logo_661_56_20220119142145.png" width="16" height="16" alt=""></span>JIBS</a>
#
#                         </div>
#                     </div>
#                 </div>
#             </li>
#
#
#
#
#             <li>
#
#
#
#                         <a href="https://n.news.naver.com/mnews/ranking/article/145/0000018624?ntype=RANKING&sid=001" class="ranking_thumb nclicks('rig.renws2')">
#                             <img src="https://mimgnews.pstatic.net/image/origin/145/2023/05/01/18624.jpg?type=nf88_60" width="88" height="60" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';">
#
#                         </a>
#
#
#
#                 <div class="list_text_wrap">
#                     <div class="list_text">
#                         <div class="list_text_inner">
#                             <a href="https://n.news.naver.com/mnews/ranking/article/145/0000018624?ntype=RANKING&sid=001" class="list_tit nclicks('rig.renws2')">적금 탔더니 그 돈으로 병원을 가네···5월 별자리 운세</a>
#
#                                 <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=145"><span class="list_press_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/145/2020/12/09/logo_145_56_20201209180915.png" width="16" height="16" alt=""></span>레이디경향</a>
#
#                         </div>
#                     </div>
#                 </div>
#             </li>
#
#     </ul>
#
#
#
#
#
#
#     <button type="button" class="refresh_button nclicks('rig.renws2new') _refreshButton">더보기</button>
#
# </div>
# <script type="text/javascript">
#     var OfficeTopRankingManager = jindo.$Class({
#         $static: {
#             RANKING_INFO_BUTTON_SELECTOR: '._rankingInfoButton',
#             RANKING_INFO_LAYER_SELECTOR : '._rankingInfoLayer',
#             RANKING_INFO_BUTTON_CLOSE_SELECTOR : '._rankingInfoCloseButton',
#             REFRESH_BUTTON_SELECTOR : '._refreshButton',
#             RANKING_LIST_SELECTOR : '._rankingList'
#         },
#
#         $init: function(base) {
#             this._welBase = jindo.$Element(base);
#             this._rankingInfoLayer = jindo.$Element(this._welBase.query(this.constructor.RANKING_INFO_LAYER_SELECTOR));
#             this._rankingListArray = jindo.$ElementList(this._welBase.queryAll(this.constructor.RANKING_LIST_SELECTOR));
#
#             this._initEvent();
#         },
#
#         _initEvent: function() {
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_SELECTOR, jindo.$Fn(this._showRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_CLOSE_SELECTOR, jindo.$Fn(this._closeRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.REFRESH_BUTTON_SELECTOR, jindo.$Fn(this._refreshRankingList, this).bind());
#         },
#
#         _showRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.toggle();
#         },
#
#         _closeRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.hide();
#         },
#
#         _refreshRankingList: function(event) {
#             event.stopDefault();
#
#             for (var i=0 ; i<this._rankingListArray.length() ; i++) {
#                 var rankingList = this._rankingListArray.get(i);
#
#                 if (rankingList.visible() === true) {
#                     var nextIndex = i + 1;
#
#                     if (nextIndex === this._rankingListArray.length()) {
#                         nextIndex = 0;
#                     }
#
#                     var nextRankingList = this._rankingListArray.get(nextIndex);
#
#                     rankingList.hide();
#                     nextRankingList.show();
#
#                     break;
#                 }
#             }
#         }
#     });
#
#     window.addEventListener("load", function() {
#         var officeTopRanking = jindo.$$.getSingle("._officeTopRanking1087473");
#         if (officeTopRanking) {
#             new OfficeTopRankingManager(officeTopRanking);
#         }
#     });
# </script>
#
#
#
#                     <div class="side_ad" id="glad_ad_sidebox"></div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 <div class="section" style="margin-bottom:20px; white-space:nowrap;" id="right_dailyList">
#  <h4>분야별 주요뉴스</h4>
#  <div class="classfy sd" style="display:block">
#   <ul class="list_txt">
#    <li> <a href="https://n.news.naver.com/mnews/article/001/0013913824?sid=100" class="nclicks(rig.secteco)" title="'설화' 김재원 최고위 복귀…'자진사퇴'엔 &quot;아직 생각 안해봐&quot;(종합)">'설화' 김재원 최고위 복귀…'자진사퇴'엔 &quot;아직 생각 안해봐&quot;(종합)</a> </li>
#    <li> <a href="https://n.news.naver.com/mnews/article/421/0006780024?sid=100" class="nclicks(rig.secteco)" title="[여론풍향계] '널뛰는' 尹&middot;정당지지율…&quot;장기 지지율 추세 파악해야&quot;">[여론풍향계] '널뛰는' 尹&middot;정당지지율…&quot;장기 지지율 추세 파악해야&quot;</a> </li>
#    <li> <a href="https://n.news.naver.com/mnews/article/022/0003808119?sid=100" class="nclicks(rig.secteco)" title="野 박광온 “주 4.5일제 향해 담대하게 나아갈 것”">野 박광온 “주 4.5일제 향해 담대하게 나아갈 것”</a> </li>
#    <li> <a href="https://n.news.naver.com/mnews/article/022/0003808132?sid=104" class="nclicks(rig.secteco)" title="대만 “유일한 남미 친구 지켰다”…파라과이 대선 결과에 ‘일단’ 안도">대만 “유일한 남미 친구 지켰다”…파라과이 대선 결과에 ‘일단’ 안도</a> </li>
#    <li> <a href="https://n.news.naver.com/mnews/article/079/0003765162?sid=104" class="nclicks(rig.secteco)" title="&quot;한국, 양육비 가장 비싼 나라&quot;…1인당 GDP의 7.7배">&quot;한국, 양육비 가장 비싼 나라&quot;…1인당 GDP의 7.7배</a> </li>
#   </ul>
#   <ul class="list_txt">
#    <ul class="list_txt">
#     <li> <a href="https://n.news.naver.com/mnews/article/001/0013914034?sid=101" class="nclicks(rig.secteco)" title="'41% 급감' 반도체에 수출 7개월째 감소…무역적자 14개월 연속(종합2보)">'41% 급감' 반도체에 수출 7개월째 감소…무역적자 14개월 연속(종합2보)</a> </li>
#     <li> <a href="https://n.news.naver.com/mnews/article/011/0004185317?sid=101" class="nclicks(rig.secteco)" title="금감원 “악의적 무차입 공매도 첫 포착…과징금 42건 부과할 것”">금감원 “악의적 무차입 공매도 첫 포착…과징금 42건 부과할 것”</a> </li>
#     <li> <a href="https://n.news.naver.com/mnews/article/092/0002290751?sid=101" class="nclicks(rig.secteco)" title="삼성전자, 5월 가정의 달 맞아 '2023형 TV 슈퍼빅세일' 진행">삼성전자, 5월 가정의 달 맞아 '2023형 TV 슈퍼빅세일' 진행</a> </li>
#     <li> <a href="https://n.news.naver.com/mnews/article/138/0002147587?sid=105" class="nclicks(rig.secteco)" title="‘중간요금제’ 속속 출격…LTE→5G 전환 이끌어낼까">‘중간요금제’ 속속 출격…LTE→5G 전환 이끌어낼까</a> </li>
#     <li> <a href="https://n.news.naver.com/mnews/article/011/0004185262?sid=105" class="nclicks(rig.secteco)" title="'노태북 열풍 이어갈까'…삼성, 인텔 13세대 기반 PC 3종 출시">'노태북 열풍 이어갈까'…삼성, 인텔 13세대 기반 PC 3종 출시</a> </li>
#    </ul>
#    <ul class="list_txt">
#     <ul class="list_txt">
#      <li> <a href="https://n.news.naver.com/mnews/article/001/0013914027?sid=102" class="nclicks(rig.secteco)" title="송영길측 &quot;宋, 내일 오전 10시 서울중앙지검 자진 출두&quot;">송영길측 &quot;宋, 내일 오전 10시 서울중앙지검 자진 출두&quot;</a> </li>
#      <li> <a href="https://n.news.naver.com/mnews/article/079/0003765120?sid=102" class="nclicks(rig.secteco)" title="'강남 투신' 10대 만났던 20대 남성 입건…자살방조죄 적용">'강남 투신' 10대 만났던 20대 남성 입건…자살방조죄 적용</a> </li>
#      <li> <a href="https://n.news.naver.com/mnews/article/469/0000737001?sid=102" class="nclicks(rig.secteco)" title="학교 급식 반찬에 개구리 사체... 법원 &quot;위탁업체 5일?영업정지 정당&quot;">학교 급식 반찬에 개구리 사체... 법원 &quot;위탁업체 5일?영업정지 정당&quot;</a> </li>
#      <li> <a href="https://n.news.naver.com/mnews/article/003/0011833398?sid=103" class="nclicks(rig.secteco)" title="조계종, 전국 65개 사찰 관람료 4일부터 면제">조계종, 전국 65개 사찰 관람료 4일부터 면제</a> </li>
#      <li> <a href="https://n.news.naver.com/mnews/article/079/0003765171?sid=103" class="nclicks(rig.secteco)" title="현대차, '대한민국 동행축제' 연계 최대 5% 할인 프로모션">현대차, '대한민국 동행축제' 연계 최대 5% 할인 프로모션</a> </li>
#     </ul>
#    </ul>
#   </ul>
#  </div>
# </div>
#
#
#
#
#
#
#
#
#
#                 <div class="section">
#  <div class="banner">
#   <a href="https://media.naver.com/channel/settings" class="nclicks(rig.banner)"> <img src="https://imgnews.pstatic.net/image/upload/item/2018/11/27/174854048_PC_%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA_%25B1%25B8%25B5%25B6%25C8%25B0%25BC%25BA%25C8%25AD.png" width="300" alt="네이버 메인에서 바로 보는 언론사 편집뉴스 지금 바로 구독해보세요!" /> </a>
#  </div>
# </div>
#
#
#
#
#
#
#
#
#
#                 <div class="section">
#  <a href="https://news.naver.com/main/assembly/index.naver" class="nclicks(rig.banner)" target="_blank"> <img src="https://imgnews.pstatic.net/image/upload/item/2021/01/08/173235779_%25B1%25B9%25C8%25B8%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA.png" width="300" height="60" border="0" alt="내일을 여는 국민의 국회" class="banner" /> </a>
# </div>
#
#
#
#
#
#
#
#
#
#                 <div class="section">
#  <div class="banner">
#   <a href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" class="nclicks(rig.banner)" target="_blank"> <img src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/183951086_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300" alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" /> </a>
#  </div>
# </div>
#
#
#
#
#
#
#
#
#
#                 <div class="section">
#  <h4> <a href="https://news.naver.com/main/ombudsman/index.naver" class="nclicks(rig.text)"> 서비스 안내 </a> </h4>
#  <ul class="list_txt">
#   <li> <a href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb" class="nclicks(rig.text)"> 고침 기사 모음 </a> </li>
#   <li> <a href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb" class="nclicks(rig.text)"> 정정&middot;반론&middot;추후 보도 기사 모음 </a> </li>
#   <li> <a href="https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb" class="nclicks(rig.text)"> 불공정 선거 보도 기사 모음 </a> </li>
#  </ul>
#  <a href="https://news.naver.com/main/ombudsman/index.naver" class="more_link nclicks(rig.text)"><span class="blind">서비스 안내</span>더보기</a>
# </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script>
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#
#         adSlot.setCustomParam("calp", 'shome');
#         window.gladsdk.displayAd(adSlot);
#     });
# </script>
#
# 					</div>
# 				</td>
# 			</tr>
# 		</table>
# 	</div>
#
# 	<hr>
# <div class="index">
#
#
#
# <div class="index_inner">
#
# 	<div class="floating_btn" >
# 		<div class="floating_inner">
# 			<a href="javascript:history.back();" class="floating_btn_back"><span class="blind">이젠 페이지</span></a>
# 			<a href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;" class="floating_btn_top"><span class="blind">맨위로</span></a>
# 		</div>
# 	</div>
# 	<div id="index.press_category" class="index_tab">
# 		<a id="index.press.btn" href="#" class="spr stit nclicks(fot.press)">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# 		<div id="index.press.area" class="index_content is_hidden"></div>
# 		<a id="index.category.btn" href="#" class="spr stit2 nclicks(fot.section)">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# 		<div id="index.category.area" class="index_content02 is_hidden"></div>
# 	</div>
# </div>
#
#
# </div>
# <hr>
# <div id="footer">
#
# <ul>
# <li class="first"><a href="http://www.naver.com/rules/service.html" class="nclicks(fot.agreement)">이용약관</a></li>
# <li><a href="/main/ombudsman/index.naver" class="nclicks(fot.guide)">서비스 안내</a></li>
# <li><a href="/main/ombudsman/edit.naver?mid=omb" class="nclicks(fot.editor)">기사배열 원칙 책임자 : 유봉석</a></li>
# <li>청소년 보호 책임자 : 이희만</li>
# <li><strong><a href="http://www.naver.com/rules/privacy.html" class="nclicks(fot.privacy)">개인정보처리방침</a></strong></li>
# <li><a href="http://www.naver.com/rules/disclaimer.html" class="nclicks(fot.disclaimer)">책임의 한계와 법적고지</a></li>
# <li><a href="#" title="새창" onclick="news.external.OPS.helpNews(); return false;" class="nclicks(fot.help)">뉴스 고객센터</a></li>
# </ul>
# 	<p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
#
#
# 	<address class="address_nhn">
# 	<a href="https://www.navercorp.com/" target="_blank" class="logo nclicks(fot.naver)"><span class="blind">NAVER</span></a>
# 	<em>Copyright &copy;</em>
# 	<a href="https://www.navercorp.com/" target="_blank" class="nclicks(fot.navercorp)">NAVER Corp.</a>
# 	<span>All Rights Reserved.</span>
# </address>
# 	<!-- -->
#
#
# </div>
# <script type="text/javascript">
#
#
#
#
#
#
#
# var index_tab = new news.index.TabController('index.press_category');
# index_tab.add(new news.index.Tab('index.press.btn','stit','index.press.area','/main/ajax/bottomIndex/press.naver'));
# index_tab.add(new news.index.Tab('index.category.btn','stit2','index.category.area','/main/ajax/bottomIndex/category.naver'));
# jindo.$Fn(index_tab.toggle, index_tab).attach(index_tab.tabs.keys(), 'click');
#
#
# (function() {
# 	news.right.RightSideFloatingManager.init();
# })();
#
#
#
#     (function() {
#         news.right.TopDownFloatingManager.init();
#     })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ;(function(){
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jindo.$Fn(function(){
#
#
# 	lcs_do();
#
#     }).attach(window, eventType);
# })();
#
#
#
#
#
#
#
#
# news.startup();
#
#
# jindo.$Fn(function(){
#     var welSkip = jindo.$Element("u_skip");
#     if (welSkip === null) {
#         return;
#     }
#     welSkip.delegate("click", "a", function(weEvent){
#         weEvent.stopDefault();
#         var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#         oWebAccessibilityUtil.moveFocus(elTarget);
#     });
# }).attach(window, "load");
#
#
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
# </body>
# </html>

# %%
# Q. response값에서 한글만 출력하세요.

# %%
# 한글만 출력
import re
texts = response.text
result = re.findall('[가-힣]+',texts)
# print(result)
' '.join(result)
# Out:
# '정치 네이버 뉴스 국회 행정 국방 외교 등 정치 분야 뉴스 제공 네이버 정치 네이버 뉴스 네이버 뉴스 네이버 뉴스 국회 행정 국방 외교 등 정치 분야 뉴스 제공 정치 홈 네이버 뉴스 광고적용 태그 추가 메인 메뉴로 바로가기 본문으로 바로가기 검색 뉴스 연예 스포츠 날씨 프리미엄 언론사별 정치 선택됨 경제 사회 생활 문화 과학 세계 랭킹 신문보기 오피니언 팩트체크 전체 언론사 전체 언론사 뉴스스탠드 뉴스스탠드 라이브러리 라이브러리 월 전체 언론사 전체 언론사 뉴스스탠드 뉴스스탠드 라이브러리 라이브러리 기사목록 정치 대통령실 국회 정당 북한 행정 국방 외교 정치일반 언론사 구독하기 네이버 프리미엄콘텐츠 안내 헤드라인 뉴스 헤드라인 뉴스와 각 기사묶음 타이틀은 기사 내용을 기반으로 자동 추출 됩니다 닫기 일본인 가네코 다쓰지 월 독립운동가 대한민국 독립 헌신 국가보훈처가 일본인으로서 대한민국 독립에 헌신한 독립유공자 가네코 후미코 선생과 후세 다쓰지 선생을 각각 년 월의 독립운동가 로 선정했다고 뉴스 한겨레 일본인 가네코 후미코 후세 다쓰지 월 독립운동가 뉴시스 박열의 그녀 독립기념관 월의 독립운동가 됐다 서울경제 월의 독립운동가 에 가네코 후미코 후세 다쓰지 선정 개의 관련뉴스 더보기 민형배 당내 비판 늘 그래왔던 분들 자기 참모에 수류탄 터뜨리는 행위 뉴스킹 라디오 뉴스킹 박지훈입니다 방송일시 년 월 일 월 진행 박지훈 변호사 출연자 민형배 더불어민주당 의원 아래 텍스트는 실제 방송 내용과 차이가 김민석 송영길 발언이 공천에 직결 황당한 상상력 최강시사 방미 성과 엇갈리는 평가 여 역사적 전환점 야 사기 외교 뉴스라이브 검찰 캠프 관계자 등 추가 압수수색 송영길 물극필반 뉴스라이브 개의 관련뉴스 더보기 한미동맹은 미래 세대 위한 유산 대통령 귀국후 트위터에 올려 하버드대에선 워싱턴 선언은 업그레이드된 제 의 방위조약 윤석열 대통령이 박 일 미국 국빈 방문을 마치고 일 서 조선일보 워싱턴 선언 핵 포함 상호방위 업그레이드 이종섭 국방장관 워싱턴 선언 제 한미상호방위조약 매일신문 이종섭 국방장관 워싱턴선언 확장억제 이행 강력한 의지 보여줘 개의 관련뉴스 더보기 속보 윤리위 김재원 태영호 징계 절차 개시 결정 윤리위 김재원 태영호 최고위원 징계 절차 개시 향후 사실 확인 당사자 소명 등 거쳐 징계 수위 결정 당원권 정지 이상 중징계 경우 내년 총선 공천 영향 가능성 김재원 태영호 잇단 설화로 당 안팎 징계 뉴시스 여당 윤리위 공식 출범 김재원 태영호 징계 착수 전망 노컷뉴스 돈봉투 의혹에 차별화 나선 오늘 첫 윤리위가 시험대 국민의힘 윤리위 첫 회의 발언 물의 김재원 징계하나 개의 관련뉴스 더보기 대통령 업그레이드된 한미동맹 청년세대 기회의 플랫폼 돼야 수석비서관회의 주재하고 동맹 안보 산업 과학기술 등에서 확장 후속조치 구체화해 달라 윤석열 대통령이 일 조 바이든 대통령과의 한미정상회담으로 한미 머니투데이 확장된 한미동맹 미래세대 기회 플랫폼 돼야 윤석열 대통령은 일 확장억제 강화 각 분야 협력 확대 등이 합의한 한미정상회담 결과와 관련해 청년 미래 세대에게 기회의 플랫폼이 되도록 후속 조치를 아시아경제 개의 관련뉴스 더보기 박대출 방송법 국회 통과하면 대통령이 거부권 행사해야 라디오 좌파매체에 점령당해 방송법 강행 공영방송 장악 꼼수 김기현 심각함이 도를 넘어도 한참 넘어 책임 있는 조치 뒤따라야 국민의힘 박대 연합뉴스 편향 패널 명 명 방미때 좌파적 의견만 윤석열 대통령의 국빈 방미 기간 라디오의 개 시사프로그램을 분석한 결과 민주당 혹은 좌파 성향을 가진 명의 출연자가 패널로 출연했지만 정 중앙일보 개의 관련뉴스 더보기 정국 뇌관 될 노란봉투법 방송법 월도 여야 쟁점 산적 월 임시국회가 일 본격적으로 시작되지만 노란 봉투 법 간호법 등 산적한 현안으로 인해 여야 간 갈등은 더욱 격화할 전망이다 일 국회에 따르면 지난 뉴스 정의 진보 노동절 맞아 노란봉투법 처리 촉구 직회부 예고도 진보 성향 정당들이 일 제 주년 노동절을 맞아 정부여당에 노란봉투법 처리를 촉구했다 정부여당이 처리에 협조하지 않을 경우 직회부 가능성도 언급했다 뉴시스 개의 관련뉴스 더보기 논란 김재원 자숙 마쳐 최고위 복귀 사퇴 없다 잇따른 말실수 로 한 달 동안 공개 활동을 중단했던 김재원 국민의힘 최고위원이 일 당 최고위원회에 복귀했다 김 최고위원은 이날 오전 국회에서 진행된 아시아경제 설화 김재원 최고위 복귀 자진사퇴 엔 아직 생각 안 해봐 연이은 설화 로 논란을 빚은 국민의힘 김재원 최고위원이 일 근신 기간을 마치고 한 달 만에 당 최고위원회의에 복귀했습니다 김 최고위원은 개의 관련뉴스 더보기 한국 올 핵잠 을 지도에서 지워버릴 위력 한국 항구에 기항 예고 의 전략 핵잠수함은 전략 핵잠수함 은 핵탄두 장착 잠수함 발사 탄도미사일 을 탑재한 핵추진 잠수함이다 타국 조선일보 히로시마 원폭 배 워싱턴선언에 등장한 핵보복 핵잠 위력 한국에 올 미 오하이오급 핵보복 전략잠수함 윤석열 대통령과 조 바이든 미국 대통령이 지난 일 현지시간 워싱턴 선언 에서 미 전략 핵잠수함 조선일보 개의 관련뉴스 더보기 워싱턴 선언 이끌어낸 지지율 주 만에 반등해 리얼미터 윤석열 대통령의 지지율이 주 만에 반등한 여론조사 결과가 일 나왔다 한미 정상회담에서 북핵에 맞서기 위한 워싱턴 선언 을 이끌어내는 등 방미 성과 조선일보 지지율 오른 대 이상 리얼미터 의회 연설 후 지지율 까지 올라와 윤석열 대통령이 지난 일 현지시간 백악관에서 열린 국빈만찬을 마친 세계일보 개의 관련뉴스 더보기 민주 노동 존중받는 나라 만들 것 주 일제로 가는 문 열겠다 더불어민주당은 일 노동절을 맞아 노동이 존중받는 대한민국을 만들겠다 고 밝혔다 권칠승 민주당 수석대변인은 이날 오전 서면브리핑에서 세계 최빈국의 뉴스 노동절 국힘 특권노조 횡포 민주 노동탄압에 맞설 것 노동절을 맞아 여야가 노동 가치를 강조했다 그러면서도 국민의힘은 노조의 특권 을 비판했다 더불어민주당은 윤석열 정부가 추진했던 주 시간 미디어오늘 개의 관련뉴스 더보기 이서진이 왜 거기서 나와 대통령 어떻게 오셨냐 미국을 국빈 방문한 윤석열 대통령이 세계적인 영상 콘텐츠 기업들을 한자리에서 만나 콘텐츠 수출 확대를 논의했다 이 자리에 배우 이서진이 등장해 눈길 한국경제 이서진이 왜 거기서 나와 어떻게 오셨냐 묻자 검찰 계실 때 미국을 국빈 방문한 윤석열 대통령이 참석한 행사에 배우 이서진이 모습을 나타냈다 윤 대통령은 지난 일 현지시간 워싱턴 미국영화협회 건 매일경제 개의 관련뉴스 더보기 대통령실 핵 포함 개념으로 한미상호방위조약 업그레이드 한국형 확장억제 구체화로 미 확장억제 실행력 질적 강화 가치동맹 역할 재확인 귀국 후 방미 성과 보도자료서 강조 대통령실은 일 윤석열 대 연합뉴스 한미정상회담 대북 확장억제 최대 성과 워싱턴 선언 방점 윤석열 대통령이 워싱턴과 보스턴에서의 박 일의 국빈 미국방문 일정을 마치고 일 현지시간 귀국길에 올랐다 년 만의 국빈 방미에 나선 윤 대통 강원도민일보 개의 관련뉴스 더보기 김민석 간호법 대통령 공약 거부권 행사하면 독특한 분 더불어민주당 김민석 정책위의장은 일 윤석열 대통령의 간호법 거부권 행사 가능성에 대해 거부권을 행사한다면 굉장히 독특한 분이라고 봐야 한다 고 주 조선 김민석 간호법 공약 거부권 행사하면 굉장히 독특한 분 윤석열 대통령이 지난달 일 야당이 국회 본회의에서 강행 처리한 간호법 제정안에 재의요구권 거부권 을 행사할 것이라는 전망이 나오는 것과 관련해 김민석 중앙일보 개의 관련뉴스 더보기 윤 대통령 트위터로 바이든 부부에 국빈만찬에 아내도 감사 미국 국빈 방문을 마치고 귀국한 윤석열 대통령이 조 바이든 미국 대통령 부부에게 감사의 뜻을 전했습니다 윤 대통령은 오늘 일 아침 시 분쯤 영 대통령 바이든 부부에 감사 글 아내가 감사 전하고 싶어 해 트위터 통해 밝혀 미국 국빈 방문을 마치고 귀국한 윤석열 대통령이 일 트위터를 통해 아내 김건희 여사 도 조 바이든 미국 대통령과 질 바이든 여사에게 머니투데이 개의 관련뉴스 더보기 김기현 한미 관계 새 이정표 수립 비난만 하는 민주당 한심 국민의힘 김기현 대표는 윤석열 대통령이 이번 국빈 방미를 통해 북핵 위협에 대한 대응 자유민주주의 가치 동맹 경제 ...

# %%
import requests as rq
from bs4 import BeautifulSoup
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100'
r = rq.get(url,headers=headers)
# print(r)
html = r.text
bs = BeautifulSoup(html, 'lxml')
print(bs.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE HTML>
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh"/>
# <meta content="width=1106" name="viewport"/>
# <meta content="정치 : 네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image"/>
# <meta content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="정치 : 네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
# <meta content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공" name="twitter:description"/>
# <title>정치 홈 : 네이버 뉴스	</title>
# <link href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/news.css" rel="stylesheet" type="text/css"/>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jindo.js" type="text/javascript"></script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jquery.js" type="text/javascript"></script>
# <script type="text/javascript">
# var _MAIN_NEWS_MENU_ID='shm';
# var _MAIN_NEWS_SECTION_ID='103';
# var ccsrv='cc.naver.com';
# var g_ssc='news.sec';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness = 3;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
#
# var gnb_timestamp = "Mon May 01 12:27:05 KST 2023";
# </script>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.service.js" type="text/javascript"></script>
# <script>
#
#     var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#     if (!isUnderIE10) {
#         var gladSDK = document.createElement("script");
#         gladSDK.async = true;
#         gladSDK.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#         document.head.appendChild(gladSDK);
#     }
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#
#     window.gladsdk.cmd.push(function () {
#         window.gladsdk.setGlobalConfig({enablePersistAd: true});
#         window.gladsdk.setHostMeta('theme', 'system');
#
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newsend',
#             adSlotElementId: 'glad_ad_newsend'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newslist',
#             adSlotElementId: 'glad_ad_newslist'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_sidebox',
#             adSlotElementId: 'glad_ad_sidebox'
#         });
#     })
# </script>
# </head>
# <body>
# <div id="wrap">
# <!-- 광고적용 태그 추가 -->
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
# <li><span class="snb_bdr"></span><a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">스포츠</a></li>
# <li><span class="snb_bdr"></span><a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">날씨</a></li>
# <li><span class="snb_bdr"></span><a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">프리미엄</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_both">
# <div class="lnb_left">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li><a class="nclicks(lnb.pcmedia)" href="/"><span class="tx">언론사별</span> </a></li>
# <li class="on"><a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
# <li><a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a></li>
# <li><a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹</span> </a></li>
# <li><a class="nclicks(lnb.paper)" href="/newspaper/home"><span class="tx">신문보기</span> </a></li>
# <li><a class="nclicks(lnb.opi)" href="/opinion/home"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(lnb.fact)" href="/main/factcheck/main.naver"><span class="tx">팩트체크</span> </a></li>
# </ul>
# </div>
# </div>
# <div class="lnb_right">
# <div class="lnb_extra">
# <div class="lnb_extra_menu">
# <ul class="lnb_extra_menu_list">
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(STA.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb">
# <span class="lnb_date"><strong>05</strong>.<strong>01</strong><span class="day">(월)</span></span>
# <ul class="lnb_side" tabindex="0">
# <li><a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li><a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li><a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# <hr/>
# <table cellpadding="0" cellspacing="0" class="container">
# <caption class="blind">기사목록</caption>
# <colgroup>
# <col class="col_snb"/>
# <col class="col_content"/>
# <col class="col_aside"/>
# </colgroup>
# <tr>
# <td class="snb">
# <div class="snb" id="snb">
# <h2 class="h2"><a class="nclicks(lmn_pol.home)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100">정치</a></h2>
# <ul class="nav">
# <li><a class="snb_s11 nclicks(lmn_pol.mnl,,1)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=264">대통령실 </a></li>
# <li><a class="snb_s12 nclicks(lmn_pol.mnl,,2)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=265">국회/정당 </a></li>
# <li><a class="snb_s13 nclicks(lmn_pol.mnl,,3)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=268">북한 </a></li>
# <li><a class="snb_s14 nclicks(lmn_pol.mnl,,4)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=266">행정 </a></li>
# <li><a class="snb_s15 nclicks(lmn_pol.mnl,,5)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=267">국방/외교 </a></li>
# <li><a class="snb_s16 nclicks(lmn_pol.mnl,,6)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=269">정치일반 </a></li>
# </ul>
# <div class="snb_banner">
# <a class="nclicks(lmn_pol.pmb,,1)" href="https://media.naver.com/channel/setting?back=main"><img alt="언론사 구독하기" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/01/14/142956425_144518244_%2525B8%2525F0%2525B9%2525D9%2525C0%2525CF%2525B8%2525DE%2525C0%2525CE.png" width="71"/></a>
# </div>
# <div class="snb_banner">
# <a class="nclicks(lmn_pol.pmb,,1)" href="https://contents.premium.naver.com/"><img alt="네이버 프리미엄콘텐츠" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71"/></a>
# </div>
# </div>
# </td>
# <td class="content">
# <div class="content" id="main_content">
# <div class="list_body section_index">
# <div class="cluster">
# <div class="cluster_title">
# <span class="cluster_title_inner"><a class="cluster_title_icon_link _news_cluster_layer_btn" href="#biF7L"><i class="cluster_title_icon">안내</i>헤드라인 뉴스</a></span>
# <div class="cluster_title_layer _news_cluster_layer is_hidden">
# <div class="cluster_title_layer_text">
#                             헤드라인 뉴스와 각 기사묶음 타이틀은 <br/> 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.
#                         </div>
# <div class="cluster_title_layer_image"></div>
# <button class="cluster_title_layer_close _news_cluster_layer_close_btn" type="button">닫기</button>
# </div>
# </div>
# </div>
# <div class="_persist">
# <div class="cluster">
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011833312?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/05/01/11833312.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011833312?sid=100">윤재옥, 한미 핵협의그룹에 "자체 핵무장 보다 더 큰 이익"</a>
# <div class="cluster_text_lede">윤재옥 국민의힘 원내대표는 1일 한미가 합의한 핵협의그룹(NPG)에 대해 "자체 핵무장 보다 더 큰 이익이 될 것"이라고 주장했다. 윤 원내대표는 이날  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011833312',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news417,0000917299',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">머니S</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/417/0000917299?sid=100">윤재옥 "워싱턴 선언, 자체 핵무장보다 더 큰 이익"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news366,0000898058',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선비즈</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898058?sid=100">與 “워싱턴 선언, 업그레이드한 제2의 한미상호방위조약”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006779811',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779811?sid=100">윤재옥 "워싱턴 선언, 우리 자체 핵무장보다 더 큰 이익될 것"</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011000_00000009&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=003&amp;aid=0011833312"><span class="cluster_foot_more_icon_num">4</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269869?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/214/2023/05/01/1269869.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269869?sid=100">'설화' 김재원 "심려끼쳐 대단히 죄송"‥한 달만 최고위 복귀</a>
# <div class="cluster_text_lede">잇따른 설화로 논란을 일으킨 김재원 국민의힘 최고위원이 한 달 만에 당 최고위원회의에 참석해 다시한번 사과의 뜻을 밝혔습니다. 김 최고위원은 '5·18  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news214,0001269869',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">MBC</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news020,0003494719',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">동아일보</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/020/0003494719?sid=100">한 달 만에 모습 드러낸 김재원 “자진사퇴 생각해 보지 않아”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news008,0004881763',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">머니투데이</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/008/0004881763?sid=100">'자숙 끝' 김재원 "심려 끼쳐 대단히 죄송"…한달 만에 최고위 복귀</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news029,0002797932',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">디지털타임스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/029/0002797932?sid=100">與 윤리위 당일 최고위 복귀한 김재원 "죄송하다...열심히 하겠다"</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010930_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=214&amp;aid=0001269869"><span class="cluster_foot_more_icon_num">37</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269848?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/214/2023/05/01/1269848.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269848?sid=100">북한, 美전략핵잠 한반도 전개 '적법' 판단에 "황당무계한 궤변"</a>
# <div class="cluster_text_lede">북한은 오늘 한미 `워싱턴 선언`에 담긴 미국 전략 핵잠수함(SSBN)의 한국 기항은 법적으로 아무런 문제가 없다는 당국의 판단에 대해 "황당무계한 궤변 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news214,0001269848',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">MBC</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news437,0000341306',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">JTBC</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/437/0000341306?sid=100">북 "미 핵잠수함 한반도 전개...'법적 문제 없다'는 해괴한 주장"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879471',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879471?sid=100">北, 美 전략핵잠 전개 '적법' 판단에 "황당무계한 궤변"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news014,0005005160',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">파이낸셜뉴스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/014/0005005160?sid=100">美 전략핵잠수함 한반도 전개 '적법' 판단에 北 "황당무계한 궤변"</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010810_00000018&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=214&amp;aid=0001269848"><span class="cluster_foot_more_icon_num">14</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054473?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/055/2023/05/01/1054473.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054473?sid=100">김기현 "한미 관계 새 이정표 수립…비난만 하는 민주당 한심"</a>
# <div class="cluster_text_lede">국민의힘 김기현 대표는 윤석열 대통령이 이번 국빈 방미를 통해 "북핵 위협에 대한 대응, 자유민주주의 가치 동맹, 경제·산업 협력 확대 등 양국 관계에  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news055,0001054473',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">SBS</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004185255',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185255?sid=100">김기현 "尹방미, 북핵 위협 대응 등 韓-美 관계 새 이정표 수립"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news008,0004881770',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">머니투데이</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/008/0004881770?sid=100">與 "尹대통령 방미, 한미관계 새로운 이정표 수립 계기 마련"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013913728',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013913728?sid=100">김기현 "尹방미, 한미 양국관계 새 이정표 수립 최대 성과 거둬"</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010940_00000015&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=055&amp;aid=0001054473"><span class="cluster_foot_more_icon_num">17</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779742?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/421/2023/05/01/6779742.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779742?sid=100">尹 "바이든 부부, 국빈 만찬에 감사…다음엔 서울서 한식으로"</a>
# <div class="cluster_text_lede">미국 국빈 방문을 마치고 돌아온 윤석열 대통령은 1일 트위터를 통해 "아내도 조 바이든 미국 대통령과 질 바이든 여사에게 정말 많은 감사를 전하고 싶어  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006779742',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011833218?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/05/01/11833218.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011833218?sid=100">尹, 바이든 부부에게 트윗 글 "아내도 감사 전하고 싶어해"</a>
# <div class="cluster_text_lede">기사내용 요약 "인상적 만찬 준비해준 질 여사에 감사" "서울서 멋진 한식으로 보답하길 바라" [서울=뉴국빈 방미를 마치고 귀국한 윤석열 대통령은 1일  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011833218',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010810_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=421&amp;aid=0006779742"><span class="cluster_foot_more_icon_num">15</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269756?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/214/2023/04/30/1269756.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269756?sid=100">국민의힘 윤리위, 내일 첫 회의‥'김재원·태영호 중징계' 나오나</a>
# <div class="cluster_text_lede">국민의힘 중앙윤리위원회가 내일 오전 당사에서 첫 회의를 열고 새로 선임된 윤리위원들에게 임명장을 수여할 예정인 가운데, 잇단 설화로 물의를 빚은 김재원· …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news214,0001269756',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">MBC</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/079/0003765077?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/079/2023/05/01/3765077.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/079/0003765077?sid=100">野 돈봉투 의혹에 차별화 나선 與, 오늘 첫 윤리위가 시험대</a>
# <div class="cluster_text_lede">새로 구성된 국민의힘 윤리위원회가 1일 첫 회의를 열고 논란이 된 최고위원들의 발언에 대한 징계논의에 착수한다. 최근 국민의힘이 더불어민주당의 '돈봉투' …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news079,0003765077',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">노컷뉴스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304281030_00001855&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=214&amp;aid=0001269756"><span class="cluster_foot_more_icon_num">55</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269875?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/214/2023/05/01/1269875.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269875?sid=100">윤 대통령 지지율 1.9%p 오른 34.5%‥4주 만에 반등 [리얼미터]</a>
# <div class="cluster_text_lede">윤석열 대통령의 국정수행 지지도가 미국 국빈 방문과 맞물려 4주 만에 반등했다는 여론조사 결과가 나왔습니다. 리얼미터가 미디어트리뷴 의뢰로 지난달 24일 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news214,0001269875',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">MBC</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003761029?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/023/2023/05/01/3761029.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003761029?sid=100">‘워싱턴 선언’ 이끌어낸 尹, 지지율 4주 만에 반등해 34.5% [리얼미터]</a>
# <div class="cluster_text_lede">윤석열 대통령의 지지율이 4주 만에 반등한 여론조사 결과가 1일 나왔다. 한미 정상회담에서 북핵에 맞서기 위한 ‘워싱턴 선언’을 이끌어내는 등 방미 성과 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news023,0003761029',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선일보</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010810_00000002&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=214&amp;aid=0001269875"><span class="cluster_foot_more_icon_num">39</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011833587?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/05/01/11833587.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011833587?sid=100">尹 "진정한 노동약자 보호 위해 기득권 고용세습 뿌리 뽑을 것"</a>
# <div class="cluster_text_lede">기사내용 요약 "모든 국민이 자유롭게 일할 권리 보장" "글로벌 스탠더드 맞게 노동 유연화" [서울=뉴윤석열 대통령은 1일 '근로자의 날'을 맞아 "진정 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011833587',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185313?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/011/2023/05/01/4185313.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185313?sid=100">[속보]尹 “소수만 기득권 누리면 자유가 아니라 특권”…근로자의날 메시지</a>
# <div class="cluster_text_lede">윤석열 대통령이 1일 “소수만이 기득권을 누린다면 그것은 자유가 아니라 특권”이라고 말했다. 근로자의날을 맞아 ‘노동조합 기득권 타파’ 중심의 노동개혁을 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004185313',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011200_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=003&amp;aid=0011833587"><span class="cluster_foot_more_icon_num">8</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898021?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/366/2023/05/01/898021.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898021?sid=100">‘전당대회 돈 봉투 의혹’에 민형배·김홍걸 복당까지…민주당 내홍 심화</a>
# <div class="cluster_text_lede">민주당, 송영길 탈당에 “진행 상황 보고 대응” 비명계는“안도할 상황 아냐…꼬리자르기” 지적 민형배 복당에도 비명계 반발 “명분 없는 복당은 책임 면피” …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news366,0000898021',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선비즈</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779896?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/421/2023/05/01/6779896.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779896?sid=100">'복당' 민형배 "이지메 세게 당한 느낌…반대파, 늘 그래온 사람들"</a>
# <div class="cluster_text_lede">민형배 더불어민주당 의원은 1일 복당 소회에 대해 "'이지메'(집단 따돌림을 의미하는 일본어)를 세게 당한 느낌"이라고 밝혔다. 민 의원은 이날 오전 Y …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006779896',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011100_00000060&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=366&amp;aid=0000898021"><span class="cluster_foot_more_icon_num">5</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013913556?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2023/05/01/13913556.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013913556?sid=100">이종섭 "워싱턴선언, 제2한미상호방위조약…억제력 획기적 향상"</a>
# <div class="cluster_text_lede">언론사 기고…"전술핵 재배치·자체핵무장 초래할 파장 고려해야" "한미동맹 기반한 '힘에 의한 평화' 필요…우리 군 3축체계 강화" 이종섭 국방부 장관은  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013913556',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054275?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/055/2023/04/30/1054275.jpg?type=ofullfill132_90" width="132"/>
# <strong class="r_ico r_vod_medium">동영상기사</strong>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054275?sid=100">"워싱턴 선언, 핵 포함 상호방위 업그레이드"</a>
# <div class="cluster_text_lede">한미 정상이 발표한 워싱턴 선언 관련, 사실상 핵공유다, 아니다, 논란이 많습니다. 방미 중에 윤석열 대통령이 직접 입장을 밝혔습니다. 워싱턴 선언은 핵 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news055,0001054275',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">SBS</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304290630_00000003&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0013913556"><span class="cluster_foot_more_icon_num">9</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002137436?sid=100">‘워싱턴 선언’ 최대 성과...중·러 ‘강한 반발’ 부담</a>
# <div class="cluster_text_lede">윤석열 대통령의 5박7일 미국 국빈방문 최대 성과로는 무엇보다 ‘워싱턴 선언’이 꼽힌다. 고도화하는 북한의 핵·미사일 위협에 맞서 대북 확장억제(핵우산)를 획기적으로 강화하고 한미 간 안보 협력 수준을 대폭 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news016,0002137436',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">헤럴드경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898009?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/366/2023/04/30/898009.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898009?sid=100">대통령실 “핵 포함한 개념으로 한미상호방위조약 개선”</a>
# <div class="cluster_text_lede">대통령실은 윤석열 대통령의 국빈 방미 성과와 관련해 “한미상호방위조약을 핵이 포함된 상호방위 개념으로 업그레이드했다”고 말했다. 30일 대통령실은 이날  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news366,0000898009',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선비즈</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304280010_00001014&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=016&amp;aid=0002137436"><span class="cluster_foot_more_icon_num">22</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879562?sid=100">與 박대출 "방송법 통과하면, 대통령이 거부권 행사해야"</a>
# <div class="cluster_text_lede">국민의힘 박대출 정책위의장은 더불어민주당 주도로 국회 본회의에 직회부된 공영방송 지배구조 개편을 위한 방송법 개정안 등과 관련해, 법안이 국회를 통과하면 대통령은 거부권, 재의요구권을 행사해야 마땅할 것이라 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879562',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/030/0003095264?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/030/2023/04/30/3095264.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/030/0003095264?sid=100">방송법, 5월 정국 뇌관으로…여야 '평행선' 속 거부권 행사 초미 관심[스페셜리포트]</a>
# <div class="cluster_text_lede">공영방송 지배구조를 바꾸는 내용의 방송3법(방송법·방송문화진흥회법·한국교육방송공사법) 개정안이 국회 본회의에 부의됐다. 부의는 본회의에서 안건 심의가 가 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news030,0003095264',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">전자신문</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304300910_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=052&amp;aid=0001879562"><span class="cluster_foot_more_icon_num">11</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011475913?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/056/2023/05/01/11475913.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011475913?sid=100">북 매체, 중러 ‘워싱턴선언’ 비판 조명…“부정적 후과 우려”</a>
# <div class="cluster_text_lede">북한이 한국과 미국 정상이 합의한 ‘워싱턴선언’을 두고 중국과 러시아 등 주요 우방국에서 내놓는 비판 목소리에 힘을 실으며 여론전에 나섰습니다. 조선중앙 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news056,0011475913',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">KBS</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/002/0002284321?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/002/2023/05/01/2284321.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/002/0002284321?sid=100">북한 "워싱턴 선언 부정적 후과"…중·러 반발 집중 조명</a>
# <div class="cluster_text_lede">'한미일' 공조 강화에 '북중러' 연대 맞불 한국과 미국이 북핵 위협 대응 방안으로 합의한 '워싱턴 선언'에 대해 북한이 1일 강하게 반발했다. 북한 관 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news002,0002284321',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">프레시안</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010800_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=056&amp;aid=0011475913"><span class="cluster_foot_more_icon_num">8</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/005/0001605144?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/005/2023/05/01/1605144.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/005/0001605144?sid=100">‘서지니형’ 왜 여기에?…尹대통령 “어떻게 오셨냐”</a>
# <div class="cluster_text_lede">미국을 국빈 방문한 윤석열 대통령이 세계적인 영상 콘텐츠 기업들을 한자리에서 만나 K-콘텐츠 수출 확대를 논의한 자리에 배우 이서진이 등장해 화제가 되고 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news005,0001605144',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">국민일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185080?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/011/2023/04/30/4185080.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185080?sid=100">‘서지니형’ 왜 거기서 나와?…尹 대통령 "어떻게 오셨냐"</a>
# <div class="cluster_text_lede">미국을 국빈 방문한 윤석열 대통령이 세계적인 영상 콘텐츠 기업들을 만나 K-콘텐츠 수출 확대를 논의한 자리에 자리에 배우 이서진이 모습을 보였다. 윤 대 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004185080',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304280850_00000028&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=005&amp;aid=0001605144"><span class="cluster_foot_more_icon_num">8</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054471?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/055/2023/05/01/1054471.jpg?type=ofullfill132_90" width="132"/>
# <strong class="r_ico r_vod_medium">동영상기사</strong>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054471?sid=100"> 박용진 "尹 성과 부풀리다…대한민국 '핵 공유 호소인' 전락"[정치쇼]</a>
# <div class="cluster_text_lede">- 尹 고생했지만 안보는 불안 경제는 거덜 - 불필요한 중-러 자극, 외나무다리 위 운명 - 대한민국 핵 공유 호소인으로 전락…국제망신 - 美, 반도체  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news055,0001054471',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">SBS</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277005?sid=100">
# ...
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/659/0000011136?ntype=RANKING&amp;sid=001">"부모 대부분 자녀들 마약 범죄 몰라".. 용돈으로 사고, …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=659"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/659/2022/01/19/logo_659_56_20220119141438.png" width="16"/></span>전주MBC</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/661/0000024311?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/661/2023/05/01/24311.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/661/0000024311?ntype=RANKING&amp;sid=001">유급휴일 '근로자의 날'.."직장인 10명 중 3명  출근 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=661"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/661/2022/01/19/logo_661_56_20220119142145.png" width="16"/></span>JIBS</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/666/0000010111?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/666/2023/05/01/10111.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/666/0000010111?ntype=RANKING&amp;sid=001">안성 양성면 물류창고서 화재…60대 직원 1명 연기흡입·  …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=666"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/666/2023/01/03/logo_666_56_20230103174615.png" width="16"/></span>경기일보</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/665/0000000882?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/665/2023/05/01/882.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/665/0000000882?ntype=RANKING&amp;sid=001">리버버스 김포~여의도 20분? 실제론 1시간 28분 [視리 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=665"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/665/2022/12/08/logo_665_56_20221208184224.png" width="16"/></span>더스쿠프</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018624?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/145/2023/05/01/18624.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018624?ntype=RANKING&amp;sid=001">적금 탔더니 그 돈으로 병원을 가네···5월 별자리 운세</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=145"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/145/2020/12/09/logo_145_56_20201209180915.png" width="16"/></span>레이디경향</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <button class="refresh_button nclicks('rig.renws2new') _refreshButton" type="button">더보기</button>
# </div>
# <script type="text/javascript">
#     var OfficeTopRankingManager = jindo.$Class({
#         $static: {
#             RANKING_INFO_BUTTON_SELECTOR: '._rankingInfoButton',
#             RANKING_INFO_LAYER_SELECTOR : '._rankingInfoLayer',
#             RANKING_INFO_BUTTON_CLOSE_SELECTOR : '._rankingInfoCloseButton',
#             REFRESH_BUTTON_SELECTOR : '._refreshButton',
#             RANKING_LIST_SELECTOR : '._rankingList'
#         },
#
#         $init: function(base) {
#             this._welBase = jindo.$Element(base);
#             this._rankingInfoLayer = jindo.$Element(this._welBase.query(this.constructor.RANKING_INFO_LAYER_SELECTOR));
#             this._rankingListArray = jindo.$ElementList(this._welBase.queryAll(this.constructor.RANKING_LIST_SELECTOR));
#
#             this._initEvent();
#         },
#
#         _initEvent: function() {
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_SELECTOR, jindo.$Fn(this._showRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_CLOSE_SELECTOR, jindo.$Fn(this._closeRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.REFRESH_BUTTON_SELECTOR, jindo.$Fn(this._refreshRankingList, this).bind());
#         },
#
#         _showRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.toggle();
#         },
#
#         _closeRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.hide();
#         },
#
#         _refreshRankingList: function(event) {
#             event.stopDefault();
#
#             for (var i=0 ; i<this._rankingListArray.length() ; i++) {
#                 var rankingList = this._rankingListArray.get(i);
#
#                 if (rankingList.visible() === true) {
#                     var nextIndex = i + 1;
#
#                     if (nextIndex === this._rankingListArray.length()) {
#                         nextIndex = 0;
#                     }
#
#                     var nextRankingList = this._rankingListArray.get(nextIndex);
#
#                     rankingList.hide();
#                     nextRankingList.show();
#
#                     break;
#                 }
#             }
#         }
#     });
#
#     window.addEventListener("load", function() {
#         var officeTopRanking = jindo.$$.getSingle("._officeTopRanking1087473");
#         if (officeTopRanking) {
#             new OfficeTopRankingManager(officeTopRanking);
#         }
#     });
# </script>
# <div class="side_ad" id="glad_ad_sidebox"></div>
# <div class="section" id="right_dailyList" style="margin-bottom:20px; white-space:nowrap;">
# <h4>분야별 주요뉴스</h4>
# <div class="classfy sd" style="display:block">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/001/0013913824?sid=100" title="'설화' 김재원 최고위 복귀…'자진사퇴'엔 &quot;아직 생각 안해봐&quot;(종합)">'설화' 김재원 최고위 복귀…'자진사퇴'엔 "아직 생각 안해봐"(종합)</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/056/0011476101?sid=100" title="[속보] 국민의힘 윤리위, 김재원 태영호 ‘징계 개시’ 결정">[속보] 국민의힘 윤리위, 김재원 태영호 ‘징계 개시’ 결정</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/448/0000407097?sid=100" title="尹대통령 긍정평가 34.5%…4주 만에 소폭 반등">尹대통령 긍정평가 34.5%…4주 만에 소폭 반등</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/022/0003808132?sid=104" title="대만 “유일한 남미 친구 지켰다”…파라과이 대선 결과에 ‘일단’ 안도">대만 “유일한 남미 친구 지켰다”…파라과이 대선 결과에 ‘일단’ 안도</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/079/0003765162?sid=104" title='"한국, 양육비 가장 비싼 나라"…1인당 GDP의 7.7배'>"한국, 양육비 가장 비싼 나라"…1인당 GDP의 7.7배</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/001/0013914034?sid=101" title="'41% 급감' 반도체에 수출 7개월째 감소…무역적자 14개월 연속(종합2보)">'41% 급감' 반도체에 수출 7개월째 감소…무역적자 14개월 연속(종합2보)</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/366/0000898085?sid=101" title="금감원 “올해 공매도 규모 급증… 무차입 공매도 33건 제재 조치 완료”">금감원 “올해 공매도 규모 급증… 무차입 공매도 33건 제재 조치 완료”</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/421/0006778342?sid=101" title="[단독]신림·상도·봉천·대방 200여채 보증금 미반환 위기…살던 집은 경매로">[단독]신림·상도·봉천·대방 200여채 보증금 미반환 위기…살던 집은 경매로</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/138/0002147587?sid=105" title="‘중간요금제’ 속속 출격…LTE→5G 전환 이끌어낼까">‘중간요금제’ 속속 출격…LTE→5G 전환 이끌어낼까</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/011/0004185262?sid=105" title="'노태북 열풍 이어갈까'…삼성, 인텔 13세대 기반 PC 3종 출시">'노태북 열풍 이어갈까'…삼성, 인텔 13세대 기반 PC 3종 출시</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/052/0001879553?sid=102" title='송영길 측 "내일 검찰 자진 출석"...與 "상습 탈선"'>송영길 측 "내일 검찰 자진 출석"...與 "상습 탈선"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/079/0003765120?sid=102" title="'강남 투신' 10대 만났던 20대 남성 입건…자살방조죄 적용">'강남 투신' 10대 만났던 20대 남성 입건…자살방조죄 적용</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/022/0003808125?sid=102" title="영양교사가 검수한 식재료에 개구리 사체… 법원 “급식업체도 책임”">영양교사가 검수한 식재료에 개구리 사체… 법원 “급식업체도 책임”</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/079/0003765164?sid=103" title="4일부터 국립공원 사찰 등 문화재 관람료 무료">4일부터 국립공원 사찰 등 문화재 관람료 무료</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/079/0003765171?sid=103" title="현대차, '대한민국 동행축제' 연계 최대 5% 할인 프로모션">현대차, '대한민국 동행축제' 연계 최대 5% 할인 프로모션</a> </li>
# </ul>
# </ul>
# </ul>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://media.naver.com/channel/settings"> <img alt="네이버 메인에서 바로 보는 언론사 편집뉴스 지금 바로 구독해보세요!" src="https://imgnews.pstatic.net/image/upload/item/2018/11/27/174854048_PC_%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA_%25B1%25B8%25B5%25B6%25C8%25B0%25BC%25BA%25C8%25AD.png" width="300"/> </a>
# </div>
# </div>
# <div class="section">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/assembly/index.naver" target="_blank"> <img alt="내일을 여는 국민의 국회" border="0" class="banner" height="60" src="https://imgnews.pstatic.net/image/upload/item/2021/01/08/173235779_%25B1%25B9%25C8%25B8%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA.png" width="300"/> </a>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" target="_blank"> <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/183951086_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300"/> </a>
# </div>
# </div>
# <div class="section">
# <h4> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"> 서비스 안내 </a> </h4>
# <ul class="list_txt">
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb"> 고침 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb"> 정정·반론·추후 보도 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb"> 불공정 선거 보도 기사 모음 </a> </li>
# </ul>
# <a class="more_link nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"><span class="blind">서비스 안내</span>더보기</a>
# </div>
# <script>
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#
#         adSlot.setCustomParam("calp", 'shome');
#         window.gladsdk.displayAd(adSlot);
#     });
# </script>
# </div>
# </td>
# </tr>
# </table>
# </div>
# <hr/>
# <div class="index">
# <div class="index_inner">
# <div class="floating_btn">
# <div class="floating_inner">
# <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
# <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
# </div>
# </div>
# <div class="index_tab" id="index.press_category">
# <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content is_hidden" id="index.press.area"></div>
# <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content02 is_hidden" id="index.category.area"></div>
# </div>
# </div>
# </div>
# <hr/>
# <div id="footer">
# <ul>
# <li class="first"><a class="nclicks(fot.agreement)" href="http://www.naver.com/rules/service.html">이용약관</a></li>
# <li><a class="nclicks(fot.guide)" href="/main/ombudsman/index.naver">서비스 안내</a></li>
# <li><a class="nclicks(fot.editor)" href="/main/ombudsman/edit.naver?mid=omb">기사배열 원칙 책임자 : 유봉석</a></li>
# <li>청소년 보호 책임자 : 이희만</li>
# <li><strong><a class="nclicks(fot.privacy)" href="http://www.naver.com/rules/privacy.html">개인정보처리방침</a></strong></li>
# <li><a class="nclicks(fot.disclaimer)" href="http://www.naver.com/rules/disclaimer.html">책임의 한계와 법적고지</a></li>
# <li><a class="nclicks(fot.help)" href="#" onclick="news.external.OPS.helpNews(); return false;" title="새창">뉴스 고객센터</a></li>
# </ul>
# <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
# <address class="address_nhn">
# <a class="logo nclicks(fot.naver)" href="https://www.navercorp.com/" target="_blank"><span class="blind">NAVER</span></a>
# <em>Copyright ©</em>
# <a class="nclicks(fot.navercorp)" href="https://www.navercorp.com/" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# <!-- -->
# </div>
# <script type="text/javascript">
#
#
#
#
#
#
#
# var index_tab = new news.index.TabController('index.press_category');
# index_tab.add(new news.index.Tab('index.press.btn','stit','index.press.area','/main/ajax/bottomIndex/press.naver'));
# index_tab.add(new news.index.Tab('index.category.btn','stit2','index.category.area','/main/ajax/bottomIndex/category.naver'));
# jindo.$Fn(index_tab.toggle, index_tab).attach(index_tab.tabs.keys(), 'click');
#
#
# (function() {
# 	news.right.RightSideFloatingManager.init();
# })();
#
#
#
#     (function() {
#         news.right.TopDownFloatingManager.init();
#     })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ;(function(){
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jindo.$Fn(function(){
#
#
# 	lcs_do();
#
#     }).attach(window, eventType);
# })();
#
#
#
#
#
#
#
#
# news.startup();
#
#
# jindo.$Fn(function(){
#     var welSkip = jindo.$Element("u_skip");
#     if (welSkip === null) {
#         return;
#     }
#     welSkip.delegate("click", "a", function(weEvent){
#         weEvent.stopDefault();
#         var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#         oWebAccessibilityUtil.moveFocus(elTarget);
#     });
# }).attach(window, "load");
#
#
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
# </body>
# </html>>

# %%
bs.find('div')
# Out:
# <div id="wrap">
# <!-- 광고적용 태그 추가 -->
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
# <li><span class="snb_bdr"></span><a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">스포츠</a></li>
# <li><span class="snb_bdr"></span><a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">날씨</a></li>
# <li><span class="snb_bdr"></span><a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">프리미엄</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_both">
# <div class="lnb_left">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li><a class="nclicks(lnb.pcmedia)" href="/"><span class="tx">언론사별</span> </a></li>
# <li class="on"><a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
# <li><a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a></li>
# <li><a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹</span> </a></li>
# <li><a class="nclicks(lnb.paper)" href="/newspaper/home"><span class="tx">신문보기</span> </a></li>
# <li><a class="nclicks(lnb.opi)" href="/opinion/home"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(lnb.fact)" href="/main/factcheck/main.naver"><span class="tx">팩트체크</span> </a></li>
# </ul>
# </div>
# </div>
# <div class="lnb_right">
# <div class="lnb_extra">
# <div class="lnb_extra_menu">
# <ul class="lnb_extra_menu_list">
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(STA.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb">
# <span class="lnb_date"><strong>05</strong>.<strong>01</strong><span class="day">(월)</span></span>
# <ul class="lnb_side" tabindex="0">
# <li><a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li><a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li><a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# <hr/>
# <table cellpadding="0" cellspacing="0" class="container">
# <caption class="blind">기사목록</caption>
# <colgroup>
# <col class="col_snb"/>
# <col class="col_content"/>
# <col class="col_aside"/>
# </colgroup>
# <tr>
# <td class="snb">
# <div class="snb" id="snb">
# <h2 class="h2"><a class="nclicks(lmn_pol.home)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100">정치</a></h2>
# <ul class="nav">
# <li><a class="snb_s11 nclicks(lmn_pol.mnl,,1)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=264">대통령실 </a></li>
# <li><a class="snb_s12 nclicks(lmn_pol.mnl,,2)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=265">국회/정당 </a></li>
# <li><a class="snb_s13 nclicks(lmn_pol.mnl,,3)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=268">북한 </a></li>
# <li><a class="snb_s14 nclicks(lmn_pol.mnl,,4)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=266">행정 </a></li>
# <li><a class="snb_s15 nclicks(lmn_pol.mnl,,5)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=267">국방/외교 </a></li>
# <li><a class="snb_s16 nclicks(lmn_pol.mnl,,6)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=269">정치일반 </a></li>
# </ul>
# <div class="snb_banner">
# <a class="nclicks(lmn_pol.pmb,,1)" href="https://media.naver.com/channel/setting?back=main"><img alt="언론사 구독하기" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/01/14/142956425_144518244_%2525B8%2525F0%2525B9%2525D9%2525C0%2525CF%2525B8%2525DE%2525C0%2525CE.png" width="71"/></a>
# </div>
# <div class="snb_banner">
# <a class="nclicks(lmn_pol.pmb,,1)" href="https://contents.premium.naver.com/"><img alt="네이버 프리미엄콘텐츠" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71"/></a>
# </div>
# </div>
# </td>
# <td class="content">
# <div class="content" id="main_content">
# <div class="list_body section_index">
# <div class="cluster">
# <div class="cluster_title">
# <span class="cluster_title_inner"><a class="cluster_title_icon_link _news_cluster_layer_btn" href="#biF7L"><i class="cluster_title_icon">안내</i>헤드라인 뉴스</a></span>
# <div class="cluster_title_layer _news_cluster_layer is_hidden">
# <div class="cluster_title_layer_text">
#                             헤드라인 뉴스와 각 기사묶음 타이틀은 <br/> 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.
#                         </div>
# <div class="cluster_title_layer_image"></div>
# <button class="cluster_title_layer_close _news_cluster_layer_close_btn" type="button">닫기</button>
# </div>
# </div>
# </div>
# <div class="_persist">
# <div class="cluster">
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011833312?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/05/01/11833312.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011833312?sid=100">윤재옥, 한미 핵협의그룹에 "자체 핵무장 보다 더 큰 이익"</a>
# <div class="cluster_text_lede">윤재옥 국민의힘 원내대표는 1일 한미가 합의한 핵협의그룹(NPG)에 대해 "자체 핵무장 보다 더 큰 이익이 될 것"이라고 주장했다. 윤 원내대표는 이날  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011833312',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news417,0000917299',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">머니S</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/417/0000917299?sid=100">윤재옥 "워싱턴 선언, 자체 핵무장보다 더 큰 이익"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news366,0000898058',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선비즈</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898058?sid=100">與 “워싱턴 선언, 업그레이드한 제2의 한미상호방위조약”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006779811',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779811?sid=100">윤재옥 "워싱턴 선언, 우리 자체 핵무장보다 더 큰 이익될 것"</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011000_00000009&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=003&amp;aid=0011833312"><span class="cluster_foot_more_icon_num">4</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269869?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/214/2023/05/01/1269869.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269869?sid=100">'설화' 김재원 "심려끼쳐 대단히 죄송"‥한 달만 최고위 복귀</a>
# <div class="cluster_text_lede">잇따른 설화로 논란을 일으킨 김재원 국민의힘 최고위원이 한 달 만에 당 최고위원회의에 참석해 다시한번 사과의 뜻을 밝혔습니다. 김 최고위원은 '5·18  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news214,0001269869',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">MBC</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news020,0003494719',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">동아일보</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/020/0003494719?sid=100">한 달 만에 모습 드러낸 김재원 “자진사퇴 생각해 보지 않아”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news008,0004881763',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">머니투데이</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/008/0004881763?sid=100">'자숙 끝' 김재원 "심려 끼쳐 대단히 죄송"…한달 만에 최고위 복귀</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news029,0002797932',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">디지털타임스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/029/0002797932?sid=100">與 윤리위 당일 최고위 복귀한 김재원 "죄송하다...열심히 하겠다"</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010930_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=214&amp;aid=0001269869"><span class="cluster_foot_more_icon_num">37</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269848?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/214/2023/05/01/1269848.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269848?sid=100">북한, 美전략핵잠 한반도 전개 '적법' 판단에 "황당무계한 궤변"</a>
# <div class="cluster_text_lede">북한은 오늘 한미 `워싱턴 선언`에 담긴 미국 전략 핵잠수함(SSBN)의 한국 기항은 법적으로 아무런 문제가 없다는 당국의 판단에 대해 "황당무계한 궤변 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news214,0001269848',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">MBC</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news437,0000341306',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">JTBC</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/437/0000341306?sid=100">북 "미 핵잠수함 한반도 전개...'법적 문제 없다'는 해괴한 주장"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879471',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879471?sid=100">北, 美 전략핵잠 전개 '적법' 판단에 "황당무계한 궤변"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news014,0005005160',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">파이낸셜뉴스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/014/0005005160?sid=100">美 전략핵잠수함 한반도 전개 '적법' 판단에 北 "황당무계한 궤변"</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010810_00000018&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=214&amp;aid=0001269848"><span class="cluster_foot_more_icon_num">14</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054473?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/055/2023/05/01/1054473.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054473?sid=100">김기현 "한미 관계 새 이정표 수립…비난만 하는 민주당 한심"</a>
# <div class="cluster_text_lede">국민의힘 김기현 대표는 윤석열 대통령이 이번 국빈 방미를 통해 "북핵 위협에 대한 대응, 자유민주주의 가치 동맹, 경제·산업 협력 확대 등 양국 관계에  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news055,0001054473',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">SBS</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004185255',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185255?sid=100">김기현 "尹방미, 북핵 위협 대응 등 韓-美 관계 새 이정표 수립"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news008,0004881770',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">머니투데이</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/008/0004881770?sid=100">與 "尹대통령 방미, 한미관계 새로운 이정표 수립 계기 마련"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013913728',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013913728?sid=100">김기현 "尹방미, 한미 양국관계 새 이정표 수립 최대 성과 거둬"</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010940_00000015&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=055&amp;aid=0001054473"><span class="cluster_foot_more_icon_num">17</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779742?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/421/2023/05/01/6779742.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779742?sid=100">尹 "바이든 부부, 국빈 만찬에 감사…다음엔 서울서 한식으로"</a>
# <div class="cluster_text_lede">미국 국빈 방문을 마치고 돌아온 윤석열 대통령은 1일 트위터를 통해 "아내도 조 바이든 미국 대통령과 질 바이든 여사에게 정말 많은 감사를 전하고 싶어  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006779742',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011833218?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/05/01/11833218.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011833218?sid=100">尹, 바이든 부부에게 트윗 글 "아내도 감사 전하고 싶어해"</a>
# <div class="cluster_text_lede">기사내용 요약 "인상적 만찬 준비해준 질 여사에 감사" "서울서 멋진 한식으로 보답하길 바라" [서울=뉴국빈 방미를 마치고 귀국한 윤석열 대통령은 1일  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011833218',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010810_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=421&amp;aid=0006779742"><span class="cluster_foot_more_icon_num">15</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269756?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/214/2023/04/30/1269756.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269756?sid=100">국민의힘 윤리위, 내일 첫 회의‥'김재원·태영호 중징계' 나오나</a>
# <div class="cluster_text_lede">국민의힘 중앙윤리위원회가 내일 오전 당사에서 첫 회의를 열고 새로 선임된 윤리위원들에게 임명장을 수여할 예정인 가운데, 잇단 설화로 물의를 빚은 김재원· …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news214,0001269756',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">MBC</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/079/0003765077?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/079/2023/05/01/3765077.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/079/0003765077?sid=100">野 돈봉투 의혹에 차별화 나선 與, 오늘 첫 윤리위가 시험대</a>
# <div class="cluster_text_lede">새로 구성된 국민의힘 윤리위원회가 1일 첫 회의를 열고 논란이 된 최고위원들의 발언에 대한 징계논의에 착수한다. 최근 국민의힘이 더불어민주당의 '돈봉투' …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news079,0003765077',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">노컷뉴스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304281030_00001855&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=214&amp;aid=0001269756"><span class="cluster_foot_more_icon_num">55</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269875?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/214/2023/05/01/1269875.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269875?sid=100">윤 대통령 지지율 1.9%p 오른 34.5%‥4주 만에 반등 [리얼미터]</a>
# <div class="cluster_text_lede">윤석열 대통령의 국정수행 지지도가 미국 국빈 방문과 맞물려 4주 만에 반등했다는 여론조사 결과가 나왔습니다. 리얼미터가 미디어트리뷴 의뢰로 지난달 24일 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news214,0001269875',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">MBC</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003761029?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/023/2023/05/01/3761029.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003761029?sid=100">‘워싱턴 선언’ 이끌어낸 尹, 지지율 4주 만에 반등해 34.5% [리얼미터]</a>
# <div class="cluster_text_lede">윤석열 대통령의 지지율이 4주 만에 반등한 여론조사 결과가 1일 나왔다. 한미 정상회담에서 북핵에 맞서기 위한 ‘워싱턴 선언’을 이끌어내는 등 방미 성과 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news023,0003761029',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선일보</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010810_00000002&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=214&amp;aid=0001269875"><span class="cluster_foot_more_icon_num">39</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011833587?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/05/01/11833587.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011833587?sid=100">尹 "진정한 노동약자 보호 위해 기득권 고용세습 뿌리 뽑을 것"</a>
# <div class="cluster_text_lede">기사내용 요약 "모든 국민이 자유롭게 일할 권리 보장" "글로벌 스탠더드 맞게 노동 유연화" [서울=뉴윤석열 대통령은 1일 '근로자의 날'을 맞아 "진정 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011833587',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185313?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/011/2023/05/01/4185313.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185313?sid=100">[속보]尹 “소수만 기득권 누리면 자유가 아니라 특권”…근로자의날 메시지</a>
# <div class="cluster_text_lede">윤석열 대통령이 1일 “소수만이 기득권을 누린다면 그것은 자유가 아니라 특권”이라고 말했다. 근로자의날을 맞아 ‘노동조합 기득권 타파’ 중심의 노동개혁을 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004185313',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011200_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=003&amp;aid=0011833587"><span class="cluster_foot_more_icon_num">8</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898021?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/366/2023/05/01/898021.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898021?sid=100">‘전당대회 돈 봉투 의혹’에 민형배·김홍걸 복당까지…민주당 내홍 심화</a>
# <div class="cluster_text_lede">민주당, 송영길 탈당에 “진행 상황 보고 대응” 비명계는“안도할 상황 아냐…꼬리자르기” 지적 민형배 복당에도 비명계 반발 “명분 없는 복당은 책임 면피” …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news366,0000898021',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선비즈</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779896?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/421/2023/05/01/6779896.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779896?sid=100">'복당' 민형배 "이지메 세게 당한 느낌…반대파, 늘 그래온 사람들"</a>
# <div class="cluster_text_lede">민형배 더불어민주당 의원은 1일 복당 소회에 대해 "'이지메'(집단 따돌림을 의미하는 일본어)를 세게 당한 느낌"이라고 밝혔다. 민 의원은 이날 오전 Y …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006779896',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011100_00000060&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=366&amp;aid=0000898021"><span class="cluster_foot_more_icon_num">5</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013913556?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2023/05/01/13913556.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013913556?sid=100">이종섭 "워싱턴선언, 제2한미상호방위조약…억제력 획기적 향상"</a>
# <div class="cluster_text_lede">언론사 기고…"전술핵 재배치·자체핵무장 초래할 파장 고려해야" "한미동맹 기반한 '힘에 의한 평화' 필요…우리 군 3축체계 강화" 이종섭 국방부 장관은  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013913556',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054275?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/055/2023/04/30/1054275.jpg?type=ofullfill132_90" width="132"/>
# <strong class="r_ico r_vod_medium">동영상기사</strong>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054275?sid=100">"워싱턴 선언, 핵 포함 상호방위 업그레이드"</a>
# <div class="cluster_text_lede">한미 정상이 발표한 워싱턴 선언 관련, 사실상 핵공유다, 아니다, 논란이 많습니다. 방미 중에 윤석열 대통령이 직접 입장을 밝혔습니다. 워싱턴 선언은 핵 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news055,0001054275',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">SBS</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304290630_00000003&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0013913556"><span class="cluster_foot_more_icon_num">9</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002137436?sid=100">‘워싱턴 선언’ 최대 성과...중·러 ‘강한 반발’ 부담</a>
# <div class="cluster_text_lede">윤석열 대통령의 5박7일 미국 국빈방문 최대 성과로는 무엇보다 ‘워싱턴 선언’이 꼽힌다. 고도화하는 북한의 핵·미사일 위협에 맞서 대북 확장억제(핵우산)를 획기적으로 강화하고 한미 간 안보 협력 수준을 대폭 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news016,0002137436',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">헤럴드경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898009?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/366/2023/04/30/898009.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898009?sid=100">대통령실 “핵 포함한 개념으로 한미상호방위조약 개선”</a>
# <div class="cluster_text_lede">대통령실은 윤석열 대통령의 국빈 방미 성과와 관련해 “한미상호방위조약을 핵이 포함된 상호방위 개념으로 업그레이드했다”고 말했다. 30일 대통령실은 이날  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news366,0000898009',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선비즈</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304280010_00001014&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=016&amp;aid=0002137436"><span class="cluster_foot_more_icon_num">22</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879562?sid=100">與 박대출 "방송법 통과하면, 대통령이 거부권 행사해야"</a>
# <div class="cluster_text_lede">국민의힘 박대출 정책위의장은 더불어민주당 주도로 국회 본회의에 직회부된 공영방송 지배구조 개편을 위한 방송법 개정안 등과 관련해, 법안이 국회를 통과하면 대통령은 거부권, 재의요구권을 행사해야 마땅할 것이라 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879562',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/030/0003095264?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/030/2023/04/30/3095264.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/030/0003095264?sid=100">방송법, 5월 정국 뇌관으로…여야 '평행선' 속 거부권 행사 초미 관심[스페셜리포트]</a>
# <div class="cluster_text_lede">공영방송 지배구조를 바꾸는 내용의 방송3법(방송법·방송문화진흥회법·한국교육방송공사법) 개정안이 국회 본회의에 부의됐다. 부의는 본회의에서 안건 심의가 가 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news030,0003095264',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">전자신문</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304300910_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=052&amp;aid=0001879562"><span class="cluster_foot_more_icon_num">11</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011475913?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/056/2023/05/01/11475913.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011475913?sid=100">북 매체, 중러 ‘워싱턴선언’ 비판 조명…“부정적 후과 우려”</a>
# <div class="cluster_text_lede">북한이 한국과 미국 정상이 합의한 ‘워싱턴선언’을 두고 중국과 러시아 등 주요 우방국에서 내놓는 비판 목소리에 힘을 실으며 여론전에 나섰습니다. 조선중앙 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news056,0011475913',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">KBS</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/002/0002284321?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/002/2023/05/01/2284321.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/002/0002284321?sid=100">북한 "워싱턴 선언 부정적 후과"…중·러 반발 집중 조명</a>
# <div class="cluster_text_lede">'한미일' 공조 강화에 '북중러' 연대 맞불 한국과 미국이 북핵 위협 대응 방안으로 합의한 '워싱턴 선언'에 대해 북한이 1일 강하게 반발했다. 북한 관 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news002,0002284321',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">프레시안</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010800_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=056&amp;aid=0011475913"><span class="cluster_foot_more_icon_num">8</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/005/0001605144?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/005/2023/05/01/1605144.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/005/0001605144?sid=100">‘서지니형’ 왜 여기에?…尹대통령 “어떻게 오셨냐”</a>
# <div class="cluster_text_lede">미국을 국빈 방문한 윤석열 대통령이 세계적인 영상 콘텐츠 기업들을 한자리에서 만나 K-콘텐츠 수출 확대를 논의한 자리에 배우 이서진이 등장해 화제가 되고 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news005,0001605144',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">국민일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185080?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/011/2023/04/30/4185080.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185080?sid=100">‘서지니형’ 왜 거기서 나와?…尹 대통령 "어떻게 오셨냐"</a>
# <div class="cluster_text_lede">미국을 국빈 방문한 윤석열 대통령이 세계적인 영상 콘텐츠 기업들을 만나 K-콘텐츠 수출 확대를 논의한 자리에 자리에 배우 이서진이 모습을 보였다. 윤 대 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004185080',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304280850_00000028&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=005&amp;aid=0001605144"><span class="cluster_foot_more_icon_num">8</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054471?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/055/2023/05/01/1054471.jpg?type=ofullfill132_90" width="132"/>
# <strong class="r_ico r_vod_medium">동영상기사</strong>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054471?sid=100"> 박용진 "尹 성과 부풀리다…대한민국 '핵 공유 호소인' 전락"[정치쇼]</a>
# <div class="cluster_text_lede">- 尹 고생했지만 안보는 불안 경제는 거덜 - 불필요한 중-러 자극, 외나무다리 위 운명 - 대한민국 핵 공유 호소인으로 전락…국제망신 - 美, 반도체  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news055,0001054471',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">SBS</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277005?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/025/2023/05/01/3277005.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277005?sid=100">박용진 “이재명, ‘돈 봉투’ 의혹 쇄신의 칼 쥐고 답 내놔야”</a>
# <div class="cluster_text_lede">박용진 더불어민주당 의원은 1일 지난 2021년 민주당 전당대회에서 불법 정치자금이 오고갔다는 ‘돈봉투 의혹’에 대해 “이재명 대표가 책임있게 쇄신의 칼 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news025,0003277005',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">중앙일보</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011000_00000104&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=055&amp;aid=0001054471"><span class="cluster_foot_more_icon_num">6</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/079/0003764965?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/079/2023/04/30/3764965.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/079/0003764965?sid=100">SSBN 부산에 기항…'비핵화 선언'과 모순 아니라고?[안보열전]</a>
# <div class="cluster_text_lede">편집자 주 튼튼한 안보가 평화를 뒷받침합니다. 밤낮없이 우리의 일상을 지키는 이들의 이야기를 전해드립니다. 치열한 현장(熱戰)의 이야기를 역사에 남기고( …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news079,0003764965',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">노컷뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003760896?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/023/2023/04/30/3760896.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003760896?sid=100">히로시마 원폭 1600배… 워싱턴선언에 등장한 美핵보복 핵잠 위력</a>
# <div class="cluster_text_lede">한국에 올 미 오하이오급 핵보복 전략잠수함 윤석열 대통령과 조 바이든 미국 대통령이 지난 26일(현지시간) ‘워싱턴 선언’에서 미 전략 핵잠수함(SSBN …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news023,0003760896',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선일보</div>
# </div>
# </div>
# </li>
# </ul>
# ...
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=657"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/657/2022/01/19/logo_657_56_20220119135625.png" width="16"/></span>대구MBC</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/658/0000039685?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/658/2023/05/01/39685.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/658/0000039685?ntype=RANKING&amp;sid=001">'부채 52조 원' 가스공사, 자사 임원에겐 '연봉 30% …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=658"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/658/2022/01/20/logo_658_56_20220120164828.png" width="16"/></span>국제신문</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/656/0000049672?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/656/2023/05/01/49672.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/656/0000049672?ntype=RANKING&amp;sid=001">"더는 못 참겠다"… 박은빈 드라마 촬영장에 벽돌 투척한  …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=656"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/656/2022/01/19/logo_656_56_20220119134936.png" width="16"/></span>대전일보</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/659/0000011136?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/659/2023/05/01/11136.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/659/0000011136?ntype=RANKING&amp;sid=001">"부모 대부분 자녀들 마약 범죄 몰라".. 용돈으로 사고, …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=659"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/659/2022/01/19/logo_659_56_20220119141438.png" width="16"/></span>전주MBC</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <ul class="section_list_ranking_press _rankingList" id="_rankingList75" style="display: none">
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/659/0000011136?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/659/2023/05/01/11136.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/659/0000011136?ntype=RANKING&amp;sid=001">"부모 대부분 자녀들 마약 범죄 몰라".. 용돈으로 사고, …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=659"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/659/2022/01/19/logo_659_56_20220119141438.png" width="16"/></span>전주MBC</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/661/0000024311?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/661/2023/05/01/24311.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/661/0000024311?ntype=RANKING&amp;sid=001">유급휴일 '근로자의 날'.."직장인 10명 중 3명  출근 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=661"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/661/2022/01/19/logo_661_56_20220119142145.png" width="16"/></span>JIBS</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/666/0000010111?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/666/2023/05/01/10111.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/666/0000010111?ntype=RANKING&amp;sid=001">안성 양성면 물류창고서 화재…60대 직원 1명 연기흡입·  …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=666"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/666/2023/01/03/logo_666_56_20230103174615.png" width="16"/></span>경기일보</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/665/0000000882?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/665/2023/05/01/882.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/665/0000000882?ntype=RANKING&amp;sid=001">리버버스 김포~여의도 20분? 실제론 1시간 28분 [視리 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=665"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/665/2022/12/08/logo_665_56_20221208184224.png" width="16"/></span>더스쿠프</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018624?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/145/2023/05/01/18624.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018624?ntype=RANKING&amp;sid=001">적금 탔더니 그 돈으로 병원을 가네···5월 별자리 운세</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=145"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/145/2020/12/09/logo_145_56_20201209180915.png" width="16"/></span>레이디경향</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <button class="refresh_button nclicks('rig.renws2new') _refreshButton" type="button">더보기</button>
# </div>
# <script type="text/javascript">
#     var OfficeTopRankingManager = jindo.$Class({
#         $static: {
#             RANKING_INFO_BUTTON_SELECTOR: '._rankingInfoButton',
#             RANKING_INFO_LAYER_SELECTOR : '._rankingInfoLayer',
#             RANKING_INFO_BUTTON_CLOSE_SELECTOR : '._rankingInfoCloseButton',
#             REFRESH_BUTTON_SELECTOR : '._refreshButton',
#             RANKING_LIST_SELECTOR : '._rankingList'
#         },
#
#         $init: function(base) {
#             this._welBase = jindo.$Element(base);
#             this._rankingInfoLayer = jindo.$Element(this._welBase.query(this.constructor.RANKING_INFO_LAYER_SELECTOR));
#             this._rankingListArray = jindo.$ElementList(this._welBase.queryAll(this.constructor.RANKING_LIST_SELECTOR));
#
#             this._initEvent();
#         },
#
#         _initEvent: function() {
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_SELECTOR, jindo.$Fn(this._showRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_CLOSE_SELECTOR, jindo.$Fn(this._closeRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.REFRESH_BUTTON_SELECTOR, jindo.$Fn(this._refreshRankingList, this).bind());
#         },
#
#         _showRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.toggle();
#         },
#
#         _closeRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.hide();
#         },
#
#         _refreshRankingList: function(event) {
#             event.stopDefault();
#
#             for (var i=0 ; i<this._rankingListArray.length() ; i++) {
#                 var rankingList = this._rankingListArray.get(i);
#
#                 if (rankingList.visible() === true) {
#                     var nextIndex = i + 1;
#
#                     if (nextIndex === this._rankingListArray.length()) {
#                         nextIndex = 0;
#                     }
#
#                     var nextRankingList = this._rankingListArray.get(nextIndex);
#
#                     rankingList.hide();
#                     nextRankingList.show();
#
#                     break;
#                 }
#             }
#         }
#     });
#
#     window.addEventListener("load", function() {
#         var officeTopRanking = jindo.$$.getSingle("._officeTopRanking1087473");
#         if (officeTopRanking) {
#             new OfficeTopRankingManager(officeTopRanking);
#         }
#     });
# </script>
# <div class="side_ad" id="glad_ad_sidebox"></div>
# <div class="section" id="right_dailyList" style="margin-bottom:20px; white-space:nowrap;">
# <h4>분야별 주요뉴스</h4>
# <div class="classfy sd" style="display:block">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/001/0013913824?sid=100" title="'설화' 김재원 최고위 복귀…'자진사퇴'엔 &quot;아직 생각 안해봐&quot;(종합)">'설화' 김재원 최고위 복귀…'자진사퇴'엔 "아직 생각 안해봐"(종합)</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/056/0011476101?sid=100" title="[속보] 국민의힘 윤리위, 김재원 태영호 ‘징계 개시’ 결정">[속보] 국민의힘 윤리위, 김재원 태영호 ‘징계 개시’ 결정</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/448/0000407097?sid=100" title="尹대통령 긍정평가 34.5%…4주 만에 소폭 반등">尹대통령 긍정평가 34.5%…4주 만에 소폭 반등</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/022/0003808132?sid=104" title="대만 “유일한 남미 친구 지켰다”…파라과이 대선 결과에 ‘일단’ 안도">대만 “유일한 남미 친구 지켰다”…파라과이 대선 결과에 ‘일단’ 안도</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/079/0003765162?sid=104" title='"한국, 양육비 가장 비싼 나라"…1인당 GDP의 7.7배'>"한국, 양육비 가장 비싼 나라"…1인당 GDP의 7.7배</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/001/0013914034?sid=101" title="'41% 급감' 반도체에 수출 7개월째 감소…무역적자 14개월 연속(종합2보)">'41% 급감' 반도체에 수출 7개월째 감소…무역적자 14개월 연속(종합2보)</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/366/0000898085?sid=101" title="금감원 “올해 공매도 규모 급증… 무차입 공매도 33건 제재 조치 완료”">금감원 “올해 공매도 규모 급증… 무차입 공매도 33건 제재 조치 완료”</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/421/0006778342?sid=101" title="[단독]신림·상도·봉천·대방 200여채 보증금 미반환 위기…살던 집은 경매로">[단독]신림·상도·봉천·대방 200여채 보증금 미반환 위기…살던 집은 경매로</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/138/0002147587?sid=105" title="‘중간요금제’ 속속 출격…LTE→5G 전환 이끌어낼까">‘중간요금제’ 속속 출격…LTE→5G 전환 이끌어낼까</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/011/0004185262?sid=105" title="'노태북 열풍 이어갈까'…삼성, 인텔 13세대 기반 PC 3종 출시">'노태북 열풍 이어갈까'…삼성, 인텔 13세대 기반 PC 3종 출시</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/052/0001879553?sid=102" title='송영길 측 "내일 검찰 자진 출석"...與 "상습 탈선"'>송영길 측 "내일 검찰 자진 출석"...與 "상습 탈선"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/079/0003765120?sid=102" title="'강남 투신' 10대 만났던 20대 남성 입건…자살방조죄 적용">'강남 투신' 10대 만났던 20대 남성 입건…자살방조죄 적용</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/022/0003808125?sid=102" title="영양교사가 검수한 식재료에 개구리 사체… 법원 “급식업체도 책임”">영양교사가 검수한 식재료에 개구리 사체… 법원 “급식업체도 책임”</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/079/0003765164?sid=103" title="4일부터 국립공원 사찰 등 문화재 관람료 무료">4일부터 국립공원 사찰 등 문화재 관람료 무료</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/079/0003765171?sid=103" title="현대차, '대한민국 동행축제' 연계 최대 5% 할인 프로모션">현대차, '대한민국 동행축제' 연계 최대 5% 할인 프로모션</a> </li>
# </ul>
# </ul>
# </ul>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://media.naver.com/channel/settings"> <img alt="네이버 메인에서 바로 보는 언론사 편집뉴스 지금 바로 구독해보세요!" src="https://imgnews.pstatic.net/image/upload/item/2018/11/27/174854048_PC_%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA_%25B1%25B8%25B5%25B6%25C8%25B0%25BC%25BA%25C8%25AD.png" width="300"/> </a>
# </div>
# </div>
# <div class="section">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/assembly/index.naver" target="_blank"> <img alt="내일을 여는 국민의 국회" border="0" class="banner" height="60" src="https://imgnews.pstatic.net/image/upload/item/2021/01/08/173235779_%25B1%25B9%25C8%25B8%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA.png" width="300"/> </a>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" target="_blank"> <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/183951086_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300"/> </a>
# </div>
# </div>
# <div class="section">
# <h4> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"> 서비스 안내 </a> </h4>
# <ul class="list_txt">
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb"> 고침 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb"> 정정·반론·추후 보도 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb"> 불공정 선거 보도 기사 모음 </a> </li>
# </ul>
# <a class="more_link nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"><span class="blind">서비스 안내</span>더보기</a>
# </div>
# <script>
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#
#         adSlot.setCustomParam("calp", 'shome');
#         window.gladsdk.displayAd(adSlot);
#     });
# </script>
# </div>
# </td>
# </tr>
# </table>
# </div>

# %%
bs.find('div',id=True)
# Out:
# <div id="wrap">
# <!-- 광고적용 태그 추가 -->
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
# <li><span class="snb_bdr"></span><a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">스포츠</a></li>
# <li><span class="snb_bdr"></span><a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">날씨</a></li>
# <li><span class="snb_bdr"></span><a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">프리미엄</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_both">
# <div class="lnb_left">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li><a class="nclicks(lnb.pcmedia)" href="/"><span class="tx">언론사별</span> </a></li>
# <li class="on"><a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
# <li><a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a></li>
# <li><a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹</span> </a></li>
# <li><a class="nclicks(lnb.paper)" href="/newspaper/home"><span class="tx">신문보기</span> </a></li>
# <li><a class="nclicks(lnb.opi)" href="/opinion/home"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(lnb.fact)" href="/main/factcheck/main.naver"><span class="tx">팩트체크</span> </a></li>
# </ul>
# </div>
# </div>
# <div class="lnb_right">
# <div class="lnb_extra">
# <div class="lnb_extra_menu">
# <ul class="lnb_extra_menu_list">
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(STA.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb">
# <span class="lnb_date"><strong>05</strong>.<strong>01</strong><span class="day">(월)</span></span>
# <ul class="lnb_side" tabindex="0">
# <li><a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li><a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li><a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# <hr/>
# <table cellpadding="0" cellspacing="0" class="container">
# <caption class="blind">기사목록</caption>
# <colgroup>
# <col class="col_snb"/>
# <col class="col_content"/>
# <col class="col_aside"/>
# </colgroup>
# <tr>
# <td class="snb">
# <div class="snb" id="snb">
# <h2 class="h2"><a class="nclicks(lmn_pol.home)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100">정치</a></h2>
# <ul class="nav">
# <li><a class="snb_s11 nclicks(lmn_pol.mnl,,1)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=264">대통령실 </a></li>
# <li><a class="snb_s12 nclicks(lmn_pol.mnl,,2)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=265">국회/정당 </a></li>
# <li><a class="snb_s13 nclicks(lmn_pol.mnl,,3)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=268">북한 </a></li>
# <li><a class="snb_s14 nclicks(lmn_pol.mnl,,4)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=266">행정 </a></li>
# <li><a class="snb_s15 nclicks(lmn_pol.mnl,,5)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=267">국방/외교 </a></li>
# <li><a class="snb_s16 nclicks(lmn_pol.mnl,,6)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=269">정치일반 </a></li>
# </ul>
# <div class="snb_banner">
# <a class="nclicks(lmn_pol.pmb,,1)" href="https://media.naver.com/channel/setting?back=main"><img alt="언론사 구독하기" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/01/14/142956425_144518244_%2525B8%2525F0%2525B9%2525D9%2525C0%2525CF%2525B8%2525DE%2525C0%2525CE.png" width="71"/></a>
# </div>
# <div class="snb_banner">
# <a class="nclicks(lmn_pol.pmb,,1)" href="https://contents.premium.naver.com/"><img alt="네이버 프리미엄콘텐츠" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71"/></a>
# </div>
# </div>
# </td>
# <td class="content">
# <div class="content" id="main_content">
# <div class="list_body section_index">
# <div class="cluster">
# <div class="cluster_title">
# <span class="cluster_title_inner"><a class="cluster_title_icon_link _news_cluster_layer_btn" href="#biF7L"><i class="cluster_title_icon">안내</i>헤드라인 뉴스</a></span>
# <div class="cluster_title_layer _news_cluster_layer is_hidden">
# <div class="cluster_title_layer_text">
#                             헤드라인 뉴스와 각 기사묶음 타이틀은 <br/> 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.
#                         </div>
# <div class="cluster_title_layer_image"></div>
# <button class="cluster_title_layer_close _news_cluster_layer_close_btn" type="button">닫기</button>
# </div>
# </div>
# </div>
# <div class="_persist">
# <div class="cluster">
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011833312?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/05/01/11833312.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011833312?sid=100">윤재옥, 한미 핵협의그룹에 "자체 핵무장 보다 더 큰 이익"</a>
# <div class="cluster_text_lede">윤재옥 국민의힘 원내대표는 1일 한미가 합의한 핵협의그룹(NPG)에 대해 "자체 핵무장 보다 더 큰 이익이 될 것"이라고 주장했다. 윤 원내대표는 이날  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011833312',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news417,0000917299',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">머니S</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/417/0000917299?sid=100">윤재옥 "워싱턴 선언, 자체 핵무장보다 더 큰 이익"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news366,0000898058',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선비즈</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898058?sid=100">與 “워싱턴 선언, 업그레이드한 제2의 한미상호방위조약”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006779811',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779811?sid=100">윤재옥 "워싱턴 선언, 우리 자체 핵무장보다 더 큰 이익될 것"</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011000_00000009&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=003&amp;aid=0011833312"><span class="cluster_foot_more_icon_num">4</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269869?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/214/2023/05/01/1269869.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269869?sid=100">'설화' 김재원 "심려끼쳐 대단히 죄송"‥한 달만 최고위 복귀</a>
# <div class="cluster_text_lede">잇따른 설화로 논란을 일으킨 김재원 국민의힘 최고위원이 한 달 만에 당 최고위원회의에 참석해 다시한번 사과의 뜻을 밝혔습니다. 김 최고위원은 '5·18  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news214,0001269869',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">MBC</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news020,0003494719',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">동아일보</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/020/0003494719?sid=100">한 달 만에 모습 드러낸 김재원 “자진사퇴 생각해 보지 않아”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news008,0004881763',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">머니투데이</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/008/0004881763?sid=100">'자숙 끝' 김재원 "심려 끼쳐 대단히 죄송"…한달 만에 최고위 복귀</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news029,0002797932',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">디지털타임스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/029/0002797932?sid=100">與 윤리위 당일 최고위 복귀한 김재원 "죄송하다...열심히 하겠다"</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010930_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=214&amp;aid=0001269869"><span class="cluster_foot_more_icon_num">37</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269848?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/214/2023/05/01/1269848.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269848?sid=100">북한, 美전략핵잠 한반도 전개 '적법' 판단에 "황당무계한 궤변"</a>
# <div class="cluster_text_lede">북한은 오늘 한미 `워싱턴 선언`에 담긴 미국 전략 핵잠수함(SSBN)의 한국 기항은 법적으로 아무런 문제가 없다는 당국의 판단에 대해 "황당무계한 궤변 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news214,0001269848',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">MBC</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news437,0000341306',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">JTBC</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/437/0000341306?sid=100">북 "미 핵잠수함 한반도 전개...'법적 문제 없다'는 해괴한 주장"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879471',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879471?sid=100">北, 美 전략핵잠 전개 '적법' 판단에 "황당무계한 궤변"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news014,0005005160',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">파이낸셜뉴스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/014/0005005160?sid=100">美 전략핵잠수함 한반도 전개 '적법' 판단에 北 "황당무계한 궤변"</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010810_00000018&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=214&amp;aid=0001269848"><span class="cluster_foot_more_icon_num">14</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054473?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/055/2023/05/01/1054473.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054473?sid=100">김기현 "한미 관계 새 이정표 수립…비난만 하는 민주당 한심"</a>
# <div class="cluster_text_lede">국민의힘 김기현 대표는 윤석열 대통령이 이번 국빈 방미를 통해 "북핵 위협에 대한 대응, 자유민주주의 가치 동맹, 경제·산업 협력 확대 등 양국 관계에  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news055,0001054473',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">SBS</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004185255',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185255?sid=100">김기현 "尹방미, 북핵 위협 대응 등 韓-美 관계 새 이정표 수립"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news008,0004881770',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">머니투데이</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/008/0004881770?sid=100">與 "尹대통령 방미, 한미관계 새로운 이정표 수립 계기 마련"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013913728',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013913728?sid=100">김기현 "尹방미, 한미 양국관계 새 이정표 수립 최대 성과 거둬"</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010940_00000015&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=055&amp;aid=0001054473"><span class="cluster_foot_more_icon_num">17</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779742?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/421/2023/05/01/6779742.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779742?sid=100">尹 "바이든 부부, 국빈 만찬에 감사…다음엔 서울서 한식으로"</a>
# <div class="cluster_text_lede">미국 국빈 방문을 마치고 돌아온 윤석열 대통령은 1일 트위터를 통해 "아내도 조 바이든 미국 대통령과 질 바이든 여사에게 정말 많은 감사를 전하고 싶어  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006779742',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011833218?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/05/01/11833218.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011833218?sid=100">尹, 바이든 부부에게 트윗 글 "아내도 감사 전하고 싶어해"</a>
# <div class="cluster_text_lede">기사내용 요약 "인상적 만찬 준비해준 질 여사에 감사" "서울서 멋진 한식으로 보답하길 바라" [서울=뉴국빈 방미를 마치고 귀국한 윤석열 대통령은 1일  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011833218',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010810_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=421&amp;aid=0006779742"><span class="cluster_foot_more_icon_num">15</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269756?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/214/2023/04/30/1269756.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269756?sid=100">국민의힘 윤리위, 내일 첫 회의‥'김재원·태영호 중징계' 나오나</a>
# <div class="cluster_text_lede">국민의힘 중앙윤리위원회가 내일 오전 당사에서 첫 회의를 열고 새로 선임된 윤리위원들에게 임명장을 수여할 예정인 가운데, 잇단 설화로 물의를 빚은 김재원· …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news214,0001269756',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">MBC</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/079/0003765077?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/079/2023/05/01/3765077.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/079/0003765077?sid=100">野 돈봉투 의혹에 차별화 나선 與, 오늘 첫 윤리위가 시험대</a>
# <div class="cluster_text_lede">새로 구성된 국민의힘 윤리위원회가 1일 첫 회의를 열고 논란이 된 최고위원들의 발언에 대한 징계논의에 착수한다. 최근 국민의힘이 더불어민주당의 '돈봉투' …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news079,0003765077',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">노컷뉴스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304281030_00001855&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=214&amp;aid=0001269756"><span class="cluster_foot_more_icon_num">55</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269875?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/214/2023/05/01/1269875.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269875?sid=100">윤 대통령 지지율 1.9%p 오른 34.5%‥4주 만에 반등 [리얼미터]</a>
# <div class="cluster_text_lede">윤석열 대통령의 국정수행 지지도가 미국 국빈 방문과 맞물려 4주 만에 반등했다는 여론조사 결과가 나왔습니다. 리얼미터가 미디어트리뷴 의뢰로 지난달 24일 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news214,0001269875',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">MBC</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003761029?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/023/2023/05/01/3761029.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003761029?sid=100">‘워싱턴 선언’ 이끌어낸 尹, 지지율 4주 만에 반등해 34.5% [리얼미터]</a>
# <div class="cluster_text_lede">윤석열 대통령의 지지율이 4주 만에 반등한 여론조사 결과가 1일 나왔다. 한미 정상회담에서 북핵에 맞서기 위한 ‘워싱턴 선언’을 이끌어내는 등 방미 성과 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news023,0003761029',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선일보</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010810_00000002&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=214&amp;aid=0001269875"><span class="cluster_foot_more_icon_num">39</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011833587?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/05/01/11833587.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011833587?sid=100">尹 "진정한 노동약자 보호 위해 기득권 고용세습 뿌리 뽑을 것"</a>
# <div class="cluster_text_lede">기사내용 요약 "모든 국민이 자유롭게 일할 권리 보장" "글로벌 스탠더드 맞게 노동 유연화" [서울=뉴윤석열 대통령은 1일 '근로자의 날'을 맞아 "진정 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011833587',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185313?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/011/2023/05/01/4185313.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185313?sid=100">[속보]尹 “소수만 기득권 누리면 자유가 아니라 특권”…근로자의날 메시지</a>
# <div class="cluster_text_lede">윤석열 대통령이 1일 “소수만이 기득권을 누린다면 그것은 자유가 아니라 특권”이라고 말했다. 근로자의날을 맞아 ‘노동조합 기득권 타파’ 중심의 노동개혁을 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004185313',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011200_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=003&amp;aid=0011833587"><span class="cluster_foot_more_icon_num">8</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898021?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/366/2023/05/01/898021.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898021?sid=100">‘전당대회 돈 봉투 의혹’에 민형배·김홍걸 복당까지…민주당 내홍 심화</a>
# <div class="cluster_text_lede">민주당, 송영길 탈당에 “진행 상황 보고 대응” 비명계는“안도할 상황 아냐…꼬리자르기” 지적 민형배 복당에도 비명계 반발 “명분 없는 복당은 책임 면피” …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news366,0000898021',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선비즈</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779896?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/421/2023/05/01/6779896.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779896?sid=100">'복당' 민형배 "이지메 세게 당한 느낌…반대파, 늘 그래온 사람들"</a>
# <div class="cluster_text_lede">민형배 더불어민주당 의원은 1일 복당 소회에 대해 "'이지메'(집단 따돌림을 의미하는 일본어)를 세게 당한 느낌"이라고 밝혔다. 민 의원은 이날 오전 Y …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006779896',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011100_00000060&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=366&amp;aid=0000898021"><span class="cluster_foot_more_icon_num">5</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013913556?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2023/05/01/13913556.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013913556?sid=100">이종섭 "워싱턴선언, 제2한미상호방위조약…억제력 획기적 향상"</a>
# <div class="cluster_text_lede">언론사 기고…"전술핵 재배치·자체핵무장 초래할 파장 고려해야" "한미동맹 기반한 '힘에 의한 평화' 필요…우리 군 3축체계 강화" 이종섭 국방부 장관은  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013913556',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054275?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/055/2023/04/30/1054275.jpg?type=ofullfill132_90" width="132"/>
# <strong class="r_ico r_vod_medium">동영상기사</strong>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054275?sid=100">"워싱턴 선언, 핵 포함 상호방위 업그레이드"</a>
# <div class="cluster_text_lede">한미 정상이 발표한 워싱턴 선언 관련, 사실상 핵공유다, 아니다, 논란이 많습니다. 방미 중에 윤석열 대통령이 직접 입장을 밝혔습니다. 워싱턴 선언은 핵 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news055,0001054275',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">SBS</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304290630_00000003&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0013913556"><span class="cluster_foot_more_icon_num">9</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002137436?sid=100">‘워싱턴 선언’ 최대 성과...중·러 ‘강한 반발’ 부담</a>
# <div class="cluster_text_lede">윤석열 대통령의 5박7일 미국 국빈방문 최대 성과로는 무엇보다 ‘워싱턴 선언’이 꼽힌다. 고도화하는 북한의 핵·미사일 위협에 맞서 대북 확장억제(핵우산)를 획기적으로 강화하고 한미 간 안보 협력 수준을 대폭 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news016,0002137436',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">헤럴드경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898009?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/366/2023/04/30/898009.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898009?sid=100">대통령실 “핵 포함한 개념으로 한미상호방위조약 개선”</a>
# <div class="cluster_text_lede">대통령실은 윤석열 대통령의 국빈 방미 성과와 관련해 “한미상호방위조약을 핵이 포함된 상호방위 개념으로 업그레이드했다”고 말했다. 30일 대통령실은 이날  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news366,0000898009',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선비즈</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304280010_00001014&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=016&amp;aid=0002137436"><span class="cluster_foot_more_icon_num">22</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879562?sid=100">與 박대출 "방송법 통과하면, 대통령이 거부권 행사해야"</a>
# <div class="cluster_text_lede">국민의힘 박대출 정책위의장은 더불어민주당 주도로 국회 본회의에 직회부된 공영방송 지배구조 개편을 위한 방송법 개정안 등과 관련해, 법안이 국회를 통과하면 대통령은 거부권, 재의요구권을 행사해야 마땅할 것이라 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879562',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/030/0003095264?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/030/2023/04/30/3095264.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/030/0003095264?sid=100">방송법, 5월 정국 뇌관으로…여야 '평행선' 속 거부권 행사 초미 관심[스페셜리포트]</a>
# <div class="cluster_text_lede">공영방송 지배구조를 바꾸는 내용의 방송3법(방송법·방송문화진흥회법·한국교육방송공사법) 개정안이 국회 본회의에 부의됐다. 부의는 본회의에서 안건 심의가 가 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news030,0003095264',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">전자신문</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304300910_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=052&amp;aid=0001879562"><span class="cluster_foot_more_icon_num">11</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011475913?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/056/2023/05/01/11475913.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011475913?sid=100">북 매체, 중러 ‘워싱턴선언’ 비판 조명…“부정적 후과 우려”</a>
# <div class="cluster_text_lede">북한이 한국과 미국 정상이 합의한 ‘워싱턴선언’을 두고 중국과 러시아 등 주요 우방국에서 내놓는 비판 목소리에 힘을 실으며 여론전에 나섰습니다. 조선중앙 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news056,0011475913',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">KBS</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/002/0002284321?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/002/2023/05/01/2284321.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/002/0002284321?sid=100">북한 "워싱턴 선언 부정적 후과"…중·러 반발 집중 조명</a>
# <div class="cluster_text_lede">'한미일' 공조 강화에 '북중러' 연대 맞불 한국과 미국이 북핵 위협 대응 방안으로 합의한 '워싱턴 선언'에 대해 북한이 1일 강하게 반발했다. 북한 관 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news002,0002284321',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">프레시안</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010800_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=056&amp;aid=0011475913"><span class="cluster_foot_more_icon_num">8</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/005/0001605144?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/005/2023/05/01/1605144.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/005/0001605144?sid=100">‘서지니형’ 왜 여기에?…尹대통령 “어떻게 오셨냐”</a>
# <div class="cluster_text_lede">미국을 국빈 방문한 윤석열 대통령이 세계적인 영상 콘텐츠 기업들을 한자리에서 만나 K-콘텐츠 수출 확대를 논의한 자리에 배우 이서진이 등장해 화제가 되고 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news005,0001605144',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">국민일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185080?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/011/2023/04/30/4185080.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185080?sid=100">‘서지니형’ 왜 거기서 나와?…尹 대통령 "어떻게 오셨냐"</a>
# <div class="cluster_text_lede">미국을 국빈 방문한 윤석열 대통령이 세계적인 영상 콘텐츠 기업들을 만나 K-콘텐츠 수출 확대를 논의한 자리에 자리에 배우 이서진이 모습을 보였다. 윤 대 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004185080',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304280850_00000028&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=005&amp;aid=0001605144"><span class="cluster_foot_more_icon_num">8</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054471?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/055/2023/05/01/1054471.jpg?type=ofullfill132_90" width="132"/>
# <strong class="r_ico r_vod_medium">동영상기사</strong>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054471?sid=100"> 박용진 "尹 성과 부풀리다…대한민국 '핵 공유 호소인' 전락"[정치쇼]</a>
# <div class="cluster_text_lede">- 尹 고생했지만 안보는 불안 경제는 거덜 - 불필요한 중-러 자극, 외나무다리 위 운명 - 대한민국 핵 공유 호소인으로 전락…국제망신 - 美, 반도체  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news055,0001054471',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">SBS</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277005?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/025/2023/05/01/3277005.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277005?sid=100">박용진 “이재명, ‘돈 봉투’ 의혹 쇄신의 칼 쥐고 답 내놔야”</a>
# <div class="cluster_text_lede">박용진 더불어민주당 의원은 1일 지난 2021년 민주당 전당대회에서 불법 정치자금이 오고갔다는 ‘돈봉투 의혹’에 대해 “이재명 대표가 책임있게 쇄신의 칼 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news025,0003277005',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">중앙일보</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011000_00000104&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=055&amp;aid=0001054471"><span class="cluster_foot_more_icon_num">6</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/079/0003764965?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/079/2023/04/30/3764965.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/079/0003764965?sid=100">SSBN 부산에 기항…'비핵화 선언'과 모순 아니라고?[안보열전]</a>
# <div class="cluster_text_lede">편집자 주 튼튼한 안보가 평화를 뒷받침합니다. 밤낮없이 우리의 일상을 지키는 이들의 이야기를 전해드립니다. 치열한 현장(熱戰)의 이야기를 역사에 남기고( …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news079,0003764965',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">노컷뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003760896?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/023/2023/04/30/3760896.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003760896?sid=100">히로시마 원폭 1600배… 워싱턴선언에 등장한 美핵보복 핵잠 위력</a>
# <div class="cluster_text_lede">한국에 올 미 오하이오급 핵보복 전략잠수함 윤석열 대통령과 조 바이든 미국 대통령이 지난 26일(현지시간) ‘워싱턴 선언’에서 미 전략 핵잠수함(SSBN …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news023,0003760896',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선일보</div>
# </div>
# </div>
# </li>
# </ul>
# ...
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=657"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/657/2022/01/19/logo_657_56_20220119135625.png" width="16"/></span>대구MBC</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/658/0000039685?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/658/2023/05/01/39685.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/658/0000039685?ntype=RANKING&amp;sid=001">'부채 52조 원' 가스공사, 자사 임원에겐 '연봉 30% …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=658"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/658/2022/01/20/logo_658_56_20220120164828.png" width="16"/></span>국제신문</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/656/0000049672?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/656/2023/05/01/49672.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/656/0000049672?ntype=RANKING&amp;sid=001">"더는 못 참겠다"… 박은빈 드라마 촬영장에 벽돌 투척한  …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=656"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/656/2022/01/19/logo_656_56_20220119134936.png" width="16"/></span>대전일보</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/659/0000011136?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/659/2023/05/01/11136.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/659/0000011136?ntype=RANKING&amp;sid=001">"부모 대부분 자녀들 마약 범죄 몰라".. 용돈으로 사고, …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=659"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/659/2022/01/19/logo_659_56_20220119141438.png" width="16"/></span>전주MBC</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <ul class="section_list_ranking_press _rankingList" id="_rankingList75" style="display: none">
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/659/0000011136?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/659/2023/05/01/11136.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/659/0000011136?ntype=RANKING&amp;sid=001">"부모 대부분 자녀들 마약 범죄 몰라".. 용돈으로 사고, …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=659"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/659/2022/01/19/logo_659_56_20220119141438.png" width="16"/></span>전주MBC</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/661/0000024311?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/661/2023/05/01/24311.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/661/0000024311?ntype=RANKING&amp;sid=001">유급휴일 '근로자의 날'.."직장인 10명 중 3명  출근 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=661"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/661/2022/01/19/logo_661_56_20220119142145.png" width="16"/></span>JIBS</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/666/0000010111?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/666/2023/05/01/10111.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/666/0000010111?ntype=RANKING&amp;sid=001">안성 양성면 물류창고서 화재…60대 직원 1명 연기흡입·  …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=666"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/666/2023/01/03/logo_666_56_20230103174615.png" width="16"/></span>경기일보</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/665/0000000882?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/665/2023/05/01/882.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/665/0000000882?ntype=RANKING&amp;sid=001">리버버스 김포~여의도 20분? 실제론 1시간 28분 [視리 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=665"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/665/2022/12/08/logo_665_56_20221208184224.png" width="16"/></span>더스쿠프</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018624?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/145/2023/05/01/18624.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018624?ntype=RANKING&amp;sid=001">적금 탔더니 그 돈으로 병원을 가네···5월 별자리 운세</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=145"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/145/2020/12/09/logo_145_56_20201209180915.png" width="16"/></span>레이디경향</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <button class="refresh_button nclicks('rig.renws2new') _refreshButton" type="button">더보기</button>
# </div>
# <script type="text/javascript">
#     var OfficeTopRankingManager = jindo.$Class({
#         $static: {
#             RANKING_INFO_BUTTON_SELECTOR: '._rankingInfoButton',
#             RANKING_INFO_LAYER_SELECTOR : '._rankingInfoLayer',
#             RANKING_INFO_BUTTON_CLOSE_SELECTOR : '._rankingInfoCloseButton',
#             REFRESH_BUTTON_SELECTOR : '._refreshButton',
#             RANKING_LIST_SELECTOR : '._rankingList'
#         },
#
#         $init: function(base) {
#             this._welBase = jindo.$Element(base);
#             this._rankingInfoLayer = jindo.$Element(this._welBase.query(this.constructor.RANKING_INFO_LAYER_SELECTOR));
#             this._rankingListArray = jindo.$ElementList(this._welBase.queryAll(this.constructor.RANKING_LIST_SELECTOR));
#
#             this._initEvent();
#         },
#
#         _initEvent: function() {
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_SELECTOR, jindo.$Fn(this._showRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_CLOSE_SELECTOR, jindo.$Fn(this._closeRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.REFRESH_BUTTON_SELECTOR, jindo.$Fn(this._refreshRankingList, this).bind());
#         },
#
#         _showRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.toggle();
#         },
#
#         _closeRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.hide();
#         },
#
#         _refreshRankingList: function(event) {
#             event.stopDefault();
#
#             for (var i=0 ; i<this._rankingListArray.length() ; i++) {
#                 var rankingList = this._rankingListArray.get(i);
#
#                 if (rankingList.visible() === true) {
#                     var nextIndex = i + 1;
#
#                     if (nextIndex === this._rankingListArray.length()) {
#                         nextIndex = 0;
#                     }
#
#                     var nextRankingList = this._rankingListArray.get(nextIndex);
#
#                     rankingList.hide();
#                     nextRankingList.show();
#
#                     break;
#                 }
#             }
#         }
#     });
#
#     window.addEventListener("load", function() {
#         var officeTopRanking = jindo.$$.getSingle("._officeTopRanking1087473");
#         if (officeTopRanking) {
#             new OfficeTopRankingManager(officeTopRanking);
#         }
#     });
# </script>
# <div class="side_ad" id="glad_ad_sidebox"></div>
# <div class="section" id="right_dailyList" style="margin-bottom:20px; white-space:nowrap;">
# <h4>분야별 주요뉴스</h4>
# <div class="classfy sd" style="display:block">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/001/0013913824?sid=100" title="'설화' 김재원 최고위 복귀…'자진사퇴'엔 &quot;아직 생각 안해봐&quot;(종합)">'설화' 김재원 최고위 복귀…'자진사퇴'엔 "아직 생각 안해봐"(종합)</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/056/0011476101?sid=100" title="[속보] 국민의힘 윤리위, 김재원 태영호 ‘징계 개시’ 결정">[속보] 국민의힘 윤리위, 김재원 태영호 ‘징계 개시’ 결정</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/448/0000407097?sid=100" title="尹대통령 긍정평가 34.5%…4주 만에 소폭 반등">尹대통령 긍정평가 34.5%…4주 만에 소폭 반등</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/022/0003808132?sid=104" title="대만 “유일한 남미 친구 지켰다”…파라과이 대선 결과에 ‘일단’ 안도">대만 “유일한 남미 친구 지켰다”…파라과이 대선 결과에 ‘일단’ 안도</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/079/0003765162?sid=104" title='"한국, 양육비 가장 비싼 나라"…1인당 GDP의 7.7배'>"한국, 양육비 가장 비싼 나라"…1인당 GDP의 7.7배</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/001/0013914034?sid=101" title="'41% 급감' 반도체에 수출 7개월째 감소…무역적자 14개월 연속(종합2보)">'41% 급감' 반도체에 수출 7개월째 감소…무역적자 14개월 연속(종합2보)</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/366/0000898085?sid=101" title="금감원 “올해 공매도 규모 급증… 무차입 공매도 33건 제재 조치 완료”">금감원 “올해 공매도 규모 급증… 무차입 공매도 33건 제재 조치 완료”</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/421/0006778342?sid=101" title="[단독]신림·상도·봉천·대방 200여채 보증금 미반환 위기…살던 집은 경매로">[단독]신림·상도·봉천·대방 200여채 보증금 미반환 위기…살던 집은 경매로</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/138/0002147587?sid=105" title="‘중간요금제’ 속속 출격…LTE→5G 전환 이끌어낼까">‘중간요금제’ 속속 출격…LTE→5G 전환 이끌어낼까</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/011/0004185262?sid=105" title="'노태북 열풍 이어갈까'…삼성, 인텔 13세대 기반 PC 3종 출시">'노태북 열풍 이어갈까'…삼성, 인텔 13세대 기반 PC 3종 출시</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/052/0001879553?sid=102" title='송영길 측 "내일 검찰 자진 출석"...與 "상습 탈선"'>송영길 측 "내일 검찰 자진 출석"...與 "상습 탈선"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/079/0003765120?sid=102" title="'강남 투신' 10대 만났던 20대 남성 입건…자살방조죄 적용">'강남 투신' 10대 만났던 20대 남성 입건…자살방조죄 적용</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/022/0003808125?sid=102" title="영양교사가 검수한 식재료에 개구리 사체… 법원 “급식업체도 책임”">영양교사가 검수한 식재료에 개구리 사체… 법원 “급식업체도 책임”</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/079/0003765164?sid=103" title="4일부터 국립공원 사찰 등 문화재 관람료 무료">4일부터 국립공원 사찰 등 문화재 관람료 무료</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/079/0003765171?sid=103" title="현대차, '대한민국 동행축제' 연계 최대 5% 할인 프로모션">현대차, '대한민국 동행축제' 연계 최대 5% 할인 프로모션</a> </li>
# </ul>
# </ul>
# </ul>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://media.naver.com/channel/settings"> <img alt="네이버 메인에서 바로 보는 언론사 편집뉴스 지금 바로 구독해보세요!" src="https://imgnews.pstatic.net/image/upload/item/2018/11/27/174854048_PC_%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA_%25B1%25B8%25B5%25B6%25C8%25B0%25BC%25BA%25C8%25AD.png" width="300"/> </a>
# </div>
# </div>
# <div class="section">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/assembly/index.naver" target="_blank"> <img alt="내일을 여는 국민의 국회" border="0" class="banner" height="60" src="https://imgnews.pstatic.net/image/upload/item/2021/01/08/173235779_%25B1%25B9%25C8%25B8%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA.png" width="300"/> </a>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" target="_blank"> <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/183951086_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300"/> </a>
# </div>
# </div>
# <div class="section">
# <h4> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"> 서비스 안내 </a> </h4>
# <ul class="list_txt">
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb"> 고침 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb"> 정정·반론·추후 보도 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb"> 불공정 선거 보도 기사 모음 </a> </li>
# </ul>
# <a class="more_link nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"><span class="blind">서비스 안내</span>더보기</a>
# </div>
# <script>
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#
#         adSlot.setCustomParam("calp", 'shome');
#         window.gladsdk.displayAd(adSlot);
#     });
# </script>
# </div>
# </td>
# </tr>
# </table>
# </div>

# %%
bs.find('div', id='header')
# Out:
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
# <li><span class="snb_bdr"></span><a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">스포츠</a></li>
# <li><span class="snb_bdr"></span><a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">날씨</a></li>
# <li><span class="snb_bdr"></span><a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">프리미엄</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_both">
# <div class="lnb_left">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li><a class="nclicks(lnb.pcmedia)" href="/"><span class="tx">언론사별</span> </a></li>
# <li class="on"><a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
# <li><a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a></li>
# <li><a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹</span> </a></li>
# <li><a class="nclicks(lnb.paper)" href="/newspaper/home"><span class="tx">신문보기</span> </a></li>
# <li><a class="nclicks(lnb.opi)" href="/opinion/home"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(lnb.fact)" href="/main/factcheck/main.naver"><span class="tx">팩트체크</span> </a></li>
# </ul>
# </div>
# </div>
# <div class="lnb_right">
# <div class="lnb_extra">
# <div class="lnb_extra_menu">
# <ul class="lnb_extra_menu_list">
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(STA.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb">
# <span class="lnb_date"><strong>05</strong>.<strong>01</strong><span class="day">(월)</span></span>
# <ul class="lnb_side" tabindex="0">
# <li><a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li><a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li><a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>

# %%
bs.div.find("a",href=True).get_text()
# Out:
# '메인 메뉴로 바로가기'

# %%
bs.select_one("[tabindex = '1']").text
# Out:
# '메인 메뉴로 바로가기'

# %%
bs.find('div',id=True).find('a').text
# Out:
# '메인 메뉴로 바로가기'

# %%
lists = bs.find('div',id=True).find_all('a')
for i in lists:
    print(i.text)
# Out:
# 메인 메뉴로 바로가기
# 본문으로 바로가기
# 검색
# NAVER
# 뉴스
# TV연예
# 스포츠
# 날씨
# 프리미엄
# 언론사별
# 정치 선택됨
# 경제
# 사회
# 생활/문화
# IT/과학
# 세계
# 랭킹
# 신문보기
# 오피니언
# TV
# 팩트체크
# 전체 언론사
# 뉴스스탠드
# 라이브러리
# 전체 언론사
# 뉴스스탠드
# 라이브러리
# 정치
# 대통령실
# 국회/정당
# 북한
# 행정
# 국방/외교
# 정치일반
#
#
# 안내헤드라인 뉴스
#
#
#
# 김기현, '음주운전 방지 장치 부착 의무화' 법안 내일 대표 발의
# '후~' 불어야 시동…김기현 '음주운전 방지장치' 법안 내일 발의
# 3번째 음주운전…중앙선 넘어 트럭 들이받았지만 '집행유예'
# '스쿨존 음주운전' 엄벌…"안전시설 설치부터"
# 40개의 관련뉴스 더보기
#
#
#
# 민주당 "尹대통령 방미, 대국민 사기 외교"
# 민주당 “尹 방미, 대국민 사기 외교…텅빈 쇼핑백”
# 민주 "尹 방미, '빈손' 넘어 '사기' 외교…경제 사안 해결 없어"
# "무한·영원한 번영" "텅 빈 쇼핑백"‥여야, 국빈방미 극과극 평가
# 24개의 관련뉴스 더보기
#
#
#
# 한·미정상회담 끝나자 ‘비싼대가 치를 것’ 위협한 북한, 군사 행동 수위 높이나?
# 北, ‘워싱턴 선언’에 핵 선제타격 위협…대형도발 강행하나
# 北, 연일 ‘워싱턴 선언’ 비난하며 도발 명분 쌓기…“군사억제력 강화 당연”
# 北김여정, 한미 비난하며 '결정적 행동' 위협…도발 명분쌓기
# 8개의 관련뉴스 더보기
#
#
#
# 민주당 "있지도 않은 핵공유 말 지어내" 정부·여당 비판한 이유는?
# 민주 “핵 공유? 대국민 사기극…아전인수식 정신 승리”
# 민주당, '사실상 핵 공유'에 "대통령실·與, 정신승리 끈 놓지 못해"
# 민주, '사실상 핵공유' 논란에 "대국민 사기극…정신승리 하자는 것"
# 31개의 관련뉴스 더보기
#
#
#
# 김여정, '정권종말' 바이든에 "미래없는 늙은이의 망언"
#
#
#
# [속보] 北김여정, 바이든 ‘정권 종말’ 발언에 “늙은이의 망언, 쉽게 넘길 수 없다”
# 85개의 관련뉴스 더보기
#
#
# 동영상기사
#
# '방미' 윤대통령, MIT 석학 만나…'디지털 바이오' 논의
#
#
#
# MIT 찾은 尹 대통령 “한국 과학기술 인력들, 보스턴 보내 배우게 할 것”
# 17개의 관련뉴스 더보기
#
#
#
# 이영, 보스턴서 '클러스터 협력안' 논의…MOU 4건 체결
#
#
#
#  보스턴 클러스터 업계 한자리에…尹 "핵심은 자본투자"(종합2보)[尹국빈방미]
# 23개의 관련뉴스 더보기
#
#
#
# 이서진이 왜 거기서 나와?…尹 대통령 "어떻게 오셨냐"
#
#
#
# 尹, 보자마자 "어떻게 오셨냐"…美국빈행사 나타난 이서진 왜
# 8개의 관련뉴스 더보기
#
#
#
# '민형배 복당' 與野 모두 비판? 속사정 들여다보니
#
#
#
# ‘꼼수 탈당 1년 민형배’…'검수완박’ 등 안조위 무력화만 두 번, 與 대책은?
# 4개의 관련뉴스 더보기
#
#
#
# 보훈처장, 美필라델피아 리틀극장 방문…'제1차 한인회의' 재현
# 박민식 보훈처장, 미국서 태극기 들고 '제1차 한인회의' 재현
# 6개의 관련뉴스 더보기
#
#
# 동영상기사
#
# 윤 대통령, 미국 국빈 방문 마치고 귀국길
#
#
#
# 尹대통령, 5박7일 '국빈 방미' 마치고 귀국길…오늘 오후 도착
# 56개의 관련뉴스 더보기
#
#
#
# 北, 연일 '워싱턴 선언' 비판…"반드시 비싼 대가 치를 것"
#
#
#
# 북한 "한미 핵전쟁 책동…상응한 군사적 억제력 키울 것"
# 24개의 관련뉴스 더보기
#
#
#
# 尹, 하버드 대담서 “워싱턴선언, 나토 다자약정보다 실효성 있다”
#
#
#
# "재학생이라면 A학점"…하버드대 교수 웃게 한 尹 답변 보니
# 13개의 관련뉴스 더보기
#
#
# 동영상기사
#
#  윤대통령 하버드대 연설…'자유 향한 여정' 주제[현장연결]
#
#
#
# 尹, 하버드서 “힘에 의한 현상 변경, 결연한 연대로 대응해야”
# 49개의 관련뉴스 더보기
#
#
#
# 홍준표 "전광훈, 급기야 대통령실 물고들어가…미적거리지 말고 끊어라"
#
#
#
# 홍준표 "`하나님도 나한테 맞는다`는 전광훈…목사인가"
# 23개의 관련뉴스 더보기
#
#
# 동영상기사
#
# 민주 새 원내대표 ‘비명’ 박광온…“이기는 통합의 길”
#
#
#
# 압도적 표 얻었지만...‘개딸’은 불신하는 박광온?
# 19개의 관련뉴스 더보기
# 헤드라인 더보기
#
# 연재보기
# 세종만사(世宗萬事)
#
#
#
#
# [세종만사]추경호 부총리, 15년만에 G7재무장관회의 참석
# [세종만사]블랙홀 된 전기·가스요금, 에너지정책 '진통'
# [세종만사]호흡곤란 '김포골드라인' 원-오 회동에도 산너머 산
# [세종만사]누리호 3차 발사 초읽기에 들어간 과기정통부
#
#
#
# 동영상기사
#
# 北 "반드시 비싼 대가 치를 것...군사적 억제력 강화"
# YTN
#
#
#
# [단독] 중학 교사 “2찍남은 멍청, 尹 술마시며 일해”. …
# 조선일보
#
#
#
# 40도 폭염에 말 죽고…바다 온도 관측 이래 최고
# KBS
#
#
#
# “가수 송민호도 타보더니 감탄” 한국인이 가장 많이 사는  …
# 헤럴드경제
#
#
#
# 남자친구와 타이완 여행 30대 숨진 채 발견…경찰, 타살  …
# SBS
#
#
#
# 과외누나 남자친구 살해한 고교생..신촌대학생 살인사건[그해 …
# 이데일리
#
#
#
# 미 언론 “한국 청년들은 ‘아메리칸 파이’보다 일자리 부족 …
# 한겨레
#
#
#
# "부끄럽지 않나" 비난에도... 11개월 '주부'가 된 남 …
# 오마이뉴스
#
#
#
# "벨라루스 국민은 러시아의 우크라 침공에 단호히 반대"
# 시사저널
#
#
#
# 역대급 카메라라던 ‘갤럭시S23 울트라’… 성능 평가는 중 …
# 조선비즈
#
#
#
# “손자가 성폭행을 했습니다”...피해자는 극단선택, 가해자 …
# 매일경제
#
#
#
# [단독] "빛·소음 때문에 짜증"…드라마 촬영장에 벽돌 투 …
# TV조선
#
#
#
# 사상 초유 '4연속 하한가'…1주일새 시총 '8조' 증발  …
# 서울경제
#
#
#
# [단독] 정부, 6월 로또 추첨장에 참관 원하는 국민 전원 …
# 국민일보
#
#
#
# 여신도 나체 석고상이라니…JMS 엽기행각 충격
# 아시아경제
#
#
#
# “납득 안 되는 딸의 죽음…왜 잊으라고만 하나요”
# 경향신문
#
#
# 동영상기사
#
# 호랑이 마주친 사슴처럼 '펄쩍'‥나흘간 잠복한 결과는?
# MBC
#
#
#
# 대만 호텔서 숨진채 발견된 30대 한국 여성.. 남자친구  …
# 파이낸셜뉴스
#
#
#
# 다큐 '문재인입니다' 첫 상영…"5년 성취 허망" 발언 빠 …
# 매일신문
#
#
#
# 소름, 전화기 넘어 그 목소리 분명 내 딸이었는데...[누 …
# 뉴시스
#
#
#
# 한효주, BTS, 성훈 트레이너가 무일푼에서 논현동 헬스장 …
# 동아일보
#
#
#
# '강남 1시간 거리'도 안통한다…광교·의정부 아파트값 40 …
# 머니투데이
#
#
#
# 샴푸 떨어졌다... 바디워시로 머리 감으면 어떻게 될까?
# 헬스조선
#
#
#
# 임창정도 당한 '주가조작', 한탕이면 46억 원 챙겨
# 한국일보
#
#
#
# 이용식 "바로 윗선배 오니 활짝 웃네"…서세원에 마지막 인 …
# 중앙일보
#
#
# 동영상기사
#
# 폭락 사태 늑장대응…커지는 금융당국 책임론
# 연합뉴스TV
#
#
#
# "4인 가족 삼겹살 외식하면 10만원"…가정의 달 앞두고  …
# JTBC
#
#
#
# 故서세원, 현지 화장 뒤 국내서 장례식…유족 “억측·루머  …
# 서울신문
#
#
#
# 45초 행사가 12분으로…한미정상 부부에 감동전한 한인 아 …
# 연합뉴스
#
#
#
# 쉰 목소리에 검사했다가 '깜짝'…이혜영 "2주간 말 못 해 …
# 한국경제
#
#
#
# 230년 된 조각상에 파란 낙서가...英 박물관에 무슨 일 …
# MBN
#
#
#
# 윤석열 대통령, 5박 7일 미국 국빈방문 마치고 귀국
# kbc광주방송
#
#
#
# 직장인 괴롭히는 '3대 갑질'은? 1위는 '직장 내 괴롭힘 …
# 노컷뉴스
#
#
#
# [알고보니] 청첩장 다 돌렸는데 갑작스레 파혼 통보…법적  …
# 뉴스1
#
#
#
# 황금연휴 여기 모르면 '낭패'…서울 곳곳이 '대변신'
# 한국경제TV
#
#
#
# 故 서세원 유해, 사망 열흘 만에 고국으로…한국서 장례식  …
# 부산일보
#
#
#
# 이창양 장관, 현대차그룹 로봇 개발 거점 '보스턴 다이내믹 …
# 데일리안
#
#
#
# 간호법 지지 나선 한의사협회 “의사들 파업하면 우리가 공백 …
# 세계일보
#
#
#
# “바이든, 尹과 듀엣하려 했다” 박지원 비난에 대통령실 “ …
# 문화일보
#
#
#
# 민주당 “尹 방미, 대국민 사기 외교…텅빈 쇼핑백”
# 채널A
#
#
#
# 1억5천만 원짜리 '바나나 작품'  먹어 치운 서울대생.. …
# 디지털데일리
#
#
#
# 트위터 기사 건당 요금낸다...머스크 "월 구독 과금체계  …
# ZDNet Korea
#
#
#
# '지금 아니면 영원히 내 집 없다'…이젠 30대가 '큰 손 …
# SBS Biz
#
#
#
# ‘죽음’에 대해 말하자 ‘자살’ 단어 내민 챗봇 [평범한  …
# 시사IN
#
#
#
# 애플페이 질주에 낙동강 오리알 된 오픈페이
# 전자신문
#
#
#
# [세금줍줍] 법인차량을 직원들이 썼는데요
# 비즈워치
#
#
#
# 대만여행 간 30대 한국 여성 숨져…동행한 남자친구 혐의  …
# 디지털타임스
#
#
#
# [속보]윤 대통령, 5박 7일 미국 국빈 방문 마치고 귀국
# 강원일보
#
#
#
# "검사 때 해외연수?" 尹 영어연설 띄우기 진심이었던 언론 …
# 미디어오늘
#
#
#
# 저는 SKY, 사수는 그냥 ‘인서울’...학벌 알고 나니  …
# 매경이코노미
#
#
#
# 박지원 "바보 대통령실? 尹이 한소절 더 안했으면 바이든이 …
# 프레시안
#
#
#
# 30대 퇴직금 평균 1180만원…50대가 퇴직금 '최고'
# 아이뉴스24
#
#
#
# 민주 "尹 방미, 빈손 외교 넘어 대국민 사기 외교...냉 …
# 강원도민일보
#
#
#
# [One with Nature] Immerse yourse …
# 코리아헤럴드
#
#
#
# “정치는 직업 아닌 소명…” 송영길 발언이 위험한 이유
# 한겨레21
#
#
#
# 은행권 정기예금 금리 최고 연 3.75%...저축은행 최고 …
# 조세일보
#
#
#
# ‘1억짜리 바나나’ 먹어치운 서울대생,  리움미술관이 용서 …
# 이코노미스트
#
#
#
# 로또 1065회 당첨번호 1등 18억, '이거 실화? 또  …
# 더팩트
#
#
#
# "김건희가 대통령이냐" 방명록 논란…김정숙, 김혜경은 어땠 …
# 주간조선
#
#
#
# “윤석열은 큰 그릇, 이익 위해 남 희생시키지 않아” [+ …
# 신동아
#
#
#
# "尹 대통령 방미만으로 증시 훈풍 글쎄…없는 것보단 나아"
# 블로터
#
#
#
# “세금으로 백신 만들어 놓곤…” 모더나 CEO 스톡옵션으로 …
# 국제신문
#
#
#
# [CEO포커스]스마게 권혁빈, 세기의 이혼… 5조원대 재산 …
# 머니S
#
#
#
# 어디 '학폭' 뿐이랴.. '직장내 괴롭힘'에 신고조차 못해 …
# JIBS
#
#
#
# ‘탈레반 리튬’ 잡아라! 아프간 1300조 리튬 눈독 들이 …
# 주간동아
#
#
#
# 체중 줄이고 혈당 천천히 낮게 올리는 음식은?
# 코메디닷컴
#
#
#
# Gaming in Korea is a real career …
# 코리아중앙데일리
#
#
#
# "간식에서 화장품 맛나요".. 거짓 구매 후기 쓴 주부 ' …
# 전주MBC
#
#
#
# HD한국조선해양, 유럽서 220억 투자…차세대 기술 선점
# 한경비즈니스
#
#
#
# 꿀 먹으며 꽃가루 옮겨…꽃과 상부상조하는 초식 개구리
# 동아사이언스
#
#
#
# 야외활동 후 ‘사마귀’가 생겼다면? ‘이것’ 주의
# 농민신문
#
#
#
# 다큐 '문재인입니다', 전주국제영화제서 첫 공개
# 대전일보
#
#
#
# 네이버 뉴스서 'URL·QR코드·언론사사이트' 이동 가능해 …
# 기자협회보
#
#
#
# “순둥이 아들의 찢어진 셔츠…죽음에 대한 예의도 없었다”
# 주간경향
#
#
#
# 30대 다문화여성 4살 아들 살해하고 경찰에 자수
# CJB청주방송
#
#
#
# [만나보니] 국가인권위원회가 제시하는 이슬람 사원 갈등 해 …
# 대구MBC
#
#
#
# 성별에 대해 우리가 갖는 ‘두려움’
# 일다
#
#
#
# 토핑 추가하면 4만원… 외면받는 金피자 [인포로 본 세상]
# 더스쿠프
#
#
#
# “물극필반 아닌 사필귀정”... 與, 송영길 전 대표 비판
# 경기일보
#
#
#
# 4년 만에 만나는 황매산 철쭉
# 중앙SUNDAY
#
#
#
# 성별에 대해 우리가 갖는 ‘두려움’
# 일다
#
#
#
# 토핑 추가하면 4만원… 외면받는 金피자 [인포로 본 세상]
# 더스쿠프
#
#
#
# “물극필반 아닌 사필귀정”... 與, 송영길 전 대표 비판
# 경기일보
#
#
#
# 4년 만에 만나는 황매산 철쭉
# 중앙SUNDAY
#
#
#
# ‘당근 마니아’ 모여! ‘영양 빵빵 접는 김밥’[주말&]
# 레이디경향
# [뉴스1 PICK]윤석열 대통령, 미국 국빈 방문 마치고 귀국
# 엇갈린 '방미 성과' 평가... "사기 외교" vs. "프랑스와 동급"
# 이재명 "박광온과 '총선승리' 역사적 소명…우리 안 차이 안 커"
# "日기시다, 5월 7∼8일 방한"...尹 '결단' 답례로 '선물' 내놓을까
# 대만 호텔방서 무슨 일이… 한국인 여성, 숨진 채 발견
# 이창양 장관, 현대차그룹 로봇 개발 거점 '보스턴 다이내믹스' 방문
# 정의선·박재욱·노홍철…한국판 '버핏과의 점심' 첫 타자로
# 尹대통령, 안보·경제 두마리 토끼 받았다[국빈방문 결산]
# 구글·MS에 다 빼앗길라.. 정부, AI 학습용 데이터 대거 개방
# 울산과기원, “AI-탄소중립-반도체 삼각편대로 20년 데스밸리 뛰어넘는다”
# 의사·간호조무사 "총파업 강행" 예고…의료대란 현실화할까(종합)
# 검찰 "청소년 마약 범죄, 사형... 공급망 뿌리 뽑겠다"
# “죄송해요”…생후 40일 아들 학대 숨지게 한 친모 영장 심사
# 문체부 “넷플릭스 투자 등 윤 대통령 방미 성공적”
# [날씨] 중부 곳곳 비…강원영동 대기 건조, 강풍까지
#
#
#
#  서비스 안내
#  고침 기사 모음
#  정정·반론·추후 보도 기사 모음
#  불공정 선거 보도 기사 모음
# 서비스 안내더보기

# %%
import urllib.request as rq

url = 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100'
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'lxml')
texts = bs.find_all('p')
print(texts)
# Out:
# [<p class="airs_info_inner"><i class="airs_info_icon_airs">AiRS</i><span class="airs_info_text"><b>추천</b>으로 구성된 뉴스를 제공합니다.</span></p>, <p class="section_sub_txt">오전 11시~오후 12시까지 집계한 결과입니다.</p>, <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>]

# %%
for t in texts:
    t = t.get_text()
    print(t,'\n')
# Out:
# AiRS추천으로 구성된 뉴스를 제공합니다.
#
# 오전 11시~오후 12시까지 집계한 결과입니다.
#
# 본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.

# %%
import urllib.request as rq
url = 'https://news.naver.com'
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'lxml')
print(bs.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <title id="browserTitleArea">
#    네이버 뉴스
#   </title>
#   <script>
#    function isMobileDevice() {
# 		return /^.*(iPhone|iPod|iPad|Android).*/.test(navigator.userAgent);
# 	}
#   </script>
#   <script>
#    (function () {
# 		try {
# 			if (isMobileDevice() && isAbleApplyPrefersColorScheme()) {
#
# 				document.querySelector("html").classList.add("DARK_THEME");
# 			}
# 		} catch(e) {}
#
# 		function isAbleApplyPrefersColorScheme() {
#
# 			if (window.matchMedia("(prefers-color-scheme)").matches === false) {
# 				return false;
# 			}
#
# 			var userAgent = navigator.userAgent;
#
# 			if (userAgent.indexOf("NAVER") > -1) {
#
# 				if (/.*NAVER\([a-zA-Z]*;\s[a-zA-Z]*;\s([0-9]*);/.test(userAgent)) {
# 					return Number(RegExp.$1) >= 1000;
# 				}
# 			} else {
#
# 				return document.cookie.indexOf("NSCS=1") > -1;
# 			}
#
# 			return false;
# 		}
# 	})();
#   </script>
#   <script>
#    var g_ssc = 'news.v3_media' || null;
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width,initial-scale=1.0,maximum-scale=1.0,minimum-scale=1.0,user-scalable=no,target-densitydpi=medium-dpi" name="viewport"/>
#   <link href="https://ssl.pstatic.net/static.news/mnews/resources/20230420_005654/css/generated/newshome.css" rel="stylesheet" type="text/css"/>
#   <link href="https://mimgnews.pstatic.net/image/news/m/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <script>
#    (function(){
# 		var userAgent = navigator.userAgent;
# 		var result = [];
#
# 		if(userAgent.indexOf('Android') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="72x72" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="96x96" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="144x144" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="192x192" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />'
# 			];
# 		}else if(userAgent.indexOf('iPhone') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="120X120" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPhone_2x_120X120.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="180x180" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPhone_3x_180X180.png" />'
# 			];
# 		}else if(userAgent.indexOf('iPad') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="167x167" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPadPro_2x_167X167.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="152x152" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPad_2x_152X152.png" />'
# 			];
# 		}
# 		document.write(result.join('\n'));
# 	})();
#   </script>
#   <script src="https://ssl.pstatic.net/static.news/mnews/resources/20230420_005654/js/generated/statistics_jquery.js" type="text/javascript">
#   </script>
#   <script>
#    document.documentElement.setAttribute('data-useragent',navigator.userAgent);
#   </script>
#   <script>
#    document.documentElement.setAttribute('data-useragent', navigator.userAgent);
#
#
# function showNoImage(elImg, type) {
#     switch (type) {
#
#         case "remove":
#             try {
#                 elImg.parentNode.removeChild(elImg);
#             } catch(e) {}
#             break;
#
#
#         case "removeParent":
#             try {
#                 elImg.parentNode.outerHTML = '';
#             } catch(e) {}
#             break;
#
#
#         case "alt":
#             elImg.outerHTML = ('<span class="noimage_text {imgClassName}">' + (elImg.alt || "") + '</span>')
#
#                 .replace('{imgClassName}', elImg.className);
#             break;
#
#
# 		case "class" :
# 			var outerHTMLSource = Number(elImg.getAttribute("height")) > 0?
#
# 				'<span class="noimage_wrap {imgClassName}" style="height:' + elImg.getAttribute("height") + 'px;"><span class="noimage"></span></span>':
# 				'<span class="noimage_wrap {imgClassName}"><span class="noimage"></span></span>';
# 			elImg.outerHTML = outerHTMLSource.replace('{imgClassName}', elImg.className);
# 			break;
#
#
#         default:
#
#             elImg.outerHTML = Number(elImg.getAttribute("height")) > 0?
#
#                 '<span class="noimage_wrap" style="height:' + elImg.getAttribute("height") + 'px;"><span class="noimage"></span></span>':
#                 '<span class="noimage_wrap"><span class="noimage"></span></span>';
#     }
# }
#
#
# function doAfterLoadEnd(callback, callbackOnPersisted) {
#     var eventName = "onpageshow" in window ? "pageshow" : "load";
#
#     callback = callback || function(){};
#     callbackOnPersisted = callbackOnPersisted || function(){};
#
#     window.addEventListener(eventName, function(e) {
#         try{
#             if(Boolean(e.persisted)){
#                 callbackOnPersisted();
#                 return;
#             }
#         }catch(e){}
#
#         callback();
#     });
# }
#   </script>
#   <meta content="네이버 뉴스" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://news.naver.com/main/home.naver" property="og:url"/>
#   <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image"/>
#   <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" property="og:description"/>
#   <meta content="네이버" property="og:article:author"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="네이버 뉴스" name="twitter:title"/>
#   <meta content="네이버 뉴스" name="twitter:site"/>
#   <meta content="네이버 뉴스" name="twitter:creator"/>
#   <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
#   <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" name="twitter:description"/>
#   <script>
#    (function () {
#         var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#         if (!isUnderIE10) {
#             var script = document.createElement("script");
#             script.async = true;
#             script.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#             document.head.appendChild(script);
#         }
#     })();
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#     window.gladsdk.cmd.push(function () {
#
#         window.gladsdk.setGlobalConfig({
#             enablePersistAd: true
#         });
#
#
#         var adUnits = [];
#
#         adUnits.push({
#             adUnitId: "p_news_sidebox",
#             adSlotElementId: "glad_ad_sidebox",
#             customParam: {
#                 calp: "home"
#             }
#         });
#
#         for (let i = 0; i < adUnits.length; i++) {
#             window.gladsdk.defineAdSlot(adUnits[i]);
#         }
#
#
#         var htmlClass = document.querySelector("html").getAttribute("class");
#         if (htmlClass && htmlClass.indexOf("DARK_THEME") > -1) {
#             window.gladsdk.setHostMeta("theme", "system");
#         }
#     });
#   </script>
#  </head>
#  <body class="as_mp_layout">
#   <div class="u_skip">
#    <a href="#ct">
#     본문 바로가기
#    </a>
#   </div>
#   <!-- Menu 구분  -->
#   <section class="news_header">
#    <header class="nh_header" role="banner">
#     <div class="Ngnb">
#      <div class="Ngnb_inner">
#       <div class="Ngnb_both">
#        <div class="Ngnb_left">
#         <span class="Ngnb_logo">
#          <a class="Nlogo_link" href="https://www.naver.com" onclick="nclk(event,'gnb.naver','','');">
#           <span class="Nicon_logo">
#            NAVER
#           </span>
#          </a>
#         </span>
#         <div class="Ngnb_service">
#          <h1 class="Nservice_item">
#           <a href="https://news.naver.com" onclick="nclk(event,'gnb.news','','');">
#            <span class="Nicon_service">
#             뉴스
#            </span>
#           </a>
#          </h1>
#          <span class="Nservice_subitem">
#           <a href="https://entertain.naver.com/home" onclick="nclk(event,'gnb.enter','','');">
#            <span class="Nicon_family Nicon_entertain">
#             연예
#            </span>
#           </a>
#          </span>
#          <span class="Nservice_subitem">
#           <a href="https://sports.news.naver.com/index" onclick="nclk(event,'gnb.sports','','');">
#            <span class="Nicon_family Nicon_sports">
#             스포츠
#            </span>
#           </a>
#          </span>
#          <span class="Nservice_subitem">
#           <a href="https://weather.naver.com/" onclick="nclk(event,'gnb.weather','','');">
#            <span class="Nicon_family Nicon_weather">
#             날씨
#            </span>
#           </a>
#          </span>
#          <span class="Nservice_subitem">
#           <a href="https://contents.premium.naver.com/" onclick="nclk(event,'gnb.premium','','');">
#            <span class="Nicon_family Nicon_premium">
#             프리미엄
#            </span>
#           </a>
#          </span>
#         </div>
#        </div>
#        <div class="Ngnb_right">
#         <div class="Ngnb_group">
#          <div class="gnb_dark_type2" id="gnb">
#          </div>
#         </div>
#         <div class="Ngnb_search is_hidden _search_content">
#         </div>
#         <div class="Ngnb_tool">
#          <a class="Ntool_button _search_content_toggle_btn" href="javascript:;" onclick="nclk(event,'gnb.sch','','');">
#           <span class="Nicon_search">
#            검색
#           </span>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="Nlnb _float_lnb">
#      <div class="Nlnb_inner">
#       <div class="Nlnb_both">
#        <div class="Nlnb_left _lnb_scroll">
#         <div class="Nlnb_menu Ntype_scroll">
#          <div class="Nlnb_menu_inner _scroll">
#           <ul class="Nlnb_menu_list" role="menu">
#            <li class="Nlist_item is_active">
#             <a aria-selected="true" class="Nitem_link" href="https://news.naver.com/?viewType=pc" onclick="nclk(event,'lnb.pcmedia','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               언론사별
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100" onclick="nclk(event,'lnb.pol','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               정치
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101" onclick="nclk(event,'lnb.eco','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               경제
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102" onclick="nclk(event,'lnb.soc','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               사회
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103" onclick="nclk(event,'lnb.lif','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               생활/문화
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105" onclick="nclk(event,'lnb.sci','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               IT/과학
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104" onclick="nclk(event,'lnb.wor','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               세계
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item _isNew">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/ranking/popularDay.naver" onclick="nclk(event,'lnb.rank','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               랭킹
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item _isNew">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/newspaper/home?viewType=pc" onclick="nclk(event,'lnb.paper','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               신문보기
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/opinion/home" onclick="nclk(event,'lnb.opi','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               오피니언
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/tv/index.naver?mid=tvh" onclick="nclk(event,'lnb.tv','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               TV
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/factcheck/main.naver" onclick="nclk(event,'lnb.fact','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               팩트체크
#              </span>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#        <div class="Nlnb_right">
#         <div class="lnb_extra" id="">
#          <div class="lnb_extra_menu">
#           <ul class="lnb_extra_menu_list">
#            <li class="lnb_extra_menu_item">
#             <a class="lnb_extra_menu_link" href="https://news.naver.com/main/officeList.naver" onclick="nclk(event,'slb.allmedia','','');">
#              전체 언론사
#             </a>
#            </li>
#            <li class="lnb_extra_menu_item">
#             <a class="lnb_extra_menu_link" href="https://newsstand.naver.com/" onclick="nclk(event,'slb.newsstand','','');" target="_blank">
#              뉴스스탠드
#             </a>
#            </li>
#            <li class="lnb_extra_menu_item">
#             <a class="lnb_extra_menu_link" href="https://newslibrary.naver.com/search/searchByDate.naver" onclick="nclk(event,'slb.library','','');" target="_blank">
#              라이브러리
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </header>
#   </section>
#   <hr/>
#   <div class="main_wrap" id="ct" role="main">
#    <div class="main_container">
#     <section class="main_content">
#      <h3 class="blind">
#       콘텐츠
#      </h3>
#      <div class="main_sublnb">
#       <div class="main_sublnb_date">
#        <strong>
#         5
#        </strong>
#        .
#        <strong>
#         1
#        </strong>
#        <span>
#         (월)
#        </span>
#       </div>
#       <ul class="main_sublnb_menu">
#        <li class="main_sublnb_item">
#         <a class="main_sublnb_link" href="https://news.naver.com/main/officeList.naver " onclick="nclk(event, 'slb.allmedia', '', '')">
#          전체 언론사
#         </a>
#        </li>
#        <li class="main_sublnb_item">
#         <a class="main_sublnb_link" href="https://newsstand.naver.com/" onclick="nclk(event, 'slb.newsstand', '', '')" target="_blank">
#          뉴스스탠드
#         </a>
#        </li>
#        <li class="main_sublnb_item">
#         <a class="main_sublnb_link" href="https://newslibrary.naver.com/search/searchByDate.naver" onclick="nclk(event, 'slb.library', '', '')" target="_blank">
#          라이브러리
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="main_brick">
#       <!-- BRICK HOUSE -->
#       <div class="grid1_wrap brick-house _brick_gid_wrapper">
#        <div class="brick-vowel _brick_column">
#         <div class="main_brick_item _press_main_status_wrapper">
#          <div class="comp_journal_subscribe">
#           <div class="cjs_title_wrap">
#            <h3 class="cjs_edit_title">
#             <span class="cjs_main">
#              언론사편집
#             </span>
#             <a class="cjs_subscribe_a" href="#feedJournalistCard" onclick="nclk(event, 'home.editassetting1', '', '')">
#              <span class="subs_text">
#               기자
#              </span>
#             </a>
#             <a class="cjs_subscribe_a" href="#feedSeriesCard" onclick="nclk(event, 'home.editassetting2', '', '')">
#              <span class="subs_text">
#               연재
#              </span>
#             </a>
#            </h3>
#            <a class="cjs_more_link" href="https://media.naver.com/channel/settings" onclick="nclk(event, 'home.editsetting', '', '')">
#             구독설정
#             <span class="ico_more">
#             </span>
#            </a>
#           </div>
#           <div class="cjs_news_flash_wrap cjs_nf_close _newsflash_wrapper">
#            <div class="cjs_nf_title">
#             <span class="ico_newsflash">
#              속보
#             </span>
#            </div>
#            <div class="cjs_nf_list _item_list">
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/021/0002569547" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                국민의힘 윤리위, ‘설화’ 김재원·태영호 징계절차 개시
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/021/2022/08/04/logo_021_56_20220804125306.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  문화일보
#                 </div>
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/082/0001210039" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                국민의힘 윤리위, 김재원·태영호 징계 절차 개시
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/082/2019/08/22/logo_082_56_20190822111222.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  부산일보
#                 </div>
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/087/0000967725" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                '돈봉투 의혹' 송영길, 내일오전 10시 서울 중앙지검 자진 출두
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/087/2019/08/22/logo_087_56_20190822110222.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  강원일보
#                 </div>
#                </div>
#               </div>
#              </div>
#             </a>
#             <button class="cjs_nf_btn_open is_close _toggle_btn" type="button">
#              <span class="blind">
#               속보 닫기
#              </span>
#             </button>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_news_preview_wrapper" data-max-page="16">
#          <div class="comp_journal_subscribe _preview_card_page" style="">
#           <div class="cjs_channel_card">
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/022" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img height="28" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/022/2018/07/18/logo_022_56_20180718152618.png?type=nf76_76_q90" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                세계일보
#                <span class="datetime">
#                 05월 01일 12:45
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="022" data-office_name="세계일보" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/022/0003808128" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/origin/022/2023/05/01/3808128.jpg?type=nf264_176&amp;ut=20230501114406" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                ‘민주당 전당대회 돈봉투’ 송영길, 2일 검찰에 자진 출두
#               </div>
#               <p class="cjs_d">
#                검찰 조사 이뤄질지는 미지수 2021년 더불어민주당 전당대회 돈 봉투 살포 의혹과 관련해 민주당 송영길 전 대표가 2일 서울중앙지검에 자진 출두한다. 더불어민주당 송영길 전 대표. 공동취재사진 송 전 대표 변호인인
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/008" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img height="28" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/008/2018/09/13/logo_008_56_20180913140213.png?type=nf76_76_q90" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                머니투데이
#                <span class="datetime">
#                 05월 01일 11:24
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="008" data-office_name="머니투데이" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/008/0004881749" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/origin/008/2023/05/01/4881749.jpg?type=nf264_176&amp;ut=20230501093901" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                [영상] 브로드웨이 한인 샌드위치 가게 폐업…배우들이 흘린 눈물
#               </div>
#               <p class="cjs_d">
#                39년간 미국 뉴욕 극장가에서 자리를 지켜온 한인 샌드위치 가게가 문을 닫았다. 이 소식에 브로드웨이 배우와 스태프 등 단골이 모여 송별하는 자리를 마련한 데 이어 외신도 이를 슬픈 소식으로 보도했다. 지난달 30일
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/032" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img height="28" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/032/2022/12/05/logo_032_56_20221205150153.png?type=nf76_76_q90" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                경향신문
#                <span class="datetime">
#                 05월 01일 11:59
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="032" data-office_name="경향신문" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/032/0003220686" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/origin/032/2023/05/01/3220686.jpg?type=nf264_176&amp;ut=20230501060303" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                연산군이 질탕하게 놀았던 탕춘대…왜 유네스코 세계유산 감인가[이기환의 Hi-story]
#               </div>
#               <p class="cjs_d">
#                “연산군이 황음무도한 짓을 벌인 탕춘대가 유네스코 세계유산감이라고?” 최근 문화재청이 한양도성과 북한산성, 탕춘대성을 포함한 ‘한양의 수도성곽’을 유네스코 세계유산 등재신청 후보로 선정했습니다. 이에따라 올해 9월에
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/666" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img height="28" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/666/2023/01/03/logo_666_56_20230103174615.png?type=nf76_76_q90" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                경기일보
#                <span class="datetime">
#                 05월 01일 12:42
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="666" data-office_name="경기일보" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/666/0000010124" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/origin/666/2023/05/01/10124.jpg?type=nf264_176&amp;ut=20230501124002" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                檢, 송영길 경선캠프 관계자 추가 압수수색
#               </div>
#               <p class="cjs_d">
#                송 전 대표 "2일 검찰에 자진 출두하겠다" 더불어민주당 송영길 전 대표가 지난달 24일 오후 인천국제공항 제1여객터미널을 통해 입국해 기자회견을하고 있다. 장용준기자 검찰이 2021년 더불어민
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/448" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img height="28" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/448/2020/08/11/logo_448_56_20200811154809.png?type=nf76_76_q90" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                TV조선
#                <span class="datetime">
#                 05월 01일 12:22
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="448" data-office_name="TV조선" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/448/0000407112" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/origin/448/2023/05/01/407112.jpg?type=nf264_176&amp;ut=20230501115101" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                尹 "업그레이드된 한미동맹, 청년·미래세대에 기회의 플랫폼"
#               </div>
#               <p class="cjs_d">
#                윤석열 대통령이 1일 이번 미국 국빈방문을 "업그레이드 되고 확장된 한미동맹"이라고 평가하며 "청년 미래 세대에게 기회의 플랫폼이 돼야 한다"고 했다. 이날 윤 대통령은 방미 귀국 이후 처음으로 주재한 수석비서관회의
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_info">
#             <button card_type="preview" class="cjs_btn_refresh _refresh_btn" data-max-page="" data-page="0" onclick="nclk(event, 'home.editnfnew', '', '')" size="5" type="button">
#              새로보기
#             </button>
#            </div>
#           </div>
#          </div>
#          <div class="comp_journal_subscribe _preview_card_page" style="display:none">
#           <div class="cjs_channel_card">
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/469" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/469/2023/02/07/logo_469_56_20230207160012.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                한국일보
#                <span class="datetime">
#                 05월 01일 12:09
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="469" data-office_name="한국일보" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/469/0000736994" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/469/2023/05/01/736994.jpg?type=nf264_176&amp;ut=20230501104001" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                "사명감? 그게 뭐죠?"... 의대 차석은 메스 대신 레이저를 잡았다
#               </div>
#               <p class="cjs_d">
#                편집자주한국은 의료 가성비가 좋다고 하죠. 아프면 예약 없이 3,000~4,000원에 전문의를 보는 나라, 흔치 않으니까요. 그러나 건보 흑자, 일부 의료인의 희생 덕에 양질의 의료를 누렸던 시대도 끝나 갑니다. 미
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/138" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/138/2018/07/18/logo_138_56_20180718153118.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                디지털데일리
#                <span class="datetime">
#                 05월 01일 12:43
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="138" data-office_name="디지털데일리" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/138/0002147600" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/138/2023/05/01/2147600.jpg?type=nf264_176&amp;ut=20230501124101" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                또 도 넘은 억지 주장…中네티즌 “한옥은 중국 전통 건축물”
#               </div>
#               <p class="cjs_d">
#                중국 네티즌들이 한복, 음력 설에 이어 한옥이 중국 문화라는 황당 주장을 펼쳐 눈살을 찌푸리게 하고 있다. 1일 게임업계에 따르면 중국 네티즌들은 에픽게임즈가 운영하는 ‘언리얼 엔진 마켓플레이스’에 올라온 한옥 애셋
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/036" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/036/2018/09/20/logo_036_56_20180920152920.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                한겨레21
#                <span class="datetime">
#                 05월 01일 10:54
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="036" data-office_name="한겨레21" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/036/0000048125" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/036/2023/05/01/48125.jpg?type=nf264_176&amp;ut=20230501104901" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                문 대통령이 오월 광주의 그 이름 하나하나 부르기까지
#               </div>
#               <p class="cjs_d">
#                “양심. 그래요, 양심. 세상에서 제일 무서운 게 그겁니다. 군인들이 쏘아 죽인 사람들의 시신을 리어카에 실어 앞세우고 수십만의 사람들과 함께 총구 앞에 섰던 날, 느닷없이 발견한 내 안의 깨끗한 무엇에 나는 놀랐습
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/020" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/020/2020/09/17/logo_020_56_20200917112548.jpg?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                동아일보
#                <span class="datetime">
#                 05월 01일 12:14
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="020" data-office_name="동아일보" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/020/0003494702" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/020/2023/05/01/3494702.jpg?type=nf264_176&amp;ut=20230501030459" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                DMZ근무 美장교 “北장교들 초코파이-도리토스 좋아해”[사람, 세계]
#               </div>
#               <p class="cjs_d">
#                “북한 장교들은 한국의 초코파이와 도리토스(나초칩)를 좋아했어요.” 2013년부터 2021년까지 유엔군 사령부 소속으로 비무장지대(DMZ)에서 근무한 미국 해군 퇴역 장교 대니얼 맥셰인 전 소령은 지난달 28일 미
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/662" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/662/2023/01/05/logo_662_56_20230105140724.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                농민신문
#                <span class="datetime">
#                 05월 01일 12:12
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="662" data-office_name="농민신문" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/662/0000019193" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/662/2023/05/01/19193.jpg?type=nf264_176&amp;ut=20230501110712" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                경기 이천시, ‘임금님표이천’ 상표 사용 30년 맞아 쌀밥데이 선포
#               </div>
#               <p class="cjs_d">
#                경기 이천시(시장 김경희)가 20일 시 농산물 브랜드인 &lt;임금님표이천&gt; 상표 사용 30년을 맞아 기념식과 함께 ‘쌀밥데이’를 선포한다. 시는 1993년 가짜 이천쌀 문제에 대응하고자 &lt;임금님표 이천쌀&gt; 상표를 사용하
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_info">
#             <button card_type="preview" class="cjs_btn_refresh _refresh_btn" data-max-page="" data-page="0" onclick="nclk(event, 'home.editnfnew', '', '')" size="5" type="button">
#              새로보기
#             </button>
#            </div>
#           </div>
#          </div>
#          <div class="comp_journal_subscribe _preview_card_page" style="display:none">
#           <div class="cjs_channel_card">
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/308" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/308/2022/06/30/logo_308_56_20220630105919.jpg?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                시사IN
#                <span class="datetime">
#                 05월 01일 06:59
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="308" data-office_name="시사IN" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/308/0000032614" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/308/2023/05/01/32614.jpg?type=nf264_176&amp;ut=20230501065504" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                폭탄이 머리 위를 지나 기시다 총리 발밑으로
#               </div>
#               <p class="cjs_d">
#                “내 머리 위를 넘어 기시다 총리의 발밑에 떨어진 순간 폭탄인 줄 알았어요.” 4월15일 오전 11시30분께, 와카야마시 사이카자키 어시장에서 중의원 보궐선거 지원 연설을 하려던 기시다 후미오 총리를 향해 연막탄 크
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/215" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/215/2020/08/12/logo_215_56_20200812134433.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                한국경제TV
#                <span class="datetime">
#                 05월 01일 11:55
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="215" data-office_name="한국경제TV" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/215/0001098713" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/215/2023/05/01/1098713.jpg?type=nf264_176&amp;ut=20230501101001" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                '부자아빠' 기요사키 "바이든 역대 최악의 대통령...경기침체 불가피"
#               </div>
#               <p class="cjs_d">
#                세계적인 베스트셀러 '부자 아빠 가난한 아빠'의 저자 로버트 기요사키가 미국 연방준비제도(Fed·연준)를 저격하고 나섰다. 27일(현지시간) 기요사키는 자신의 트위터를 통해 연준이 미국 경제의 심장 역할을 하는 지역
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/088" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/088/2019/08/22/logo_088_56_20190822111422.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                매일신문
#                <span class="datetime">
#                 05월 01일 12:24
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="088" data-office_name="매일신문" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/088/0000811736" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/088/2023/05/01/811736.jpg?type=nf264_176&amp;ut=20230501122501" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                '돈봉투 의혹' 송영길, 내일 오전 10시 검찰 자진 출두
#               </div>
#               <p class="cjs_d">
#                송영길 더불어민주당 전 대표가 2일 검찰에 자진 출두할 예정이다. 송 전 대표 측 선종문 변호사는 1일 언론에 보낸 메시지를 통해 "송 전 대표가 2일 오전 10시 서울중앙지방검찰청에 자진해 출두할 것"이라고 밝혔다
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/421" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/421/2021/02/09/logo_421_56_20210209173713.jpg?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                뉴스1
#                <span class="datetime">
#                 05월 01일 12:28
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="421" data-office_name="뉴스1" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/421/0006779976" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/421/2023/05/01/6779976.jpg?type=nf264_176&amp;ut=20230501110501" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                영장실질심사 앞둔 민주노총 건설노조 간부 분신…심정지 상태
#               </div>
#               <p class="cjs_d">
#                한귀섭 윤왕근 신관호 기자 = 1일 오전 9시 35분쯤 강원 강릉에 위치한 춘천지법 강릉지원 앞에서 양모씨(50)가 분신을 시도했다. 경찰과 소방당국에 따르면 양씨는 심정지 상태로 출동한 소방당국에 의해 인근 병원으
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/082" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/082/2019/08/22/logo_082_56_20190822111222.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                부산일보
#                <span class="datetime">
#                 05월 01일 12:31
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
# ...
#              <div class="cjs_channel_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/057/2019/11/25/logo_057_56_20191125103925.png" loading="lazy" onerror="showNoImage(this)"/>
#              </div>
#              <div class="cjs_channel_name">
#               MBN
#              </div>
#             </a>
#            </li>
#            <li class="cjs_channel_item">
#             <a aria-checked="false" class="cjs_channel_a _item" data-office_id="422" href="javascript:;" role="checkbox">
#              <div class="cjs_channel_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/422/2019/11/29/logo_422_56_20191129165529.jpg" loading="lazy" onerror="showNoImage(this)"/>
#              </div>
#              <div class="cjs_channel_name">
#               연합뉴스TV
#              </div>
#             </a>
#            </li>
#            <li class="cjs_channel_item">
#             <a aria-checked="false" class="cjs_channel_a _item" data-office_id="374" href="javascript:;" role="checkbox">
#              <div class="cjs_channel_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/374/2020/12/29/logo_374_56_20201229152554.jpg" loading="lazy" onerror="showNoImage(this)"/>
#              </div>
#              <div class="cjs_channel_name">
#               SBS Biz
#              </div>
#             </a>
#            </li>
#            <li class="cjs_channel_item">
#             <a aria-checked="false" class="cjs_channel_a _item" data-office_id="449" href="javascript:;" role="checkbox">
#              <div class="cjs_channel_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/449/2020/06/26/logo_449_56_20200626104826.png" loading="lazy" onerror="showNoImage(this)"/>
#              </div>
#              <div class="cjs_channel_name">
#               채널A
#              </div>
#             </a>
#            </li>
#            <li class="cjs_channel_item">
#             <a aria-checked="false" class="cjs_channel_a _item" data-office_id="437" href="javascript:;" role="checkbox">
#              <div class="cjs_channel_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/437/2020/08/25/logo_437_56_20200825135552.png" loading="lazy" onerror="showNoImage(this)"/>
#              </div>
#              <div class="cjs_channel_name">
#               JTBC
#              </div>
#             </a>
#            </li>
#            <li class="cjs_channel_item">
#             <a aria-checked="false" class="cjs_channel_a _item" data-office_id="056" href="javascript:;" role="checkbox">
#              <div class="cjs_channel_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/056/2021/10/28/logo_056_56_20211028103053.png" loading="lazy" onerror="showNoImage(this)"/>
#              </div>
#              <div class="cjs_channel_name">
#               KBS
#              </div>
#             </a>
#            </li>
#            <li class="cjs_channel_item">
#             <a aria-checked="false" class="cjs_channel_a _item" data-office_id="214" href="javascript:;" role="checkbox">
#              <div class="cjs_channel_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/214/2020/06/30/logo_214_56_20200630111130.png" loading="lazy" onerror="showNoImage(this)"/>
#              </div>
#              <div class="cjs_channel_name">
#               MBC
#              </div>
#             </a>
#            </li>
#           </ul>
#           <div class="cjs_info">
#            <button class="cjs_btn_refresh _refresh_btn" onclick="nclk(event, 'home.edittnew', '', '')" type="button">
#             새로보기
#            </button>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="brick-vowel _brick_column">
#        </div>
#        <div class="brick-vowel _brick_column">
#        </div>
#       </div>
#      </div>
#     </section>
#     <section class="main_aside _aside_wrapper">
#      <div class="main_aside_inner _aside_content">
#       <h3 class="blind">
#        구독
#       </h3>
#       <div class="_aside">
#       </div>
#       <script>
#        doAfterLoadEnd(loadAside);
#
#
# function loadAside() {
#     var forcePcVersion = "";
#
#     if (isMobileDevice() && !forcePcVersion) {
#         return;
#     }
#     var iframe = append();
#     var asideFixed;
#
#     window.addEventListener('message', function(event) {
#         var data = event.data;
#
#         if (event.origin !== "https://news.naver.com") {
#             return;
#         }
#
#         if (data.type === "setIframeSize" && data.height) {
#             iframe.style.height = data.height + 'px';
#             iframe.style.visibility = "";
#
#             try {
#                 asideFixed.deactivate(); // event 중복 적용되지 않게
#             } catch(e) {}
#
#             asideFixed = AsideFixed({
#                 "wrapper" : document.querySelector("._aside_wrapper")
#
#             });
#         }
#     });
#
#
#     function append() {
#         var iframe = document.createElement('iframe');
#
#         iframe.width = "100%";
#         iframe.height = "0";
#         iframe.style.visibility = "hidden";
#         iframe.setAttribute("frameborder", "no");
#         iframe.setAttribute("scrolling", "no");
#         iframe.src = "https://news.naver.com/aside?oid=";
#
#         document.querySelector("._aside").appendChild(iframe);
#
#         return iframe;
#     }
# }
#       </script>
#      </div>
#     </section>
#     <div class="layer_toast" style="display: none">
#     </div>
#     <div class="layer_toast_journal_subscribe _subscribe_toast_layer" style="display: none">
#      <button class="lt_btn_set _subscribe_toast_btn" onclick="nclk(event, 'home.edittallchk', '', '')" type="button">
#      </button>
#     </div>
#    </div>
#   </div>
#   <!-- //ct -->
#   <hr/>
#   <div class="mp_footer">
#    <div class="f_subinfo">
#     <div class="f_subinfoinner">
#      <div class="f_notice">
#       <h5 class="f_notice_badge">
#        공지
#       </h5>
#       <a class="f_notice_link" data-mpurl='{"m":"https://m.news.naver.com/ombudsman/noticeread?notiId=715","p":"https://news.naver.com/main/ombudsman/readView.naver?notiId=715"}' href="https://m.news.naver.com/ombudsman/noticeread?notiId=715" onclick="nclk(event, 'fot.noticetext', '', '');">
#        <p class="f_notice_text">
#         기자·연재 카드 개선 안내
#        </p>
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="f_maininfo">
#     <div class="f_maininfoinner">
#      <a class="r_pg_top _go_top" href="javascript:;" id="goTop" onclick="nclk(event, 'fot.pctop', '', '');">
#       맨위로
#      </a>
#      <footer role="contentinfo">
#       <p class="u_ftlkw _footer_login" id="u_ftlkw">
#        <a class="u_ftlk" data-mpurl='{"m":"https://m.naver.com/services.html","p":"https://www.naver.com/more.html"}' href="https://m.naver.com/services.html" onclick="nclk(event,'fot.serviceall','','');">
#         전체서비스
#        </a>
#       </p>
#       <p class="u_cr">
#        <span class="u_ftm">
#         <span class="u_cri u_cri_v1">
#          <a class="u_cra" data-mpurl='{"m":"https://policy.naver.com/policy-mobile/term.html?type=1?type=1","p":"https://policy.naver.com/rules/service.html"}' href="https://policy.naver.com/policy-mobile/term.html?type=1?type=1" onclick="nclk(event,'fot.agreement','','');">
#           이용약관
#          </a>
#         </span>
#         <span class="u_cri u_cri_v1">
#          <a class="u_cra" data-mpurl='{"m":"https://policy.naver.com/policy-mobile/privacy.html","p":"https://policy.naver.com/rules/privacy.html"}' href="https://policy.naver.com/policy-mobile/privacy.html" onclick="nclk(event,'fot.privacy','','');">
#           <strong>
#            개인정보처리방침
#           </strong>
#          </a>
#         </span>
#         <span class="u_cri u_cri_v1">
#          청소년 보호 책임자 : 이희만
#         </span>
#         <span class="u_cri u_cri_v1">
#          <a class="u_cra" data-mpurl='{"m":"https://m.news.naver.com/ombudsman/index","p":"https://news.naver.com/main/ombudsman/index.naver"}' href="https://m.news.naver.com/ombudsman/index" onclick="nclk(event,'fot.guide','','');">
#           서비스안내
#          </a>
#         </span>
#        </span>
#        <span class="u_cri">
#         각 언론사가 직접 콘텐츠를 편집합니다.
#        </span>
#       </p>
#      </footer>
#     </div>
#    </div>
#   </div>
#   <script src="https://ssl.pstatic.net/static.news/mnews/resources/20230420_005654/js/generated/news.mobile.js" type="text/javascript">
#   </script>
#   <script src="https://ssl.pstatic.net/static.news/mnews/resources/20230420_005654/js/generated/pressmain.dependency.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /**
#  * 이 파일은 모바일 뉴스 서비스 전체 페이지에 적용되는 스크립트로써,
#  * 코드 추가 시 Front-End 성능 관점에서 주의를 요합니다.
#  */
# jQuery(window).on('load', function(){
#     setTimeout(onload, 10);
#
#     function onload(){
#         var oLnb = new news.Lnb('._lnb_scroll');
#         new news.ImageLazyLoader().load("img[data-src]");
#         new news.MoveTopButton("._go_top");
#
#
#         new news.HistoryManager().init("naver_mobile_news_history", "");
#
#         // iframe lazy-loading
#         (function(){
#             try {
#                 Array.prototype.slice.apply(document.querySelectorAll('iframe[data-src]'))
#                     .forEach(function(iframeEl) {
#                         var originSrc = iframeEl.getAttribute('data-src');
#                         if(originSrc) {
#                             iframeEl.setAttribute('src', originSrc);
#                         }
#                     });
#             }catch(e) {}
#         })();
#
#         if(typeof init === "function"){
#             init();
#         }
#
#         var cookie = news.Cookie.getInstance();
#         var isShownNewLnb = cookie.getItem("isShownNewLnb");
#         if(isShownNewLnb == null) {
#             isShownNewLnb = "Y";
#             cookie.setItem("isShownNewLnb", isShownNewLnb, 3650, "", "/");
#             $("._isNew").addClass("is_new");
#         }
#
#         {
#             var footerLogin = jQuery(document).find('._footer_login');
#             if(footerLogin <= 0) {
#                 return;
#             }
#
#             // 디바이스에 따라 로그인, 로그아웃 URL 분기
#             var loginUrl = "https://nid.naver.com/nidlogin.login";
#             var logoutUrl = "https://nid.naver.com/nidlogin.logout?";
#             if (news.Util.getAgentInfo().bMobileOrTablet) {
#                 loginUrl = "https://nid.naver.com/nidlogin.login?svctype=262144";
#                 logoutUrl = "https://nid.naver.com/nidlogin.logout?svctype=262144&";
#             }
#
#             if(news.LoginAssistor.isLoginUser()) {
#                 footerLogin.prepend('<a href="javascript:news.Util.logout(\''+logoutUrl+'url=\'+encodeURIComponent(location.href));" class="u_ftlk" id="news_logout" onclick="nclk(event,\'fot.logout\',\'\',\'\');" >로그아웃</a>')
#             }else {
#                 footerLogin.prepend('<a href="'+loginUrl+'" class="u_ftlk" id="news_login" onclick="nclk(event,\'fot.login\',\'\',\'\');" >로그인</a>')
#             }
#         }
#     }
# });
#   </script>
#   <script id="feedRefreshButtonTemplate" type="text/x-handlebars-template">
#    {{buttonText}}
#     <span class="paging">
#         <span class="blind">현재</span>{{currentPage}}
#         <em class="total"> / <span class="blind">전체</span>{{totalPage}}</em>
#     </span>
#   </script>
#   <script type="text/javascript">
#    FeedCard($('._journalist_feed_card_wrapper'), 'journalist', 'https://m.news.naver.com');
#     FeedCard($('._series_feed_card_wrapper'), 'series', 'https://m.news.naver.com');
#     BrickGridForEditByPress($("._brick_gid_wrapper"));
#     PressMainStatusCard($('._press_main_status_wrapper'));
#     NewsFlashCard($('._newsflash_wrapper'));
#
#
#
#
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#         adSlot.setCustomParam("calp", 'home');
#         window.gladsdk.displayAd(adSlot);
#
#
#         window.gladsdk.addEventListener(window.gladsdk.event.ERROR, function (ad, error) {
#             $("._card_ad").hide();
#         });
#     });
#
#     $('._channel_news_card_wrapper').each(function () {
#         var wrapper = $(this);
#         ChannelNewsCard(wrapper, 'https://m.news.naver.com');
#     })
#
#     ChannelNewsPreviewCard($('._channel_news_preview_wrapper'), 'https://m.news.naver.com');
#     SubscribeBannerShortCard($('._short_subscribe_banner_card_wrapper'), 'https://m.news.naver.com');
#     SubscribeBannerLongCard($('._long_subscribe_banner_card_wrapper'), 'https://m.news.naver.com');
#
#     WeeklySpecialReportCard($('._weekly_special_report_card_wrapper'));
#
#     $('._horizontal_card_wrapper').each(function () {
#         var wrapper = $(this);
#         HorizontalTypeCard(wrapper, 'https://m.news.naver.com');
#     });
#
#     SpecialReportCard($('._special_report_card_wrapper'), 'https://m.news.naver.com');
#
#     ArticleLinkParamsAppender('news_media_pc');
#   </script>
#   <script>
#    var gnb_service = 'news';
#     var gnb_logout = encodeURIComponent(location.href);
#     var gnb_template = 'gnb_utf8';
#     var gnb_brightness = 3;
#
#     doAfterLoadEnd(function () {
#         try {
#             GlobalMPUrlManager.init();
#         } catch (e) {}
#     });
#
#     doAfterLoadEnd(function() {
#         if (!document.querySelector('#gnb') || isMobileDevice() === true) {
#             return;
#         }
#
#         var gnb_src = "https://ssl.pstatic.net/static.gn/templates/gnb_utf8?2023050112";
#
#         // GnbHelper를 이용하여 GNB Layer를 닫을 수 있도록 지원한다.
#         if (window.jindo) {
#             jindo.LazyLoading.load(
#                 gnb_src,
#                 function() {
#                     try {
#                         getGNB();
#                     } catch(e) {}
#                 },
#                 'utf-8'
#             );
#
#             jindo.$Fn(function (oEvent) {
#
#                 GnbHelper.attachClick(oEvent.$value().target);
#             }).attach(document, 'click');
#         } else if (window.jQuery) {
#             new news.JsLoader().
#                 load(
#                     [gnb_src],
#                     function() {
#                         try {
#                             getGNB();
#                         } catch(e) {}
#                     }
#                 );
#
#             $(document).on("click", function(event) {
#                 GnbHelper.attachClick(event.target);
#             });
#         }
#     });
#   </script>
#   <script>
#    doAfterLoadEnd(function() {
#         if (!document.querySelector('.news_header')){
#             return;
#         }
#
#         try {
#             GnbFloatingManager.init();
#         } catch (e) { }
#     });
#   </script>
#   <script>
#    doAfterLoadEnd(function() {
#     try {
#         new SearchAutoComplete({
#             content: document.querySelector("._search_content"),
#             contentToggleBtn: document.querySelector("._search_content_toggle_btn"),
#             isMobile: isMobileDevice(),
#             nClickType: "newsM"
#         });
#     } catch(e) {}
# });
#   </script>
#   <!-- LCS -->
#   <script type="text/javascript">
#    function initMa(){
#     var data = {
#         "service": "news",
#         "baseInfo": {
#             "category": (function(){
#
#                 var result = "언론사별(신규)";
#
#                 if(result !== ""){
#                     return result;
#                 }
#                 try{
#
#                     return document.querySelector('meta[property="og:title"]')
#                         .getAttribute('content')
#                         .replace(/[\s]*:+[\s]*네이버[\s]*뉴스/, '');
#                 }catch(e){
#                     return "";
#                 }
#             })()
#         },
#         "extraInfo": {}
#     };
#
#
#
#     try{
#         ma.init({
#             api: "https://ma.news.naver.com/l",
#             data: data
#         });
#     }catch(e){}
# }
#   </script>
#   <script type="text/javascript">
#    var eventType = "onpageshow" in window ? "pageshow" : "load";
# jQuery(window).on(eventType, function() {
#
#
#
# lcs_do();
#
#
#     try{
#         initMa();
#     }catch(e){}
# });
#   </script>
#   <!-- //LCS -->
#   <div id="videoWrap">
#   </div>
#  </body>
# </html>

# %%
# Q. p 태그 데이터를 모두 불러와서 텍스트만 출력

# %%
# bs.find_all
texts = bs.find_all('p')
for t in texts:
    print(t.string)
# Out:
# 검찰 조사 이뤄질지는 미지수 2021년 더불어민주당 전당대회 돈 봉투 살포 의혹과 관련해 민주당 송영길 전 대표가 2일 서울중앙지검에 자진 출두한다. 더불어민주당 송영길 전 대표. 공동취재사진 송 전 대표 변호인인
# 39년간 미국 뉴욕 극장가에서 자리를 지켜온 한인 샌드위치 가게가 문을 닫았다. 이 소식에 브로드웨이 배우와 스태프 등 단골이 모여 송별하는 자리를 마련한 데 이어 외신도 이를 슬픈 소식으로 보도했다. 지난달 30일
# “연산군이 황음무도한 짓을 벌인 탕춘대가 유네스코 세계유산감이라고?” 최근 문화재청이 한양도성과 북한산성, 탕춘대성을 포함한 ‘한양의 수도성곽’을 유네스코 세계유산 등재신청 후보로 선정했습니다. 이에따라 올해 9월에
# 송 전 대표 "2일 검찰에 자진 출두하겠다" 더불어민주당 송영길 전 대표가 지난달 24일 오후 인천국제공항 제1여객터미널을 통해 입국해 기자회견을하고 있다. 장용준기자 검찰이 2021년 더불어민
# 윤석열 대통령이 1일 이번 미국 국빈방문을 "업그레이드 되고 확장된 한미동맹"이라고 평가하며 "청년 미래 세대에게 기회의 플랫폼이 돼야 한다"고 했다. 이날 윤 대통령은 방미 귀국 이후 처음으로 주재한 수석비서관회의
# 편집자주한국은 의료 가성비가 좋다고 하죠. 아프면 예약 없이 3,000~4,000원에 전문의를 보는 나라, 흔치 않으니까요. 그러나 건보 흑자, 일부 의료인의 희생 덕에 양질의 의료를 누렸던 시대도 끝나 갑니다. 미
# 중국 네티즌들이 한복, 음력 설에 이어 한옥이 중국 문화라는 황당 주장을 펼쳐 눈살을 찌푸리게 하고 있다. 1일 게임업계에 따르면 중국 네티즌들은 에픽게임즈가 운영하는 ‘언리얼 엔진 마켓플레이스’에 올라온 한옥 애셋
# “양심. 그래요, 양심. 세상에서 제일 무서운 게 그겁니다. 군인들이 쏘아 죽인 사람들의 시신을 리어카에 실어 앞세우고 수십만의 사람들과 함께 총구 앞에 섰던 날, 느닷없이 발견한 내 안의 깨끗한 무엇에 나는 놀랐습
# “북한 장교들은 한국의 초코파이와 도리토스(나초칩)를 좋아했어요.” 2013년부터 2021년까지 유엔군 사령부 소속으로 비무장지대(DMZ)에서 근무한 미국 해군 퇴역 장교 대니얼 맥셰인 전 소령은 지난달 28일 미
# 경기 이천시(시장 김경희)가 20일 시 농산물 브랜드인 <임금님표이천> 상표 사용 30년을 맞아 기념식과 함께 ‘쌀밥데이’를 선포한다. 시는 1993년 가짜 이천쌀 문제에 대응하고자 <임금님표 이천쌀> 상표를 사용하
# “내 머리 위를 넘어 기시다 총리의 발밑에 떨어진 순간 폭탄인 줄 알았어요.” 4월15일 오전 11시30분께, 와카야마시 사이카자키 어시장에서 중의원 보궐선거 지원 연설을 하려던 기시다 후미오 총리를 향해 연막탄 크
# 세계적인 베스트셀러 '부자 아빠 가난한 아빠'의 저자 로버트 기요사키가 미국 연방준비제도(Fed·연준)를 저격하고 나섰다. 27일(현지시간) 기요사키는 자신의 트위터를 통해 연준이 미국 경제의 심장 역할을 하는 지역
# 송영길 더불어민주당 전 대표가 2일 검찰에 자진 출두할 예정이다. 송 전 대표 측 선종문 변호사는 1일 언론에 보낸 메시지를 통해 "송 전 대표가 2일 오전 10시 서울중앙지방검찰청에 자진해 출두할 것"이라고 밝혔다
# 한귀섭 윤왕근 신관호 기자 = 1일 오전 9시 35분쯤 강원 강릉에 위치한 춘천지법 강릉지원 앞에서 양모씨(50)가 분신을 시도했다. 경찰과 소방당국에 따르면 양씨는 심정지 상태로 출동한 소방당국에 의해 인근 병원으
# 국민의힘 중앙당 윤리위원회가 잇단 설화로 논란을 빚은 김재원·태영호 최고위원에 대한 징계 절차를 개시했다. 1일 황정근 윤리위원장은 서울 여의도 국민의힘 중앙당사에서 오전 10시부터 2시간가량 윤리위 첫 회의를 연
# 근로자의날까지 이어지는 5월 첫 황금 연휴에 관광객들이 제주로 몰려들고 있습니다. 국내 관광객은 물론 제주를 찾는 외국인 관광객도 빠르게 늘어나고 있습니다. 특히 다음달 3일까지 중국 노동절 연휴가 이어지고, 일본
# "다음 달이 우리 막내 생일이어서 미리 생일 선물을 준비했는데, 이제 전해줄 수가 없습니다." 가족의 사랑을 듬뿍 받았던 초등학생 막내딸, 등굣길에 1.5t이 넘는 화물에 깔려 하루아침에 세상을 떠났습니다. 사고가
# 검찰이 청소년 마약범죄에 대해서는 최고 사형까지 구형하겠다며 엄정 대응을 예고했습니다. 검찰은 당장 '학원가 마약 음료' 사건에 가중처벌 조항을 적용하는 방안을 검토하고 있습니다. 취재기자 연결해 자세한 내용 알아봅
# AV 배우 인터뷰한 <성+인물> 논란, 어떻게 봐야하나? "AV산업은 일본 내 ‘성착취 구조’의 첨단에 자리합니다. 그 구조에 대한 비판적 고려 없이 이를 콘텐츠화한다뇨." - 이나영 중앙대학교 사회학과 교수 AV(
# 콜센터 상담사에게 상습적으로 폭언을 일삼던 민원인이 실형을 선고받았다. 폭언을 자주 한다면 타인에게 상처를 주는 것뿐만이 아니라 스스로 정신질환이 있는지 점검해 볼 필요가 있다. 서울특별시 120다산콜재단은 폭행·협
# 삼성전자와 네이버가 손잡는 사례가 늘어나고 있다. 지난해 연말 ‘초거대 인공지능(AI)’에 활용된 반도체 솔루션 개발을 위한 업무 협약을 시작으로 금융과 정보기술(IT) 등에서 협력 범위를 넓혀 나가고 있다. 최근
# 일본의 중노년 싱글여성 단체인 ‘와쿠와쿠 시니어 싱글즈’가 릿쿄대학 유자와 나오미(湯澤直美) 씨와 북경JAC 협력으로 중고령 싱글여성의 생활실태를 조사했다. ‘와쿠와쿠’(두근두근이라는 뜻)는 2016년에 50세 이상
# 최근 들어 10대들이 연루된 마약 범죄 사건이 '무시할 수 없는 수준'에 이르렀습니다. 청소년이 피해자인 경우가 많지만, 직접 마약을 판매하는 가해자인 사례도 적지 않습니다. 대검찰청은 오늘(1일) "대부분 부모는
# 2020년 코로나19 바이러스가 처음 확산한 중국 후베이성 우한시의 방역 실태를 고발했다가 실종된 중국 시민이 3년만에 석방될 예정이라는 보도가 나왔다. 30일(현지시간) AP통신은 해당 시민의 친척과 익명을 요구한
# 박의래 특파원 = 인도에서 주민 6명의 목숨을 앗아간 야생 코끼리를 포획하기 위해 공무원 150명과 훈련된 코끼리 4마리가 동원된 대규모 작전이 펼쳐졌다. 1일(현지시간) 인디언 익스프레스 등에 따르면 인도 남부 케
# 고공행진하는 먹거리 물가에 가정의 달을 맞이하는 서민들의 표정이 어둡다. 4인 가족 기준 10만원을 넘나드는 외식비에 소비자들 사이에선 "가족 모임이 무섭다"는 말까지 나온다. 원주에 거주하는 40대 직장인 홍모씨는
# 월 10만원씩 저축한 청년에게 3년 만기 시 최대 원금의 세 배를 추가로 지급하는 '청년내일저축계좌' 신청이 시작된다. 1일 보건복지부에 따르면 이날부터 오는 26일까지 청년내일저축계좌 신규 가입자를 모집한다. 대상
# Korea's exports fell for the seventh consecutive month in April due primarily to weak demand for semiconductors amid an
# 우리나라에서 세단의 대명사는 쏘나타였다. 특히 강남 지역에서 자주 보이는 수입차에 ‘강남 쏘나타’라는 별명을 붙이기도 했다. 최근 세단 모델이 위기를 겪는 가운데 고급스러운 디자인과 효율 높은 친환경 디젤 엔진을 탑
# # 김포의 황금빛 들녘을 상징한다는 이름, 김포골드라인. 하지만 개통 이후 줄곧 극심한 혼잡으로 각종 논란을 겪고 있는 비운의 노선이기도 합니다. 이 문제를 해결하기 위해 서울시에서 대체교통수단인 '리버버스(Rive
# 2023년 4월 13일 국회 본회의에서 '대구경북신공항 건설을 위한 특별법'이 통과됐습니다. 대구경북신공항은 현재 대구 도심에 있는 군 공항인 K2와 대구국제공항을 경북 의성군 비안면과 군위군 소보면으로 새롭게 옮기
# 소시에테제네랄(SG) 증권발 주가 폭락 사태와 관련해 가수 임창정씨가 지난해 12월 의혹의 핵심 당사자인 투자자문사 대표 라덕연씨가 주최한 또 다른 행사에도 참석했던 것으로 드러났다. 임씨 측은 "엔터 관련 투자를
# 요즘 4대강 사업의 주역들이 부쩍 대중 앞에 자주 등장하고 있다. 이명박 전 대통령(이하 존칭 생략)은 며칠 전 측근 유인촌의 연극을 관람했고 앞으로 4대강도 방문할 예정이라고 한다. 4대강 추진본부장이었던 심명필은
# 근로자의 날인 오늘(1일) 직장인 10명 중 3명이 출근한다는 조사 결과가 나왔습니다. 근로기준법상 유급휴일인 만큼 오늘 일을 한 분들은 휴일 수당을 받으실 수 있는데요. 기사 내용 잘 보시고, 나도 받는 게 맞는지
# 잉글랜드 프리미어리그(EPL)에서 뛰고 있는 손흥민(31·토트넘 홋스퍼)의 반칙 상황을 ‘무술’에 비유한 유명 해설가가 인종차별 논란에 휩싸였다. 손흥민은 1일(한국시간)에 열린 2022-23시즌 EPL 34라운드
# 수백억원대 이스타항공 배임·횡령 혐의로 재판에 넘겨진 이상직 전 국회의원이 징역 6년을 확정받았다. 구속 당시 자신을 '불사조'라고 비유하며 부활을 호언한 것으로 알려진 그는 수의를 입고 후속 재판을 받게 됐다. 특
# 10대 학생의 극단적 선택이 SNS에 노출된 것과 관련해 온라인 커뮤니티 '우울증 갤러리'가 경찰 수사를 받고 있는데요. 경찰의 커뮤니티 폐쇄 요청과 이를 수용하지 않은 방심위의 결정을 두고 여러 이야기가 나옵니다.
# 독일 나치 부역자의 보석 700점, 2000억원어치가 경매에 나온다. 카르티에, 불가리 등 명품 브랜드의 희귀 보석들이다. 미국 뉴욕 크리스티 경매는 이달부터 오스트리아 억만장자인 하이디 호르텐의 소장품 중 보석 7
# 중국 누리꾼들이 한옥과 관련해 "중국 건축 문화의 일부"라고 주장해 논란이 일고 있습니다. 1일 게임 업체 에픽게임즈의 '언리얼 엔진 마켓플레이스'에 올라온 한옥 관련 데이터엔 중국 누리꾼의 악성 댓글이 달렸습니다.
# 지난 4월 21일 국회에서 상속세 과세체계 개편과 관련한 토론회가 열렸다. 더불어민주당 정책위원회 수석부의장인 김병욱·송기헌·유동수 의원이 주최했다. 토론회 명칭은 ‘상속세 유산취득세 방식 긍정적 검토 토론회’다.
# 2016년 5월1일. 경기 안산시 단원구 바닷가에서 신원미상 남성의 시신이 발견됐다. 마대에 담긴 시신은 신체 일부만 있었다. 일대에 대대적인 경찰 수색이 펼쳐졌다. 이틀 후 약 20km 떨어진 바닷가에서 시신의 나
# 최근 한 초등학생이 등굣길이 1.5t짜리 원통형 화물에 치여 숨진 사고와 관련, 유족 측이 먹먹한 심경을 전했다. 1일 한 온라인 커뮤니티에는 '부산 영도구 청학동 A 양 아빠입니다'라는 제목의 글이 올라왔다. 부산
# 한국문화정보원 "피해 사례 수집 중" 김치와 한복 등을 자기들 문화라고 억지 주장을 펼쳐 세계적인 비웃음을 사고 있는 중국이 이번에는 한옥에 대해 "한국 문화가 아닌 중국의 전통문화"라는 우기는 일이 벌어졌다. 정부
# 미국 우주개발 스타트업이 물을 동력으로 쓰는 우주선을 개발해 우주 운송사업에 뛰어들겠다고 선언했다. 지구 저궤도 운송은 내년 말 첫 시험을 거쳐 2025년 상용 서비스를 시작한다는 야심찬 계획이다. 일론 머스크가 설
# 중국이 우리나라 반도체 산업에 대한 압박에 나섰다. 원산지 점검과 통관 검사 강화 조치에 이어 우리 기업의 중국 수출 계약 취소 사례까지 등장, 미-중 갈등으로 인해 국내 기업 피해가 가시화되는 것이 아니냐는 우려가
# “김익래 회장이 주가 조작을 알았을 가능성은 0.0001%도 없다. 공교롭게 그때 매각을 했던 것이고 사실 그 전부터 팔려고 했다. 김 회장은 주가 조작 혐의를 받는 H투자자문 라덕연 대표와도 전혀 친분이 없다. 직
# 5·1 노동절을 맞아 여야가 노동 가치를 강조했다. 그러면서도 국민의힘은 '노조의 특권'을 비판했다. 더불어민주당은 윤석열 정부가 추진했던 '주 69시간 근무제'를 비판했다. 유상범 국민의힘 수석대변인은 1일 "윤석
# 더불어민주당 박광온 원내대표가 취임 일주일도 되지 않아 이른바 개딸들의 거센 공격을 받고 있다. 이에 이재명 대표가 연휴 기간에 직접 페이스북에 글을 올려 개딸들에게 자제를 요청했으나, 그들의 분노가 좀처럼 가라앉지
# 네이버가 불공정 논란이 일었던 뉴스콘텐츠제휴 약관을 전면 수정해 재공지했다. 네이버는 28일 오후 뉴스콘텐츠제휴 언론사들에 이메일을 보내 “(기존 약관 대신) 추가 수정한 개정 약관으로 재동의를 구하고자 한다”며 “
# 간호법 제정에 반대하며 단식을 해온 곽지연 대한간호조무사협회 회장이 단식 농성에 돌입한 지 닷새만인 어제 병원으로 이송됐습니다. 농성 현장을 찾은 조규홍 보건복지부 장관은 "같은 간호 인력 간에도 협의가 이뤄지지 않
# 1일 윤석열 대통령 국정 수행 지지도가 미국 국빈 방문과 맞물려 4주 만에 반등했다는 여론조사 결과가 나왔다. 리얼미터가 미디어트리뷴 의뢰로 지난달 24일부터 28일까지 닷새간 전국 18세 이상 유권자 2507명을
# # 국내 한 정유사에 다니는 A씨는 입사 이후 사수에게 혼나가며 일을 배웠다. 사수는 엄격했지만, 일처리가 빨랐고 업무 방식도 잘 알려줬다. 나름 사수에게 만족하며 다니던 A씨는 최근 ‘인사기록카드’를 보고 멈칫했다
# 근로자의 날인 오늘(1일) 양대노총을 비롯한 노동 단체들이 서울 도심 곳곳에서 대규모 집회를 엽니다. 민주노총은 오늘 오후 2시 서울 종로구 동화면세점 앞에서 '세계노동절대회'를 열고 7월 총파업 투쟁을 선포할 계획
# 기사내용 요약 AP 보도…"분란 혐의 등으로 3년형 선고" 코로나19가 처음 유행한 중국 후베이성 우한 실태를 고발했던 시민이 3년 만에 석방될 것이라고 AP통신이 30일(현지시간) 보도했다. 통신은 이 시민의 친척
# ※기사 내 링크는 서울경제신문 홈페이지에서 이용할 수 있습니다. 일회용 '럭키 나너 콘디쇼닝 샴푸'. 얼마 전 변수빈 디프다제주 대표와 일행들이 한림 해변에서 주운 쓰레기입니다. 찾아보니 무려 1980년 출시된 제품
# 지난해 부채 급증으로 빚더미에 앉은 한국가스공사가 자사 임원에게 전년보다 30%나 오른 연봉을 지급한 것으로 나타났다. 1일 공공기관 경영정보 공개 시스템 ‘알리오’에 따르면 지난해 가스공사 상임 임원의 평균 연봉은
# 유통업계의 디지털 전환(DX)은 거스를 수 없는 변화다. DX에 성공한 기업이 살아남고, 실패하면 도태될 것이란 긴장감이 감돌고 있다. 생존에 위협을 받은 유통업계는 DX에 대규모 투자를 쏟아붓고 있지만, 출혈경쟁
# 충북 청주 흥덕경찰서는 여장을 하고 여자화장실에 들어간 20대 A씨를 성폭력범죄의 처벌 등에 관한 특례법 위반 혐의로 붙잡아 조사하고 있습니다. A씨는 4월 27일 오전 1시쯤 긴 머리 가발을 쓰고 여장을 한 채 청
# 미국 뉴욕 타임스스퀘어에 있던 작은 샌드위치 가게가 문을 닫자 브로드웨이 배우들이 한자리에 모였다. 40년 가까이 이 가게를 운영한 한인 사장의 ‘은퇴식’을 열어주기 위해서였다. 최근 미국 폭스5 뉴욕, CBS 뉴욕
# 해마다 천만 명이 넘는 관광객이 찾는 여수에 새로운 관광단지가 조성 중입니다. 가장 먼저 루지 테마파크가 문을 연 것을 시작으로 2026년까지 세계적인 브랜드 호텔과 대관람차도 추가로 들어설 예정입니다. 여수와 고흥
# 배우 원빈·이나영 부부가 2018년 매입한 서울 강남구 청담동 건물이 300억원을 호가하는 것으로 알려졌다. 30일 부동산 업계에 따르면, 원빈과 이나영은 2018년 2월 지하철 분당선 압구정로데오역에서 300m 거
# 우리나라 4월 수출이 지난해 10월 이후 7개월째 하락세를 보이면서, 무역수지도 14개월 연속 하락세를 면치 못했다. 지난 1일 관세청이 발표한 '3월 수출입 현황(잠정치)'에 따르면, 수출은 496억2000만 달러
# 동원그룹, 맥도날드 인수 포기… “메뉴 하나도 글로벌 본사 허락 필요” 2016년 맥도날드 매각 불발 때도 ‘자율권’ 걸림돌 지적 업계 “스타벅스와 달리 작은 것 하나도 본사 허락받아야” KG그룹, KFC 운영 당시
# 1일 국민의힘 윤리위원회의 첫 회의가 예정된 가운데 징계 개시 여부에 촉각이 쏠리고 있는 김재원 최고위원이 약 한 달 만에 최고위원회의에 복귀해 사과했다. '제주 4·3사건 김일성 지시설'로 논란을 일으켰던 태영호
# 볼트엣마켓(Vault@Market)은 가치있는 거래 정보를 제공하고 투자자를 보호(Vault)하는, <블로터>의 새로운 자본시장 정보제공 서비스입니다. AI(인공지능) 영상감시솔루션 전문기업 트루엔의 수요예측이 4월
# 지난달 28일 부산 영도구 청학동 스쿨존에서 1.5t짜리 원통형 화물에 치여 숨진 아이의 아빠가 온라인 커뮤니티에 자신의 심경을 올렸다. 아빠는 생전 딸의 사랑스러웠던 여러 모습을 메모하듯이 남기며 딸을 추억했다.
# A 3.1 magnitude natural earthquake hit Okcheon, North Chungcheong Province, Sunday, the state weather agency said. The q
# 천연기념물 지정된 순천 승주 평지마을 이팝나무 ▲ 장성 백양사 쌍계루 앞의 이팝나무. 각진국사가 꽂은 지팡이가 자랐다는 전설이 전해진다. 꽃이 활짝 핀 지난해 5월 풍경이다. ⓒ 이돈삼 이팝나무꽃이 피고 있다. 연둣
# "2000년대 중반에 라페스타가 어땠냐고요? 지금의 스타필드와 비슷했다고 보면 될 거예요. 음식점, 옷 가게, 놀거리 등 없는 게 없었으니까요. 지금은 잘 안 오게 돼요. 인스타그램에서 관심이 많은 음식점이나 카페가
# 지난달 15일부터 군벌 간 무력 충돌로 극도의 혼란에 빠진 수단에서 또다시 72시간 동안 휴전이 연장됐습니다. 한편 군벌의 다툼에 대북 제재로 금지된 북한의 무기가 사용됐을 수 있다고 미국 북한 전문 매체가 보도했습
# 송영길이 추켜세운 인천시 직원, 강원도 넘어가 남헌기가 망상 개발사업 맡는 데 기여 개발사업자 선정 의혹 덮고 밀어붙인 최문순…"남씨와 정치권의 유착 주장 꽤 구체적" 인천 미추홀구와 강원 동해시 망상동. 직선 거리
# 국립공원 입장이 '완전' 무료화된다. 그동안 국립공원 지역 내에 위치한 사찰에서 국가 지정 문화재관람 명목으로 등산객들로부터 입장료를 받아왔는데, 대한불교조계종이 26일 관람료를 면제한다고 밝혔다. 면제 조치는 5월
# ● 진중권 “尹, 박근혜 정권보다 퇴행적” ● 박성민 “민주당 분열 가능성 60%” [+영상] 윤석열 1년을 말하다 [+영상] 국민의힘을 말하다 [+영상] 민주당을 말하다 2024년 4월 10일 치러지는 22대 총선
# LG에너지솔루션·삼성SDI 1분기 호실적… 금융당국 “2차전지 신용거래 급증” 우려 “떨어질 땐 다 같이, 오를 땐 혼자.” 4월 26일 한 LG에너지솔루션 주주가 어닝 서프라이즈 소식에 보인 반응이다. 이날 LG에
# 민주노총 건설노조 강원건설지부 소속 간부가 구속 전 피의자 심문을 앞두고 분신을 시도했다. 소방당국과 경찰 등에 따르면 1일 오전 9시 35분 쯤 춘천법원 강릉지원 앞에서 건설노조 간부 A(50)씨가 몸에 휘발성 물
# 지난달 28일 부산 영도구 스쿨존(어린이보호구역)에서 1.5톤짜리 선박용 장비에 치여 숨진 초등학생의 아버지가 온라인 커뮤니티에 자신의 심경을 적은 글을 올렸다. 지난달 30일 한 온라인 커뮤니티에 ‘부산 영도구 청
# 정부가 저소득층 청년 저축액의 최대 3배까지 같은 금액을 추가 지원하는 '청년내일저축계좌' 신규 가입자 모집이 1일 시작된다. 중위소득 100% 이하 가구의 만19세~34세 일하는 청년이이라면 청년내일저축계좌를 개설
# 더불어민주당 전당대회 돈봉투 의혹을 수사하는 검찰이 송영길 전 대표 캠프 관계자를 추가 압수수색하고 있다. 서울중앙지검 반부패수사2부(김영철 부장검사)는 1일 오전부터 송영길 전 더불어민주당 당대표의 경선 캠프 지역
# 배우 박은빈의 차기작인 드라마 ‘무인도의 디바’ 촬영장에서 40대 남성이 던진 벽돌에 스태프가 다치는 사건이 발생했다. 서울 혜화경찰서는 한밤중 드라마 촬영 현장에 벽돌을 던진 혐의로 40대 남성 A씨를 불구속 입건
# 올해 전주국제영화제에서 공개된 다큐멘터리 영화 ‘문재인입니다’(10일 개봉)는 잡초를 좋아하는 자연인 문재인의 일상과 문 전 대통령 주변 인사들의 ‘입’을 빌린 대통령 문재인의 면모를 병치시킨다. 문 전 대통령의 정
# 한 서울대생이 1억 5,000만 원 상당의 미술 작품 속 바나나를 먹은 사실이 알려졌는데요, 그 이유가 석연치 않습니다. 서울대 미학과 재학생 노 모 씨는 지난달 27일 리움미술관에서 진행한 마우리치오 카텔란의 개인
# 운동을 위해 시간과 비용을 들여 열심히 했는데도 몸의 변화가 없다면, 자신의 운동 습관을 체크해 봐야 한다. 특히 체중, 허리 사이즈, 근육의 양 등 중요 수치에 변화가 없다면, 운동 효과에 대한 회의감마저 갖게 된
# None
# [효자 車보험]㊤아픈 손가락은 옛말
# [효자 車보험]㊥돈 냄새 맡은 중소 손보사들
# [효자 車보험]㊦치솟는 한방 진료비 논란
# 외신 "美, 韓 핵무장론 달래기 시도…핵잠 기항 동북아 불안정 키울 것"
# 워싱턴선언 '동상이몽'? 대통령실 "사실상 핵공유" 美당국자 "핵공유 아냐"
# 尹대통령 '워싱턴선언' 후속행보, 한미 '핵공유' 온도차
# '자체 핵무장' 주장 태영호 "尹대통령에 영업왕 칭호까지 줘야겠다"
# 등골 휘는 5월 ‘가정의 달’…“어버이날·어린이날 부담”
# “나 빼고 다 해외 가네”…5월 연휴 내내 SNS엔 여행 사진이
# 매년 1억~4억명의 생명을 위협하는 ‘OOO’ 감염
# 야외활동 후 ‘사마귀’가 생겼다면? ‘이것’ 주의
# [스페셜리포트]방송법, 5월 정국 뇌관으로…여야 '평행선' 속 거부권 행사 초미 관심
# [스페셜리포트]해외 공영방송 지배구조 사례 보니…"공영방송 정의 먼저"
# [사설] 방송법 개정, 여야 타협점 모색해야
# [ET뷰]방송법 부의 의결…윤 정부, 방송개혁 정국으로
# [퇴직연금을 깨워라]① "자산배분형 디딤돌펀드에 주목하라"
# [퇴직연금을 깨워라]②하반기 디폴트옵션 의무화…운용 성적표 공개
# 고용부·금감원 "퇴직연금 수익률 높이자…시장 경쟁 유도"
# [사설] 윤 대통령 방미 폄훼·옹호 넘어 여야가 머리 맞대야
# [박정호의 시시각각] 대중시인 김지하, 대중가수 조용필
# [윤석만의 시선] 교대 커트라인 하락, 교사 인기 하락 탓?
# [리셋 코리아] 한·미 사이버동맹 걸맞은 사이버 역량 갖춰야
# '내 돈'에 손댄 은행사람들… 사라진 양심과 제식구 감싸기 [SCOOP 관점]
# 근로시간 69시간… 구로의 불편한 등대 [視리즈]
# 냉면, 비빔밥… 1만원으로 먹을 게 없는 야속한 시절
# 문 닫는 도봉고등학교 가보니… 사라질 공간에 남은 흔적들
# 여성을 가둔 감옥을 부수자, 마녀들과 춤추자
# 정통 워맨스, 그런데 킬힐 못 벗은 언니들의 '퀸메이커'
# 피해자 보호 관점 실종된 '나는 신이다' 열풍
# 60대에 '별의 순간' 양자경...트랜스젠더 연기로 8세에 은곰상
# [THINK ENGLISH] 이르면 올해 거리에서 배달 로봇 보게 될 듯
# [THINK ENGLISH] 윤 대통령, 전세사기 매물 경매 중단 지시
# [THINK ENGLISH] 조선 회화사의 공백 채울 걸작들의 귀환
# K-콘텐츠 점령한 ‘센 언니’들…유리 천장 뚫는 여성 서사의 진화[K-콘텐츠 뒤흔드는 걸크러쉬]
# 콘텐츠가 앞서간 알파걸의 시대 [K-콘텐츠 뒤흔드는 걸크러쉬]
# 조선의 걸 크러시와 K-컬처의 여전사들 [EDITOR's LETTER]
# 수차례 경고했는데…통학로서 아이를 또 잃었다
# 40년째 비탈길서 안전불감 작업…영도구도 단속 손놨다
# 어린이보호구역 등굣길 사망사고多...부산 교통사고만 매년 40여건
# 통학로 공사위험 꼼꼼하게 대비한 북구 행정 눈길
# 尹 “韓 핵무장 마음 먹으면 1년 이내에도 가능” 하버드大 연설
# 7, 8일 방한 가닥 기시다, ‘과거사 사죄-반성’ 밝힐지 주목
# 김여정 “결정적 행동” 핵 선제타격 위협… 정부 “초조함 반영”
# 中 “尹 압도적 친미정책, 北中러 보복 직면하게 될것”
# "진료비 많이 주면 비대면도 오케이" 의사의 태세전환 이유
# 국회에 법안 4개 발의됐지만…여야 막론 약사·의사 의원들 반대
# 초진 허용두고 전세계도 갈렸다… 플랫폼 vs 의료계 피터지는 이유
# 24년 묵히다 다시 '시계 제로'…결국 中에도 밀린 韓 비대면 진료
# "점심은 전통시장, 저녁은 맛길에서"... 부산 최대 번화가의 상생 프로젝트
# 천년고도 경주 성동시장... '라이브 커머스'로 2막 엽니다
# '삼겹살도 골라 먹는 재미' 고기먹방의 성지 아시나요
# "내가 번 돈 쟤한테 다 줘"…임창정, 또 투자자 행사 참석 논란
# ‘주가 조작 논란’ 임창정, ‘압구정 빌딩설’ 해명…“파주 건물 1채 뿐”
# 임창정 측 “주가조작단 ‘1조 파티’, 초대손님일 뿐 내용 몰랐다”
# 확장억제 강화 ‘워싱턴 선언’ 최대 성과…신냉전 구도 ‘숙제’ [국빈방미 결산]
# 첨단기술 동맹 맺고 8조 투자유치…IRA·반도체법 우려는 ‘여전’ [국빈방미 결산]
# “핵 보장 첫걸음” “경제성과 아쉬워”…한미정상회담 엇갈린 평가[국빈방미 결산]
# 尹대통령 “바이든 부부, 국빈 만찬 감사…다음엔 서울에서”
# [RSAC2023] 한-미 사이버동맹, ‘파이브아이즈’ 수준으로 강화
# [RSAC2023] 전시회 성황리 개막··· 보안 리더 기업 대부분 참여
# [RSAC2023] SIEM 시대 종말? 팔마 트렐릭스 CEO “SecOps 혁명 이뤄야”
# [RSAC2023] “사이버보안에 AI 기술 활용코자 하는 움직임 확인”
# 따뜻한 날씨에 늘어난 호흡기감염병…예방·관리수칙은?
# 무심코 먹은 감자튀김이 정신건강을 위협한다?
# '스마트폰'이 '뇌종양'에 미치는 안타까운 영향
# 취침 시간 34분 늦추면 고혈압 위험 ↑
# 방미 이후 후속 조치 주력...尹, 간호법 대응 '고심'
# 與 "제2의 한미방위조약" vs 野 "대국민 사기"
# '준비 부족' 지적한 박지원에 대통령실 "반국가적 작태"
# '핵 선제공격 위협' 北, 도발 카드 '만지작'
# SG발 주가폭락 사태, 8종목은 왜 타깃이 됐나?
# 전문가 79% “챗GPT 답변이 의사보다 낫다”
# 한국판 ‘버핏과 점심’ 1호 행사...정의선·박재욱과 방송인 노홍철
# 1분기 아파트 매입, 30대 비율 사상 최고
# 비대면 진료 초진 허용, 서로 물러설 수 없는 이유 [보건의료 리포트]
# 바이오헬스 인재 양성 나선 정부, 빠른 변화와 소통 필요하다 [보건의료 리포트]
# 바이오헬스 성장 위한 정부 '선물보따리'…'오답노트' 반복하나 [보건의료 리포트]
# [보건의료 리포트] 길 잃은 ‘혁신형 제약기업’, 변신의 갈림길 서다
# [오늘과학] 동료의 퇴사, 남은 직원들에게 미치는 영향은
# [오늘과학] 남성 육아휴직, 가족 구성원 성평등 의식 높인다
# [오늘과학] 북미서 발견된 5000만년 전 고추 화석
# [오늘과학] 하얗게 세어버린 머리카락 되돌리는 법
# [법정B컷]"전세사기요? 전 심부름만"…'빌라왕' 재판 판사의 분노
# SSBN 부산에 기항…'비핵화 선언'과 모순 아니라고?[안보열전]
# [그래?픽!]"저도 선생님 XX까요" 교권 추락…학생인권 때문이라고?
# [딥뉴스]리버버스는 '골병라인'을 구할 수 있을까
# 지지율로 본 尹정부 1년…최고 53%·최저 24%
# 한미, 포괄적 전략동맹 격상…확장억제 명문화[尹정부 개혁 1년]
# 주점·편의점 매출 150%↑…용산 상권 '특수'[용산시대 1년]
# "용산공원 개방 계기로 국민소통 강화되길"[용산시대 1년]
# 핵협의체 신설·전략자산 전개 확대…실효성 제고는 과제
# [뉴스초점] 박진 외교부 장관 '워싱턴 선언' 채택 등 방미 성과 설명
# 12년 만의 국빈 방문…글로벌 포괄적 전략동맹 확대
# 글로벌 리더 尹, 국격 드높였다…5박 7일간 국빈 방미 일정 마치고 귀국
# 尹, 안보·경제 동맹 후속조치 주력…중·러 간극도 좁혀야
# 尹 귀국에 여야 공방전…"대국민 사기 외교" vs "워싱턴선언, 승리 방정식"
# [직설] 순방 마친 윤 대통령 앞에 현안 '산적'…간호법 '거부권' 여부 관심
# [굿모닝 마켓] "실적만 따라간다"…뉴욕 증시 일제히 상승 마감
# [김대호 박사의 오늘 기업·사람] 한화·대우조선·HD현대·인텔·아마존·삼성·SK·FRB·JP모건·PNC
# [어제장 오늘장] '형만 한 아우 없다'…코스피는 회복했지만 코스닥은 또 하락
# '전세사기 피해자'가 되기 위한 조건?
# 국가 개입은 '전세사기'로 제한…깡통전세는 어쩌나
# '전세사기 바로 옆건물'…인천 건축왕 주상복합 가보니
# [중국은, 왜] '21세기 베를린', 대만…투키디데스는 틀렸나
# [우알생] 그들은 왜 '거지방'에 열광하나…조언대로 하루 살아보니
# [퍼센트] '근로자의 날' 누가 쉬고 못 쉬나…법이 갈라놓은 노동자들
# 수단 무력충돌 격화에…정부, 경찰까지 동원했다
# '극단적 선택' 성범죄자 앱스타인, CIA 수장·세계 석학도 자택 초대 이력
# 中, 연일 한미정상회담 깎아내리기…"친미 악몽될 것"
# 정부, '워싱턴 선언' 폄훼 중국 비판…"불순한 의도"
# [정승조의 아트홀릭] 미술관이 가장 잘하는 걸 안 볼 이유는 없다
# [아무튼, 자수] 꽃보다 그녀 ‘세월을 수놓다’
# ‘우주 최초 수달 공무원’ 충주씨의 귀한 실물 사진 보러오세요
# [명품 컷] 비 오는 날의 수채화처럼 청아한 각원사의 봄풍경
# 미국은 ‘국익’, 한국은 ‘미익’ [정상회담특집①]
# “냉전 때와 닮아…과거로 가는 동맹” [정상회담특집②]
# 과거사 사죄 요구가 ‘무릎 꿇리는’ 일인가
# 윤 대통령, 대만을 “세계적 문제”로 언급해 중국의 반발 부르다
# 대통령실이 꼽은 尹 국빈 방미 성과는
# "`워싱턴 선언` 3가지 포인트 눈여겨봐야…매우 잘된 선언"
# 대통령실 “‘워싱턴선언’, 제2한미상호방위조약…방미 최고성과”
# 국빈방미에 안보성과까지…높아진 대한민국 위상 실감
# ‘윤석열 특수활동비’ 6월 23일 공개된다
# [주간 뉴스타파] 1,243일만의 승소... '검사' 윤석열, 검증의 시간
# 확정판결 검찰예산 신속히 공개 안 하면, '간접강제' 신청한다
# 검찰의 방패를 뚫고, 정보공개 최종 판결을 받아내기까지
# 우크라, 크름반도 유류시설 공격 인정…“대반격 위한 준비”
# ‘제로백 3.8초’부터 ‘럭셔리’까지… 전기차 미래 뽐냈다[자동차]
# ‘깡통 전세’ 전세보증보험 가입 안돼…이제 전세가율 90%까지만 가입 가능
# 이번 방미 긍정 평가?...尹 지지율 4주만에 반등, 34.5%[리얼미터]
# 도대체 바닥은 어디일까...제주 아파트값 3억씩 ‘뚝뚝’ [김경민의 부동산NOW]
# “이러다 20억 다시 찍으려나”...마포 집값 슬금슬금 오른다 [김경민의 부동산NOW]
# 용인 반도체 클러스터 수혜지 어디?...이천·동탄 등 경기 남부 ‘반세권’ 뜬다[김경민의 부동산NOW]
# 아파트 이름만 무려 25글자?...“길고 어려운 아파트명 쉽게 바꾸자”
# AI 시대 우리는 무엇을 하고 살게 될까? 나의 미래 계급은? [SDF다이어리]
# [씨네멘터리] 디자이너들이 꼽은 최고의 영화 포스터는?
# [월드리포트] 확장억제 성과 논란…'말의 성찬'이 부른 후과
# [월드리포트] 일본 남성 아이돌 대부 '성착취' 의혹…주류 언론 나서나
# "민간 방송 공정성을 누가 심판할 수 있나"
# '핵무장론' 미련 못버리는 조선일보, 과거에는 어땠나
# '부실 감사' 논란에 한겨레 노조위원장 사퇴 파문
# 추경 가능성 생존 몸부림 TBS 앞에 강경한 서울시 의회
# [세계를 가다]물가 뛴다고…이집트 정부, 닭발 먹기 캠페인
# [아는기자]순방 외교서 ‘한일·한미일’ 이야기 많이 나온 이유는?
# [아는기자]‘주가조작 의혹’ 8개는 어떤 종목인가?
# [아는기자]“나의 친구”…윤석열-바이든, 36시간 동안 4개 일정
# NYT "미국서 환대받은 윤 대통령, 한국 분위기는 달라"
# 윤 대통령 "마음 먹으면 1년 이내 핵무장 가능하지만..."
# 윤 대통령 "전체주의가 민주주의 위협, 민주세력으로 위장"
# '사실상 핵공유'는 성과 부풀리기? 대통령실 "용어 집착할 필요 없어"
# "주가급등 후 하따까지"…이 '작전' 어디서 봤더라?[손엄지의 주식살롱]
# [단독]골퍼 A씨측 "라덕연 1년전 알게돼…라대표, 회사 사줄테니 관리해라"
# [작전이 판친다]임창정도 30억?…연예인·골퍼·의사 엮인 주가조작판
# [작전이 판친다] 세력 손털기 도와주는 '하따'…유튜버도 부채질
# [경제혹한 대응法]⑥ “회생기업 M&A는 ‘진술과 보증’이 없다…옥석 가리는 게 최대 관건”
# [경제혹한 대응法]⑤ “쌍용차·STX중공업도 시련 겪었다…회생, 기업이 살아있단 걸 확인시켜주는 과정”
# [경제혹한 대응法]④ “지금은 불황 초입…기업 회생 절차, 타이밍 빨라야 희생 줄일 수 있어”
# [경제혹한 대응法]③ “한번에 무너지거나, 한번에 살아나거나…IT기업 구조조정은 속도가 생명”
# 박광온 “‘돈 봉투 의혹’ 회피 말아야…대의원제 폐지는 시기상조”
# 40도 폭염에 말 죽고…바다 온도 관측 이래 최고
# “베트남 10명 중 1명이 X해요” 혐오 발언 시의원, 해명은? [주말엔]
# “안보 강화·경제 아쉬움”…미국 의원들이 본 방미 성과 [특파원 리포트]
# 퍼스트리퍼블릭 문제 확산 여부…5월 FOMC가 핵심 [위클리 3분 월스트리트]
# 국내서 투자유치 추진한 엘엔에프…막판에 싱가포르 택한 이유는[시그널]
# 플랫폼 시대 끝났다? VC, 반·배 스타트업 외엔 무관심
# 美 퍼스트리퍼블릭 입찰에 JP모건 등 참여…아시아 증시 개장 전 발표
# '97% 폭락' 美은행주에 뭉칫돈 … "포모 조급증 벗어나야"
# 겁없는 서학불개미…美 3배ETF에 1조
# 서학 불개미 어쩌나 …'밈주식' 베드배스, 결국 파산신청
# "SVB 감독 부실했다" 연준, 파산 책임 인정
# [레고랜드 1년] ① 장밋빛 기대 속 개장 '빛과 그림자' 교차…논란 여전
# [레고랜드 1년] ② '폐쇄성' 넘어 상생으로…"담장 밖까지 지갑 열려야"
# [레고랜드 1년] ③ 이순규 사장 "지역상생 통해 랜드마크 역할 할 것"(끝)
# ‘워싱턴 선언’ 들고 온 尹… 한일·한미일 연쇄회담 예고
# ‘핵협의그룹’ 판 키우기 원하는 美… 긴밀 협력 속도 내는 한일
# 中 “韓에 악몽, 이익보다 손실 클 것”… 사드 후 최악 우려
# 스포츠 꽃피운 금융, 비인기 스포츠도 키운다
# "홀인원 축하금 준다고?" 필드 가기 전엔 이 카드
# "올해는 우리가 이긴다" 은행권, 프로야구 예·적금 출시 봇물
# "북한 7차 핵실험 시 독자 핵무장으로 갈 수 밖에" 윤상현 국민의힘 의원 직격 인터뷰 [시사스페셜]
# 윤 대통령 오늘 귀국…여야, 방미 성과 '극과 극' 평가  [시사스페셜]
# 귀국 5일 만에 압수수색, 송영길 소환 빨라지나  [시사스페셜]
# 내일 윤리위 첫 회의, 김재원 '5·18 이전 징계' 무게  [시사스페셜]
# 尹, 12년 만의 국빈 방문…쏟아진 최초 기록들 [한미 新밀월 ②]
# '확장억제 강화' 워싱턴 선언의 성과와 과제는 [한미 新밀월 ①]
# 韓-美 첨단기술동맹 새 지평…59억 달러 투자 유치 성과
# '한미 신(新)밀월 시대' 열어젖힌 윤대통령, 귀국 장도 올랐다
# “매달 월급처럼 배당금이 또박또박” 요즘 인기 모으는 월배당 ETF
# ‘노랜딩’ 가능성 날린 SVB 파산, 다음 악재는 국제유가?
# “KB? 미래에셋? 어느 게 좋나요” 목돈 마련 돕는 다양한 청년 펀드들
# 월 소득 4000만 원으로 주담대 먼저 갚으세요
# Yoon fetes new nuclear accord as allies take harder line on NK
# Samsung eyeing 25% cut in chip production: analysts
# [Herald Interview] Winds of change in Korea's labor movement
# 오리고기 먹었더니, 몸속 혈관에 변화가?
# 혈압 관리에 주의...나트륨 많이 든 뜻밖 식품 5
# 체중 줄이고 혈당 천천히 낮게 올리는 음식은?
# 사상 최대 규모 ‘영월~양구 강원 내륙고속도’ 정부 첫 검토 착수
# 춘천 상중도(孤山) 발굴현장 공개…팽팽한 신경전
# 상업지 '춘천 명동입구' 주거지 '강원대 후문 먹자골목' 도내 최고 땅값 기록
# 강원 의료계 4일 부분파업…의료대란 오나?
# 적과 아군뿐인 ‘치명적’ 윤석열 외교…북·중·러 반발 거세진다
# 10년 뒤 불확실, 미국 올인 없다…기밀문서 속 각국 ‘생존외교술’
# 김건희 여사 방미 단독 일정 7개…갤러리 관람만 취재 ‘허용’
# 기업 이익도 한반도 미래도 못 챙긴 윤 대통령의 ‘가치외교’
# 가족모임 많은 5월, "외식비 부담돼요"…치킨·삼겹살 등 줄인상
# [남궁창성의 용산리포트] 16. 김건희 여사의 국빈방미 내조 외교
# 1분기 전국 아파트 거래 4명중 1명은 30대…2019년 이후 최대
# [최동열의 산썰(山說)] 6.산에서 어명을 받은 소나무들
# 전두환 손자 폭로는 인정 욕구와 가족 사랑의 발로 [+영상]
# “석열아, 먼저 손 내밀고 더 많이 들어라” [+영상]
# “尹, 술 마실 땐 ‘통 큰 사람’… 정치는 통 크게 못했다” [+영상]
# ‘길복순’ 전도연 “집에선 아이에게 쩔쩔매는 엄마예요”
# '돈봉투 파문' 민주당은 여유 왜? '이정도 스캔들 별 문제 없어' 안일한 인식 탓" [촌철살인]
# 尹 대통령 방미 성과 "100% 만족하기 어려워도 너무 폄하할 필요는 없어" [촌철살인]
# '구하라·박수홍' 변호인 "권경애, 변호사의 수치..법, 정의 실현하는지 의문"[여의도초대석]
# 장예찬 "송영길은 꼬리, 몸통은 이재명..연결고리 '키맨'은 바로 '이사람'"[여의도초대석]
# [기획] 中, 한미 밀착에 `경제보복` 예고
# [경고음 커지는 對中 수출] 반도체·배터리·스마트폰도 고전… 對中 무역적자 굳어질수도
# [경고음 커지는 對中 수출] 尹 방미로 냉랭해진 中… 당분간 갈등 기류 불가피
# 엉터리 아파트 추첨, "어? 5백 명이 빠졌네?"
# "형도 친부도 계모도 살해하고".. 자신도 극단 선택
# 지역특화비자 취업박람회.."외국인 300명 운집"
# 농촌 살리는 '활력 사업'..지속 추진은 과제
# [약손+] 아이들도 힘들다, '새 학기 증후군' ⑨ADHD라는 오해
# [영상+] "내 꼬리는 빨개" 가창 부채꼬리바위딱새
# [뉴스+] 죽음의 과속 방지턱···사고 잇따르는 이유는?
# [들어보니] 우리는 보통 사람입니다 | 빅벙커
# 민간 주도 혁신성장 궤도 올랐지만… 감세發 세수펑크 우려 '딜레마'[尹정부 1년 성과와 전망]
# 시장·기업 중심 정책 대전환… 수출·물가 등 지표 개선 '숙제'[尹정부 1년 성과와 전망]
# 민간 소비 살아났지만 저성장 탈출은 역부족[尹정부 1년 성과와 전망]
# 강제추행 혐의 B.A.P 전 멤버 징역 10개월 확정
# 대법 "군 병원에서 수술받다 숨진 군인, 보훈 대상자 인정 안돼"
# "조명·소음 방해돼" 드라마 촬영 현장에 벽돌 던진 40대 입건
# 경기 오산 예식장 건물서 불‥1백명 대피
# '안보·공급망·기술' 한·미 동맹 강화…기업 우려는 해소 못했다
# "워싱턴 선언은 제2 한·미 상호방위조약"
# 윤석열 대통령 "과학기술 협력은 한·미 동맹 새로운 영역"
# 윤석열 대통령 "핵무장, 1년내 가능하지만 NPT 존중 의무"
# 5박7일 안보·경제 행보… 與 ‘찬사’ 野 ‘혹평’ [윤 대통령 방미 성과와 평가]
# 행안부 “경기북부특별자치도, 분도 검토가 먼저”
# 경기도, 내년 ‘인구인지예산’ 편성…저출생·고령화 대응 나선다
# 직장갑질119, "괴롭힘·야근·징계해고 '3대 갑질' 만연"
# 406개 판결문으로 본 ‘법원으로 간 학폭’
# 학교폭력 그 이후, ‘생기부 빨간 줄’보다 중요한 것들이 있다
# 드라마보다 더 잔인한 현실, ‘학폭’ 판결문 406개 분석 [금요시사회]
# [뉴스 즉설]시치미 뚝 송영길, 동문서답 이재명, '돈봉투 민주당' 뭐가 중한디?
# [픽&톡]"마스크 벗었다고 코로나 끝난 게 아니다"
# [뉴스 즉설]영길이 형 아웃, 7인회 해체, 이재명 퇴진… 돈봉투 후폭풍 어디까지
# [줌인] 충청 인구감소 가속화
# 윤 대통령 귀국…‘미국 올인’ 후속 과제, 파도처럼 밀려온다
# 윤 대통령, 국빈 방미 마치고 서울공항 도착
# 일 언론 “기시다, 5월7~8일 방한해 정상회담 추진”···대통령실 “결정된 바 없어”
# 윤 대통령 ‘아메리칸 파이’···백악관의 ‘치밀한 빌드업’ 있었다
# 인파로 가득한 '서울페스타 2023 명동 페스티벌' [TF사진관]
# 윤석열, '5박 7일간 국빈 방미' 마치고 귀국 [TF사진관]
# 서울 밤하늘에 펼쳐진 '화려한 드론 쇼' [TF사진관]
# '방배본동' 모자 쓴 전성수 서초구청장 [TF사진관]
# 한·미 ‘新밀월’… 尹, 핵우산 들고 귀국
# “워싱턴 선언, 나토 약정보다 실효적… 한·미 방위 업그레이드”
# 尹 ‘아메리칸 파이’, 방미 하이라이트
# ‘가을이 사건’ 가스라이팅 있었나… 친모 입에 쏠린 눈
# [단독] 사상자 10명 ‘에쓰오일 폭발 사고’ 외국인 CEO, 처벌 대상서 빠졌다
# 성공작 평가 진주시 캐릭터 ‘하모’, 소극적 활용에 관심 ‘시들’
# 궂은 날씨에도 청춘의 춤은 뜨거웠다… 데스팟크루, 부산 댄스 페스티벌 우승
# [뉴스야?!] 전세 사기에 침묵하는 친文?
# [따져보니] '지역사회'가 뭐길래…'간호법' 대립 이유는?
# [단독] "빛·소음 때문에 짜증"…드라마 촬영장에 벽돌 투척한 주민 입건
# [포커스] '가짜뉴스' 몸살 앓는 지구…곳곳서 '전쟁'
# "꼭 재배해보고 작물 선택"…초보 귀농인의 '스마트 팜' 도전기 [귀농귀촌애(愛)]
# 美, 마약 엄벌에도 복용률 늘어… 치료 통해 ‘중독의 고리’ 끊어야 [세계는 지금]
# 천연고무 최대생산국 태국, 수출 세계 1위 제품들은? [박종현의 아세안 코너]
# ‘K방산 수출 첨병’ FA-50 생산현장을 가다 [S 스토리]
# 김재원 "심려 끼쳐 죄송", 태영호 "소신 변함  없어"..징계  향방은
# 해독작용 뛰어난 '미나리'.."대장염 개선에도 효과"
# 유급휴일 '근로자의 날'.."직장인 10명 중 3명  출근"
# 어디 '학폭' 뿐이랴.. '직장내 괴롭힘'에 신고조차 못해 "출근길이 지옥"
# 구독하신 기자가 최근 48시간 이내 작성한 기사가 제공됩니다. 전체 구독 리스트는 구독 설정에서 확인하세요.
# 기자별 기사를 자동 추천해 드립니다. 기자를 구독하시면 해당 기자의 최신 기사를 언론사별에서 확인할 수 있습니다.
# 국내 온·오프라인 유통업체들이 중소기업과 소상공인 제품을 최대 50%까지 할인 판매하는 ‘대한민국 동행축제’ 행사가 1일부터 열린다. 중소벤처기업부는 1일부터 28일까지 국내 최대 규모 판매 촉진 행사인 ‘함께하면 대박 나는 2023 동행축제’를 연다고 지난 30일 밝혔다. 이 기간 250여 개 유통 채널에서 중소기업·소상공인 제품 1만9000여 개를 최대 50% 할인 판매한다. 쿠팡 등 국내 주요 온라인 쇼핑몰 46곳은 가정의 달을 맞아 식품·유아용품·패션잡화·뷰티제품 등을 최대 50%까지 할인하고, 위메프·티몬·11번가 등 9개 라이브커머스 채널에서는 인플루언서가 참여하는 방송을 통해 중소기업 제품을 판매한다. 슈퍼마켓과 편의점에선 식품과 생필품 중심의 할인 행사를, 백화점에선 중소기업 제품 기획전을 연다. 지역경제 활성화를 위해 지역 우수제품 판매 특별전을 열고, 인천공항 면세점에선 중소기업 제품 특별 기획전이 시작된다. 소비 촉진을 위해 전통시장 등에서 쓸 수 있는 온누리 상...
# 보령시가 행정안전부에서 실시한 '2022년도 공공데이터 제공 운영실태 평가'에서 2년 연속 우수기관으로 선정됐다. 이번 평가는 45개 중앙행정기관, 243개 지방자치단체, 282개 공공기관 등 총 570개 기관을 대상 진행됐으며, 공공데이터의 '개방', '활용', '품질', '관리체계', '기타(감점)' 등 5개 영역 16개 지표로 나누어 평가했다. 2022년도 실태평가 결과에 따르면 시는 평가점수 80.47점을 기록했으며, 전국 기초자치단체 평균 평가점수 56점에 비해 월등한 성적을 보였다. 관리체계 영역에서는 공공데이터 제공책임관 주재 간담회, 공공데이터 제공 운영 교육, 공공데이터 표준 정의서 개정 등을 충실히 이행하여 공공데이터 관리체계를 마련해 높은 평가를 받았다. 또한 개방 영역에서는 보유 데이터 전수조사 및 수요조사를 통해 신규데이터 발굴을 위한 노력한 것과 '2022 보령방문의 해'를 맞아 보령시 관광지도, 홍보영상 등 신규 비정형 데이터를 개방한 것이 좋은 점수를 받...
# 구독한 연재 중 최근 48시간 이내 작성된 기사가 제공됩니다. 전체 구독 리스트는 구독 설정에서 확인하세요.
# 다양한 연재 기사를 자동 추천해 드립니다. 연재를 구독하시면 해당 연재의 최신 기사를 언론사별에서 확인할 수 있습니다.
# 기자·연재 카드 개선 안내
# None
# None

# %%
# Q. p 태그 데이터를 모두 불러와서 한글만 출력

# %%
url = 'https://news.naver.com'
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'lxml')

import re
texts = bs.text
result = re.findall('[가-힣]+',texts)
' '.join(result)
# Out:
# '네이버 뉴스 본문 바로가기 뉴스 연예 스포츠 날씨 프리미엄 검색 언론사별 정치 경제 사회 생활 문화 과학 세계 랭킹 신문보기 오피니언 팩트체크 전체 언론사 뉴스스탠드 라이브러리 콘텐츠 월 전체 언론사 뉴스스탠드 라이브러리 언론사편집 기자 연재 구독설정 월 일 구독 한옥은 중국 건축 또 억지 중국 누리꾼 댓글 테러 정부가 메타버스 콘텐츠 창작자들을 위해 무료로 개방한 한국 전통문화 데이터가 일부 중국 누리꾼들의 댓글 테러로 몸살을 앓고 있습니다 오늘 일 게임업계에 따르면 에픽게임즈가 운영하는 언리얼 엔진 마켓플레이스 에 매일경제 월 일 구독 이서진이 왜 거기서 나와 어떻게 오셨냐 묻자 검찰 계실 때 미국을 국빈 방문한 윤석열 대통령이 참석한 행사에 배우 이서진이 모습을 나타냈다 윤 대통령은 지난 일 현지시간 워싱턴 미국영화협회 건물에서 개최된 글로벌 영상콘텐츠 리더십 포럼 에 참석했다 이 광주방송 월 일 구독 유승민 한미정상회담 코리안 파이는 뭘 얻었나 큰 성과 없어 유승민 국민의힘 전 의원이 한미정상회담 결과 와 관련 대한민국 대통령이면 대한민국 국민들께서 가장 위협을 느끼는 북핵문제에 대해서 이번에 길과 방향을 제대로 틀고 왔어야 된다 면서 그런데 오히려 미국한테 좀 동아일보 월 일 구독 근무 장교 장교들 초코파이 도리토스 좋아해 사람 세계 북한 장교들은 한국의 초코파이와 도리토스 나초칩 를 좋아했어요 년부터 년까지 유엔군 사령부 소속으로 비무장지대 에서 근무한 미국 해군 퇴역 장교 대니얼 맥셰인 전 소령은 지난달 일 미 월 일 구독 최대 만원 서울시 청년월세 어떻게 받나요 서울시는 청년에게 월세 최대 만원을 지원하는 년도 청년월세 대상자를 모집합니다 청년월세는 서울의 높은 주거비 부담을 덜어주기 위해 만 세 청년 만 천명에게 개월간 월세 최대 만원을 새로보기 한국경제 월 일 구독 제네시스 벤츠까지 제치더니 이번엔 오픈카 승부수 국내에서 벤츠를 이미 앞지른 제네시스가 글로벌에서도 판매량이 꾸준히 증가하며 승승장구하고 있다 특히 최근에는 컨버터블 콘셉트카를 공개하며 고급 차 이미지 굳히기에 나섰다 일 업계에 따르면 지난해 제네시스 브랜드 조선일보 월 일 구독 갤럭시 플립 예상도 보니 폴더 모양 대화면 삼성전자가 하반기에 출시하는 폴더블폰 갤럭시 플립 의 예상도를 미국의 한 테크 블로그가 공개했다 삼성전자는 차기작의 외부 화면을 인치 수준으로 키울 예정인데 이 블로그는 인치 폴더 모양 의 채널 월 일 구독 근로자의 날 서울 도심 곳곳 대규모 집회 근로자의 날인 오늘 일 양대노총을 비롯한 노동 단체들이 서울 도심 곳곳에서 대규모 집회를 엽니다 민주노총은 오늘 오후 시 서울 종로구 동화면세점 앞에서 세계노동절대회 를 열고 월 총파업 투쟁을 선포할 계획 오마이뉴스 월 일 구독 속이 썩어 구멍이 크게 뚫려도 너무 예쁩니다 천연기념물 지정된 순천 승주 평지마을 이팝나무 장성 백양사 쌍계루 앞의 이팝나무 각진국사가 꽂은 지팡이가 자랐다는 전설이 전해진다 꽃이 활짝 핀 지난해 월 풍경이다 이돈삼 이팝나무꽃이 피고 있다 연둣 월 일 구독 동영상 재생시간 청소년 마약범죄 최대 사형 구형 학원가 사건 적용 검토 검찰이 청소년 마약범죄에 대해서는 최고 사형까지 구형하겠다며 엄정 대응을 예고했습니다 검찰은 당장 학원가 마약 음료 사건에 가중처벌 조항을 적용하는 방안을 검토하고 있습니다 취재기자 연결해 자세한 내용 알아봅 새로보기 코메디닷컴 월 일 구독 운동 효과 떨어뜨리는 잘못된 운동 습관 운동을 위해 시간과 비용을 들여 열심히 했는데도 몸의 변화가 없다면 자신의 운동 습관을 체크해 봐야 한다 특히 체중 허리 사이즈 근육의 양 등 중요 수치에 변화가 없다면 운동 효과에 대한 회의감마저 갖게 된 여성신문 월 일 구독 만원 저축에 정부지원 년 최대 만원 청년내일저축 신청 시작 정부가 저소득층 청년 저축액의 최대 배까지 같은 금액을 추가 지원하는 청년내일저축계좌 신규 가입자 모집이 일 시작된다 중위소득 이하 가구의 만 세 세 일하는 청년이이라면 청년내일저축계좌를 개설 코리아중앙데일리 월 일 구독 더팩트 월 일 구독 배터리 아저씨 투자 조언 돈 벌 기회 왔다 향후 년은 국내 배터리 산업 영상 에코프로그룹주 더 오른다 국내 배터리업계 주목해야 비판적 읽기 피력 기관 증권사 등 이해관계 있다 돈 벌 기회가 주어져 있다 년 주기로 꼭 투자해야 하는 투자 대상들이 생기는데 그게 마침 배터리 머니투데이 월 일 구독 르포 베일에 싸인 라덕연 오른팔 집에도 에도 없었다 월 일 시 분 방문하였지만 부재중인 관계로 배달안내드립니다 지난달 일 오후 시쯤 머니투데이가 찾은 서울 노원구의 한 주택 앞 현관문에는 출입국관리소가 씨 앞으로 보낸 등기를 수령하라는 새로보기 중앙일보 월 일 구독 원빈 이나영 청담동 빌딩 몸값 억 년새 배이상 뛰었다 배우 원빈 이나영 부부가 년 매입한 서울 강남구 청담동 건물이 억원을 호가하는 것으로 알려졌다 일 부동산 업계에 따르면 원빈과 이나영은 년 월 지하철 분당선 압구정로데오역에서 거 부산일보 월 일 구독 갑자기 화나서 컵라면 먹던 초등생에 흉기 휘두르고 도주한 대 구속기소 컵라면을 먹던 초등학생에게 흉기를 휘둘러 다치게 한 대가 재판에 넘겨졌다 일 수원지검 평택지청 형사 부는 살인미수 혐의로 군을 구속기소 했다고 밝혔다 군은 지난 달 일 경기도 평택시의 한 아 프레시안 월 일 구독 성행위 촬영물이 엔터 로 신동엽 뒤로 감춰진 성착취 배우 인터뷰한 성 인물 논란 어떻게 봐야하나 산업은 일본 내 성착취 구조 의 첨단에 자리합니다 그 구조에 대한 비판적 고려 없이 이를 콘텐츠화한다뇨 이나영 중앙대학교 사회학과 교수 청주방송 월 일 구독 속리산 법주사 문화재 관람료 폐지 관광활성화 기대 충북 보은군 속리산 법주사가 징수해 온 문화재 관람료가 폐지될 예정임에 따라 지역 관광경기 활성화 기대가 높아지고 있습니다 국가지정문화재 민간 소유자 또는 관리단체가 문화재 관람료를 감면하면 그 비용을 국가가 지원 더스쿠프 월 일 구독 김포골드라인 리버버스 실패작 수상택시 년 만의 오버랩 리즈 때만 되면 포털 뉴스란에 심심찮게 등장하는 단어가 있습니다 수상택시입니다 그 옆에는 늘 함께 붙어다니는 말이 있습니다 서울시입니다 서울시는 년부터 서울의 교통혼잡을 완화하기 위한 대안으로 수상택 새로보기 월 일 구독 동영상 재생시간 수단 군벌 또 시간 휴전 합의 북한 무기 사용 지난달 일부터 군벌 간 무력 충돌로 극도의 혼란에 빠진 수단에서 또다시 시간 동안 휴전이 연장됐습니다 한편 군벌의 다툼에 대북 제재로 금지된 북한의 무기가 사용됐을 수 있다고 미국 북한 전문 매체가 보도했습 문화일보 월 일 구독 살아있는 전직 대통령을 다큐로 문재인입니다 가 빚은 문화의 정치화 올해 전주국제영화제에서 공개된 다큐멘터리 영화 문재인입니다 일 개봉 는 잡초를 좋아하는 자연인 문재인의 일상과 문 전 대통령 주변 인사들의 입 을 빌린 대통령 문재인의 면모를 병치시킨다 문 전 대통령의 정 디지털타임스 월 일 구독 윤재옥 박광온 다른 듯 닮은 꼴 케미 친윤 비명 의 부드러운 리더십 온건 성향이어서 당사자간 소통은 무리 없을 전망이지만 거대 여야 양강 대립 구도 속 운신의 폭 좁다는 지적도 사법리스크 따라 비주류 박광온 변수될수도 국민의힘과 더불어민주당이 나란히 새 원내사령탑을 뽑으면서 입법 조세일보 월 일 구독 수출 개월째 감소 개월 연속 무역적자 기록 우리나라 월 수출이 지난해 월 이후 개월째 하락세를 보이면서 무역수지도 개월 연속 하락세를 면치 못했다 지난 일 관세청이 발표한 월 수출입 현황 잠정치 에 따르면 수출은 억 만 달러 서울경제 월 일 구독 지금까지 횟집서 먹는 매운탕 은 매운탕이 아니다 먹을꼰대 겉모습은 꼰대지만 누구보다 맛에 진심인 이우석 먹고놀기연구소 소장이 풀어내는 쉬운 미식 이번에는 호불호가 갈리기 십상인 매운탕 편으로 찾아왔습니다 이우석 먹고놀기연구소 소장은 횟집에서 회 뜨고 남은 생선으로 끓 새로보기 주간조선 월 일 구독 똘똘한 석이 낫다 개딸이 기존 팬덤과 다른 이유 여기 있다 더불어민주당 박광온 원내대표가 취임 일주일도 되지 않아 이른바 개딸들의 거센 공격을 받고 있다 이에 이재명 대표가 연휴 기간에 직접 페이스북에 글을 올려 개딸들에게 자제를 요청했으나 그들의 분노 ...

# %% [markdown]
# #### requests + bs

# %% [markdown]
# #### 과제1_0501.
# 'https://news.naver.com/' 에서 title 내용을 세가지 방법으로 출력하세요.

# %%
# requests
from bs4 import BeautifulSoup
import requests
import re
url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=105"
res = requests.get(url).text
soup = BeautifulSoup(res,'html.parser')
wf = soup.find('wf').text
text = ''.join(re.findall('[^A-Z0-9]?[0-9가-힣]+[^A-Z0-9]?',wf))
text
# Out:
# '(하늘상태) 이번 예보기간은 대체로 흐린 날이 많겠으나, 8일(월)~11일(목)은 대체로 맑겠습니다.(기온) 이번 예보기간 아침 기온은 4~17도로 평년(최저기온 6~12도)과 비슷하거나 조금 높겠고, 낮 기온은 13~26도로 평년(최고기온 17~25도)과 비슷하거나 조금 낮겠습니다.(해상) 동해중부해상의 물결은 5일(금)~6일(토)은 1.0~3.0m로 높게 일겠습니다.(주말전망) 6일(토)~7일(일)은 대체로 흐리겠습니다. 아침 기온은 6~17도, 낮 기온은 13~22도가 되겠습니다. 4일(목)부터 7일(일) 사이 기압골의 발달 정도와 이동 속도에 따라 강수시점과 구역이 변경될 가능성이 있으니, 앞으로 발표되는 최신 예보를 반드시 참고하기 바랍니다.'

# %%
# urllib
import re
from bs4 import BeautifulSoup
import urllib.request
import urllib.parse

API = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"
# 매개변수를 URL 인코딩합니다.
values = {
    'stnId': '109' # 서울 109, 강원도 105
}
params = urllib.parse.urlencode(values)
# 요청 전용 URL을 생성합니다.
url = API + "?" + params
print("url=", url)

res = urllib.request.urlopen(url)
soup = BeautifulSoup(res,'html.parser')
wf = soup.find('wf').string
text = ''.join(re.findall('[^A-Z0-9]?[0-9가-힣]+[^A-Z0-9]?',wf))
text
# Out:
# url= http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=109
# '(강수) 4일(목)~7일(일)은 대체로 흐리겠고, 8일(월)~11일(목)은 맑겠습니다.(기온) 아침 기온은 4일(목)~7일(일)은 10~17도로 평년(최저기온 9~12도)보다 높겠고, 그 밖의 날은 8~13도로 평년과 비슷하겠습니다. 이번 예보기간 낮 기온은 18~25도로 평년(최고기온 20~24도)과 비슷하겠습니다.(해상) 서해중부해상의 물결은 4일(목)~5일(금)은 1.0~3.0m로 높게 일겠고, 그 밖의 날은 1.0~2.0m로 일겠습니다.(주말전망) 6일(토)과 7일(일)은 대체로 흐리겠습니다. 아침 기온은 10~16도, 낮 기온은 19~21도가 되겠습니다. 4일(목)부터 7일(일) 사이 기압골의 발달 정도와 이동 속도에 따라 강수 예보가 변경될 수 있으니, 앞으로 발표되는 최신 예보를 반드시 참고하기 바랍니다.'

# %% [markdown]
# #### 연습 : urllib

# %% [markdown]
# #### 과제2_0501.
# "http://www.naver.com" 사이트에서 span 태그에 연결된 한글만을 불필요한 공백을 제거한 후 출력하세요.

# %% [markdown]
# #### 과제3_0501.
# "http://www.naver.com" 사이트에서 span 태그에 연결된 문자 + 숫자를 불필요한 공백을 제거한 후 출력하세요.

# %% [markdown]
# #### Q. "http://www.naver.com" 사이트에서 a 태그에 id가 있는 경우에 대하여 연결된 문자 + 숫자를 아래와 같이 출력하세요.
# - 해당되는 조건에 맞게 모두 출력
# - 한글만 열방향으로 출력
# - 불필요한 공백을 제거한 후 한글만 한줄에 출력

# %%
# A.
import urllib.request as rq
import re
url = "http://www.naver.com"
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'html.parser')
texts = bs.find_all('a',id=True)
texts
# Out:
# [<a class="_2aeXMlrb BMgpjddw" data-clk="dropdownload1b" href="https://installer-whale.pstatic.net/downloads/banner/RydDy7/WhaleSetup.exe" id="NM_whale_download_btn"><span style="background-color: #0436c7">다운로드</span></a>,
#  <a class="link_set" data-clk="top.mkhome" href="https://help.naver.com/support/welcomePage/guide.help" id="NM_set_home_btn">네이버를 시작페이지로</a>,
#  <a class="btn_keyboard" href="#" id="ke_kbd_btn" onclick="return false;" role="button"><span class="blind">한글 입력기</span><span class="ico_keyboard"></span></a>,
#  <a aria-pressed="false" class="btn_arw _btn_arw fold" data-atcmp-element="" href="#" id="nautocomplete" role="button" tabindex="2"><span class="blind">자동완성 레이어</span><span class="ico_arr"></span></a>,
#  <a class="btn_set" data-clk="tca.like" href="#" id="NM_THEME_EDIT_SET" role="button">관심주제 설정</a>,
#  <a class="content_top" href="#wrap" id="NM_scroll_top_btn"><span class="blind">TOP</span></a>]

# %% [markdown]
# #### 과제4_0501.
# "http://www.naver.com" 사이트에서 a 태그에 id가 있는 경우에 대하여 연결된 문자 + 숫자를 아래와 같이 출력하세요.
# - 해당되는 조건에 맞게 모두 출력
# - 한글만 열방향으로 출력
# - 불필요한 공백을 제거한 후 한글만 한줄에 출력

# %%
import urllib.request as rq
import re
url = "http://www.naver.com"
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'lxml')
text = bs.find('div').get_text()
text
# Out:
# ' 뉴스스탠드 바로가기 주제별캐스트 바로가기 타임스퀘어 바로가기 쇼핑캐스트 바로가기 로그인 바로가기 '

# %%
from bs4 import BeautifulSoup
import urllib.request as rq
url = 'https://news.naver.com/'
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'lxml')
print(bs.find_all('p'))
# Out:
# [<p class="cjs_d">미국 뉴욕 타임스스퀘어에 있던 작은 샌드위치 가게가 문을 닫자 브로드웨이 배우들이 한자리에 모였다. 40년 가까이 이 가게를 운영한 한인 사장의 ‘은퇴식’을 열어주기 위해서였다. 최근 미국 폭스5 뉴욕, CBS 뉴욕</p>, <p class="cjs_d">“4인 가족이 1주일 정도 해외에 함께 나가면, 10만원을 훌쩍 넘어가는 게 현실이다” (여행객) “1주일이나 열흘간 해외에 갔다고 십몇만원(로밍요금)을 내야 하는 것은 과해 보인다” (박윤규 과학기술정보통신부 2차</p>, <p class="cjs_d">운동을 위해 시간과 비용을 들여 열심히 했는데도 몸의 변화가 없다면, 자신의 운동 습관을 체크해 봐야 한다. 특히 체중, 허리 사이즈, 근육의 양 등 중요 수치에 변화가 없다면, 운동 효과에 대한 회의감마저 갖게 된</p>, <p class="cjs_d">국민의힘 중앙윤리위원회가 오늘(1일) 설화로 논란을 일으킨 김재원·태영호 최고위원에 대한 징계 절차 개시를 결정했습니다. 국민의힘 윤리위는 오늘 오전 10시 서울 여의도 중앙당사에서 첫 회의를 열고 윤리위 안건에 대</p>, <p class="cjs_d">AV 배우 인터뷰한 &lt;성+인물&gt; 논란, 어떻게 봐야하나? "AV산업은 일본 내 ‘성착취 구조’의 첨단에 자리합니다. 그 구조에 대한 비판적 고려 없이 이를 콘텐츠화한다뇨." - 이나영 중앙대학교 사회학과 교수 AV(</p>, <p class="cjs_d">시중에 유통 중인 한 ‘무알코올 맥주’에서 세균수 기준 부적합이 확인돼 식품의약품안전처가 전량 회수조치에 나섰습니다. 식약처는 오비맥주 광주공장에서 제조한 ‘버드와이저 제로(Budweiser Zero)’가 세균수 기</p>, <p class="cjs_d">국내에서 벤츠를 이미 앞지른 제네시스가 글로벌에서도 판매량이 꾸준히 증가하며 승승장구하고 있다. 특히 최근에는 컨버터블 콘셉트카를 공개하며 고급 차 이미지 굳히기에 나섰다. 1일 업계에 따르면 지난해 제네시스 브랜드</p>, <p class="cjs_d"># 때만 되면 포털 뉴스란에 심심찮게 등장하는 단어가 있습니다. 수상택시입니다. 그 옆에는 늘 함께 붙어다니는 말이 있습니다. 서울시입니다. # 서울시는 2005년부터 서울의 교통혼잡을 완화하기 위한 대안으로 수상택</p>, <p class="cjs_d">미국 우주개발 스타트업이 물을 동력으로 쓰는 우주선을 개발해 우주 운송사업에 뛰어들겠다고 선언했다. 지구 저궤도 운송은 내년 말 첫 시험을 거쳐 2025년 상용 서비스를 시작한다는 야심찬 계획이다. 일론 머스크가 설</p>, <p class="cjs_d">네이버가 불공정 논란이 일었던 뉴스콘텐츠제휴 약관을 전면 수정해 재공지했다. 네이버는 28일 오후 뉴스콘텐츠제휴 언론사들에 이메일을 보내 “(기존 약관 대신) 추가 수정한 개정 약관으로 재동의를 구하고자 한다”며 “</p>, <p class="cjs_d">부산지역의 올해 1분기 건축 허가·착공·준공 실적이 지난해 같은 기간에 비해 크게 개선된 것으로 나타났다. 특히 경기 동향을 확인할 수 있는 후행 지표인 준공 면적 증가율은 전국 1위를 기록했다. 1일 국토교통부에 </p>, <p class="cjs_d">윤석열 대통령의 5박7일 국빈 방미 일정이 끝난 가운데 대통령의 미 의회 ‘영어’ 연설에 관한 반응이 뜨거웠다. 이와 관련 중요한 것은 ‘외교 성과’라는 지적과 함께 외신의 보도 내용도 눈길을 끈다. 태영호 국민의힘</p>, <p class="cjs_d">리얼미터선 4주 만에 반등, 한국갤럽은 하락세 尹대통령, '방미 성과' 홍보 매진하고 국정 드라이브 5박7일간의 미국 국빈 방문 일정을 마치고 귀국한 윤석열 대통령이 '지지율 반등'이라는 성적표를 받게 됐다. 1일 </p>, <p class="cjs_d">마이크로바이옴 시장의 게임체인저가 등장했다. 투약 방법의 불편함이 마이크로바이옴 치료제의 한계로 지적됐는데 간편하게 ‘먹는’ 방법의 마이크로바이옴 치료제가 세상에 나온 것이다. 이에 마이크로바이옴 치료제 시장 성장은</p>, <p class="cjs_d">컵라면을 먹던 초등학생에게 흉기를 휘둘러 다치게 한 10대가 재판에 넘겨졌다. 1일 수원지검 평택지청 형사1부는 살인미수 혐의로 A(17) 군을 구속기소 했다고 밝혔다. A 군은 지난 달 3일 경기도 평택시의 한 아</p>, <p class="cjs_d">“내 머리 위를 넘어 기시다 총리의 발밑에 떨어진 순간 폭탄인 줄 알았어요.” 4월15일 오전 11시30분께, 와카야마시 사이카자키 어시장에서 중의원 보궐선거 지원 연설을 하려던 기시다 후미오 총리를 향해 연막탄 크</p>, <p class="cjs_d">윤석열 대통령은 1일 133번째 '근로자의 날'을 맞아 "진정한 노동 약자를 보호하기 위해 노사 법치주의를 확립하고, 우리 헌법 정신에 위배되는 기득권의 고용세습은 확실히 뿌리 뽑을 것"이라고 밝혔다. 윤 대통령은 </p>, <p class="cjs_d">Korea's exports fell for the seventh consecutive month in April due primarily to weak demand for semiconductors amid an </p>, <p class="cjs_d">온건 성향이어서 당사자간 소통은 무리 없을 전망이지만 거대 여야 양강 대립 구도 속 운신의 폭 좁다는 지적도 사법리스크 따라 '비주류' 박광온 변수될수도 국민의힘과 더불어민주당이 나란히 새 원내사령탑을 뽑으면서 입법</p>, <p class="cjs_d">윤석열 대통령이 미국 백악관 국빈 만찬에서 '아메리칸 파이'(American Pie)를 부른 모습이 여러 외신에도 보도되며 화제를 모으고 있다. 윤 대통령은 미국 국빈 방문 중 지난 달 26일(현지시간) 열린 백악관</p>, <p class="cjs_d">편집자주한국은 의료 가성비가 좋다고 하죠. 아프면 예약 없이 3,000~4,000원에 전문의를 보는 나라, 흔치 않으니까요. 그러나 건보 흑자, 일부 의료인의 희생 덕에 양질의 의료를 누렸던 시대도 끝나 갑니다. 미</p>, <p class="cjs_d">겉모습은 꼰대지만 누구보다 맛에 진심인 이우석 먹고놀기연구소 소장이 풀어내는 쉬운 미식, 이번에는 호불호가 갈리기 십상인 매운탕 편으로 찾아왔습니다. 이우석 먹고놀기연구소 소장은 "횟집에서 회 뜨고 남은 생선으로 끓</p>, <p class="cjs_d">정부가 문화유산을 활용한 게임·메타버스 창작을 지원하기 위해 무료로 개방한 문화재 3D 데이터에 중국 누리꾼들의 '댓글 테러'가 이어지고 있다. 1일 게임 업계 등에 따르면 에픽게임즈가 운영하는 '언리얼 엔진 마켓플</p>, <p class="cjs_d">우리나라에서 세단의 대명사는 쏘나타였다. 특히 강남 지역에서 자주 보이는 수입차에 ‘강남 쏘나타’라는 별명을 붙이기도 했다. 최근 세단 모델이 위기를 겪는 가운데 고급스러운 디자인과 효율 높은 친환경 디젤 엔진을 탑</p>, <p class="cjs_d">LG에너지솔루션·삼성SDI 1분기 호실적… 금융당국 “2차전지 신용거래 급증” 우려 “떨어질 땐 다 같이, 오를 땐 혼자.” 4월 26일 한 LG에너지솔루션 주주가 어닝 서프라이즈 소식에 보인 반응이다. 이날 LG에</p>, <p class="cjs_d">한은금융망에 신규 가입한 보험회사가 약 1년 사이에 두 배나 증가한 것으로 나타났다. 한국은행은 이례적이라는 평가를 내놨다. 보험사는 보험상품의 만기가 길어 장기물 자산 중심으로 거래를 해왔으나, 지난해 말 자금난에</p>, <p class="cjs_d">"에코프로그룹주 더 오른다…국내 배터리업계 주목해야'" '비판적 읽기' 피력…"기관·증권사 등 이해관계 있다" "돈 벌 기회가 주어져 있다. 10년 주기로 꼭 투자해야 하는 투자 대상들이 생기는데, 그게 마침 배터리</p>, <p class="cjs_d">서울시는 청년에게 월세 최대 20만원을 지원하는 '2023년도 청년월세' 대상자를 모집합니다. 청년월세는 서울의 높은 주거비 부담을 덜어주기 위해 만 19∼39세 청년 2만5천명에게 10개월간 월세 최대 2 ...
#
#
#
#                                 방송 모아보기 클릭 시<br/>해당 방송사 뉴스를 볼 수 있으며<br/><span class="comp_ico_live">LIVE</span> 표시가 된 경우 생중계로<br/>시청 가능합니다.
#
#
#                     </p>, <p class="cjs_dept_desc">'돈봉투 파문' 민주당은 여유 왜? '이정도 스캔들 별 문제 없어' 안일한 인식 탓" [촌철살인]</p>, <p class="cjs_dept_desc">尹 대통령 방미 성과 "100% 만족하기 어려워도 너무 폄하할 필요는 없어" [촌철살인]</p>, <p class="cjs_dept_desc">'구하라·박수홍' 변호인 "권경애, 변호사의 수치..법, 정의 실현하는지 의문"[여의도초대석]</p>, <p class="cjs_dept_desc">장예찬 "송영길은 꼬리, 몸통은 이재명..연결고리 '키맨'은 바로 '이사람'"[여의도초대석]</p>, <p class="cjs_dept_desc">[THINK ENGLISH] 이르면 올해 거리에서 배달 로봇 보게 될 듯</p>, <p class="cjs_dept_desc">[THINK ENGLISH] 윤 대통령, 전세사기 매물 경매 중단 지시</p>, <p class="cjs_dept_desc">[THINK ENGLISH] 조선 회화사의 공백 채울 걸작들의 귀환</p>, <p class="cjs_dept_desc">"점심은 전통시장, 저녁은 맛길에서"... 부산 최대 번화가의 상생 프로젝트</p>, <p class="cjs_dept_desc">천년고도 경주 성동시장... '라이브 커머스'로 2막 엽니다</p>, <p class="cjs_dept_desc">'삼겹살도 골라 먹는 재미' 고기먹방의 성지 아시나요</p>, <p class="cjs_dept_desc">[RSAC2023] 한-미 사이버동맹, ‘파이브아이즈’ 수준으로 강화</p>, <p class="cjs_dept_desc">[RSAC2023] 전시회 성황리 개막··· 보안 리더 기업 대부분 참여</p>, <p class="cjs_dept_desc">[RSAC2023] SIEM 시대 종말? 팔마 트렐릭스 CEO “SecOps 혁명 이뤄야”</p>, <p class="cjs_dept_desc">[RSAC2023] “사이버보안에 AI 기술 활용코자 하는 움직임 확인”</p>, <p class="cjs_dept_desc">5월 '가정의달'? 아니 '걱정의달'.. 사먹기도, 해먹기도 부담 "지갑만  텅텅"</p>, <p class="cjs_dept_desc">김재원 "심려 끼쳐 죄송", 태영호 "소신 변함  없어"..징계  향방은</p>, <p class="cjs_dept_desc">해독작용 뛰어난 '미나리'.."대장염 개선에도 효과"</p>, <p class="cjs_dept_desc">유급휴일 '근로자의 날'.."직장인 10명 중 3명  출근"</p>, <p class="cjs_dept_desc">확장억제 강화 ‘워싱턴 선언’ 최대 성과…신냉전 구도 ‘숙제’ [국빈방미 결산]</p>, <p class="cjs_dept_desc">첨단기술 동맹 맺고 8조 투자유치…IRA·반도체법 우려는 ‘여전’ [국빈방미 결산]</p>, <p class="cjs_dept_desc">“핵 보장 첫걸음” “경제성과 아쉬워”…한미정상회담 엇갈린 평가[국빈방미 결산]</p>, <p class="cjs_dept_desc">尹대통령 “바이든 부부, 국빈 만찬 감사…다음엔 서울에서”</p>, <p class="cjs_dept_desc">K-콘텐츠 점령한 ‘센 언니’들…유리 천장 뚫는 여성 서사의 진화[K-콘텐츠 뒤흔드는 걸크러쉬]</p>, <p class="cjs_dept_desc">콘텐츠가 앞서간 알파걸의 시대 [K-콘텐츠 뒤흔드는 걸크러쉬]</p>, <p class="cjs_dept_desc">조선의 걸 크러시와 K-컬처의 여전사들 [EDITOR's LETTER]</p>, <p class="cjs_dept_desc">강제추행 혐의 B.A.P 전 멤버 징역 10개월 확정</p>, <p class="cjs_dept_desc">대법 "군 병원에서 수술받다 숨진 군인, 보훈 대상자 인정 안돼"</p>, <p class="cjs_dept_desc">"조명·소음 방해돼" 드라마 촬영 현장에 벽돌 던진 40대 입건</p>, <p class="cjs_dept_desc">경기 오산 예식장 건물서 불‥1백명 대피</p>, <p class="cjs_dept_desc">“복리후생 꿈도 못꿔”…기업간 복지 양극화 심각 [5·1 근로자의 날]</p>, <p class="cjs_dept_desc">5박7일 안보·경제 행보… 與 ‘찬사’ 野 ‘혹평’ [윤 대통령 방미 성과와 평가]</p>, <p class="cjs_dept_desc">행안부 “경기북부특별자치도, 분도 검토가 먼저”</p>, <p class="cjs_dept_desc">경기도, 내년 ‘인구인지예산’ 편성…저출생·고령화 대응 나선다</p>, <p class="cjs_dept_desc">엉터리 아파트 추첨, "어? 5백 명이 빠졌네?"</p>, <p class="cjs_dept_desc">"형도 친부도 계모도 살해하고".. 자신도 극단 선택</p>, <p class="cjs_dept_desc">지역특화비자 취업박람회.."외국인 300명 운집"</p>, <p class="cjs_dept_desc">농촌 살리는 '활력 사업'..지속 추진은 과제</p>, <p class="cjs_dept_desc">윤 대통령 귀국…‘미국 올인’ 후속 과제, 파도처럼 밀려온다</p>, <p class="cjs_dept_desc">윤 대통령, 국빈 방미 마치고 서울공항 도착</p>, <p class="cjs_dept_desc">일 언론 “기시다, 5월7~8일 방한해 정상회담 추진”···대통령실 “결정된 바 없어”</p>, <p class="cjs_dept_desc">윤 대통령 ‘아메리칸 파이’···백악관의 ‘치밀한 빌드업’ 있었다</p>, <p class="cjs_dept_desc">[직설] 순방 마친 윤 대통령 앞에 현안 '산적'…간호법 '거부권' 여부 관심</p>, <p class="cjs_dept_desc">[손에 잡히는 재테크] ‘굴비'로 만드는 '적금밥상'…돈도 재미도 잡는 적금?</p>, <p class="cjs_dept_desc">[굿모닝 마켓] "실적만 따라간다"…뉴욕 증시 일제히 상승 마감</p>, <p class="cjs_dept_desc">[김대호 박사의 오늘 기업·사람] 한화·대우조선·HD현대·인텔·아마존·삼성·SK·FRB·JP모건·PNC</p>, <p class="cjs_dept_desc">사회초년생·신혼부부 울린 인천 미추홀 '전세사기'</p>, <p class="cjs_dept_desc">'전세사기 피해자'가 되기 위한 조건?</p>, <p class="cjs_dept_desc">국가 개입은 '전세사기'로 제한…깡통전세는 어쩌나</p>, <p class="cjs_dept_desc">민간 주도 혁신성장 궤도 올랐지만… 감세發 세수펑크 우려 '딜레마'[尹정부 1년 성과와 전망]</p>, <p class="cjs_dept_desc">시장·기업 중심 정책 대전환… 수출·물가 등 지표 개선 '숙제'[尹정부 1년 성과와 전망]</p>, <p class="cjs_dept_desc">민간 소비 살아났지만 저성장 탈출은 역부족[尹정부 1년 성과와 전망]</p>, <p class="cjs_dept_desc">글로벌 리더 尹, 국격 드높였다…5박 7일간 국빈 방미 일정 마치고 귀국</p>, <p class="cjs_dept_desc">尹, 안보·경제 동맹 후속조치 주력…중·러 간극도 좁혀야</p>, <p class="cjs_dept_desc">尹 귀국에 여야 공방전…"대국민 사기 외교" vs "워싱턴선언, 승리 방정식"</p>, <p class="cjs_dept_desc">尹, 이달 한일·한미일 연쇄회담…한미일 협력 심화 본격화</p>, <p class="cjs_dept_desc">기시다 지지율, 외교 성과 힘입어 8개월 만에 50%대 회복</p>, <p class="cjs_dept_desc">기시다, 내달 초순 방한 '가닥'…식민지배 사죄·반성 언급할까</p>, <p class="cjs_dept_desc">'안보·공급망·기술' 한·미 동맹 강화…기업 우려 ...
# <a class="u_ftlk" data-mpurl='{"m":"https://m.naver.com/services.html","p":"https://www.naver.com/more.html"}' href="https://m.naver.com/services.html" onclick="nclk(event,'fot.serviceall','','');">전체서비스</a>
# </p>, <p class="u_cr">
# <span class="u_ftm">
# <span class="u_cri u_cri_v1"><a class="u_cra" data-mpurl='{"m":"https://policy.naver.com/policy-mobile/term.html?type=1?type=1","p":"https://policy.naver.com/rules/service.html"}' href="https://policy.naver.com/policy-mobile/term.html?type=1?type=1" onclick="nclk(event,'fot.agreement','','');">이용약관</a></span>
# <span class="u_cri u_cri_v1"><a class="u_cra" data-mpurl='{"m":"https://policy.naver.com/policy-mobile/privacy.html","p":"https://policy.naver.com/rules/privacy.html"}' href="https://policy.naver.com/policy-mobile/privacy.html" onclick="nclk(event,'fot.privacy','','');"><strong>개인정보처리방침</strong></a></span>
# <span class="u_cri u_cri_v1">청소년 보호 책임자 : 이희만</span>
# <span class="u_cri u_cri_v1"><a class="u_cra" data-mpurl='{"m":"https://m.news.naver.com/ombudsman/index","p":"https://news.naver.com/main/ombudsman/index.naver"}' href="https://m.news.naver.com/ombudsman/index" onclick="nclk(event,'fot.guide','','');">서비스안내</a></span>
# </span>
# <span class="u_cri">각 언론사가 직접 콘텐츠를 편집합니다.</span>
# </p>]

# %%
# find() : 하나의 요소만 가져 옴
print(bs.find('p'))
# Out:
# <p class="cjs_d">미국 뉴욕 타임스스퀘어에 있던 작은 샌드위치 가게가 문을 닫자 브로드웨이 배우들이 한자리에 모였다. 40년 가까이 이 가게를 운영한 한인 사장의 ‘은퇴식’을 열어주기 위해서였다. 최근 미국 폭스5 뉴욕, CBS 뉴욕</p>

# %%
# limit : 태그의 양을 제한
print(bs.find_all('p', limit=1),'\n')
print(bs.find_all('p', limit=10))
# Out:
# [<p class="cjs_d">미국 뉴욕 타임스스퀘어에 있던 작은 샌드위치 가게가 문을 닫자 브로드웨이 배우들이 한자리에 모였다. 40년 가까이 이 가게를 운영한 한인 사장의 ‘은퇴식’을 열어주기 위해서였다. 최근 미국 폭스5 뉴욕, CBS 뉴욕</p>]
#
# [<p class="cjs_d">미국 뉴욕 타임스스퀘어에 있던 작은 샌드위치 가게가 문을 닫자 브로드웨이 배우들이 한자리에 모였다. 40년 가까이 이 가게를 운영한 한인 사장의 ‘은퇴식’을 열어주기 위해서였다. 최근 미국 폭스5 뉴욕, CBS 뉴욕</p>, <p class="cjs_d">“4인 가족이 1주일 정도 해외에 함께 나가면, 10만원을 훌쩍 넘어가는 게 현실이다” (여행객) “1주일이나 열흘간 해외에 갔다고 십몇만원(로밍요금)을 내야 하는 것은 과해 보인다” (박윤규 과학기술정보통신부 2차</p>, <p class="cjs_d">운동을 위해 시간과 비용을 들여 열심히 했는데도 몸의 변화가 없다면, 자신의 운동 습관을 체크해 봐야 한다. 특히 체중, 허리 사이즈, 근육의 양 등 중요 수치에 변화가 없다면, 운동 효과에 대한 회의감마저 갖게 된</p>, <p class="cjs_d">국민의힘 중앙윤리위원회가 오늘(1일) 설화로 논란을 일으킨 김재원·태영호 최고위원에 대한 징계 절차 개시를 결정했습니다. 국민의힘 윤리위는 오늘 오전 10시 서울 여의도 중앙당사에서 첫 회의를 열고 윤리위 안건에 대</p>, <p class="cjs_d">AV 배우 인터뷰한 &lt;성+인물&gt; 논란, 어떻게 봐야하나? "AV산업은 일본 내 ‘성착취 구조’의 첨단에 자리합니다. 그 구조에 대한 비판적 고려 없이 이를 콘텐츠화한다뇨." - 이나영 중앙대학교 사회학과 교수 AV(</p>, <p class="cjs_d">시중에 유통 중인 한 ‘무알코올 맥주’에서 세균수 기준 부적합이 확인돼 식품의약품안전처가 전량 회수조치에 나섰습니다. 식약처는 오비맥주 광주공장에서 제조한 ‘버드와이저 제로(Budweiser Zero)’가 세균수 기</p>, <p class="cjs_d">국내에서 벤츠를 이미 앞지른 제네시스가 글로벌에서도 판매량이 꾸준히 증가하며 승승장구하고 있다. 특히 최근에는 컨버터블 콘셉트카를 공개하며 고급 차 이미지 굳히기에 나섰다. 1일 업계에 따르면 지난해 제네시스 브랜드</p>, <p class="cjs_d"># 때만 되면 포털 뉴스란에 심심찮게 등장하는 단어가 있습니다. 수상택시입니다. 그 옆에는 늘 함께 붙어다니는 말이 있습니다. 서울시입니다. # 서울시는 2005년부터 서울의 교통혼잡을 완화하기 위한 대안으로 수상택</p>, <p class="cjs_d">미국 우주개발 스타트업이 물을 동력으로 쓰는 우주선을 개발해 우주 운송사업에 뛰어들겠다고 선언했다. 지구 저궤도 운송은 내년 말 첫 시험을 거쳐 2025년 상용 서비스를 시작한다는 야심찬 계획이다. 일론 머스크가 설</p>, <p class="cjs_d">네이버가 불공정 논란이 일었던 뉴스콘텐츠제휴 약관을 전면 수정해 재공지했다. 네이버는 28일 오후 뉴스콘텐츠제휴 언론사들에 이메일을 보내 “(기존 약관 대신) 추가 수정한 개정 약관으로 재동의를 구하고자 한다”며 “</p>]

# %% [markdown]
# url = 'https://news.naver.com/' 사이트 p태크에서 class가 cjs_ht인 데이터를 출력하세요.

# %%
from bs4 import BeautifulSoup
import requests as rq
url = 'https://news.naver.com/'
r = rq.get(url)
html = r.text
bs = BeautifulSoup(html, 'lxml')

# print(bs.find('p', class_="cjs_ht"))
print(bs.find_all('p', {'class':"cjs_d"}))
# Out:
# [<p class="cjs_d">“북한 장교들은 한국의 초코파이와 도리토스(나초칩)를 좋아했어요.” 2013년부터 2021년까지 유엔군 사령부 소속으로 비무장지대(DMZ)에서 근무한 미국 해군 퇴역 장교 대니얼 맥셰인 전 소령은 지난달 28일 미 </p>, <p class="cjs_d">“내 머리 위를 넘어 기시다 총리의 발밑에 떨어진 순간 폭탄인 줄 알았어요.” 4월15일 오전 11시30분께, 와카야마시 사이카자키 어시장에서 중의원 보궐선거 지원 연설을 하려던 기시다 후미오 총리를 향해 연막탄 크</p>, <p class="cjs_d">마이크로바이옴 시장의 게임체인저가 등장했다. 투약 방법의 불편함이 마이크로바이옴 치료제의 한계로 지적됐는데 간편하게 ‘먹는’ 방법의 마이크로바이옴 치료제가 세상에 나온 것이다. 이에 마이크로바이옴 치료제 시장 성장은</p>, <p class="cjs_d">정부가 메타버스 콘텐츠 창작자들을 위해 무료로 개방한 한국 전통문화 데이터가 일부 중국 누리꾼들의 댓글 테러로 몸살을 앓고 있습니다. 오늘(1일) 게임업계에 따르면 에픽게임즈가 운영하는 '언리얼 엔진 마켓플레이스'에</p>, <p class="cjs_d">세상을 바라보고 해석하는 시각이 남다른 Z세대(1990년대 중반~2000년대 초반 출생 세대). 그들이 바라보는 세상은 어떤 모습일까요. 머니S는 Z세대 기자들이 직접 발로 뛰며 그들의 시각으로 취재한 기사로 꾸미는</p>, <p class="cjs_d">겉모습은 꼰대지만 누구보다 맛에 진심인 이우석 먹고놀기연구소 소장이 풀어내는 쉬운 미식, 이번에는 호불호가 갈리기 십상인 매운탕 편으로 찾아왔습니다. 이우석 먹고놀기연구소 소장은 "횟집에서 회 뜨고 남은 생선으로 끓</p>, <p class="cjs_d">윤석열 대통령이 미국 백악관 국빈 만찬에서 '아메리칸 파이'(American Pie)를 부른 모습이 여러 외신에도 보도되며 화제를 모으고 있다. 윤 대통령은 미국 국빈 방문 중 지난 달 26일(현지시간) 열린 백악관</p>, <p class="cjs_d">윤석열 대통령의 5박7일 국빈 방미 일정이 끝난 가운데 대통령의 미 의회 ‘영어’ 연설에 관한 반응이 뜨거웠다. 이와 관련 중요한 것은 ‘외교 성과’라는 지적과 함께 외신의 보도 내용도 눈길을 끈다. 태영호 국민의힘</p>, <p class="cjs_d">소시에테제네랄(SG)증권 발 주가 폭락 사태와 관련해 피해자라고 나선 가서 임창정이 이른바 '1조 축하 파티'에 이어 또 다른 고액 투자자 모임에도 임 씨가 나간 사실이 1일 밝혀졌다. SBS에 따르면 임창정은 지난</p>, <p class="cjs_d">중국이 우리나라 반도체 산업에 대한 압박에 나섰다. 원산지 점검과 통관 검사 강화 조치에 이어 우리 기업의 중국 수출 계약 취소 사례까지 등장, 미-중 갈등으로 인해 국내 기업 피해가 가시화되는 것이 아니냐는 우려가</p>, <p class="cjs_d">근력 운동 중 한 세트할 때 몇 번 동작을 반복하는가? 대부분 10~15번이라고 답할 것이다. 이 숫자는 도대체 어디서 온 걸까? 사실 5번 이하로 해도 된다. 30번 이상으로 해도 된다. 운동 목적에 따라 달라질 </p>, <p class="cjs_d">동원그룹, 맥도날드 인수 포기… “메뉴 하나도 글로벌 본사 허락 필요” 2016년 맥도날드 매각 불발 때도 ‘자율권’ 걸림돌 지적 업계 “스타벅스와 달리 작은 것 하나도 본사 허락받아야” KG그룹, KFC 운영 당시</p>, <p class="cjs_d">미국 뉴욕 타임스스퀘어에 있던 작은 샌드위치 가게가 문을 닫자 브로드웨이 배우들이 한자리에 모였다. 40년 가까이 이 가게를 운영한 한인 사장의 ‘은퇴식’을 열어주기 위해서였다. 최근 미국 폭스5 뉴욕, CBS 뉴욕</p>, <p class="cjs_d">LG에너지솔루션·삼성SDI 1분기 호실적… 금융당국 “2차전지 신용거래 급증” 우려 “떨어질 땐 다 같이, 오를 땐 혼자.” 4월 26일 한 LG에너지솔루션 주주가 어닝 서프라이즈 소식에 보인 반응이다. 이날 LG에</p>, <p class="cjs_d">기사내용 요약 AP 보도…"분란 혐의 등으로 3년형 선고" 코로나19가 처음 유행한 중국 후베이성 우한 실태를 고발했던 시민이 3년 만에 석방될 것이라고 AP통신이 30일(현지시간) 보도했다. 통신은 이 시민의 친척</p>, <p class="cjs_d">세계적인 베스트셀러 '부자 아빠 가난한 아빠'의 저자 로버트 기요사키가 미국 연방준비제도(Fed·연준)를 저격하고 나섰다. 27일(현지시간) 기요사키는 자신의 트위터를 통해 연준이 미국 경제의 심장 역할을 하는 지역</p>, <p class="cjs_d">간호법 제정에 반대하며 단식을 해온 곽지연 대한간호조무사협회 회장이 단식 농성에 돌입한 지 닷새만인 어제 병원으로 이송됐습니다. 농성 현장을 찾은 조규홍 보건복지부 장관은 "같은 간호 인력 간에도 협의가 이뤄지지 않</p>, <p class="cjs_d">문 전 대통령의 퇴임 후 일상을 보여주는 다큐멘터리 영화 '문재인입니다'가 29일 전주 국제영화제에서 공개됐다. 다큐는 문 전 대통령이 평산마을에 도착한 지난해 봄부터 가을까지 시간적 순서에 따라 반려견과 함께 마을</p>, <p class="cjs_d">더불어민주당 박광온 원내대표가 취임 일주일도 되지 않아 이른바 개딸들의 거센 공격을 받고 있다. 이에 이재명 대표가 연휴 기간에 직접 페이스북에 글을 올려 개딸들에게 자제를 요청했으나, 그들의 분노가 좀처럼 가라앉지</p>, <p class="cjs_d">국민의힘 윤리위원회는 1일 실언으로 논란을 일으킨 김재원, 태영호 최고위원에 대한 징계를 개시하기로 결정했다. 황정근 윤리위원장은 이날 오전 여의도 중앙당사에서 열린 전체회의 후 브리핑에서 "김재원 최고위원과 태영호</p>, <p class="cjs_d">송영길 전 대표가 내일(2일) '2021년 전당대회 돈 봉투 의혹'과 관련해 기자회견을 열 예정입니다. 당시 자신의 경선 캠프에 몸담았던 관계자들을 대상으로 검찰의 강제수사가 이어지자 직접 반박에 나서기로 한 것으로</p>, <p class="cjs_d">1년5개월 넘게 해고 상태인 서울 중구 명동 세종호텔 해고노동자들의 천막농성장이 강제로 뜯겨나갔다. 농성 인원이 적은 2023년 4월4일 서울 중구청은 경찰까지 동원해 주변을 지키며 ‘행정대집행’이란 이름으로 농성장</p>, <p class="cjs_d">올여름 엘니뇨의 발달로 남부지방을 중심으로 많은 비가 내릴 것으로 보인다. 기상청은 현재 중립상태를 유지하고 있는 엘니뇨·라니냐 감시구역(열대태평양 남위5도~북위5도, 서경170도~서경120도 지역) 해수면 온도가 </p>, <p class="cjs_d">전국민주노동조합총연맹 제주지역본부가 '세계노동절 제주대회'를 열고, 7월 총파업에 나서겠다고 선포했습니다. 민주노총 제주본부는 오늘(1일) 오전 제주시청 앞에서 조합원 1,000여명이 참여한 가운데, '2023 세계</p>, <p class="cjs_d">올해 전주국제영화제에서 공개된 다큐멘터리 영화 ‘문재인입니다’(10일 개봉)는 잡초를 좋아하는 자연인 문재인의 일상과 문 전 대통령 주변 인사들의 ‘입’을 빌린 대통령 문재인의 면모를 병치시킨다. 문 전 대통령의 정</p>, <p class="cjs_d">이재명 더불어민주당 대표가 1일 근로자의 날을 맞아 "133년 전 노동자들이 '8시간 노동'을 외치며 일어섰건만, 2023년 대한민국에선 '주 69시간 노동'이 국가 정책으로 추진돼 땀 흘려 일하는 시민의 삶이 위태</p>, <p class="cjs_d">KG모빌리티(구 쌍용자동차)가 전기버스 업체인 에디슨 모터스 인수에 열중입니다. 에디슨 모터스는 한때 KG그룹과 쌍용차 인수를 두고 경쟁을 벌였던 곳입니다. 에디슨 모터스는 쌍용차 인수 본 계약까지 체결했지만 인수금</p>, <p class="cjs_d">“금융규제 방식은 포크레인식으로 모두 다 이렇게 엎어 버리는 방식인데, 기술의 분야를 그런 식으로 규제를 하면 기술이 발전할 수 없겠지요.”(최화인 블록체인 에반젤리스트) “이 대목이 지금 되게 좀 중요한 것 같은데< ...

# %%
# Q. texts = bs.find_all('p', {'class':"cjs_d"})에서 한글만 출력하세요(p테그별로 열방향)

# %%
texts = bs.find_all('p', {'class':'cjs_d'})

for text in texts:
    print(text.text,'\n')
# Out:
# “북한 장교들은 한국의 초코파이와 도리토스(나초칩)를 좋아했어요.” 2013년부터 2021년까지 유엔군 사령부 소속으로 비무장지대(DMZ)에서 근무한 미국 해군 퇴역 장교 대니얼 맥셰인 전 소령은 지난달 28일 미
#
# “내 머리 위를 넘어 기시다 총리의 발밑에 떨어진 순간 폭탄인 줄 알았어요.” 4월15일 오전 11시30분께, 와카야마시 사이카자키 어시장에서 중의원 보궐선거 지원 연설을 하려던 기시다 후미오 총리를 향해 연막탄 크
#
# 마이크로바이옴 시장의 게임체인저가 등장했다. 투약 방법의 불편함이 마이크로바이옴 치료제의 한계로 지적됐는데 간편하게 ‘먹는’ 방법의 마이크로바이옴 치료제가 세상에 나온 것이다. 이에 마이크로바이옴 치료제 시장 성장은
#
# 정부가 메타버스 콘텐츠 창작자들을 위해 무료로 개방한 한국 전통문화 데이터가 일부 중국 누리꾼들의 댓글 테러로 몸살을 앓고 있습니다. 오늘(1일) 게임업계에 따르면 에픽게임즈가 운영하는 '언리얼 엔진 마켓플레이스'에
#
# 세상을 바라보고 해석하는 시각이 남다른 Z세대(1990년대 중반~2000년대 초반 출생 세대). 그들이 바라보는 세상은 어떤 모습일까요. 머니S는 Z세대 기자들이 직접 발로 뛰며 그들의 시각으로 취재한 기사로 꾸미는
#
# 겉모습은 꼰대지만 누구보다 맛에 진심인 이우석 먹고놀기연구소 소장이 풀어내는 쉬운 미식, 이번에는 호불호가 갈리기 십상인 매운탕 편으로 찾아왔습니다. 이우석 먹고놀기연구소 소장은 "횟집에서 회 뜨고 남은 생선으로 끓
#
# 윤석열 대통령이 미국 백악관 국빈 만찬에서 '아메리칸 파이'(American Pie)를 부른 모습이 여러 외신에도 보도되며 화제를 모으고 있다. 윤 대통령은 미국 국빈 방문 중 지난 달 26일(현지시간) 열린 백악관
#
# 윤석열 대통령의 5박7일 국빈 방미 일정이 끝난 가운데 대통령의 미 의회 ‘영어’ 연설에 관한 반응이 뜨거웠다. 이와 관련 중요한 것은 ‘외교 성과’라는 지적과 함께 외신의 보도 내용도 눈길을 끈다. 태영호 국민의힘
#
# 소시에테제네랄(SG)증권 발 주가 폭락 사태와 관련해 피해자라고 나선 가서 임창정이 이른바 '1조 축하 파티'에 이어 또 다른 고액 투자자 모임에도 임 씨가 나간 사실이 1일 밝혀졌다. SBS에 따르면 임창정은 지난
#
# 중국이 우리나라 반도체 산업에 대한 압박에 나섰다. 원산지 점검과 통관 검사 강화 조치에 이어 우리 기업의 중국 수출 계약 취소 사례까지 등장, 미-중 갈등으로 인해 국내 기업 피해가 가시화되는 것이 아니냐는 우려가
#
# 근력 운동 중 한 세트할 때 몇 번 동작을 반복하는가? 대부분 10~15번이라고 답할 것이다. 이 숫자는 도대체 어디서 온 걸까? 사실 5번 이하로 해도 된다. 30번 이상으로 해도 된다. 운동 목적에 따라 달라질
#
# 동원그룹, 맥도날드 인수 포기… “메뉴 하나도 글로벌 본사 허락 필요” 2016년 맥도날드 매각 불발 때도 ‘자율권’ 걸림돌 지적 업계 “스타벅스와 달리 작은 것 하나도 본사 허락받아야” KG그룹, KFC 운영 당시
#
# 미국 뉴욕 타임스스퀘어에 있던 작은 샌드위치 가게가 문을 닫자 브로드웨이 배우들이 한자리에 모였다. 40년 가까이 이 가게를 운영한 한인 사장의 ‘은퇴식’을 열어주기 위해서였다. 최근 미국 폭스5 뉴욕, CBS 뉴욕
#
# LG에너지솔루션·삼성SDI 1분기 호실적… 금융당국 “2차전지 신용거래 급증” 우려 “떨어질 땐 다 같이, 오를 땐 혼자.” 4월 26일 한 LG에너지솔루션 주주가 어닝 서프라이즈 소식에 보인 반응이다. 이날 LG에
#
# 기사내용 요약 AP 보도…"분란 혐의 등으로 3년형 선고" 코로나19가 처음 유행한 중국 후베이성 우한 실태를 고발했던 시민이 3년 만에 석방될 것이라고 AP통신이 30일(현지시간) 보도했다. 통신은 이 시민의 친척
#
# 세계적인 베스트셀러 '부자 아빠 가난한 아빠'의 저자 로버트 기요사키가 미국 연방준비제도(Fed·연준)를 저격하고 나섰다. 27일(현지시간) 기요사키는 자신의 트위터를 통해 연준이 미국 경제의 심장 역할을 하는 지역
#
# 간호법 제정에 반대하며 단식을 해온 곽지연 대한간호조무사협회 회장이 단식 농성에 돌입한 지 닷새만인 어제 병원으로 이송됐습니다. 농성 현장을 찾은 조규홍 보건복지부 장관은 "같은 간호 인력 간에도 협의가 이뤄지지 않
#
# 문 전 대통령의 퇴임 후 일상을 보여주는 다큐멘터리 영화 '문재인입니다'가 29일 전주 국제영화제에서 공개됐다. 다큐는 문 전 대통령이 평산마을에 도착한 지난해 봄부터 가을까지 시간적 순서에 따라 반려견과 함께 마을
#
# 더불어민주당 박광온 원내대표가 취임 일주일도 되지 않아 이른바 개딸들의 거센 공격을 받고 있다. 이에 이재명 대표가 연휴 기간에 직접 페이스북에 글을 올려 개딸들에게 자제를 요청했으나, 그들의 분노가 좀처럼 가라앉지
#
# 국민의힘 윤리위원회는 1일 실언으로 논란을 일으킨 김재원, 태영호 최고위원에 대한 징계를 개시하기로 결정했다. 황정근 윤리위원장은 이날 오전 여의도 중앙당사에서 열린 전체회의 후 브리핑에서 "김재원 최고위원과 태영호
#
# 송영길 전 대표가 내일(2일) '2021년 전당대회 돈 봉투 의혹'과 관련해 기자회견을 열 예정입니다. 당시 자신의 경선 캠프에 몸담았던 관계자들을 대상으로 검찰의 강제수사가 이어지자 직접 반박에 나서기로 한 것으로
#
# 1년5개월 넘게 해고 상태인 서울 중구 명동 세종호텔 해고노동자들의 천막농성장이 강제로 뜯겨나갔다. 농성 인원이 적은 2023년 4월4일 서울 중구청은 경찰까지 동원해 주변을 지키며 ‘행정대집행’이란 이름으로 농성장
#
# 올여름 엘니뇨의 발달로 남부지방을 중심으로 많은 비가 내릴 것으로 보인다. 기상청은 현재 중립상태를 유지하고 있는 엘니뇨·라니냐 감시구역(열대태평양 남위5도~북위5도, 서경170도~서경120도 지역) 해수면 온도가
#
# 전국민주노동조합총연맹 제주지역본부가 '세계노동절 제주대회'를 열고, 7월 총파업에 나서겠다고 선포했습니다. 민주노총 제주본부는 오늘(1일) 오전 제주시청 앞에서 조합원 1,000여명이 참여한 가운데, '2023 세계
#
# 올해 전주국제영화제에서 공개된 다큐멘터리 영화 ‘문재인입니다’(10일 개봉)는 잡초를 좋아하는 자연인 문재인의 일상과 문 전 대통령 주변 인사들의 ‘입’을 빌린 대통령 문재인의 면모를 병치시킨다. 문 전 대통령의 정
#
# 이재명 더불어민주당 대표가 1일 근로자의 날을 맞아 "133년 전 노동자들이 '8시간 노동'을 외치며 일어섰건만, 2023년 대한민국에선 '주 69시간 노동'이 국가 정책으로 추진돼 땀 흘려 일하는 시민의 삶이 위태
#
# KG모빌리티(구 쌍용자동차)가 전기버스 업체인 에디슨 모터스 인수에 열중입니다. 에디슨 모터스는 한때 KG그룹과 쌍용차 인수를 두고 경쟁을 벌였던 곳입니다. 에디슨 모터스는 쌍용차 인수 본 계약까지 체결했지만 인수금
#
# “금융규제 방식은 포크레인식으로 모두 다 이렇게 엎어 버리는 방식인데, 기술의 분야를 그런 식으로 규제를 하면 기술이 발전할 수 없겠지요.”(최화인 블록체인 에반젤리스트) “이 대목이 지금 되게 좀 중요한 것 같은데
#
# 운동을 위해 시간과 비용을 들여 열심히 했는데도 몸의 변화가 없다면, 자신의 운동 습관을 체크해 봐야 한다. 특히 체중, 허리 사이즈, 근육의 양 등 중요 수치에 변화가 없다면, 운동 효과에 대한 회의감마저 갖게 된
#
# '정권교체 예상' 여론조사 크게 엇나가…대만, 한숨 돌릴 듯 이재림 특파원 = 금전 외교를 앞세운 중국의 영향력 확대 의지도, 중남미에 거세게 일렁이는 온건 좌파 물결('핑크 타이드')도 인구 750만명의 남미 내륙
#
# 경기 이천시(시장 김경희)가 20일 시 농산물 브랜드인 <임금님표이천> 상표 사용 30년을 맞아 기념식과 함께 ‘쌀밥데이’를 선포한다. 시는 1993년 가짜 이천쌀 문제에 대응하고자 <임금님표 이천쌀> 상표를 사용하
#
# 요즘 4대강 사업의 주역들이 부쩍 대중 앞에 자주 등장하고 있다. 이명박 전 대통령(이하 존칭 생략)은 며칠 전 측근 유인촌의 연극을 관람했고 앞으로 4대강도 방문할 예정이라고 한다. 4대강 추진본부장이었던 심명필은
#
# 국립공원 입장이 '완전' 무료화된다. 그동안 국립공원 지역 내에 위치한 사찰에서 국가 지정 문화재관람 명목으로 등산객들로부터 입장료를 받아왔는데, 대한불교조계종이 26일 관람료를 면제한다고 밝혔다. 면제 조치는 5월
#
# 우리나라 4월 수출이 지난해 10월 이후 7개월째 하락세를 보이면서, 무역수지도 14개월 연속 하락세를 면치 못했다. 지난 1일 관세청이 발표한 '3월 수출입 현황(잠정치)'에 따르면, 수출은 496억2000만 달러
#
# 지난 4월 21일 국회에서 상속세 과세체계 개편과 관련한 토론회가 열렸다. 더불어민주당 정책위원회 수석부의장인 김병욱·송기헌·유동수 의원이 주최했다. 토론회 명칭은 ‘상속세 유산취득세 방식 긍정적 검토 토론회’다.
#
# 우리나라에서 세단의 대명사는 쏘나타였다. 특히 강남 지역에서 자주 보이는 수입차에 ‘강남 쏘나타’라는 별명을 붙이기도 했다. 최근 세단 모델이 위기를 겪는 가운데 고급스러운 디자인과 효율 높은 친환경 디젤 엔진을 탑
#
# 한은금융망에 신규 가입한 보험회사가 약 1년 사이에 두 배나 증가한 것으로 나타났다. 한국은행은 이례적이라는 평가를 내놨다. 보험사는 보험상품의 만기가 길어 장기물 자산 중심으로 거래를 해왔으나, 지난해 말 자금난에
#
# 2023년 4월 13일 국회 본회의에서 '대구경북신공항 건설을 위한 특별법'이 통과됐습니다. 대구경북신공항은 현재 대구 도심에 있는 군 공항인 K2와 대구국제공항을 경북 의성군 비안면과 군위군 소보면으로 새롭게 옮기
#
# ● 진중권 “尹, 박근혜 정권보다 퇴행적” ● 박성민 “민주당 분열 가능성 60%” [+영상] 윤석열 1년을 말하다 [+영상] 국민의힘을 말하다 [+영상] 민주당을 말하다 2024년 4월 10일 치러지는 22대 총선
#
# 이틀 만에 두 번째 압수수색 송영길 전 더불어민주당 대표. 연합뉴스 '더불어민주당 전당대회 돈봉투 의혹' 피의자로 입건된 송영길 전 민주당 대표가 오는 2일 검찰에 자진 출석하겠다고 밝혔다. 송 전 대표 측 선종문
#
# 편집자주한국은 의료 가성비가 좋다고 하죠. 아프면 예약 없이 3,000~4,000원에 전문의를 보는 나라, 흔치 않으니까요. 그러나 건보 흑자, 일부 의료인의 희생 덕에 양질의 의료를 누렸던 시대도 끝나 갑니다. 미
#
# 일본의 중노년 싱글여성 단체인 ‘와쿠와쿠 시니어 싱글즈’가 릿쿄대학 유자와 나오미(湯澤直美) 씨와 북경JAC 협력으로 중고령 싱글여성의 생활실태를 조사했다. ‘와쿠와쿠’(두근두근이라는 뜻)는 2016년에 50세 이상
#
# 윤석열 대통령은 1일 133번째 '근로자의 날'을 맞아 "진정한 노동 약자를 보호하기 위해 노사 법치주의를 확립하고, 우리 헌법 정신에 위배되는 기득권의 고용세습은 확실히 뿌리 뽑을 것"이라고 밝혔다. 윤 대통령은
#
# 서울시는 청년에게 월세 최대 20만원을 지원하는 '2023년도 청년월세' 대상자를 모집합니다. 청년월세는 서울의 높은 주거비 부담을 덜어주기 위해 만 19∼39세 청년 2만5천명에게 10개월간 월세 최대 20만원을
#
# 음상준 보건의료전문기자 = 간호법 제정안과 중범죄를 저지른 의료인 면허를 취소한다는 내용의 의료법 개정안(의료인면허 취소법)이 지난 27일 국회 본회의를 통과했지만, 그 후폭풍이 계속되고 있다. 간호법 제정을 반대한
#
# 삼성전자 스마트폰 광고 모델을 맡아온 방탄소년단(BTS) 멤버 슈가가 제품에 대한 남다른 애정을 드러내 화제다. 지난달 30일 유튜브에는 '갤럭시만 셀동 찍어 주겠다는 참 모델', '이 영상을 삼성 회장님께 받칩니다
#
# “제주도에 있을 때 먹었던 흑돼지와 냉면이 최애 음식이라고 말할 수 있어요. 두 번째는 아무래도 한국인의 소울 푸드인 김치찌개죠. 무슨 일이 있어도 김치찌개만 먹으면 기분 전환이 되는 느낌이랄까? 세 번째로는 순댓국
#
# 배우 원빈·이나영 부부가 2018년 매입한 서울 강남구 청담동 건물이 300억원을 호가하는 것으로 알려졌다. 30일 부동산 업계에 따르면, 원빈과 이나영은 2018년 2월 지하철 분당선 압구정로데오역에서 300m 거
#
# 컵라면을 먹던 초등학생에게 흉기를 휘둘러 다치게 한 10대가 재판에 넘겨졌다. 1일 수원지검 평택지청 형사1부는 살인미수 혐의로 A(17) 군을 구속기소 했다고 밝혔다. A 군은 지난 달 3일 경기도 평택시의 한 아
#
# 네이버가 불공정 논란이 일었던 뉴스콘텐츠제휴 약관을 전면 수정해 재공지했다. 네이버는 28일 오후 뉴스콘텐츠제휴 언론사들에 이메일을 보내 “(기존 약관 대신) 추가 수정한 개정 약관으로 재동의를 구하고자 한다”며 “
#
# 근로자의 날인 오늘(1일) 양대노총을 비롯한 노동 단체들이 서울 도심 곳곳에서 대규모 집회를 엽니다. 민주노총은 오늘 오후 2시 서울 종로구 동화면세점 앞에서 '세계노동절대회'를 열고 7월 총파업 투쟁을 선포할 계획
#
# 유승민 국민의힘 전 의원이 '한미정상회담 결과'와 관련, "대한민국 대통령이면 대한민국 국민들께서 가장 위협을 느끼는 북핵문제에 대해서 이번에 길과 방향을 제대로 틀고 왔어야 된다"면서 "그런데 오히려 미국한테 좀
#
# 천연기념물 지정된 순천 승주 평지마을 이팝나무 ▲ 장성 백양사 쌍계루 앞의 이팝나무. 각진국사가 꽂은 지팡이가 자랐다는 전설이 전해진다. 꽃이 활짝 핀 지난해 5월 풍경이다. ⓒ 이돈삼 이팝나무꽃이 피고 있다. 연둣
#
# 2016년 5월1일. 경기 안산시 단원구 바닷가에서 신원미상 남성의 시신이 발견됐다. 마대에 담긴 시신은 신체 일부만 있었다. 일대에 대대적인 경찰 수색이 펼쳐졌다. 이틀 후 약 20km 떨어진 바닷가에서 시신의 나
#
# Korea's exports fell for the seventh consecutive month in April due primarily to weak demand for semiconductors amid an
#
# 청소년을 겨냥한 마약 범죄가 기승을 부리자 검찰이 최대 사형까지 구형하겠다며 특단의 조치를 내놨습니다. 검찰은 최근 발생한 '학원가 마약 음료' 사건부터 이번 가중처벌 조항을 적용하는 방안을 검토하고 있습니다. 취재
#
# "에코프로그룹주 더 오른다…국내 배터리업계 주목해야'" '비판적 읽기' 피력…"기관·증권사 등 이해관계 있다" "돈 벌 기회가 주어져 있다. 10년 주기로 꼭 투자해야 하는 투자 대상들이 생기는데, 그게 마침 배터리
#
# # 때만 되면 포털 뉴스란에 심심찮게 등장하는 단어가 있습니다. 수상택시입니다. 그 옆에는 늘 함께 붙어다니는 말이 있습니다. 서울시입니다. # 서울시는 2005년부터 서울의 교통혼잡을 완화하기 위한 대안으로 수상택
#
# 수원지검 평택지청 전경 평택의 한 아파트단지에서 초등학생을 흉기로 습격하고 달아난 고교생이 구속 기소됐다. 수원지검 평
#
# 삼성전자와 네이버가 손잡는 사례가 늘어나고 있다. 지난해 연말 ‘초거대 인공지능(AI)’에 활용된 반도체 솔루션 개발을 위한 업무 협약을 시작으로 금융과 정보기술(IT) 등에서 협력 범위를 넓혀 나가고 있다. 최근
#
# “4인 가족이 1주일 정도 해외에 함께 나가면, 10만원을 훌쩍 넘어가는 게 현실이다” (여행객) “1주일이나 열흘간 해외에 갔다고 십몇만원(로밍요금)을 내야 하는 것은 과해 보인다” (박윤규 과학기술정보통신부 2차
#
# 5월1일 노동절(근로자의 날)을 맞아 주요 신문들이 우리 사회 노동자들의 현실을 분석한 기획 보도들을 내놨다. 정부가 노동 관련 현행 법·제도 사각지대를 보완하고 노동 탄압이 우려되는 정책을 재고해야 한다는 주문이
#
# 정부가 문화유산을 활용한 게임·메타버스 창작을 지원하기 위해 무료로 개방한 문화재 3D 데이터에 중국 누리꾼들의 '댓글 테러'가 이어지고 있다. 1일 게임 업계 등에 따르면 에픽게임즈가 운영하는 '언리얼 엔진 마켓플
#
# 약사 면허증을 위조해 2년 동안 가짜 약사 행세를 해온 40대가 경찰에 검거됐습니다. 제주경찰청 의료·안전사고 전문수사팀은 40대 A 씨를 공문서위조 및 행사, 사기와 약사법 위반 혐의 등으로 검찰에 송치했다고 밝혔
#
# 중증 자폐성 장애를 가진 특수학교 소속 수영 꿈나무가 정작 교내에 있는 특수 수영장은 사용하지 못해 좌절하고 있다. 일반 학생들의 수영 수업에 밀려 특수학교 학생에 대한 수영 수업은 뒷전이 됐기 때문이다. 사설 스포
#
# 중국 네티즌들이 한복, 음력 설에 이어 한옥이 중국 문화라는 황당 주장을 펼쳐 눈살을 찌푸리게 하고 있다. 1일 게임업계에 따르면 중국 네티즌들은 에픽게임즈가 운영하는 ‘언리얼 엔진 마켓플레이스’에 올라온 한옥 애셋
#
# 윤희근 경찰청장이 1계급 특진 임용을 내걸고 '건폭'과 '마약 수사'를 독려하면서 내부에서는 '윗선 입맛에 맞는 수사만 할 것'이라는 우려의 목소리가 나오고 있습니다. 윤 청장은 지난달 17일 전북경찰청을 찾아 '건
#
# 지난달 28일 부산 영도구 청학동 스쿨존에서 1.5t짜리 원통형 화물에 치여 숨진 아이의 아빠가 온라인 커뮤니티에 자신의 심경을 올렸다. 아빠는 생전 딸의 사랑스러웠던 여러 모습을 메모하듯이 남기며 딸을 추억했다.
#
# 10대 학생의 극단적 선택이 SNS에 노출된 것과 관련해 온라인 커뮤니티 '우울증 갤러리'가 경찰 수사를 받고 있는데요. 경찰의 커뮤니티 폐쇄 요청과 이를 수용하지 않은 방심위의 결정을 두고 여러 이야기가 나옵니다.
#
# 4년간 폭력을 행사하고 교제를 강요한 여자친구에게 이별을 통보받자 승용차로 들이받고 흉기로 살해하려 한 40대가 중형을 선고받았다. 경남 창원지법 제4형사부(장유진 부장판사)는 살인미수와 특수상해, 특수협박 등으로
#
# 한 서울대생이 1억 5,000만 원 상당의 미술 작품 속 바나나를 먹고 "아침을 안 먹고 와서 배고파 먹었다"라고 한 사실이 알려졌습니다. 서울대 미학과 재학생 노 모 씨는 지난달 27일 리움미술관에서 진행한 마우리
#
# 리얼미터선 4주 만에 반등, 한국갤럽은 하락세 尹대통령, '방미 성과' 홍보 매진하고 국정 드라이브 5박7일간의 미국 국빈 방문 일정을 마치고 귀국한 윤석열 대통령이 '지지율 반등'이라는 성적표를 받게 됐다. 1일
#
# 정부가 저소득층 청년 저축액의 최대 3배까지 같은 금액을 추가 지원하는 '청년내일저축계좌' 신규 가입자 모집이 1일 시작된다. 중위소득 100% 이하 가구의 만19세~34세 일하는 청년이이라면 청년내일저축계좌를 개설
#
# '서울특별시 동대문구 답십리4동 51번지 12호 13통 2반' 1981년도 이상호씨(호적명 이대호) 가족이 살았던 주소다. 그리고 그해 실종 또는 유괴된 상호씨의 아들 이은권씨(당시 만 2세· 사진)가 40년이 넘게
#
# 온건 성향이어서 당사자간 소통은 무리 없을 전망이지만 거대 여야 양강 대립 구도 속 운신의 폭 좁다는 지적도 사법리스크 따라 '비주류' 박광온 변수될수도 국민의힘과 더불어민주당이 나란히 새 원내사령탑을 뽑으면서 입법
#
# A 3.1 magnitude natural earthquake hit Okcheon, North Chungcheong Province, Sunday, the state weather agency said. The q
#
# 충북 보은군 속리산 법주사가 징수해 온 문화재 관람료가 폐지될 예정임에 따라 지역 관광경기 활성화 기대가 높아지고 있습니다. 국가지정문화재 민간 소유자 또는 관리단체가 문화재 관람료를 감면하면 그 비용을 국가가 지원
#
# 검거 전 보험금 지급 청구 소송 구속 수감 후에도 소송 이어가 ‘가평 계곡 살인’으로 세상을 떠들썩하게 했던 이은해가 1심에 이어 항소심에서도 무기징역을 선고 받았습니다. 이은해의 내연남이자 공범인 조현수 역시 1심
#
# 미국 우주개발 스타트업이 물을 동력으로 쓰는 우주선을 개발해 우주 운송사업에 뛰어들겠다고 선언했다. 지구 저궤도 운송은 내년 말 첫 시험을 거쳐 2025년 상용 서비스를 시작한다는 야심찬 계획이다. 일론 머스크가 설
#
# AV 배우 인터뷰한 <성+인물> 논란, 어떻게 봐야하나? "AV산업은 일본 내 ‘성착취 구조’의 첨단에 자리합니다. 그 구조에 대한 비판적 고려 없이 이를 콘텐츠화한다뇨." - 이나영 중앙대학교 사회학과 교수 AV(
#
# 잉글랜드 프리미어리그(EPL)에서 뛰고 있는 손흥민(31·토트넘 홋스퍼)의 반칙 상황을 ‘무술’에 비유한 유명 해설가가 인종차별 논란에 휩싸였다. 손흥민은 1일(한국시간)에 열린 2022-23시즌 EPL 34라운드
#
# 국내에서 벤츠를 이미 앞지른 제네시스가 글로벌에서도 판매량이 꾸준히 증가하며 승승장구하고 있다. 특히 최근에는 컨버터블 콘셉트카를 공개하며 고급 차 이미지 굳히기에 나섰다. 1일 업계에 따르면 지난해 제네시스 브랜드

# %%
texts = bs.find_all('p',{'class':'cjs_d'})
for i in texts:
    t = ' '.join(re.findall('[가-힣]+',i.text))
    print(t)
# Out:
# 북한 장교들은 한국의 초코파이와 도리토스 나초칩 를 좋아했어요 년부터 년까지 유엔군 사령부 소속으로 비무장지대 에서 근무한 미국 해군 퇴역 장교 대니얼 맥셰인 전 소령은 지난달 일 미
# 내 머리 위를 넘어 기시다 총리의 발밑에 떨어진 순간 폭탄인 줄 알았어요 월 일 오전 시 분께 와카야마시 사이카자키 어시장에서 중의원 보궐선거 지원 연설을 하려던 기시다 후미오 총리를 향해 연막탄 크
# 마이크로바이옴 시장의 게임체인저가 등장했다 투약 방법의 불편함이 마이크로바이옴 치료제의 한계로 지적됐는데 간편하게 먹는 방법의 마이크로바이옴 치료제가 세상에 나온 것이다 이에 마이크로바이옴 치료제 시장 성장은
# 정부가 메타버스 콘텐츠 창작자들을 위해 무료로 개방한 한국 전통문화 데이터가 일부 중국 누리꾼들의 댓글 테러로 몸살을 앓고 있습니다 오늘 일 게임업계에 따르면 에픽게임즈가 운영하는 언리얼 엔진 마켓플레이스 에
# 세상을 바라보고 해석하는 시각이 남다른 세대 년대 중반 년대 초반 출생 세대 그들이 바라보는 세상은 어떤 모습일까요 머니 는 세대 기자들이 직접 발로 뛰며 그들의 시각으로 취재한 기사로 꾸미는
# 겉모습은 꼰대지만 누구보다 맛에 진심인 이우석 먹고놀기연구소 소장이 풀어내는 쉬운 미식 이번에는 호불호가 갈리기 십상인 매운탕 편으로 찾아왔습니다 이우석 먹고놀기연구소 소장은 횟집에서 회 뜨고 남은 생선으로 끓
# 윤석열 대통령이 미국 백악관 국빈 만찬에서 아메리칸 파이 를 부른 모습이 여러 외신에도 보도되며 화제를 모으고 있다 윤 대통령은 미국 국빈 방문 중 지난 달 일 현지시간 열린 백악관
# 윤석열 대통령의 박 일 국빈 방미 일정이 끝난 가운데 대통령의 미 의회 영어 연설에 관한 반응이 뜨거웠다 이와 관련 중요한 것은 외교 성과 라는 지적과 함께 외신의 보도 내용도 눈길을 끈다 태영호 국민의힘
# 소시에테제네랄 증권 발 주가 폭락 사태와 관련해 피해자라고 나선 가서 임창정이 이른바 조 축하 파티 에 이어 또 다른 고액 투자자 모임에도 임 씨가 나간 사실이 일 밝혀졌다 에 따르면 임창정은 지난
# 중국이 우리나라 반도체 산업에 대한 압박에 나섰다 원산지 점검과 통관 검사 강화 조치에 이어 우리 기업의 중국 수출 계약 취소 사례까지 등장 미 중 갈등으로 인해 국내 기업 피해가 가시화되는 것이 아니냐는 우려가
# 근력 운동 중 한 세트할 때 몇 번 동작을 반복하는가 대부분 번이라고 답할 것이다 이 숫자는 도대체 어디서 온 걸까 사실 번 이하로 해도 된다 번 이상으로 해도 된다 운동 목적에 따라 달라질
# 동원그룹 맥도날드 인수 포기 메뉴 하나도 글로벌 본사 허락 필요 년 맥도날드 매각 불발 때도 자율권 걸림돌 지적 업계 스타벅스와 달리 작은 것 하나도 본사 허락받아야 그룹 운영 당시
# 미국 뉴욕 타임스스퀘어에 있던 작은 샌드위치 가게가 문을 닫자 브로드웨이 배우들이 한자리에 모였다 년 가까이 이 가게를 운영한 한인 사장의 은퇴식 을 열어주기 위해서였다 최근 미국 폭스 뉴욕 뉴욕
# 에너지솔루션 삼성 분기 호실적 금융당국 차전지 신용거래 급증 우려 떨어질 땐 다 같이 오를 땐 혼자 월 일 한 에너지솔루션 주주가 어닝 서프라이즈 소식에 보인 반응이다 이날 에
# 기사내용 요약 보도 분란 혐의 등으로 년형 선고 코로나 가 처음 유행한 중국 후베이성 우한 실태를 고발했던 시민이 년 만에 석방될 것이라고 통신이 일 현지시간 보도했다 통신은 이 시민의 친척
# 세계적인 베스트셀러 부자 아빠 가난한 아빠 의 저자 로버트 기요사키가 미국 연방준비제도 연준 를 저격하고 나섰다 일 현지시간 기요사키는 자신의 트위터를 통해 연준이 미국 경제의 심장 역할을 하는 지역
# 간호법 제정에 반대하며 단식을 해온 곽지연 대한간호조무사협회 회장이 단식 농성에 돌입한 지 닷새만인 어제 병원으로 이송됐습니다 농성 현장을 찾은 조규홍 보건복지부 장관은 같은 간호 인력 간에도 협의가 이뤄지지 않
# 문 전 대통령의 퇴임 후 일상을 보여주는 다큐멘터리 영화 문재인입니다 가 일 전주 국제영화제에서 공개됐다 다큐는 문 전 대통령이 평산마을에 도착한 지난해 봄부터 가을까지 시간적 순서에 따라 반려견과 함께 마을
# 더불어민주당 박광온 원내대표가 취임 일주일도 되지 않아 이른바 개딸들의 거센 공격을 받고 있다 이에 이재명 대표가 연휴 기간에 직접 페이스북에 글을 올려 개딸들에게 자제를 요청했으나 그들의 분노가 좀처럼 가라앉지
# 국민의힘 윤리위원회는 일 실언으로 논란을 일으킨 김재원 태영호 최고위원에 대한 징계를 개시하기로 결정했다 황정근 윤리위원장은 이날 오전 여의도 중앙당사에서 열린 전체회의 후 브리핑에서 김재원 최고위원과 태영호
# 송영길 전 대표가 내일 일 년 전당대회 돈 봉투 의혹 과 관련해 기자회견을 열 예정입니다 당시 자신의 경선 캠프에 몸담았던 관계자들을 대상으로 검찰의 강제수사가 이어지자 직접 반박에 나서기로 한 것으로
# 년 개월 넘게 해고 상태인 서울 중구 명동 세종호텔 해고노동자들의 천막농성장이 강제로 뜯겨나갔다 농성 인원이 적은 년 월 일 서울 중구청은 경찰까지 동원해 주변을 지키며 행정대집행 이란 이름으로 농성장
# 올여름 엘니뇨의 발달로 남부지방을 중심으로 많은 비가 내릴 것으로 보인다 기상청은 현재 중립상태를 유지하고 있는 엘니뇨 라니냐 감시구역 열대태평양 남위 도 북위 도 서경 도 서경 도 지역 해수면 온도가
# 전국민주노동조합총연맹 제주지역본부가 세계노동절 제주대회 를 열고 월 총파업에 나서겠다고 선포했습니다 민주노총 제주본부는 오늘 일 오전 제주시청 앞에서 조합원 여명이 참여한 가운데 세계
# 올해 전주국제영화제에서 공개된 다큐멘터리 영화 문재인입니다 일 개봉 는 잡초를 좋아하는 자연인 문재인의 일상과 문 전 대통령 주변 인사들의 입 을 빌린 대통령 문재인의 면모를 병치시킨다 문 전 대통령의 정
# 이재명 더불어민주당 대표가 일 근로자의 날을 맞아 년 전 노동자들이 시간 노동 을 외치며 일어섰건만 년 대한민국에선 주 시간 노동 이 국가 정책으로 추진돼 땀 흘려 일하는 시민의 삶이 위태
# 모빌리티 구 쌍용자동차 가 전기버스 업체인 에디슨 모터스 인수에 열중입니다 에디슨 모터스는 한때 그룹과 쌍용차 인수를 두고 경쟁을 벌였던 곳입니다 에디슨 모터스는 쌍용차 인수 본 계약까지 체결했지만 인수금
# 금융규제 방식은 포크레인식으로 모두 다 이렇게 엎어 버리는 방식인데 기술의 분야를 그런 식으로 규제를 하면 기술이 발전할 수 없겠지요 최화인 블록체인 에반젤리스트 이 대목이 지금 되게 좀 중요한 것 같은데
# 운동을 위해 시간과 비용을 들여 열심히 했는데도 몸의 변화가 없다면 자신의 운동 습관을 체크해 봐야 한다 특히 체중 허리 사이즈 근육의 양 등 중요 수치에 변화가 없다면 운동 효과에 대한 회의감마저 갖게 된
# 정권교체 예상 여론조사 크게 엇나가 대만 한숨 돌릴 듯 이재림 특파원 금전 외교를 앞세운 중국의 영향력 확대 의지도 중남미에 거세게 일렁이는 온건 좌파 물결 핑크 타이드 도 인구 만명의 남미 내륙
# 경기 이천시 시장 김경희 가 일 시 농산물 브랜드인 임금님표이천 상표 사용 년을 맞아 기념식과 함께 쌀밥데이 를 선포한다 시는 년 가짜 이천쌀 문제에 대응하고자 임금님표 이천쌀 상표를 사용하
# 요즘 대강 사업의 주역들이 부쩍 대중 앞에 자주 등장하고 있다 이명박 전 대통령 이하 존칭 생략 은 며칠 전 측근 유인촌의 연극을 관람했고 앞으로 대강도 방문할 예정이라고 한다 대강 추진본부장이었던 심명필은
# 국립공원 입장이 완전 무료화된다 그동안 국립공원 지역 내에 위치한 사찰에서 국가 지정 문화재관람 명목으로 등산객들로부터 입장료를 받아왔는데 대한불교조계종이 일 관람료를 면제한다고 밝혔다 면제 조치는 월
# 우리나라 월 수출이 지난해 월 이후 개월째 하락세를 보이면서 무역수지도 개월 연속 하락세를 면치 못했다 지난 일 관세청이 발표한 월 수출입 현황 잠정치 에 따르면 수출은 억 만 달러
# 지난 월 일 국회에서 상속세 과세체계 개편과 관련한 토론회가 열렸다 더불어민주당 정책위원회 수석부의장인 김병욱 송기헌 유동수 의원이 주최했다 토론회 명칭은 상속세 유산취득세 방식 긍정적 검토 토론회 다
# 우리나라에서 세단의 대명사는 쏘나타였다 특히 강남 지역에서 자주 보이는 수입차에 강남 쏘나타 라는 별명을 붙이기도 했다 최근 세단 모델이 위기를 겪는 가운데 고급스러운 디자인과 효율 높은 친환경 디젤 엔진을 탑
# 한은금융망에 신규 가입한 보험회사가 약 년 사이에 두 배나 증가한 것으로 나타났다 한국은행은 이례적이라는 평가를 내놨다 보험사는 보험상품의 만기가 길어 장기물 자산 중심으로 거래를 해왔으나 지난해 말 자금난에
# 년 월 일 국회 본회의에서 대구경북신공항 건설을 위한 특별법 이 통과됐습니다 대구경북신공항은 현재 대구 도심에 있는 군 공항인 와 대구국제공항을 경북 의성군 비안면과 군위군 소보면으로 새롭게 옮기
# 진중권 박근혜 정권보다 퇴행적 박성민 민주당 분열 가능성 영상 윤석열 년을 말하다 영상 국민의힘을 말하다 영상 민주당을 말하다 년 월 일 치러지는 대 총선
# 이틀 만에 두 번째 압수수색 송영길 전 더불어민주당 대표 연합뉴스 더불어민주당 전당대회 돈봉투 의혹 피의자로 입건된 송영길 전 민주당 대표가 오는 일 검찰에 자진 출석하겠다고 밝혔다 송 전 대표 측 선종문
# 편집자주한국은 의료 가성비가 좋다고 하죠 아프면 예약 없이 원에 전문의를 보는 나라 흔치 않으니까요 그러나 건보 흑자 일부 의료인의 희생 덕에 양질의 의료를 누렸던 시대도 끝나 갑니다 미
# 일본의 중노년 싱글여성 단체인 와쿠와쿠 시니어 싱글즈 가 릿쿄대학 유자와 나오미 씨와 북경 협력으로 중고령 싱글여성의 생활실태를 조사했다 와쿠와쿠 두근두근이라는 뜻 는 년에 세 이상
# 윤석열 대통령은 일 번째 근로자의 날 을 맞아 진정한 노동 약자를 보호하기 위해 노사 법치주의를 확립하고 우리 헌법 정신에 위배되는 기득권의 고용세습은 확실히 뿌리 뽑을 것 이라고 밝혔다 윤 대통령은
# 서울시는 청년에게 월세 최대 만원을 지원하는 년도 청년월세 대상자를 모집합니다 청년월세는 서울의 높은 주거비 부담을 덜어주기 위해 만 세 청년 만 천명에게 개월간 월세 최대 만원을
# 음상준 보건의료전문기자 간호법 제정안과 중범죄를 저지른 의료인 면허를 취소한다는 내용의 의료법 개정안 의료인면허 취소법 이 지난 일 국회 본회의를 통과했지만 그 후폭풍이 계속되고 있다 간호법 제정을 반대한
# 삼성전자 스마트폰 광고 모델을 맡아온 방탄소년단 멤버 슈가가 제품에 대한 남다른 애정을 드러내 화제다 지난달 일 유튜브에는 갤럭시만 셀동 찍어 주겠다는 참 모델 이 영상을 삼성 회장님께 받칩니다
# 제주도에 있을 때 먹었던 흑돼지와 냉면이 최애 음식이라고 말할 수 있어요 두 번째는 아무래도 한국인의 소울 푸드인 김치찌개죠 무슨 일이 있어도 김치찌개만 먹으면 기분 전환이 되는 느낌이랄까 세 번째로는 순댓국
# 배우 원빈 이나영 부부가 년 매입한 서울 강남구 청담동 건물이 억원을 호가하는 것으로 알려졌다 일 부동산 업계에 따르면 원빈과 이나영은 년 월 지하철 분당선 압구정로데오역에서 거
# 컵라면을 먹던 초등학생에게 흉기를 휘둘러 다치게 한 대가 재판에 넘겨졌다 일 수원지검 평택지청 형사 부는 살인미수 혐의로 군을 구속기소 했다고 밝혔다 군은 지난 달 일 경기도 평택시의 한 아
# 네이버가 불공정 논란이 일었던 뉴스콘텐츠제휴 약관을 전면 수정해 재공지했다 네이버는 일 오후 뉴스콘텐츠제휴 언론사들에 이메일을 보내 기존 약관 대신 추가 수정한 개정 약관으로 재동의를 구하고자 한다 며
# 근로자의 날인 오늘 일 양대노총을 비롯한 노동 단체들이 서울 도심 곳곳에서 대규모 집회를 엽니다 민주노총은 오늘 오후 시 서울 종로구 동화면세점 앞에서 세계노동절대회 를 열고 월 총파업 투쟁을 선포할 계획
# 유승민 국민의힘 전 의원이 한미정상회담 결과 와 관련 대한민국 대통령이면 대한민국 국민들께서 가장 위협을 느끼는 북핵문제에 대해서 이번에 길과 방향을 제대로 틀고 왔어야 된다 면서 그런데 오히려 미국한테 좀
# 천연기념물 지정된 순천 승주 평지마을 이팝나무 장성 백양사 쌍계루 앞의 이팝나무 각진국사가 꽂은 지팡이가 자랐다는 전설이 전해진다 꽃이 활짝 핀 지난해 월 풍경이다 이돈삼 이팝나무꽃이 피고 있다 연둣
# 년 월 일 경기 안산시 단원구 바닷가에서 신원미상 남성의 시신이 발견됐다 마대에 담긴 시신은 신체 일부만 있었다 일대에 대대적인 경찰 수색이 펼쳐졌다 이틀 후 약 떨어진 바닷가에서 시신의 나
#
# 청소년을 겨냥한 마약 범죄가 기승을 부리자 검찰이 최대 사형까지 구형하겠다며 특단의 조치를 내놨습니다 검찰은 최근 발생한 학원가 마약 음료 사건부터 이번 가중처벌 조항을 적용하는 방안을 검토하고 있습니다 취재
# 에코프로그룹주 더 오른다 국내 배터리업계 주목해야 비판적 읽기 피력 기관 증권사 등 이해관계 있다 돈 벌 기회가 주어져 있다 년 주기로 꼭 투자해야 하는 투자 대상들이 생기는데 그게 마침 배터리
# 때만 되면 포털 뉴스란에 심심찮게 등장하는 단어가 있습니다 수상택시입니다 그 옆에는 늘 함께 붙어다니는 말이 있습니다 서울시입니다 서울시는 년부터 서울의 교통혼잡을 완화하기 위한 대안으로 수상택
# 수원지검 평택지청 전경 평택의 한 아파트단지에서 초등학생을 흉기로 습격하고 달아난 고교생이 구속 기소됐다 수원지검 평
# 삼성전자와 네이버가 손잡는 사례가 늘어나고 있다 지난해 연말 초거대 인공지능 에 활용된 반도체 솔루션 개발을 위한 업무 협약을 시작으로 금융과 정보기술 등에서 협력 범위를 넓혀 나가고 있다 최근
# 인 가족이 주일 정도 해외에 함께 나가면 만원을 훌쩍 넘어가는 게 현실이다 여행객 주일이나 열흘간 해외에 갔다고 십몇만원 로밍요금 을 내야 하는 것은 과해 보인다 박윤규 과학기술정보통신부 차
# 월 일 노동절 근로자의 날 을 맞아 주요 신문들이 우리 사회 노동자들의 현실을 분석한 기획 보도들을 내놨다 정부가 노동 관련 현행 법 제도 사각지대를 보완하고 노동 탄압이 우려되는 정책을 재고해야 한다는 주문이
# 정부가 문화유산을 활용한 게임 메타버스 창작을 지원하기 위해 무료로 개방한 문화재 데이터에 중국 누리꾼들의 댓글 테러 가 이어지고 있다 일 게임 업계 등에 따르면 에픽게임즈가 운영하는 언리얼 엔진 마켓플
# 약사 면허증을 위조해 년 동안 가짜 약사 행세를 해온 대가 경찰에 검거됐습니다 제주경찰청 의료 안전사고 전문수사팀은 대 씨를 공문서위조 및 행사 사기와 약사법 위반 혐의 등으로 검찰에 송치했다고 밝혔
# 중증 자폐성 장애를 가진 특수학교 소속 수영 꿈나무가 정작 교내에 있는 특수 수영장은 사용하지 못해 좌절하고 있다 일반 학생들의 수영 수업에 밀려 특수학교 학생에 대한 수영 수업은 뒷전이 됐기 때문이다 사설 스포
# 중국 네티즌들이 한복 음력 설에 이어 한옥이 중국 문화라는 황당 주장을 펼쳐 눈살을 찌푸리게 하고 있다 일 게임업계에 따르면 중국 네티즌들은 에픽게임즈가 운영하는 언리얼 엔진 마켓플레이스 에 올라온 한옥 애셋
# 윤희근 경찰청장이 계급 특진 임용을 내걸고 건폭 과 마약 수사 를 독려하면서 내부에서는 윗선 입맛에 맞는 수사만 할 것 이라는 우려의 목소리가 나오고 있습니다 윤 청장은 지난달 일 전북경찰청을 찾아 건
# 지난달 일 부산 영도구 청학동 스쿨존에서 짜리 원통형 화물에 치여 숨진 아이의 아빠가 온라인 커뮤니티에 자신의 심경을 올렸다 아빠는 생전 딸의 사랑스러웠던 여러 모습을 메모하듯이 남기며 딸을 추억했다
# 대 학생의 극단적 선택이 에 노출된 것과 관련해 온라인 커뮤니티 우울증 갤러리 가 경찰 수사를 받고 있는데요 경찰의 커뮤니티 폐쇄 요청과 이를 수용하지 않은 방심위의 결정을 두고 여러 이야기가 나옵니다
# 년간 폭력을 행사하고 교제를 강요한 여자친구에게 이별을 통보받자 승용차로 들이받고 흉기로 살해하려 한 대가 중형을 선고받았다 경남 창원지법 제 형사부 장유진 부장판사 는 살인미수와 특수상해 특수협박 등으로
# 한 서울대생이 억 만 원 상당의 미술 작품 속 바나나를 먹고 아침을 안 먹고 와서 배고파 먹었다 라고 한 사실이 알려졌습니다 서울대 미학과 재학생 노 모 씨는 지난달 일 리움미술관에서 진행한 마우리
# 리얼미터선 주 만에 반등 한국갤럽은 하락세 대통령 방미 성과 홍보 매진하고 국정 드라이브 박 일간의 미국 국빈 방문 일정을 마치고 귀국한 윤석열 대통령이 지지율 반등 이라는 성적표를 받게 됐다 일
# 정부가 저소득층 청년 저축액의 최대 배까지 같은 금액을 추가 지원하는 청년내일저축계좌 신규 가입자 모집이 일 시작된다 중위소득 이하 가구의 만 세 세 일하는 청년이이라면 청년내일저축계좌를 개설
# 서울특별시 동대문구 답십리 동 번지 호 통 반 년도 이상호씨 호적명 이대호 가족이 살았던 주소다 그리고 그해 실종 또는 유괴된 상호씨의 아들 이은권씨 당시 만 세 사진 가 년이 넘게
# 온건 성향이어서 당사자간 소통은 무리 없을 전망이지만 거대 여야 양강 대립 구도 속 운신의 폭 좁다는 지적도 사법리스크 따라 비주류 박광온 변수될수도 국민의힘과 더불어민주당이 나란히 새 원내사령탑을 뽑으면서 입법
#
# 충북 보은군 속리산 법주사가 징수해 온 문화재 관람료가 폐지될 예정임에 따라 지역 관광경기 활성화 기대가 높아지고 있습니다 국가지정문화재 민간 소유자 또는 관리단체가 문화재 관람료를 감면하면 그 비용을 국가가 지원
# 검거 전 보험금 지급 청구 소송 구속 수감 후에도 소송 이어가 가평 계곡 살인 으로 세상을 떠들썩하게 했던 이은해가 심에 이어 항소심에서도 무기징역을 선고 받았습니다 이은해의 내연남이자 공범인 조현수 역시 심
# 미국 우주개발 스타트업이 물을 동력으로 쓰는 우주선을 개발해 우주 운송사업에 뛰어들겠다고 선언했다 지구 저궤도 운송은 내년 말 첫 시험을 거쳐 년 상용 서비스를 시작한다는 야심찬 계획이다 일론 머스크가 설
# 배우 인터뷰한 성 인물 논란 어떻게 봐야하나 산업은 일본 내 성착취 구조 의 첨단에 자리합니다 그 구조에 대한 비판적 고려 없이 이를 콘텐츠화한다뇨 이나영 중앙대학교 사회학과 교수
# 잉글랜드 프리미어리그 에서 뛰고 있는 손흥민 토트넘 홋스퍼 의 반칙 상황을 무술 에 비유한 유명 해설가가 인종차별 논란에 휩싸였다 손흥민은 일 한국시간 에 열린 시즌 라운드
# 국내에서 벤츠를 이미 앞지른 제네시스가 글로벌에서도 판매량이 꾸준히 증가하며 승승장구하고 있다 특히 최근에는 컨버터블 콘셉트카를 공개하며 고급 차 이미지 굳히기에 나섰다 일 업계에 따르면 지난해 제네시스 브랜드

# %%
texts = bs.find_all('p', {'class':"cjs_d"})
for t in texts:
    t = str(t)
    t = re.findall('[가-힣]+',t)
    t = ' '.join(t)
    print(t,'\n')
# Out:
# 북한 장교들은 한국의 초코파이와 도리토스 나초칩 를 좋아했어요 년부터 년까지 유엔군 사령부 소속으로 비무장지대 에서 근무한 미국 해군 퇴역 장교 대니얼 맥셰인 전 소령은 지난달 일 미
#
# 내 머리 위를 넘어 기시다 총리의 발밑에 떨어진 순간 폭탄인 줄 알았어요 월 일 오전 시 분께 와카야마시 사이카자키 어시장에서 중의원 보궐선거 지원 연설을 하려던 기시다 후미오 총리를 향해 연막탄 크
#
# 마이크로바이옴 시장의 게임체인저가 등장했다 투약 방법의 불편함이 마이크로바이옴 치료제의 한계로 지적됐는데 간편하게 먹는 방법의 마이크로바이옴 치료제가 세상에 나온 것이다 이에 마이크로바이옴 치료제 시장 성장은
#
# 정부가 메타버스 콘텐츠 창작자들을 위해 무료로 개방한 한국 전통문화 데이터가 일부 중국 누리꾼들의 댓글 테러로 몸살을 앓고 있습니다 오늘 일 게임업계에 따르면 에픽게임즈가 운영하는 언리얼 엔진 마켓플레이스 에
#
# 세상을 바라보고 해석하는 시각이 남다른 세대 년대 중반 년대 초반 출생 세대 그들이 바라보는 세상은 어떤 모습일까요 머니 는 세대 기자들이 직접 발로 뛰며 그들의 시각으로 취재한 기사로 꾸미는
#
# 겉모습은 꼰대지만 누구보다 맛에 진심인 이우석 먹고놀기연구소 소장이 풀어내는 쉬운 미식 이번에는 호불호가 갈리기 십상인 매운탕 편으로 찾아왔습니다 이우석 먹고놀기연구소 소장은 횟집에서 회 뜨고 남은 생선으로 끓
#
# 윤석열 대통령이 미국 백악관 국빈 만찬에서 아메리칸 파이 를 부른 모습이 여러 외신에도 보도되며 화제를 모으고 있다 윤 대통령은 미국 국빈 방문 중 지난 달 일 현지시간 열린 백악관
#
# 윤석열 대통령의 박 일 국빈 방미 일정이 끝난 가운데 대통령의 미 의회 영어 연설에 관한 반응이 뜨거웠다 이와 관련 중요한 것은 외교 성과 라는 지적과 함께 외신의 보도 내용도 눈길을 끈다 태영호 국민의힘
#
# 소시에테제네랄 증권 발 주가 폭락 사태와 관련해 피해자라고 나선 가서 임창정이 이른바 조 축하 파티 에 이어 또 다른 고액 투자자 모임에도 임 씨가 나간 사실이 일 밝혀졌다 에 따르면 임창정은 지난
#
# 중국이 우리나라 반도체 산업에 대한 압박에 나섰다 원산지 점검과 통관 검사 강화 조치에 이어 우리 기업의 중국 수출 계약 취소 사례까지 등장 미 중 갈등으로 인해 국내 기업 피해가 가시화되는 것이 아니냐는 우려가
#
# 근력 운동 중 한 세트할 때 몇 번 동작을 반복하는가 대부분 번이라고 답할 것이다 이 숫자는 도대체 어디서 온 걸까 사실 번 이하로 해도 된다 번 이상으로 해도 된다 운동 목적에 따라 달라질
#
# 동원그룹 맥도날드 인수 포기 메뉴 하나도 글로벌 본사 허락 필요 년 맥도날드 매각 불발 때도 자율권 걸림돌 지적 업계 스타벅스와 달리 작은 것 하나도 본사 허락받아야 그룹 운영 당시
#
# 미국 뉴욕 타임스스퀘어에 있던 작은 샌드위치 가게가 문을 닫자 브로드웨이 배우들이 한자리에 모였다 년 가까이 이 가게를 운영한 한인 사장의 은퇴식 을 열어주기 위해서였다 최근 미국 폭스 뉴욕 뉴욕
#
# 에너지솔루션 삼성 분기 호실적 금융당국 차전지 신용거래 급증 우려 떨어질 땐 다 같이 오를 땐 혼자 월 일 한 에너지솔루션 주주가 어닝 서프라이즈 소식에 보인 반응이다 이날 에
#
# 기사내용 요약 보도 분란 혐의 등으로 년형 선고 코로나 가 처음 유행한 중국 후베이성 우한 실태를 고발했던 시민이 년 만에 석방될 것이라고 통신이 일 현지시간 보도했다 통신은 이 시민의 친척
#
# 세계적인 베스트셀러 부자 아빠 가난한 아빠 의 저자 로버트 기요사키가 미국 연방준비제도 연준 를 저격하고 나섰다 일 현지시간 기요사키는 자신의 트위터를 통해 연준이 미국 경제의 심장 역할을 하는 지역
#
# 간호법 제정에 반대하며 단식을 해온 곽지연 대한간호조무사협회 회장이 단식 농성에 돌입한 지 닷새만인 어제 병원으로 이송됐습니다 농성 현장을 찾은 조규홍 보건복지부 장관은 같은 간호 인력 간에도 협의가 이뤄지지 않
#
# 문 전 대통령의 퇴임 후 일상을 보여주는 다큐멘터리 영화 문재인입니다 가 일 전주 국제영화제에서 공개됐다 다큐는 문 전 대통령이 평산마을에 도착한 지난해 봄부터 가을까지 시간적 순서에 따라 반려견과 함께 마을
#
# 더불어민주당 박광온 원내대표가 취임 일주일도 되지 않아 이른바 개딸들의 거센 공격을 받고 있다 이에 이재명 대표가 연휴 기간에 직접 페이스북에 글을 올려 개딸들에게 자제를 요청했으나 그들의 분노가 좀처럼 가라앉지
#
# 국민의힘 윤리위원회는 일 실언으로 논란을 일으킨 김재원 태영호 최고위원에 대한 징계를 개시하기로 결정했다 황정근 윤리위원장은 이날 오전 여의도 중앙당사에서 열린 전체회의 후 브리핑에서 김재원 최고위원과 태영호
#
# 송영길 전 대표가 내일 일 년 전당대회 돈 봉투 의혹 과 관련해 기자회견을 열 예정입니다 당시 자신의 경선 캠프에 몸담았던 관계자들을 대상으로 검찰의 강제수사가 이어지자 직접 반박에 나서기로 한 것으로
#
# 년 개월 넘게 해고 상태인 서울 중구 명동 세종호텔 해고노동자들의 천막농성장이 강제로 뜯겨나갔다 농성 인원이 적은 년 월 일 서울 중구청은 경찰까지 동원해 주변을 지키며 행정대집행 이란 이름으로 농성장
#
# 올여름 엘니뇨의 발달로 남부지방을 중심으로 많은 비가 내릴 것으로 보인다 기상청은 현재 중립상태를 유지하고 있는 엘니뇨 라니냐 감시구역 열대태평양 남위 도 북위 도 서경 도 서경 도 지역 해수면 온도가
#
# 전국민주노동조합총연맹 제주지역본부가 세계노동절 제주대회 를 열고 월 총파업에 나서겠다고 선포했습니다 민주노총 제주본부는 오늘 일 오전 제주시청 앞에서 조합원 여명이 참여한 가운데 세계
#
# 올해 전주국제영화제에서 공개된 다큐멘터리 영화 문재인입니다 일 개봉 는 잡초를 좋아하는 자연인 문재인의 일상과 문 전 대통령 주변 인사들의 입 을 빌린 대통령 문재인의 면모를 병치시킨다 문 전 대통령의 정
#
# 이재명 더불어민주당 대표가 일 근로자의 날을 맞아 년 전 노동자들이 시간 노동 을 외치며 일어섰건만 년 대한민국에선 주 시간 노동 이 국가 정책으로 추진돼 땀 흘려 일하는 시민의 삶이 위태
#
# 모빌리티 구 쌍용자동차 가 전기버스 업체인 에디슨 모터스 인수에 열중입니다 에디슨 모터스는 한때 그룹과 쌍용차 인수를 두고 경쟁을 벌였던 곳입니다 에디슨 모터스는 쌍용차 인수 본 계약까지 체결했지만 인수금
#
# 금융규제 방식은 포크레인식으로 모두 다 이렇게 엎어 버리는 방식인데 기술의 분야를 그런 식으로 규제를 하면 기술이 발전할 수 없겠지요 최화인 블록체인 에반젤리스트 이 대목이 지금 되게 좀 중요한 것 같은데
#
# 운동을 위해 시간과 비용을 들여 열심히 했는데도 몸의 변화가 없다면 자신의 운동 습관을 체크해 봐야 한다 특히 체중 허리 사이즈 근육의 양 등 중요 수치에 변화가 없다면 운동 효과에 대한 회의감마저 갖게 된
#
# 정권교체 예상 여론조사 크게 엇나가 대만 한숨 돌릴 듯 이재림 특파원 금전 외교를 앞세운 중국의 영향력 확대 의지도 중남미에 거세게 일렁이는 온건 좌파 물결 핑크 타이드 도 인구 만명의 남미 내륙
#
# 경기 이천시 시장 김경희 가 일 시 농산물 브랜드인 임금님표이천 상표 사용 년을 맞아 기념식과 함께 쌀밥데이 를 선포한다 시는 년 가짜 이천쌀 문제에 대응하고자 임금님표 이천쌀 상표를 사용하
#
# 요즘 대강 사업의 주역들이 부쩍 대중 앞에 자주 등장하고 있다 이명박 전 대통령 이하 존칭 생략 은 며칠 전 측근 유인촌의 연극을 관람했고 앞으로 대강도 방문할 예정이라고 한다 대강 추진본부장이었던 심명필은
#
# 국립공원 입장이 완전 무료화된다 그동안 국립공원 지역 내에 위치한 사찰에서 국가 지정 문화재관람 명목으로 등산객들로부터 입장료를 받아왔는데 대한불교조계종이 일 관람료를 면제한다고 밝혔다 면제 조치는 월
#
# 우리나라 월 수출이 지난해 월 이후 개월째 하락세를 보이면서 무역수지도 개월 연속 하락세를 면치 못했다 지난 일 관세청이 발표한 월 수출입 현황 잠정치 에 따르면 수출은 억 만 달러
#
# 지난 월 일 국회에서 상속세 과세체계 개편과 관련한 토론회가 열렸다 더불어민주당 정책위원회 수석부의장인 김병욱 송기헌 유동수 의원이 주최했다 토론회 명칭은 상속세 유산취득세 방식 긍정적 검토 토론회 다
#
# 우리나라에서 세단의 대명사는 쏘나타였다 특히 강남 지역에서 자주 보이는 수입차에 강남 쏘나타 라는 별명을 붙이기도 했다 최근 세단 모델이 위기를 겪는 가운데 고급스러운 디자인과 효율 높은 친환경 디젤 엔진을 탑
#
# 한은금융망에 신규 가입한 보험회사가 약 년 사이에 두 배나 증가한 것으로 나타났다 한국은행은 이례적이라는 평가를 내놨다 보험사는 보험상품의 만기가 길어 장기물 자산 중심으로 거래를 해왔으나 지난해 말 자금난에
#
# 년 월 일 국회 본회의에서 대구경북신공항 건설을 위한 특별법 이 통과됐습니다 대구경북신공항은 현재 대구 도심에 있는 군 공항인 와 대구국제공항을 경북 의성군 비안면과 군위군 소보면으로 새롭게 옮기
#
# 진중권 박근혜 정권보다 퇴행적 박성민 민주당 분열 가능성 영상 윤석열 년을 말하다 영상 국민의힘을 말하다 영상 민주당을 말하다 년 월 일 치러지는 대 총선
#
# 이틀 만에 두 번째 압수수색 송영길 전 더불어민주당 대표 연합뉴스 더불어민주당 전당대회 돈봉투 의혹 피의자로 입건된 송영길 전 민주당 대표가 오는 일 검찰에 자진 출석하겠다고 밝혔다 송 전 대표 측 선종문
#
# 편집자주한국은 의료 가성비가 좋다고 하죠 아프면 예약 없이 원에 전문의를 보는 나라 흔치 않으니까요 그러나 건보 흑자 일부 의료인의 희생 덕에 양질의 의료를 누렸던 시대도 끝나 갑니다 미
#
# 일본의 중노년 싱글여성 단체인 와쿠와쿠 시니어 싱글즈 가 릿쿄대학 유자와 나오미 씨와 북경 협력으로 중고령 싱글여성의 생활실태를 조사했다 와쿠와쿠 두근두근이라는 뜻 는 년에 세 이상
#
# 윤석열 대통령은 일 번째 근로자의 날 을 맞아 진정한 노동 약자를 보호하기 위해 노사 법치주의를 확립하고 우리 헌법 정신에 위배되는 기득권의 고용세습은 확실히 뿌리 뽑을 것 이라고 밝혔다 윤 대통령은
#
# 서울시는 청년에게 월세 최대 만원을 지원하는 년도 청년월세 대상자를 모집합니다 청년월세는 서울의 높은 주거비 부담을 덜어주기 위해 만 세 청년 만 천명에게 개월간 월세 최대 만원을
#
# 음상준 보건의료전문기자 간호법 제정안과 중범죄를 저지른 의료인 면허를 취소한다는 내용의 의료법 개정안 의료인면허 취소법 이 지난 일 국회 본회의를 통과했지만 그 후폭풍이 계속되고 있다 간호법 제정을 반대한
#
# 삼성전자 스마트폰 광고 모델을 맡아온 방탄소년단 멤버 슈가가 제품에 대한 남다른 애정을 드러내 화제다 지난달 일 유튜브에는 갤럭시만 셀동 찍어 주겠다는 참 모델 이 영상을 삼성 회장님께 받칩니다
#
# 제주도에 있을 때 먹었던 흑돼지와 냉면이 최애 음식이라고 말할 수 있어요 두 번째는 아무래도 한국인의 소울 푸드인 김치찌개죠 무슨 일이 있어도 김치찌개만 먹으면 기분 전환이 되는 느낌이랄까 세 번째로는 순댓국
#
# 배우 원빈 이나영 부부가 년 매입한 서울 강남구 청담동 건물이 억원을 호가하는 것으로 알려졌다 일 부동산 업계에 따르면 원빈과 이나영은 년 월 지하철 분당선 압구정로데오역에서 거
#
# 컵라면을 먹던 초등학생에게 흉기를 휘둘러 다치게 한 대가 재판에 넘겨졌다 일 수원지검 평택지청 형사 부는 살인미수 혐의로 군을 구속기소 했다고 밝혔다 군은 지난 달 일 경기도 평택시의 한 아
#
# 네이버가 불공정 논란이 일었던 뉴스콘텐츠제휴 약관을 전면 수정해 재공지했다 네이버는 일 오후 뉴스콘텐츠제휴 언론사들에 이메일을 보내 기존 약관 대신 추가 수정한 개정 약관으로 재동의를 구하고자 한다 며
#
# 근로자의 날인 오늘 일 양대노총을 비롯한 노동 단체들이 서울 도심 곳곳에서 대규모 집회를 엽니다 민주노총은 오늘 오후 시 서울 종로구 동화면세점 앞에서 세계노동절대회 를 열고 월 총파업 투쟁을 선포할 계획
#
# 유승민 국민의힘 전 의원이 한미정상회담 결과 와 관련 대한민국 대통령이면 대한민국 국민들께서 가장 위협을 느끼는 북핵문제에 대해서 이번에 길과 방향을 제대로 틀고 왔어야 된다 면서 그런데 오히려 미국한테 좀
#
# 천연기념물 지정된 순천 승주 평지마을 이팝나무 장성 백양사 쌍계루 앞의 이팝나무 각진국사가 꽂은 지팡이가 자랐다는 전설이 전해진다 꽃이 활짝 핀 지난해 월 풍경이다 이돈삼 이팝나무꽃이 피고 있다 연둣
#
# 년 월 일 경기 안산시 단원구 바닷가에서 신원미상 남성의 시신이 발견됐다 마대에 담긴 시신은 신체 일부만 있었다 일대에 대대적인 경찰 수색이 펼쳐졌다 이틀 후 약 떨어진 바닷가에서 시신의 나
#
#
#
# 청소년을 겨냥한 마약 범죄가 기승을 부리자 검찰이 최대 사형까지 구형하겠다며 특단의 조치를 내놨습니다 검찰은 최근 발생한 학원가 마약 음료 사건부터 이번 가중처벌 조항을 적용하는 방안을 검토하고 있습니다 취재
#
# 에코프로그룹주 더 오른다 국내 배터리업계 주목해야 비판적 읽기 피력 기관 증권사 등 이해관계 있다 돈 벌 기회가 주어져 있다 년 주기로 꼭 투자해야 하는 투자 대상들이 생기는데 그게 마침 배터리
#
# 때만 되면 포털 뉴스란에 심심찮게 등장하는 단어가 있습니다 수상택시입니다 그 옆에는 늘 함께 붙어다니는 말이 있습니다 서울시입니다 서울시는 년부터 서울의 교통혼잡을 완화하기 위한 대안으로 수상택
#
# 수원지검 평택지청 전경 평택의 한 아파트단지에서 초등학생을 흉기로 습격하고 달아난 고교생이 구속 기소됐다 수원지검 평
#
# 삼성전자와 네이버가 손잡는 사례가 늘어나고 있다 지난해 연말 초거대 인공지능 에 활용된 반도체 솔루션 개발을 위한 업무 협약을 시작으로 금융과 정보기술 등에서 협력 범위를 넓혀 나가고 있다 최근
#
# 인 가족이 주일 정도 해외에 함께 나가면 만원을 훌쩍 넘어가는 게 현실이다 여행객 주일이나 열흘간 해외에 갔다고 십몇만원 로밍요금 을 내야 하는 것은 과해 보인다 박윤규 과학기술정보통신부 차
#
# 월 일 노동절 근로자의 날 을 맞아 주요 신문들이 우리 사회 노동자들의 현실을 분석한 기획 보도들을 내놨다 정부가 노동 관련 현행 법 제도 사각지대를 보완하고 노동 탄압이 우려되는 정책을 재고해야 한다는 주문이
#
# 정부가 문화유산을 활용한 게임 메타버스 창작을 지원하기 위해 무료로 개방한 문화재 데이터에 중국 누리꾼들의 댓글 테러 가 이어지고 있다 일 게임 업계 등에 따르면 에픽게임즈가 운영하는 언리얼 엔진 마켓플
#
# 약사 면허증을 위조해 년 동안 가짜 약사 행세를 해온 대가 경찰에 검거됐습니다 제주경찰청 의료 안전사고 전문수사팀은 대 씨를 공문서위조 및 행사 사기와 약사법 위반 혐의 등으로 검찰에 송치했다고 밝혔
#
# 중증 자폐성 장애를 가진 특수학교 소속 수영 꿈나무가 정작 교내에 있는 특수 수영장은 사용하지 못해 좌절하고 있다 일반 학생들의 수영 수업에 밀려 특수학교 학생에 대한 수영 수업은 뒷전이 됐기 때문이다 사설 스포
#
# 중국 네티즌들이 한복 음력 설에 이어 한옥이 중국 문화라는 황당 주장을 펼쳐 눈살을 찌푸리게 하고 있다 일 게임업계에 따르면 중국 네티즌들은 에픽게임즈가 운영하는 언리얼 엔진 마켓플레이스 에 올라온 한옥 애셋
#
# 윤희근 경찰청장이 계급 특진 임용을 내걸고 건폭 과 마약 수사 를 독려하면서 내부에서는 윗선 입맛에 맞는 수사만 할 것 이라는 우려의 목소리가 나오고 있습니다 윤 청장은 지난달 일 전북경찰청을 찾아 건
#
# 지난달 일 부산 영도구 청학동 스쿨존에서 짜리 원통형 화물에 치여 숨진 아이의 아빠가 온라인 커뮤니티에 자신의 심경을 올렸다 아빠는 생전 딸의 사랑스러웠던 여러 모습을 메모하듯이 남기며 딸을 추억했다
#
# 대 학생의 극단적 선택이 에 노출된 것과 관련해 온라인 커뮤니티 우울증 갤러리 가 경찰 수사를 받고 있는데요 경찰의 커뮤니티 폐쇄 요청과 이를 수용하지 않은 방심위의 결정을 두고 여러 이야기가 나옵니다
#
# 년간 폭력을 행사하고 교제를 강요한 여자친구에게 이별을 통보받자 승용차로 들이받고 흉기로 살해하려 한 대가 중형을 선고받았다 경남 창원지법 제 형사부 장유진 부장판사 는 살인미수와 특수상해 특수협박 등으로
#
# 한 서울대생이 억 만 원 상당의 미술 작품 속 바나나를 먹고 아침을 안 먹고 와서 배고파 먹었다 라고 한 사실이 알려졌습니다 서울대 미학과 재학생 노 모 씨는 지난달 일 리움미술관에서 진행한 마우리
#
# 리얼미터선 주 만에 반등 한국갤럽은 하락세 대통령 방미 성과 홍보 매진하고 국정 드라이브 박 일간의 미국 국빈 방문 일정을 마치고 귀국한 윤석열 대통령이 지지율 반등 이라는 성적표를 받게 됐다 일
#
# 정부가 저소득층 청년 저축액의 최대 배까지 같은 금액을 추가 지원하는 청년내일저축계좌 신규 가입자 모집이 일 시작된다 중위소득 이하 가구의 만 세 세 일하는 청년이이라면 청년내일저축계좌를 개설
#
# 서울특별시 동대문구 답십리 동 번지 호 통 반 년도 이상호씨 호적명 이대호 가족이 살았던 주소다 그리고 그해 실종 또는 유괴된 상호씨의 아들 이은권씨 당시 만 세 사진 가 년이 넘게
#
# 온건 성향이어서 당사자간 소통은 무리 없을 전망이지만 거대 여야 양강 대립 구도 속 운신의 폭 좁다는 지적도 사법리스크 따라 비주류 박광온 변수될수도 국민의힘과 더불어민주당이 나란히 새 원내사령탑을 뽑으면서 입법
#
#
#
# 충북 보은군 속리산 법주사가 징수해 온 문화재 관람료가 폐지될 예정임에 따라 지역 관광경기 활성화 기대가 높아지고 있습니다 국가지정문화재 민간 소유자 또는 관리단체가 문화재 관람료를 감면하면 그 비용을 국가가 지원
#
# 검거 전 보험금 지급 청구 소송 구속 수감 후에도 소송 이어가 가평 계곡 살인 으로 세상을 떠들썩하게 했던 이은해가 심에 이어 항소심에서도 무기징역을 선고 받았습니다 이은해의 내연남이자 공범인 조현수 역시 심
#
# 미국 우주개발 스타트업이 물을 동력으로 쓰는 우주선을 개발해 우주 운송사업에 뛰어들겠다고 선언했다 지구 저궤도 운송은 내년 말 첫 시험을 거쳐 년 상용 서비스를 시작한다는 야심찬 계획이다 일론 머스크가 설
#
# 배우 인터뷰한 성 인물 논란 어떻게 봐야하나 산업은 일본 내 성착취 구조 의 첨단에 자리합니다 그 구조에 대한 비판적 고려 없이 이를 콘텐츠화한다뇨 이나영 중앙대학교 사회학과 교수
#
# 잉글랜드 프리미어리그 에서 뛰고 있는 손흥민 토트넘 홋스퍼 의 반칙 상황을 무술 에 비유한 유명 해설가가 인종차별 논란에 휩싸였다 손흥민은 일 한국시간 에 열린 시즌 라운드
#
# 국내에서 벤츠를 이미 앞지른 제네시스가 글로벌에서도 판매량이 꾸준히 증가하며 승승장구하고 있다 특히 최근에는 컨버터블 콘셉트카를 공개하며 고급 차 이미지 굳히기에 나섰다 일 업계에 따르면 지난해 제네시스 브랜드

# %%
import requests as rq
from bs4 import BeautifulSoup

url = 'https://news.daum.net/politics'

r = rq.get(url)
html = r.text
bs = BeautifulSoup(html,'html.parser')

print(bs.find_all('h2'),'\n')
print(bs.find('h2',id='mainContent').text)
# Out:
# [<h2 class="screen_out">뉴스 메인메뉴</h2>, <h2 class="screen_out" id="mainContent">정치</h2>, <h2 class="tit_direct">바로가기</h2>, <h2 class="screen_out">서비스 이용정보</h2>]
#
# 정치

# %%
# Q. 네이버 영화 랭킹 조회순 첫번째 영화제목을 출력하세요.

# %%
url = 'https://serieson.naver.com/v3/movie/ranking/realtime'
r = rq.get(url)
html = r.text
bs = BeautifulSoup(html,'html.parser')
print(bs.find('span',class_='Title_title__s9o0D').text)
# Out:
# 던전 앤 드래곤: 도적들의 명예

# %%
import requests
from bs4 import BeautifulSoup

url = "https://serieson.naver.com/v3/movie/ranking/realtime"

# HTTP GET 요청을 보냅니다.
response = requests.get(url)

# HTTP 요청이 성공적으로 전달되었다면, 웹사이트의 HTML 코드를 가져옵니다.
if response.status_code == 200:
    # HTML 코드를 파싱합니다.
    soup = BeautifulSoup(response.text, "html.parser")
# print(soup)
soup.find("span", class_="Title_title__s9o0D").text
# Out:
# '던전 앤 드래곤: 도적들의 명예'

# %% [markdown]
# #### 과제5_0501.
# 네이버 영화 랭킹 실시간 조회 데이터를 가져와서 Top 10 영화를 아래와 같이 출력하세요.

# %%
1: 던전 앤 드래곤: 도적들의 명예
2: 존 윅
3: 존 윅 3: 파라벨룸

# %% [markdown]
# #### 과제6_0501.
# url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100' 사이트에서 뉴스기사 제목을 출력하세요.

# %%
from bs4 import BeautifulSoup 
import re # 정규 표현식을 사용할 때 
html = """
<ul>
  <li><a href="hoge.html">hoge</li>
  <li><a href="https://example.com/fuga">fuga*</li>
  <li><a href="https://example.com/foo">foo*</li>
  <li><a href="http://example.com/aaa">aaa</li>
</ul>
"""
soup = BeautifulSoup(html, "html.parser")
# 정규 표현식으로 href에서 https인 것 추출하기 
li = soup.find_all(href=re.compile(r"^https://"))
print(li,'\n')
for e in li: print(e.attrs['href'])
# Out:
# [<a href="https://example.com/fuga">fuga*</a>, <a href="https://example.com/foo">foo*</a>]
#
# https://example.com/fuga
# https://example.com/foo

# %% [markdown]
# ### CSS 선택자
# - 원하는 정보만 선별하여 수집하고 싶을 때 css선택자를 활용할 수 있음
# - (CSS 선택자 설명 추가)
# - F12 >> 수집하고 싶은 부분 클릭 >> 태그 선택 >> copy Selector
# - BeautifulSoup의 select_one, select 활용

# %%
# select_one()
import requests as rq
from bs4 import BeautifulSoup

url = 'https://news.daum.net/politics#1'
r = rq.get(url)
html = r.text
bs = BeautifulSoup(html,'lxml')

# lines = bs.select('body > div > main > section > div.main-sub > div > ul > li:nth-child(1) > strong > a')
line = bs.select_one('body > div > main > section > div.main-sub > div > ul > li:nth-child(1) > strong > a')

print(line.text)
# Out:
# 용혜인 "'초단시간 노동자 권리찾기법' 발의 추진"

# %%
# select()
import requests as rq
from bs4 import BeautifulSoup

url = 'https://news.daum.net/politics#1'
r = rq.get(url)
html = r.text
bs = BeautifulSoup(html,'lxml')

# lines = bs.select('body > div > main > section > div.main-sub > div > ul > li:nth-child(1) > strong > a')
lines = bs.select('body > div > main > section > div > div > ul > li > strong > a')
body = '\n'.join([line.text for line in lines])
print(body)
# Out:
# 尹 지지율 4주 만에 반등 34.5%..'미국 국빈 방문 영향'
# 송영길 측 회계담당자, 수사 직전 파리 방문…"가족 요청"
# 증평역 설치 100주년…군청 앞에 기념 표지판 제막
# 천아용인 모였다…이준석 “1000원밥? 똑바로 하면 2만원 내고도 온다”
# 용혜인 "'초단시간 노동자 권리찾기법' 발의 추진"
# 나라 곳간 우려는 뒷전... 재정소요 법안 '비용추계서 제출' 유명무실
# 5월 임시국회 시작…여야, '노란봉투법' 충돌 예고
# 민주당 “맞벌이 학부모 위한 주 4일제 적극 검토”
# 尹대통령, 한총리와 주례회동 취소…"방미 직후 사정 등 고려"
# 노동절에 노동자 갈라치는 대통령…“고용세습 뿌리 뽑겠다”

# %%
# Q. 한글만 출력하세요( 개행 없이)

# %%
texts = re.findall('[가-힣0-9]+',body)
print(' '.join(texts))
# Out:
# 지지율 4주 만에 반등 34 5 미국 국빈 방문 영향 송영길 측 회계담당자 수사 직전 파리 방문 가족 요청 증평역 설치 100주년 군청 앞에 기념 표지판 제막 천아용인 모였다 이준석 1000원밥 똑바로 하면 2만원 내고도 온다 용혜인 초단시간 노동자 권리찾기법 발의 추진 나라 곳간 우려는 뒷전 재정소요 법안 비용추계서 제출 유명무실 5월 임시국회 시작 여야 노란봉투법 충돌 예고 민주당 맞벌이 학부모 위한 주 4일제 적극 검토 대통령 한총리와 주례회동 취소 방미 직후 사정 등 고려 노동절에 노동자 갈라치는 대통령 고용세습 뿌리 뽑겠다

# %% [markdown]
# #### 과제7_0501.
# 네이버 뉴스 데이터 사회분야 데이터를 가져와서 다음을 수행하세요.
# - 첫번째 뉴스 제목과 href를 출력
# - 뉴스 전체 제목과 href를 출력(열방향)

# %%
import requests as rq
from bs4 import BeautifulSoup

url = 'https://news.daum.net/politics#1'
r = rq.get(url)
html = r.text
bs = BeautifulSoup(html,'lxml')
lines = bs.select('body > div > main > section > div > div > ul > li > strong > a')
for line in lines:
    print(line.text)
# Out:
# 금융위기 때 부실 금융사도 지원했으면서…피해 세입자는 왜?
# 여야, 엇갈린 방미 평가...'전세 사기 특별법' 본격 논의
# 내일 윤리위 첫 회의, 김재원 '5·18 이전 징계' 무게  [시사스페셜]
# 30대 퇴직금 평균 1180만원…전체 평균의 79% 수준
# 박광온 `통합` 내세웠지만… 민주당 계파결집 갈수록 심화
# 적과 아군 뿐인 ‘치명적’ 윤석열 외교…북·중·러 반발 거세진다
# 檢, 송영길 금품살포 공범 영장 적시…"지시 여부 확인할 것"
# 돈봉투·쇄신·개딸… 野 새 원내사령탑 과제 산적
# 북한, 연일 '워싱턴 선언' 비난…릴레이 도발 나서나
# 與, 윤리위·노동개혁특위 본격 가동

# %%
# 데이터 가져오기 > 텍스트 형식으로 추출 > 바이너리 형식으로 추출
import requests as rq
import warnings
warnings.filterwarnings('ignore')

url = "http://api.aoikujira.com/time/get.php"
r = rq.get(url).text
print(r)
b = rq.get(url).content
print(b)
# Out:
# 2023/05/03 14:12:38
# b'2023/05/03 14:12:38'

# %%
# url = "http://naver.com"를 텍스트와 바이너리로 가져오세요.
url = "http://naver.com"
r = rq.get(url).text
print(r)
b = rq.get(url).content
print(b)

# %%
# requests로 요청 시 데이터를 실어 보내는 경우 데이터를 딕셔너리 형태로 만들어 보내는 방식(get 방식)
# url = "http://naver.com"을 "https://www.naver.com/?key1=value1&key2=value2"로 만드세요.

url = "http://naver.com"
res = rq.get(url, params = {"key1":"value1", "key2":"value2"})
print(res.url)
# Out:
# https://www.naver.com/?key1=value1&key2=value2

# %%
# post 요청 시 데이터가 url에 포함되지 않고 header의 body에 포함됨
# body 데이터 추가 시 data를 사용

url = "http://naver.com"
res = rq.post(url, data = {"key1":"value1", "key2":"value2"})
print(res.url)
# Out:
# https://www.naver.com/

# %%
from bs4 import BeautifulSoup

headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
url = "https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100"
req = rq.get(url, headers=headers)
bs = BeautifulSoup(req.content, 'html.parser')
print(bs.prettify())
# Out:
# <!DOCTYPE HTML>
# <html lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta contents="always" name="referrer"/>
#   <meta content="600" http-equiv="refresh">
#    <meta content="width=1106" name="viewport">
#     <meta content="정치 : 네이버 뉴스" property="og:title"/>
#     <meta content="website" property="og:type"/>
#     <meta content="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100" property="og:url"/>
#     <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image">
#      <meta content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공" property="og:description"/>
#      <meta content="네이버" property="og:article:author">
#       <meta content="summary" name="twitter:card"/>
#       <meta content="정치 : 네이버 뉴스" name="twitter:title"/>
#       <meta content="네이버 뉴스" name="twitter:site"/>
#       <meta content="네이버 뉴스" name="twitter:creator"/>
#       <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
#       <meta content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공" name="twitter:description"/>
#       <title>
#        정치 홈 : 네이버 뉴스
#       </title>
#       <link href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#       <link href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/common.css" rel="stylesheet" type="text/css"/>
#       <link href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/news.css" rel="stylesheet" type="text/css"/>
#       <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jindo.js" type="text/javascript">
#       </script>
#       <script charset="utf-8" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jquery.js" type="text/javascript">
#       </script>
#       <script type="text/javascript">
#        var _MAIN_NEWS_MENU_ID='shm';
# var _MAIN_NEWS_SECTION_ID='103';
# var ccsrv='cc.naver.com';
# var g_ssc='news.sec';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness = 3;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
#
# var gnb_timestamp = "Wed May 03 14:24:51 KST 2023";
#       </script>
#       <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.service.js" type="text/javascript">
#       </script>
#       <script>
#        var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#     if (!isUnderIE10) {
#         var gladSDK = document.createElement("script");
#         gladSDK.async = true;
#         gladSDK.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#         document.head.appendChild(gladSDK);
#     }
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#
#     window.gladsdk.cmd.push(function () {
#         window.gladsdk.setGlobalConfig({enablePersistAd: true});
#         window.gladsdk.setHostMeta('theme', 'system');
#
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newsend',
#             adSlotElementId: 'glad_ad_newsend'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newslist',
#             adSlotElementId: 'glad_ad_newslist'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_sidebox',
#             adSlotElementId: 'glad_ad_sidebox'
#         });
#     })
#       </script>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body>
#   <div id="wrap">
#    <!-- 광고적용 태그 추가 -->
#    <div id="da_base">
#    </div>
#    <div id="da_stake">
#    </div>
#    <div class="header" id="header">
#     <div id="u_skip">
#      <a href="#lnb" tabindex="1">
#       <span>
#        메인 메뉴로 바로가기
#       </span>
#      </a>
#      <a href="#main_content" tabindex="2">
#       <span>
#        본문으로 바로가기
#       </span>
#      </a>
#     </div>
#     <div class="snb_area">
#      <div class="snb_inner">
#       <div class="gnb_area">
#        <div class="gnb_wrap">
#         <div class="gnb_dark_type2" id="gnb">
#         </div>
#        </div>
#        <div class="gnb_search is_hidden _search_content">
#        </div>
#        <div class="gnb_tool" id="gnb_search_tool">
#         <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;">
#          <span class="icon_search">
#           검색
#          </span>
#         </a>
#        </div>
#       </div>
#       <div id="snb_wrap">
#        <h1>
#         <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/">
#          <span class="blind">
#           NAVER
#          </span>
#         </a>
#         <a class="h_news nclicks(gnb.news)" href="/">
#          <span class="blind">
#           뉴스
#          </span>
#         </a>
#        </h1>
#        <ul class="snb_related_service">
#         <li>
#          <span class="snb_bdr">
#          </span>
#          <a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">
#           TV연예
#          </a>
#         </li>
#         <li>
#          <span class="snb_bdr">
#          </span>
#          <a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">
#           스포츠
#          </a>
#         </li>
#         <li>
#          <span class="snb_bdr">
#          </span>
#          <a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">
#           날씨
#          </a>
#         </li>
#         <li>
#          <span class="snb_bdr">
#          </span>
#          <a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">
#           프리미엄
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#     <div class="lnb_area">
#      <div class="lnb_inner">
#       <div class="lnb_both">
#        <div class="lnb_left">
#         <div class="lnb_menu" id="lnb">
#          <ul>
#           <li>
#            <a class="nclicks(lnb.pcmedia)" href="/">
#             <span class="tx">
#              언론사별
#             </span>
#            </a>
#           </li>
#           <li class="on">
#            <a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100">
#             <span class="tx">
#              정치
#             </span>
#             <span class="blind">
#              선택됨
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101">
#             <span class="tx">
#              경제
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102">
#             <span class="tx">
#              사회
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103">
#             <span class="tx">
#              생활/문화
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105">
#             <span class="tx">
#              IT/과학
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104">
#             <span class="tx">
#              세계
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111">
#             <span class="tx">
#              랭킹
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(lnb.paper)" href="/newspaper/home">
#             <span class="tx">
#              신문보기
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(lnb.opi)" href="/opinion/home">
#             <span class="tx">
#              오피니언
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh">
#             <span class="tx">
#              TV
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(lnb.fact)" href="/main/factcheck/main.naver">
#             <span class="tx">
#              팩트체크
#             </span>
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="lnb_right">
#         <div class="lnb_extra">
#          <div class="lnb_extra_menu">
#           <ul class="lnb_extra_menu_list">
#            <li class="lnb_extra_menu_item">
#             <a class="lnb_extra_menu_link nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">
#              전체 언론사
#             </a>
#            </li>
#            <li class="lnb_extra_menu_item">
#             <a class="lnb_extra_menu_link nclicks(STA.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">
#              뉴스스탠드
#             </a>
#            </li>
#            <li class="lnb_extra_menu_item">
#             <a class="lnb_extra_menu_link nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">
#              라이브러리
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="lnb">
#      <span class="lnb_date">
#       <strong>
#        05
#       </strong>
#       .
#       <strong>
#        03
#       </strong>
#       <span class="day">
#        (수)
#       </span>
#      </span>
#      <ul class="lnb_side" tabindex="0">
#       <li>
#        <a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">
#         전체 언론사
#        </a>
#       </li>
#       <li>
#        <a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">
#         뉴스스탠드
#        </a>
#       </li>
#       <li>
#        <a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">
#         라이브러리
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <hr/>
#    <table cellpadding="0" cellspacing="0" class="container">
#     <caption class="blind">
#      기사목록
#     </caption>
#     <colgroup>
#      <col class="col_snb"/>
#      <col class="col_content"/>
#      <col class="col_aside"/>
#     </colgroup>
#     <tr>
#      <td class="snb">
#       <div class="snb" id="snb">
#        <h2 class="h2">
#         <a class="nclicks(lmn_pol.home)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100">
#          정치
#         </a>
#        </h2>
#        <ul class="nav">
#         <li>
#          <a class="snb_s11 nclicks(lmn_pol.mnl,,1)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=264">
#           대통령실
#          </a>
#         </li>
#         <li>
#          <a class="snb_s12 nclicks(lmn_pol.mnl,,2)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=265">
#           국회/정당
#          </a>
#         </li>
#         <li>
#          <a class="snb_s13 nclicks(lmn_pol.mnl,,3)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=268">
#           북한
#          </a>
#         </li>
#         <li>
#          <a class="snb_s14 nclicks(lmn_pol.mnl,,4)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=266">
#           행정
#          </a>
#         </li>
#         <li>
#          <a class="snb_s15 nclicks(lmn_pol.mnl,,5)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=267">
#           국방/외교
#          </a>
#         </li>
#         <li>
#          <a class="snb_s16 nclicks(lmn_pol.mnl,,6)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=269">
#           정치일반
#          </a>
#         </li>
#        </ul>
#        <div class="snb_banner">
#         <a class="nclicks(lmn_pol.pmb,,1)" href="https://media.naver.com/channel/setting?back=main">
#          <img alt="언론사 구독하기" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/01/14/142956425_144518244_%2525B8%2525F0%2525B9%2525D9%2525C0%2525CF%2525B8%2525DE%2525C0%2525CE.png" width="71"/>
#         </a>
#        </div>
#        <div class="snb_banner">
#         <a class="nclicks(lmn_pol.pmb,,1)" href="https://contents.premium.naver.com/">
#          <img alt="네이버 프리미엄콘텐츠" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71"/>
#         </a>
#        </div>
#       </div>
#      </td>
#      <td class="content">
#       <div class="content" id="main_content">
#        <div class="list_body section_index">
#         <div class="cluster">
#          <div class="cluster_title">
#           <span class="cluster_title_inner">
#            <a class="cluster_title_icon_link _news_cluster_layer_btn" href="#biF7L">
#             <i class="cluster_title_icon">
#              안내
#             </i>
#             헤드라인 뉴스
#            </a>
#           </span>
#           <div class="cluster_title_layer _news_cluster_layer is_hidden">
#            <div class="cluster_title_layer_text">
#             헤드라인 뉴스와 각 기사묶음 타이틀은
#             <br/>
#             기사 내용을 기반으로
#             <strong>
#              자동 추출
#             </strong>
#             됩니다.
#            </div>
#            <div class="cluster_title_layer_image">
#            </div>
#            <button class="cluster_title_layer_close _news_cluster_layer_close_btn" type="button">
#             닫기
#            </button>
#           </div>
#          </div>
#         </div>
#         <div class="_persist">
#          <div class="cluster">
#           <div class="cluster_group _cluster_content">
#            <div class="cluster_body">
#             <ul class="cluster_list">
#              <li class="cluster_item">
#               <div class="cluster_thumb">
#                <div class="cluster_thumb_inner">
#                 <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011477677?sid=100">
#                  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/056/2023/05/03/11477677.jpg?type=ofullfill132_90" width="132"/>
#                 </a>
#                </div>
#               </div>
#               <div class="cluster_text">
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011477677?sid=100">
#                 국회 정개특위, 선거제 개편 ‘500인 공론조사’ 실시…KBS 생중계
#                </a>
#                <div class="cluster_text_lede">
#                 국회 정치개혁특별위원회(정개특위)는 오는 6일과 13일 양일간 500명의 시민참여단을 대상으로 국회의원 선거제도 개편에 대한 공론조사를 실시하고, KBS …
#                </div>
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news056,0011477677',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  KBS
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li class="cluster_item as_line">
#               <div class="cluster_text">
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news018,0005477769',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  이데일리
#                 </div>
#                </div>
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/018/0005477769?sid=100">
#                 `선거제 개편` 공론화 본격화…대표 시민 500인 토론
#                </a>
#               </div>
#              </li>
#              <li class="cluster_item as_line">
#               <div class="cluster_text">
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news014,0005006585',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  파이낸셜뉴스
#                 </div>
#                </div>
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/014/0005006585?sid=100">
#                 '선거제도, 국회의원이 아닌 국민이 결정하자' 정개특위, 시민 500명 참여 토론회 연다
#                </a>
#               </div>
#              </li>
#              <li class="cluster_item as_line">
#               <div class="cluster_text">
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news009,0005125082',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  매일경제
#                 </div>
#                </div>
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/009/0005125082?sid=100">
#                 선거개편 공론화…시민참여단 500명 모여 토론한다
#                </a>
#               </div>
#              </li>
#             </ul>
#            </div>
#            <div class="cluster_foot">
#             <div class="cluster_foot_inner">
#              <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305031050_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=056&amp;aid=0011477677">
#               <span class="cluster_foot_more_icon_num">
#                8
#               </span>
#               <span class="cluster_foot_more_text">
#                개의 관련뉴스 더보기
#               </span>
#              </a>
#             </div>
#            </div>
#           </div>
#           <div class="cluster_group _cluster_content">
#            <div class="cluster_body">
#             <ul class="cluster_list">
#              <li class="cluster_item">
#               <div class="cluster_thumb">
#                <div class="cluster_thumb_inner">
#                 <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898653?sid=100">
#                  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/366/2023/05/03/898653.jpg?type=ofullfill132_90" width="132"/>
#                 </a>
#                </div>
#               </div>
#               <div class="cluster_text">
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898653?sid=100">
#                 野 의원 독도 방문에 日 항의…외교부 “부당한 주장 일축”
#                </a>
#                <div class="cluster_text_lede">
#                 정부는 3일 전용기 더불어민주당 의원의 독도 방문에 대한 일본 측 항의에 “일본 측의 부당한 주장은 외교 채널을 통해 일축했다”고 밝혔다. 외교부 당국자 …
#                </div>
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news366,0000898653',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  조선비즈
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li class="cluster_item as_line">
#               <div class="cluster_text">
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004186276',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  서울경제
#                 </div>
#                </div>
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004186276?sid=100">
#                 정부, "野 독도 방문 부당' 日항의에 "부당한 주장"
#                </a>
#               </div>
#              </li>
#              <li class="cluster_item as_line">
#               <div class="cluster_text">
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news016,0002138197',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  헤럴드경제
#                 </div>
#                </div>
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002138197?sid=100">
#                 더불어민주당 경북도당 청년·대학생위 독도 현지서 ‘독도영유권수호 다짐’
#                </a>
#               </div>
#              </li>
#              <li class="cluster_item as_line">
#               <div class="cluster_text">
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news079,0003766028',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  노컷뉴스
#                 </div>
#                </div>
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/079/0003766028?sid=100">
#                 韓의원 독도 방문에…日 "윤석열 정권에 대한 반발이냐"[이슈시개]
#                </a>
#               </div>
#              </li>
#             </ul>
#            </div>
#            <div class="cluster_foot">
#             <div class="cluster_foot_inner">
#              <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305021530_00000499&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=366&amp;aid=0000898653">
#               <span class="cluster_foot_more_icon_num">
#                77
#               </span>
#               <span class="cluster_foot_more_text">
#                개의 관련뉴스 더보기
#               </span>
#              </a>
#             </div>
#            </div>
#           </div>
#           <div class="cluster_group _cluster_content">
#            <div class="cluster_body">
#             <ul class="cluster_list">
#              <li class="cluster_item">
#               <div class="cluster_thumb">
#                <div class="cluster_thumb_inner">
#                 <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006783769?sid=100">
#                  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/421/2023/05/03/6783769.jpg?type=ofullfill132_90" width="132"/>
#                 </a>
#                </div>
#               </div>
#               <div class="cluster_text">
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006783769?sid=100">
#                 '태영호 녹취록'에 與 '산 넘어 산'…태영호 징계 수위에 영향은
#                </a>
#                <div class="cluster_text_lede">
#                 이진복 대통령실 정무수석이 22대 총선 공천 문제를 거론하며 한일 관계에 대한 옹호 발언을 해달라고 요청했다는 태영호 국민의힘 최고위원의 녹취가 공개되면 …
#                </div>
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006783769',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  뉴스1
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li class="cluster_item as_line">
#               <div class="cluster_text">
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news586,0000057017',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  시사저널
#                 </div>
#                </div>
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/586/0000057017?sid=100">
#                 '체리따봉'부터 '태영호 녹취록'까지, 용산 '당무 개입'은 이제 시작?
#                </a>
#               </div>
#              </li>
#              <li class="cluster_item as_line">
#               <div class="cluster_text">
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news437,0000341508',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  JTBC
#                 </div>
#                </div>
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/437/0000341508?sid=100">
#                 '태영호 녹취록'에 국민의힘 발칵…당내서도 "불법 공천개입"
#                </a>
#               </div>
#              </li>
#              <li class="cluster_item as_line">
#               <div class="cluster_text">
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news215,0001099017',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  한국경제TV
#                 </div>
#                </div>
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/215/0001099017?sid=100">
#                 대통령실 공천 개입? 태영호 녹취록 논란에 與 '선긋기'
#                </a>
#               </div>
#              </li>
#             </ul>
#            </div>
#            <div class="cluster_foot">
#             <div class="cluster_foot_inner">
#              <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305012010_00000017&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=421&amp;aid=0006783769">
#               <span class="cluster_foot_more_icon_num">
#                82
#               </span>
#               <span class="cluster_foot_more_text">
#                개의 관련뉴스 더보기
#               </span>
#              </a>
#             </div>
#            </div>
#           </div>
#           <div class="cluster_group _cluster_content">
#            <div class="cluster_body">
#             <ul class="cluster_list">
#              <li class="cluster_item">
#               <div class="cluster_thumb">
#                <div class="cluster_thumb_inner">
#                 <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/417/0000917923?sid=100">
#                  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/417/2023/05/03/917923.jpg?type=ofullfill132_90" width="132"/>
#                 </a>
#                </div>
#               </div>
#               <div class="cluster_text">
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/417/0000917923?sid=100">
#                 장예찬 "태영호 녹취록, 일벌백계해야"… 김성태 "중징계감 아니야"
#                </a>
#                <div class="cluster_text_lede">
#                 이른바 '공천 녹취록' 유출과 관련해 여당 내부에서 의견이 엇갈리고 있다. 장예찬 국민의힘 최고위원은 "누구든 일벌백계 읍참마속의 기조로 엄하게 다뤄야  …
#                </div>
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news417,0000917923',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  머니S
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li class="cluster_item as_line">
#               <div class="cluster_text">
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news028,0002638294',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  한겨레
#                 </div>
#                </div>
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/028/0002638294?sid=100">
#                 장예찬 “용산과 더 가까운 나도 공천 부탁 들은 적 없다”
#                </a>
#               </div>
#              </li>
#              <li class="cluster_item as_line">
#               <div class="cluster_text">
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news214,0001270371',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  MBC
#                 </div>
#                </div>
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001270371?sid=100">
#                 장예찬 "내가 태영호보다 대통령실과 더 가까운데.. 공천-부탁 들어본 적 없어" [시선집중]
#                </a>
#               </div>
#              </li>
#              <li class="cluster_item as_line">
#               <div class="cluster_text">
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news014,0005006466',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  파이낸셜뉴스
#                 </div>
#                </div>
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/014/0005006466?sid=100">
#                 장예찬 "내가 태영호보다 대통령실과 더 가깝지만 공천‧부탁 들어본 적 없다"
#                </a>
#               </div>
#              </li>
#             </ul>
#            </div>
#            <div class="cluster_foot">
#             <div class="cluster_foot_inner">
#              <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305031000_00000388&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=417&amp;aid=0000917923">
#               <span class="cluster_foot_more_icon_num">
#                9
#               </span>
#               <span class="cluster_foot_more_text">
#                개의 관련뉴스 더보기
#               </span>
#              </a>
#             </div>
#            </div>
#           </div>
#           <div class="cluster_group _cluster_content">
#            <div class="cluster_body">
#             <ul class="cluster_list">
#              <li class="cluster_item">
#               <div class="cluster_thumb">
#                <div class="cluster_thumb_inner">
#                 <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011477621?sid=100">
#                  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/056/2023/05/03/11477621.jpg?type=ofullfill132_90" width="132"/>
#                 </a>
#                </div>
#               </div>
#               <div class="cluster_text">
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011477621?sid=100">
#                 ‘돈 봉투 의혹’ 민주당 윤관석·이성만 의원 자진 탈당 결정
#                </a>
#                <div class="cluster_text_lede">
#                 '돈 봉투 의혹'에 휩싸인 더불어민주당 윤관석, 이성만 의원이 자진 탈당을 결정했습니다. 민주당 윤관석, 이성만 의원은 오늘(3일) 국회에서 비공개 최고 …
#                </div>
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news056,0011477621',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  KBS
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li class="cluster_item">
#               <div class="cluster_thumb">
#                <div class="cluster_thumb_inner">
#                 <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005254124?sid=100">
#                  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/277/2023/05/03/5254124.jpg?type=ofullfill132_90" width="132"/>
#                 </a>
#                </div>
#               </div>
#               <div class="cluster_text">
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005254124?sid=100">
#                 '돈봉투' 의혹 윤관석·이성만 민주당 탈당…"선당후사 마음으로..."
#                </a>
#                <div class="cluster_text_lede">
#                 ‘전당대회 돈봉투’ 논란과 윤관석·이성만 의원이 더불어민주당을 탈당하기로 했다. 윤 의원과 이 의원은 3일 민주당 지도부와 면담을 거친 뒤 기자들에게 탈 …
#                </div>
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news277,0005254124',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  아시아경제
#                 </div>
#                </div>
#               </div>
#              </li>
#             </ul>
#            </div>
#            <div class="cluster_foot">
#             <div class="cluster_foot_inner">
#              <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305021920_00000080&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=056&amp;aid=0011477621">
#               <span class="cluster_foot_more_icon_num">
#                85
#               </span>
#               <span class="cluster_foot_more_text">
#                개의 관련뉴스 더보기
#               </span>
#              </a>
#             </div>
#            </div>
#           </div>
#           <div class="cluster_group _cluster_content">
#            <div class="cluster_body">
#             <ul class="cluster_list">
#              <li class="cluster_item">
#               <div class="cluster_thumb">
#                <div class="cluster_thumb_inner">
#                 <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/018/0005477679?sid=100">
#                  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/018/2023/05/03/5477679.jpg?type=ofullfill132_90" width="132"/>
#                 </a>
#                </div>
#               </div>
#               <div class="cluster_text">
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/018/0005477679?sid=100">
#                 '야권 원로' 유인태, 국민의힘 친윤모임 국민공감서 특강
#                </a>
#                <div class="cluster_text_lede">
#                 야권 원로 인사인 유인태 전 국회 사무총장이 국민의힘 내 친윤 그룹 공부 모임인 ‘국민공감’에서 특강을 진행한다. 유인태 전 국회사무총장(사진=연합뉴스) …
#                </div>
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news018,0005477679',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  이데일리
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li class="cluster_item">
#               <div class="cluster_thumb">
#                <div class="cluster_thumb_inner">
#                 <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/020/0003495187?sid=100">
#                  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/020/2023/05/03/3495187.jpg?type=ofullfill132_90" width="132"/>
#                 </a>
#                </div>
#               </div>
#               <div class="cluster_text">
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/020/0003495187?sid=100">
#                 野 원로 유인태, 與 공부모임 ‘국민공감’서 특강한다
#                </a>
#                <div class="cluster_text_lede">
#                 야권 원로인 유인태 전 국회 사무총장이 국민의힘 내 친윤 그룹 공부모임인 ‘국민공감’에서 특강을 한다. 국민공감에 따르면 유 전 사무총장은 오는 9일 오 …
#                </div>
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news020,0003495187',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  동아일보
#                 </div>
#                </div>
#               </div>
#              </li>
#             </ul>
#            </div>
#            <div class="cluster_foot">
#             <div class="cluster_foot_inner">
#              <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305030940_00000158&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=018&amp;aid=0005477679">
#               <span class="cluster_foot_more_icon_num">
#                11
#               </span>
#               <span class="cluster_foot_more_text">
#                개의 관련뉴스 더보기
#               </span>
#              </a>
#             </div>
#            </div>
#           </div>
#           <div class="cluster_group _cluster_content">
#            <div class="cluster_body">
#             <ul class="cluster_list">
#              <li class="cluster_item">
#               <div class="cluster_thumb">
#                <div class="cluster_thumb_inner">
#                 <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/018/0005477719?sid=100">
#                  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/018/2023/05/03/5477719.jpg?type=ofullfill132_90" width="132"/>
#                 </a>
#                </div>
#               </div>
#               <div class="cluster_text">
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/018/0005477719?sid=100">
#                 이재명 "尹 정권 폭력적 탄압에 노동자 죽음 선택…대통령 사과하길"
#                </a>
#                <div class="cluster_text_lede">
#                 이재명 더불어민주당 대표가 지난 2일 분신 시도 후 끝내 사망한 노동자를 두고 “윤석열 정권의 노조 탄압이 결국 소중한 생명을 앗아갔다”고 강하게 비판했 …
#                </div>
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news018,0005477719',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  이데일리
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li class="cluster_item">
#               <div class="cluster_thumb">
#                <div class="cluster_thumb_inner">
#                 <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/008/0004882736?sid=100">
#                  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/008/2023/05/03/4882736.jpg?type=ofullfill132_90" width="132"/>
#                 </a>
#                </div>
#               </div>
#               <div class="cluster_text">
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/008/0004882736?sid=100">
#                 이재명, 노조원 분신 사망에 "대통령에 원천 책임…사과해야"
#                </a>
#                <div class="cluster_text_lede">
#                 최근 정부에 항의하며 분신한 건설노조 간부가 숨진 것과 관련, 이재명 더불어민주당 대표가 3일 "원천적 책임은 대통령에게 있다"며 "대통령에게 진솔한 사 …
#                </div>
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news008,0004882736',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  머니투데이
#                 </div>
#                </div>
#               </div>
#              </li>
#             </ul>
#            </div>
#            <div class="cluster_foot">
#             <div class="cluster_foot_inner">
#              <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305031000_00000008&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=018&amp;aid=0005477719">
#               <span class="cluster_foot_more_icon_num">
#                30
#               </span>
#               <span class="cluster_foot_more_text">
#                개의 관련뉴스 더보기
#               </span>
#              </a>
#             </div>
#            </div>
#           </div>
#           <div class="cluster_group _cluster_content">
#            <div class="cluster_body">
#             <ul class="cluster_list">
#              <li class="cluster_item">
#               <div class="cluster_thumb">
#                <div class="cluster_thumb_inner">
#                 <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/018/0005477752?sid=100">
#                  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/018/2023/05/03/5477752.jpg?type=ofullfill132_90" width="132"/>
#                 </a>
#                </div>
#               </div>
#               <div class="cluster_text">
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/018/0005477752?sid=100">
#                 상습적으로 임금 안 주는 사업주, 정부 지원사업 제한한다
#                </a>
#                <div class="cluster_text_lede">
#                 3개월분 이상 체불하는 등 상습적으로 임금을 체불하면서 적극적인 청산노력을 기울이지 않는 사업주에 대해 형사처벌 외 경제적 제재가 추가된다. 이정식 고용 …
#                </div>
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news018,0005477752',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  이데일리
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li class="cluster_item">
#               <div class="cluster_thumb">
#                <div class="cluster_thumb_inner">
#                 <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005254083?sid=100">
#                  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/277/2023/05/03/5254083.jpg?type=ofullfill132_90" width="132"/>
#                 </a>
#                </div>
#               </div>
#               <div class="cluster_text">
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005254083?sid=100">
#                 "임금 3개월 밀리면 신용제재"…'상습체불 근절대책'
#                </a>
#                <div class="cluster_text_lede">
#                 임금을 3개월분 이상 상습적으로 체불하는 등 적극적인 청산노력을 기울이지 않는 사업주에 대해 신용제재와 정부지원 제한 등 경제적 제재가 강화된다. 고용노 …
#                </div>
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news277,0005254083',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  아시아경제
#                 </div>
#                </div>
#               </div>
#              </li>
#             </ul>
#            </div>
#            <div class="cluster_foot">
#             <div class="cluster_foot_inner">
#              <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305030930_00000008&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=018&amp;aid=0005477752">
#               <span class="cluster_foot_more_icon_num">
#                36
#               </span>
#               <span class="cluster_foot_more_text">
#                개의 관련뉴스 더보기
#               </span>
#              </a>
#             </div>
#            </div>
#           </div>
#           <div class="cluster_group _cluster_content" style="display: none">
#            <div class="cluster_body">
#             <ul class="cluster_list">
#              <li class="cluster_item">
#               <div class="cluster_thumb">
#                <div class="cluster_thumb_inner">
#                 <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011836567?sid=100">
#                  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/05/02/11836567.jpg?type=ofullfill132_90" width="132"/>
#                 </a>
#                </div>
#               </div>
#               <div class="cluster_text">
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011836567?sid=100">
#                 민주 "기시다 총리 방한, 과거사 사과부터 받아야"
#                </a>
#                <div class="cluster_text_lede">
#                 더불어민주당은 일본 기시다 총리가 오는 7일과 8일 방한한다는 정부 발표에 대해 "과거사 사과부터 받아야 한다"고 직격했다. 권칠승 수석대변인은 2일 논 …
#                </div>
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011836567',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  뉴시스
#                 </div>
#                </div>
#               </div>
#              </li>
#              <li class="cluster_item">
#               <div class="cluster_thumb">
#                <div class="cluster_thumb_inner">
#                 <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054970?sid=100">
#                  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/055/2023/05/02/1054970.jpg?type=ofullfill132_90" width="132"/>
#                  <strong class="r_ico r_vod_medium">
#                   동영상기사
#                  </strong>
#                 </a>
#                </div>
#               </div>
#               <div class="cluster_text">
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054970?sid=100">
#                 대통령실 "기시다 7일 방한"…내일 안보실장 사전 회담
#                </a>
#                <div class="cluster_text_lede">
#                 기시다 일본 총리가 오는 7일부터 1박 2일 일정으로 한국을 방문합니다. 내일(3일)은 두 나라 안보실장이 먼저 만나 정상회담에서 어떤 의제를 다룰지 논 …
#                </div>
#                <div class="cluster_text_info _rcount" data-comment="{gno:'news055,0001054970',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                 <div class="cluster_text_press">
#                  SBS
#                 </div>
#                </div>
#               </div>
#              </li>
#             </ul>
#            </div>
#            <div class="cluster_foot">
#             <div class="cluster_foot_inner">
#              <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304290110_00000004&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=003&amp;aid=0011836567">
#               <span class="cluster_foot_more_icon_num">
#                110
#               </span>
#               <span class="cluster_foot_more_text">
#                개의 관련뉴스 더보기
#               </span>
#              </a>
#             </div>
#            </div>
#           </div>
#           <div class="cluster_group _cluster_content" style="display: none">
#            <div class="cluster_body">
#             <ul class="cluster_list">
#              <li class="cluster_item">
#               <div class="cluster_thumb">
#                <div class="cluster_thumb_inner">
#                 <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001880447?sid=100">
#                  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/052/2023/05/03/1880447.jpg?type=ofullfill132_90" width="132"/>
#                  <strong class="r_ico r_vod_medium">
#                   동영상기사
#                  </strong>
#                 </a>
#                </div>
#               </div>
#               <div class="cluster_text">
#                <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001880447?sid=100">
#                 北 반발 수위 고조...한미 정상 겨냥 '화형식'까지
#                </a>
#                <div class="cluster_text_lede">
# ...
#            <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/665/2023/05/03/892.jpg?type=nf88_60" width="88"/>
#           </a>
#           <div class="list_text_wrap">
#            <div class="list_text">
#             <div class="list_text_inner">
#              <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/665/0000000892?ntype=RANKING&amp;sid=001">
#               1년 만에 론칭? 리버버스 졸속과 땜빵 사이 [視리즈]
#              </a>
#              <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=665">
#               <span class="list_press_thumb">
#                <img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/665/2022/12/08/logo_665_56_20221208184224.png" width="16"/>
#               </span>
#               더스쿠프
#              </a>
#             </div>
#            </div>
#           </div>
#          </li>
#          <li>
#           <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018643?ntype=RANKING&amp;sid=001">
#            <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/145/2023/05/03/18643.jpg?type=nf88_60" width="88"/>
#           </a>
#           <div class="list_text_wrap">
#            <div class="list_text">
#             <div class="list_text_inner">
#              <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018643?ntype=RANKING&amp;sid=001">
#               ‘스시테러’ 정신 못 차렸나…일본 방송인 망원시장서 침 묻 …
#              </a>
#              <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=145">
#               <span class="list_press_thumb">
#                <img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/145/2020/12/09/logo_145_56_20201209180915.png" width="16"/>
#               </span>
#               레이디경향
#              </a>
#             </div>
#            </div>
#           </div>
#          </li>
#         </ul>
#         <button class="refresh_button nclicks('rig.renws2new') _refreshButton" type="button">
#          더보기
#         </button>
#        </div>
#        <script type="text/javascript">
#         var OfficeTopRankingManager = jindo.$Class({
#         $static: {
#             RANKING_INFO_BUTTON_SELECTOR: '._rankingInfoButton',
#             RANKING_INFO_LAYER_SELECTOR : '._rankingInfoLayer',
#             RANKING_INFO_BUTTON_CLOSE_SELECTOR : '._rankingInfoCloseButton',
#             REFRESH_BUTTON_SELECTOR : '._refreshButton',
#             RANKING_LIST_SELECTOR : '._rankingList'
#         },
#
#         $init: function(base) {
#             this._welBase = jindo.$Element(base);
#             this._rankingInfoLayer = jindo.$Element(this._welBase.query(this.constructor.RANKING_INFO_LAYER_SELECTOR));
#             this._rankingListArray = jindo.$ElementList(this._welBase.queryAll(this.constructor.RANKING_LIST_SELECTOR));
#
#             this._initEvent();
#         },
#
#         _initEvent: function() {
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_SELECTOR, jindo.$Fn(this._showRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_CLOSE_SELECTOR, jindo.$Fn(this._closeRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.REFRESH_BUTTON_SELECTOR, jindo.$Fn(this._refreshRankingList, this).bind());
#         },
#
#         _showRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.toggle();
#         },
#
#         _closeRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.hide();
#         },
#
#         _refreshRankingList: function(event) {
#             event.stopDefault();
#
#             for (var i=0 ; i<this._rankingListArray.length() ; i++) {
#                 var rankingList = this._rankingListArray.get(i);
#
#                 if (rankingList.visible() === true) {
#                     var nextIndex = i + 1;
#
#                     if (nextIndex === this._rankingListArray.length()) {
#                         nextIndex = 0;
#                     }
#
#                     var nextRankingList = this._rankingListArray.get(nextIndex);
#
#                     rankingList.hide();
#                     nextRankingList.show();
#
#                     break;
#                 }
#             }
#         }
#     });
#
#     window.addEventListener("load", function() {
#         var officeTopRanking = jindo.$$.getSingle("._officeTopRanking1087473");
#         if (officeTopRanking) {
#             new OfficeTopRankingManager(officeTopRanking);
#         }
#     });
#        </script>
#        <div class="side_ad" id="glad_ad_sidebox">
#        </div>
#        <div class="section" id="right_dailyList" style="margin-bottom:20px; white-space:nowrap;">
#         <h4>
#          분야별 주요뉴스
#         </h4>
#         <div class="classfy sd" style="display:block">
#          <ul class="list_txt">
#           <li>
#            <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/023/0003761500?sid=100" title="이재명, 윤관석·이성만 탈당 질문에 “태영호 녹취는요?”">
#             이재명, 윤관석·이성만 탈당 질문에 “태영호 녹취는요?”
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/081/0003358387?sid=100" title="‘韓의원 독도 방문’ 항의한 일본…외교부 “부당한 주장 일축”">
#             ‘韓의원 독도 방문’ 항의한 일본…외교부 “부당한 주장 일축”
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/001/0013919121?sid=100" title="임금체불 한해 1조3천억원…상습체불 사업주 신용대출 제한(종합)">
#             임금체불 한해 1조3천억원…상습체불 사업주 신용대출 제한(종합)
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/469/0000737382?sid=104" title="한국서 침 묻은 꼬치로 판매 음식 푹푹 찌른 일본인?뭇매">
#             한국서 침 묻은 꼬치로 판매 음식 푹푹 찌른 일본인?뭇매
#            </a>
#           </li>
#           <li>
#            <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/016/0002138482?sid=104" title="美 부채가 더 걱정…백악관 “협상 불가’ 재천명, 디폴트 우려 고조">
#             美 부채가 더 걱정…백악관 “협상 불가’ 재천명, 디폴트 우려 고조
#            </a>
#           </li>
#          </ul>
#          <ul class="list_txt">
#           <ul class="list_txt">
#            <li>
#             <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/092/0002291046?sid=101" title='[ADB2023] 尹 대통령 "韓, 아시아 협력 공동망 구축"'>
#              [ADB2023] 尹 대통령 "韓, 아시아 협력 공동망 구축"
#             </a>
#            </li>
#            <li>
#             <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/008/0004882800?sid=101" title="대한항공, 부산세계박람회 유치 기원 특별 항공기 공개">
#              대한항공, 부산세계박람회 유치 기원 특별 항공기 공개
#             </a>
#            </li>
#            <li>
#             <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/469/0000737369?sid=101" title="최저가 노트북 업체의 몰락... 뒤엔 G마켓·경쟁사 '갑질 동맹'">
#              최저가 노트북 업체의 몰락... 뒤엔 G마켓·경쟁사 '갑질 동맹'
#             </a>
#            </li>
#            <li>
#             <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011837838?sid=105" title="카카오게임즈, 2분기 반등 자신…'오딘' 日 보내고 '아레스' 출격(종합)">
#              카카오게임즈, 2분기 반등 자신…'오딘' 日 보내고 '아레스' 출격(종합)
#             </a>
#            </li>
#            <li>
#             <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011837882?sid=105" title="삼성, 올해 '월드 디제이 페스티벌'에 갤럭시 찐팬 초청">
#              삼성, 올해 '월드 디제이 페스티벌'에 갤럭시 찐팬 초청
#             </a>
#            </li>
#           </ul>
#           <ul class="list_txt">
#            <ul class="list_txt">
#             <li>
#              <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/002/0002284613?sid=102" title="건설노동자 분신 사망에 &quot;尹 정부, '건폭' 신조어까지 만들어 노조 매도하더니…&quot;">
#               건설노동자 분신 사망에 "尹 정부, '건폭' 신조어까지 만들어 노조 매도하더니…"
#              </a>
#             </li>
#             <li>
#              <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011838110?sid=102" title="엠폭스 환자 52명 중 50명이 남성…96% '성접촉' 감염(종합)">
#               엠폭스 환자 52명 중 50명이 남성…96% '성접촉' 감염(종합)
#              </a>
#             </li>
#             <li>
#              <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/057/0001739755?sid=102" title='송영길 전 보좌관 검찰 출석…"돈 봉투 본 적도 없어"'>
#               송영길 전 보좌관 검찰 출석…"돈 봉투 본 적도 없어"
#              </a>
#             </li>
#             <li>
#              <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/422/0000596819?sid=103" title="[날씨] 중부 초여름 더위…내일 전국 '비소식'">
#               [날씨] 중부 초여름 더위…내일 전국 '비소식'
#              </a>
#             </li>
#             <li>
#              <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/018/0005477970?sid=103" title="KG 모빌리티, '렉스턴 뉴 아레나·스포츠&amp;칸 쿨멘' 출격">
#               KG 모빌리티, '렉스턴 뉴 아레나·스포츠&amp;칸 쿨멘' 출격
#              </a>
#             </li>
#            </ul>
#           </ul>
#          </ul>
#         </div>
#        </div>
#        <div class="section">
#         <div class="banner">
#          <a class="nclicks(rig.banner)" href="https://media.naver.com/channel/settings">
#           <img alt="네이버 메인에서 바로 보는 언론사 편집뉴스 지금 바로 구독해보세요!" src="https://imgnews.pstatic.net/image/upload/item/2018/11/27/174854048_PC_%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA_%25B1%25B8%25B5%25B6%25C8%25B0%25BC%25BA%25C8%25AD.png" width="300">
#           </img>
#          </a>
#         </div>
#        </div>
#        <div class="section">
#         <a class="nclicks(rig.banner)" href="https://news.naver.com/main/assembly/index.naver" target="_blank">
#          <img alt="내일을 여는 국민의 국회" border="0" class="banner" height="60" src="https://imgnews.pstatic.net/image/upload/item/2021/01/08/173235779_%25B1%25B9%25C8%25B8%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA.png" width="300">
#          </img>
#         </a>
#        </div>
#        <div class="section">
#         <div class="banner">
#          <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" target="_blank">
#           <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/183951086_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300">
#           </img>
#          </a>
#         </div>
#        </div>
#        <div class="section">
#         <h4>
#          <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver">
#           서비스 안내
#          </a>
#         </h4>
#         <ul class="list_txt">
#          <li>
#           <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb">
#            고침 기사 모음
#           </a>
#          </li>
#          <li>
#           <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb">
#            정정·반론·추후 보도 기사 모음
#           </a>
#          </li>
#          <li>
#           <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb">
#            불공정 선거 보도 기사 모음
#           </a>
#          </li>
#         </ul>
#         <a class="more_link nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver">
#          <span class="blind">
#           서비스 안내
#          </span>
#          더보기
#         </a>
#        </div>
#        <script>
#         window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#
#         adSlot.setCustomParam("calp", 'shome');
#         window.gladsdk.displayAd(adSlot);
#     });
#        </script>
#       </div>
#      </td>
#     </tr>
#    </table>
#   </div>
#   <hr/>
#   <div class="index">
#    <div class="index_inner">
#     <div class="floating_btn">
#      <div class="floating_inner">
#       <a class="floating_btn_back" href="javascript:history.back();">
#        <span class="blind">
#         이젠 페이지
#        </span>
#       </a>
#       <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;">
#        <span class="blind">
#         맨위로
#        </span>
#       </a>
#      </div>
#     </div>
#     <div class="index_tab" id="index.press_category">
#      <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">
#       언론사 목록
#       <span class="_stit_tab_arrow stit_arrow">
#        <span class="blind">
#         열기
#        </span>
#       </span>
#       <span class="loading" style="display:none;">
#        로딩 중
#       </span>
#      </a>
#      <div class="index_content is_hidden" id="index.press.area">
#      </div>
#      <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">
#       분야별 목록
#       <span class="_stit_tab_arrow stit_arrow">
#        <span class="blind">
#         열기
#        </span>
#       </span>
#       <span class="loading" style="display:none;">
#        로딩 중
#       </span>
#      </a>
#      <div class="index_content02 is_hidden" id="index.category.area">
#      </div>
#     </div>
#    </div>
#   </div>
#   <hr/>
#   <div id="footer">
#    <ul>
#     <li class="first">
#      <a class="nclicks(fot.agreement)" href="http://www.naver.com/rules/service.html">
#       이용약관
#      </a>
#     </li>
#     <li>
#      <a class="nclicks(fot.guide)" href="/main/ombudsman/index.naver">
#       서비스 안내
#      </a>
#     </li>
#     <li>
#      <a class="nclicks(fot.editor)" href="/main/ombudsman/edit.naver?mid=omb">
#       기사배열 원칙 책임자 : 유봉석
#      </a>
#     </li>
#     <li>
#      청소년 보호 책임자 : 이희만
#     </li>
#     <li>
#      <strong>
#       <a class="nclicks(fot.privacy)" href="http://www.naver.com/rules/privacy.html">
#        개인정보처리방침
#       </a>
#      </strong>
#     </li>
#     <li>
#      <a class="nclicks(fot.disclaimer)" href="http://www.naver.com/rules/disclaimer.html">
#       책임의 한계와 법적고지
#      </a>
#     </li>
#     <li>
#      <a class="nclicks(fot.help)" href="#" onclick="news.external.OPS.helpNews(); return false;" title="새창">
#       뉴스 고객센터
#      </a>
#     </li>
#    </ul>
#    <p class="copyright">
#     본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.
#    </p>
#    <address class="address_nhn">
#     <a class="logo nclicks(fot.naver)" href="https://www.navercorp.com/" target="_blank">
#      <span class="blind">
#       NAVER
#      </span>
#     </a>
#     <em>
#      Copyright ©
#     </em>
#     <a class="nclicks(fot.navercorp)" href="https://www.navercorp.com/" target="_blank">
#      NAVER Corp.
#     </a>
#     <span>
#      All Rights Reserved.
#     </span>
#    </address>
#    <!-- -->
#   </div>
#   <script type="text/javascript">
#    var index_tab = new news.index.TabController('index.press_category');
# index_tab.add(new news.index.Tab('index.press.btn','stit','index.press.area','/main/ajax/bottomIndex/press.naver'));
# index_tab.add(new news.index.Tab('index.category.btn','stit2','index.category.area','/main/ajax/bottomIndex/category.naver'));
# jindo.$Fn(index_tab.toggle, index_tab).attach(index_tab.tabs.keys(), 'click');
#
#
# (function() {
# 	news.right.RightSideFloatingManager.init();
# })();
#
#
#
#     (function() {
#         news.right.TopDownFloatingManager.init();
#     })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ;(function(){
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jindo.$Fn(function(){
#
#
# 	lcs_do();
#
#     }).attach(window, eventType);
# })();
#
#
#
#
#
#
#
#
# news.startup();
#
#
# jindo.$Fn(function(){
#     var welSkip = jindo.$Element("u_skip");
#     if (welSkip === null) {
#         return;
#     }
#     welSkip.delegate("click", "a", function(weEvent){
#         weEvent.stopDefault();
#         var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#         oWebAccessibilityUtil.moveFocus(elTarget);
#     });
# }).attach(window, "load");
#
#
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
#   </script>
#  </body>
# </html>

# %%
# Out:
# '메인 메뉴로 바로가기'

# %%
bs.find_all('div')
# Out:
# [<div id="wrap">
#  <!-- 광고적용 태그 추가 -->
#  <div id="da_base"></div>
#  <div id="da_stake"></div>
#  <div class="header" id="header">
#  <div id="u_skip">
#  <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
#  <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
#  </div>
#  <div class="snb_area">
#  <div class="snb_inner">
#  <div class="gnb_area">
#  <div class="gnb_wrap">
#  <div class="gnb_dark_type2" id="gnb"></div>
#  </div>
#  <div class="gnb_search is_hidden _search_content">
#  </div>
#  <div class="gnb_tool" id="gnb_search_tool">
#  <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
#  </div>
#  </div>
#  <div id="snb_wrap">
#  <h1>
#  <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
#  <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
#  </h1>
#  <ul class="snb_related_service">
#  <li><span class="snb_bdr"></span><a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
#  <li><span class="snb_bdr"></span><a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">스포츠</a></li>
#  <li><span class="snb_bdr"></span><a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">날씨</a></li>
#  <li><span class="snb_bdr"></span><a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">프리미엄</a></li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  <div class="lnb_area">
#  <div class="lnb_inner">
#  <div class="lnb_both">
#  <div class="lnb_left">
#  <div class="lnb_menu" id="lnb">
#  <ul>
#  <li><a class="nclicks(lnb.pcmedia)" href="/"><span class="tx">언론사별</span> </a></li>
#  <li class="on"><a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> <span class="blind">선택됨</span></a></li>
#  <li><a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
#  <li><a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a></li>
#  <li><a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
#  <li><a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
#  <li><a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
#  <li><a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹</span> </a></li>
#  <li><a class="nclicks(lnb.paper)" href="/newspaper/home"><span class="tx">신문보기</span> </a></li>
#  <li><a class="nclicks(lnb.opi)" href="/opinion/home"><span class="tx">오피니언</span> </a></li>
#  <li><a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a></li>
#  <li><a class="nclicks(lnb.fact)" href="/main/factcheck/main.naver"><span class="tx">팩트체크</span> </a></li>
#  </ul>
#  </div>
#  </div>
#  <div class="lnb_right">
#  <div class="lnb_extra">
#  <div class="lnb_extra_menu">
#  <ul class="lnb_extra_menu_list">
#  <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
#  <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(STA.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
#  <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="lnb">
#  <span class="lnb_date"><strong>05</strong>.<strong>03</strong><span class="day">(수)</span></span>
#  <ul class="lnb_side" tabindex="0">
#  <li><a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
#  <li><a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
#  <li><a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
#  </ul>
#  </div>
#  </div>
#  <hr/>
#  <table cellpadding="0" cellspacing="0" class="container">
#  <caption class="blind">기사목록</caption>
#  <colgroup>
#  <col class="col_snb"/>
#  <col class="col_content"/>
#  <col class="col_aside"/>
#  </colgroup>
#  <tr>
#  <td class="snb">
#  <div class="snb" id="snb">
#  <h2 class="h2"><a class="nclicks(lmn_pol.home)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100">정치</a></h2>
#  <ul class="nav">
#  <li><a class="snb_s11 nclicks(lmn_pol.mnl,,1)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=264">대통령실 </a></li>
#  <li><a class="snb_s12 nclicks(lmn_pol.mnl,,2)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=265">국회/정당 </a></li>
#  <li><a class="snb_s13 nclicks(lmn_pol.mnl,,3)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=268">북한 </a></li>
#  <li><a class="snb_s14 nclicks(lmn_pol.mnl,,4)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=266">행정 </a></li>
#  <li><a class="snb_s15 nclicks(lmn_pol.mnl,,5)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=267">국방/외교 </a></li>
#  <li><a class="snb_s16 nclicks(lmn_pol.mnl,,6)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=269">정치일반 </a></li>
#  </ul>
#  <div class="snb_banner">
#  <a class="nclicks(lmn_pol.pmb,,1)" href="https://media.naver.com/channel/setting?back=main"><img alt="언론사 구독하기" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/01/14/142956425_144518244_%2525B8%2525F0%2525B9%2525D9%2525C0%2525CF%2525B8%2525DE%2525C0%2525CE.png" width="71"/></a>
#  </div>
#  <div class="snb_banner">
#  <a class="nclicks(lmn_pol.pmb,,1)" href="https://contents.premium.naver.com/"><img alt="네이버 프리미엄콘텐츠" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71"/></a>
#  </div>
#  </div>
#  </td>
#  <td class="content">
#  <div class="content" id="main_content">
#  <div class="list_body section_index">
#  <div class="cluster">
#  <div class="cluster_title">
#  <span class="cluster_title_inner"><a class="cluster_title_icon_link _news_cluster_layer_btn" href="#biF7L"><i class="cluster_title_icon">안내</i>헤드라인 뉴스</a></span>
#  <div class="cluster_title_layer _news_cluster_layer is_hidden">
#  <div class="cluster_title_layer_text">
#                              헤드라인 뉴스와 각 기사묶음 타이틀은 <br/> 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.
#                          </div>
#  <div class="cluster_title_layer_image"></div>
#  <button class="cluster_title_layer_close _news_cluster_layer_close_btn" type="button">닫기</button>
#  </div>
#  </div>
#  </div>
#  <div class="_persist">
#  <div class="cluster">
#  <div class="cluster_group _cluster_content">
#  <div class="cluster_body">
#  <ul class="cluster_list">
#  <li class="cluster_item">
#  <div class="cluster_thumb">
#  <div class="cluster_thumb_inner">
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011477677?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/056/2023/05/03/11477677.jpg?type=ofullfill132_90" width="132"/>
#  </a>
#  </div>
#  </div>
#  <div class="cluster_text">
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011477677?sid=100">국회 정개특위, 선거제 개편 ‘500인 공론조사’ 실시…KBS 생중계</a>
#  <div class="cluster_text_lede">국회 정치개혁특별위원회(정개특위)는 오는 6일과 13일 양일간 500명의 시민참여단을 대상으로 국회의원 선거제도 개편에 대한 공론조사를 실시하고, KBS …</div>
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news056,0011477677',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">KBS</div>
#  </div>
#  </div>
#  </li>
#  <li class="cluster_item as_line">
#  <div class="cluster_text">
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news018,0005477769',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">이데일리</div>
#  </div>
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/018/0005477769?sid=100">`선거제 개편` 공론화 본격화…대표 시민 500인 토론</a>
#  </div>
#  </li>
#  <li class="cluster_item as_line">
#  <div class="cluster_text">
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news014,0005006585',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">파이낸셜뉴스</div>
#  </div>
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/014/0005006585?sid=100">'선거제도, 국회의원이 아닌 국민이 결정하자' 정개특위, 시민 500명 참여 토론회 연다</a>
#  </div>
#  </li>
#  <li class="cluster_item as_line">
#  <div class="cluster_text">
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news009,0005125082',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">매일경제</div>
#  </div>
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/009/0005125082?sid=100">선거개편 공론화…시민참여단 500명 모여 토론한다</a>
#  </div>
#  </li>
#  </ul>
#  </div>
#  <div class="cluster_foot">
#  <div class="cluster_foot_inner">
#  <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305031050_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=056&amp;aid=0011477677"><span class="cluster_foot_more_icon_num">8</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
#  </div>
#  </div>
#  </div>
#  <div class="cluster_group _cluster_content">
#  <div class="cluster_body">
#  <ul class="cluster_list">
#  <li class="cluster_item">
#  <div class="cluster_thumb">
#  <div class="cluster_thumb_inner">
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898653?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/366/2023/05/03/898653.jpg?type=ofullfill132_90" width="132"/>
#  </a>
#  </div>
#  </div>
#  <div class="cluster_text">
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898653?sid=100">野 의원 독도 방문에 日 항의…외교부 “부당한 주장 일축”</a>
#  <div class="cluster_text_lede">정부는 3일 전용기 더불어민주당 의원의 독도 방문에 대한 일본 측 항의에 “일본 측의 부당한 주장은 외교 채널을 통해 일축했다”고 밝혔다. 외교부 당국자 …</div>
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news366,0000898653',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">조선비즈</div>
#  </div>
#  </div>
#  </li>
#  <li class="cluster_item as_line">
#  <div class="cluster_text">
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004186276',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">서울경제</div>
#  </div>
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004186276?sid=100">정부, "野 독도 방문 부당' 日항의에 "부당한 주장"</a>
#  </div>
#  </li>
#  <li class="cluster_item as_line">
#  <div class="cluster_text">
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news016,0002138197',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">헤럴드경제</div>
#  </div>
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002138197?sid=100">더불어민주당 경북도당 청년·대학생위 독도 현지서 ‘독도영유권수호 다짐’</a>
#  </div>
#  </li>
#  <li class="cluster_item as_line">
#  <div class="cluster_text">
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news079,0003766028',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">노컷뉴스</div>
#  </div>
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/079/0003766028?sid=100">韓의원 독도 방문에…日 "윤석열 정권에 대한 반발이냐"[이슈시개]</a>
#  </div>
#  </li>
#  </ul>
#  </div>
#  <div class="cluster_foot">
#  <div class="cluster_foot_inner">
#  <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305021530_00000499&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=366&amp;aid=0000898653"><span class="cluster_foot_more_icon_num">77</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
#  </div>
#  </div>
#  </div>
#  <div class="cluster_group _cluster_content">
#  <div class="cluster_body">
#  <ul class="cluster_list">
#  <li class="cluster_item">
#  <div class="cluster_thumb">
#  <div class="cluster_thumb_inner">
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006783769?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/421/2023/05/03/6783769.jpg?type=ofullfill132_90" width="132"/>
#  </a>
#  </div>
#  </div>
#  <div class="cluster_text">
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006783769?sid=100">'태영호 녹취록'에 與 '산 넘어 산'…태영호 징계 수위에 영향은</a>
#  <div class="cluster_text_lede">이진복 대통령실 정무수석이 22대 총선 공천 문제를 거론하며 한일 관계에 대한 옹호 발언을 해달라고 요청했다는 태영호 국민의힘 최고위원의 녹취가 공개되면 …</div>
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006783769',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">뉴스1</div>
#  </div>
#  </div>
#  </li>
#  <li class="cluster_item as_line">
#  <div class="cluster_text">
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news586,0000057017',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">시사저널</div>
#  </div>
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/586/0000057017?sid=100">'체리따봉'부터 '태영호 녹취록'까지, 용산 '당무 개입'은 이제 시작?</a>
#  </div>
#  </li>
#  <li class="cluster_item as_line">
#  <div class="cluster_text">
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news437,0000341508',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">JTBC</div>
#  </div>
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/437/0000341508?sid=100">'태영호 녹취록'에 국민의힘 발칵…당내서도 "불법 공천개입"</a>
#  </div>
#  </li>
#  <li class="cluster_item as_line">
#  <div class="cluster_text">
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news215,0001099017',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">한국경제TV</div>
#  </div>
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/215/0001099017?sid=100">대통령실 공천 개입? 태영호 녹취록 논란에 與 '선긋기'</a>
#  </div>
#  </li>
#  </ul>
#  </div>
#  <div class="cluster_foot">
#  <div class="cluster_foot_inner">
#  <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305012010_00000017&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=421&amp;aid=0006783769"><span class="cluster_foot_more_icon_num">82</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
#  </div>
#  </div>
#  </div>
#  <div class="cluster_group _cluster_content">
#  <div class="cluster_body">
#  <ul class="cluster_list">
#  <li class="cluster_item">
#  <div class="cluster_thumb">
#  <div class="cluster_thumb_inner">
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/417/0000917923?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/417/2023/05/03/917923.jpg?type=ofullfill132_90" width="132"/>
#  </a>
#  </div>
#  </div>
#  <div class="cluster_text">
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/417/0000917923?sid=100">장예찬 "태영호 녹취록, 일벌백계해야"… 김성태 "중징계감 아니야"</a>
#  <div class="cluster_text_lede">이른바 '공천 녹취록' 유출과 관련해 여당 내부에서 의견이 엇갈리고 있다. 장예찬 국민의힘 최고위원은 "누구든 일벌백계 읍참마속의 기조로 엄하게 다뤄야  …</div>
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news417,0000917923',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">머니S</div>
#  </div>
#  </div>
#  </li>
#  <li class="cluster_item as_line">
#  <div class="cluster_text">
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news028,0002638294',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">한겨레</div>
#  </div>
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/028/0002638294?sid=100">장예찬 “용산과 더 가까운 나도 공천 부탁 들은 적 없다”</a>
#  </div>
#  </li>
#  <li class="cluster_item as_line">
#  <div class="cluster_text">
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news214,0001270371',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">MBC</div>
#  </div>
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001270371?sid=100"> 장예찬 "내가 태영호보다 대통령실과 더 가까운데.. 공천-부탁 들어본 적 없어" [시선집중]</a>
#  </div>
#  </li>
#  <li class="cluster_item as_line">
#  <div class="cluster_text">
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news014,0005006466',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">파이낸셜뉴스</div>
#  </div>
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/014/0005006466?sid=100">장예찬 "내가 태영호보다 대통령실과 더 가깝지만 공천‧부탁 들어본 적 없다"</a>
#  </div>
#  </li>
#  </ul>
#  </div>
#  <div class="cluster_foot">
#  <div class="cluster_foot_inner">
#  <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305031000_00000388&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=417&amp;aid=0000917923"><span class="cluster_foot_more_icon_num">9</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
#  </div>
#  </div>
#  </div>
#  <div class="cluster_group _cluster_content">
#  <div class="cluster_body">
#  <ul class="cluster_list">
#  <li class="cluster_item">
#  <div class="cluster_thumb">
#  <div class="cluster_thumb_inner">
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011477621?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/056/2023/05/03/11477621.jpg?type=ofullfill132_90" width="132"/>
#  </a>
#  </div>
#  </div>
#  <div class="cluster_text">
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011477621?sid=100">‘돈 봉투 의혹’ 민주당 윤관석·이성만 의원 자진 탈당 결정</a>
#  <div class="cluster_text_lede">'돈 봉투 의혹'에 휩싸인 더불어민주당 윤관석, 이성만 의원이 자진 탈당을 결정했습니다. 민주당 윤관석, 이성만 의원은 오늘(3일) 국회에서 비공개 최고 …</div>
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news056,0011477621',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">KBS</div>
#  </div>
#  </div>
#  </li>
#  <li class="cluster_item">
#  <div class="cluster_thumb">
#  <div class="cluster_thumb_inner">
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005254124?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/277/2023/05/03/5254124.jpg?type=ofullfill132_90" width="132"/>
#  </a>
#  </div>
#  </div>
#  <div class="cluster_text">
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005254124?sid=100">'돈봉투' 의혹 윤관석·이성만 민주당 탈당…"선당후사 마음으로..."</a>
#  <div class="cluster_text_lede">‘전당대회 돈봉투’ 논란과 윤관석·이성만 의원이 더불어민주당을 탈당하기로 했다. 윤 의원과 이 의원은 3일 민주당 지도부와 면담을 거친 뒤 기자들에게 탈 …</div>
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news277,0005254124',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">아시아경제</div>
#  </div>
#  </div>
#  </li>
#  </ul>
#  </div>
#  <div class="cluster_foot">
#  <div class="cluster_foot_inner">
#  <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305021920_00000080&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=056&amp;aid=0011477621"><span class="cluster_foot_more_icon_num">85</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
#  </div>
#  </div>
#  </div>
#  <div class="cluster_group _cluster_content">
#  <div class="cluster_body">
#  <ul class="cluster_list">
#  <li class="cluster_item">
#  <div class="cluster_thumb">
#  <div class="cluster_thumb_inner">
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/018/0005477679?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/018/2023/05/03/5477679.jpg?type=ofullfill132_90" width="132"/>
#  </a>
#  </div>
#  </div>
#  <div class="cluster_text">
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/018/0005477679?sid=100">'야권 원로' 유인태, 국민의힘 친윤모임 국민공감서 특강</a>
#  <div class="cluster_text_lede">야권 원로 인사인 유인태 전 국회 사무총장이 국민의힘 내 친윤 그룹 공부 모임인 ‘국민공감’에서 특강을 진행한다. 유인태 전 국회사무총장(사진=연합뉴스) …</div>
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news018,0005477679',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">이데일리</div>
#  </div>
#  </div>
#  </li>
#  <li class="cluster_item">
#  <div class="cluster_thumb">
#  <div class="cluster_thumb_inner">
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/020/0003495187?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/020/2023/05/03/3495187.jpg?type=ofullfill132_90" width="132"/>
#  </a>
#  </div>
#  </div>
#  <div class="cluster_text">
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/020/0003495187?sid=100">野 원로 유인태, 與 공부모임 ‘국민공감’서 특강한다</a>
#  <div class="cluster_text_lede">야권 원로인 유인태 전 국회 사무총장이 국민의힘 내 친윤 그룹 공부모임인 ‘국민공감’에서 특강을 한다. 국민공감에 따르면 유 전 사무총장은 오는 9일 오 …</div>
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news020,0003495187',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">동아일보</div>
#  </div>
#  </div>
#  </li>
#  </ul>
#  </div>
#  <div class="cluster_foot">
#  <div class="cluster_foot_inner">
#  <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305030940_00000158&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=018&amp;aid=0005477679"><span class="cluster_foot_more_icon_num">11</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
#  </div>
#  </div>
#  </div>
#  <div class="cluster_group _cluster_content">
#  <div class="cluster_body">
#  <ul class="cluster_list">
#  <li class="cluster_item">
#  <div class="cluster_thumb">
#  <div class="cluster_thumb_inner">
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/018/0005477719?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/018/2023/05/03/5477719.jpg?type=ofullfill132_90" width="132"/>
#  </a>
#  </div>
#  </div>
#  <div class="cluster_text">
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/018/0005477719?sid=100">이재명 "尹 정권 폭력적 탄압에 노동자 죽음 선택…대통령 사과하길"</a>
#  <div class="cluster_text_lede">이재명 더불어민주당 대표가 지난 2일 분신 시도 후 끝내 사망한 노동자를 두고 “윤석열 정권의 노조 탄압이 결국 소중한 생명을 앗아갔다”고 강하게 비판했 …</div>
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news018,0005477719',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">이데일리</div>
#  </div>
#  </div>
#  </li>
#  <li class="cluster_item">
#  <div class="cluster_thumb">
#  <div class="cluster_thumb_inner">
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/008/0004882736?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/008/2023/05/03/4882736.jpg?type=ofullfill132_90" width="132"/>
#  </a>
#  </div>
#  </div>
#  <div class="cluster_text">
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/008/0004882736?sid=100">이재명, 노조원 분신 사망에 "대통령에 원천 책임…사과해야"</a>
#  <div class="cluster_text_lede">최근 정부에 항의하며 분신한 건설노조 간부가 숨진 것과 관련, 이재명 더불어민주당 대표가 3일 "원천적 책임은 대통령에게 있다"며 "대통령에게 진솔한 사 …</div>
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news008,0004882736',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">머니투데이</div>
#  </div>
#  </div>
#  </li>
#  </ul>
#  </div>
#  <div class="cluster_foot">
#  <div class="cluster_foot_inner">
#  <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305031000_00000008&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=018&amp;aid=0005477719"><span class="cluster_foot_more_icon_num">30</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
#  </div>
#  </div>
#  </div>
#  <div class="cluster_group _cluster_content">
#  <div class="cluster_body">
#  <ul class="cluster_list">
#  <li class="cluster_item">
#  <div class="cluster_thumb">
#  <div class="cluster_thumb_inner">
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/018/0005477752?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/018/2023/05/03/5477752.jpg?type=ofullfill132_90" width="132"/>
#  </a>
#  </div>
#  </div>
#  <div class="cluster_text">
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/018/0005477752?sid=100">상습적으로 임금 안 주는 사업주, 정부 지원사업 제한한다</a>
#  <div class="cluster_text_lede">3개월분 이상 체불하는 등 상습적으로 임금을 체불하면서 적극적인 청산노력을 기울이지 않는 사업주에 대해 형사처벌 외 경제적 제재가 추가된다. 이정식 고용 …</div>
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news018,0005477752',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">이데일리</div>
#  </div>
#  </div>
#  </li>
#  <li class="cluster_item">
#  <div class="cluster_thumb">
#  <div class="cluster_thumb_inner">
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005254083?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/277/2023/05/03/5254083.jpg?type=ofullfill132_90" width="132"/>
#  </a>
#  </div>
#  </div>
#  <div class="cluster_text">
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005254083?sid=100">"임금 3개월 밀리면 신용제재"…'상습체불 근절대책'</a>
#  <div class="cluster_text_lede">임금을 3개월분 이상 상습적으로 체불하는 등 적극적인 청산노력을 기울이지 않는 사업주에 대해 신용제재와 정부지원 제한 등 경제적 제재가 강화된다. 고용노 …</div>
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news277,0005254083',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">아시아경제</div>
#  </div>
#  </div>
#  </li>
#  </ul>
#  </div>
#  <div class="cluster_foot">
#  <div class="cluster_foot_inner">
#  <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305030930_00000008&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=018&amp;aid=0005477752"><span class="cluster_foot_more_icon_num">36</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
#  </div>
#  </div>
#  </div>
#  <div class="cluster_group _cluster_content" style="display: none">
#  <div class="cluster_body">
#  <ul class="cluster_list">
#  <li class="cluster_item">
#  <div class="cluster_thumb">
#  <div class="cluster_thumb_inner">
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011836567?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/05/02/11836567.jpg?type=ofullfill132_90" width="132"/>
#  </a>
#  </div>
#  </div>
#  <div class="cluster_text">
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011836567?sid=100">민주 "기시다 총리 방한, 과거사 사과부터 받아야"</a>
#  <div class="cluster_text_lede">더불어민주당은 일본 기시다 총리가 오는 7일과 8일 방한한다는 정부 발표에 대해 "과거사 사과부터 받아야 한다"고 직격했다. 권칠승 수석대변인은 2일 논 …</div>
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011836567',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">뉴시스</div>
#  </div>
#  </div>
#  </li>
#  <li class="cluster_item">
#  <div class="cluster_thumb">
#  <div class="cluster_thumb_inner">
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054970?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/055/2023/05/02/1054970.jpg?type=ofullfill132_90" width="132"/>
#  <strong class="r_ico r_vod_medium">동영상기사</strong>
#  </a>
#  </div>
#  </div>
#  <div class="cluster_text">
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054970?sid=100">대통령실 "기시다 7일 방한"…내일 안보실장 사전 회담</a>
#  <div class="cluster_text_lede">기시다 일본 총리가 오는 7일부터 1박 2일 일정으로 한국을 방문합니다. 내일(3일)은 두 나라 안보실장이 먼저 만나 정상회담에서 어떤 의제를 다룰지 논 …</div>
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news055,0001054970',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">SBS</div>
#  </div>
#  </div>
#  </li>
#  </ul>
#  </div>
#  <div class="cluster_foot">
#  <div class="cluster_foot_inner">
#  <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304290110_00000004&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=003&amp;aid=0011836567"><span class="cluster_foot_more_icon_num">110</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
#  </div>
#  </div>
#  </div>
#  <div class="cluster_group _cluster_content" style="display: none">
#  <div class="cluster_body">
#  <ul class="cluster_list">
#  <li class="cluster_item">
#  <div class="cluster_thumb">
#  <div class="cluster_thumb_inner">
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001880447?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/052/2023/05/03/1880447.jpg?type=ofullfill132_90" width="132"/>
#  <strong class="r_ico r_vod_medium">동영상기사</strong>
#  </a>
#  </div>
#  </div>
#  <div class="cluster_text">
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001880447?sid=100">北 반발 수위 고조...한미 정상 겨냥 '화형식'까지</a>
#  <div class="cluster_text_lede">북한이 확장억제 강화 방안이 담긴 워싱턴 선언에 대해 한미 정상을 겨냥한 화형식까지 열며 반발 수위를 높이고 있습니다. 김여정의 막말 담화에 이은 비난  …</div>
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001880447',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">YTN</div>
#  </div>
#  </div>
#  </li>
#  <li class="cluster_item">
#  <div class="cluster_thumb">
#  <div class="cluster_thumb_inner">
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/022/0003808913?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/022/2023/05/03/3808913.jpg?type=ofullfill132_90" width="132"/>
#  </a>
#  </div>
#  </div>
#  <div class="cluster_text">
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/022/0003808913?sid=100">北, 워싱턴선언 반발 수위 고조…한미 정상 겨냥 ‘화형식’ 진행</a>
#  <div class="cluster_text_lede">청년학생 ‘복수결의모임’ 2일 개최 “늙다리 전쟁괴수와 특등하수인의 추악한 몰골들이 재가루로…” 북한이 ‘워싱턴 선언’을 비난하는 청년학생 집회를 열고  …</div>
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news022,0003808913',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">세계일보</div>
#  </div>
#  </div>
#  </li>
#  </ul>
#  </div>
#  <div class="cluster_foot">
#  <div class="cluster_foot_inner">
#  <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305030700_00000006&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=052&amp;aid=0001880447"><span class="cluster_foot_more_icon_num">44</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
#  </div>
#  </div>
#  </div>
#  <div class="cluster_group _cluster_content" style="display: none">
#  <div class="cluster_body">
#  <ul class="cluster_list">
#  <li class="cluster_item">
#  <div class="cluster_thumb">
#  <div class="cluster_thumb_inner">
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001880354?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/052/2023/05/03/1880354.jpg?type=ofullfill132_90" width="132"/>
#  </a>
#  </div>
#  </div>
#  <div class="cluster_text">
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001880354?sid=100">태영호 "비서관이 녹취록 유출? 허위사실"</a>
#  <div class="cluster_text_lede">태영호 국민의힘 최고위원이 녹취록 유출자로 자신의 보좌진이 의심받는 상황에 유감을 표했다. 2일 태 최고위원은 자신의 SNS 계정에 "현재 일부 유튜버들 …</div>
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001880354',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">YTN</div>
#  </div>
#  </div>
#  </li>
#  <li class="cluster_item">
#  <div class="cluster_thumb">
#  <div class="cluster_thumb_inner">
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/057/0001739696?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/057/2023/05/03/1739696.jpg?type=ofullfill132_90" width="132"/>
#  </a>
#  </div>
#  </div>
#  <div class="cluster_text">
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/057/0001739696?sid=100">"태영호 녹취록 유출자, 이들일 것"...유튜버들의 마녀사냥</a>
#  <div class="cluster_text_lede">태영호 국민의힘 최고위원은 녹취록 파문으로 자신의 보좌진이 유출자로 의심받는 상황에 강력 반발하며 유감을 표했습니다. 태 최고위원은 전날(2일) 밤 페이 …</div>
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news057,0001739696',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">MBN</div>
#  </div>
#  </div>
#  </li>
#  </ul>
#  </div>
#  <div class="cluster_foot">
#  <div class="cluster_foot_inner">
#  <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305030800_00000037&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=052&amp;aid=0001880354"><span class="cluster_foot_more_icon_num">14</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
#  </div>
#  </div>
#  </div>
#  <div class="cluster_group _cluster_content" style="display: none">
#  <div class="cluster_body">
#  <ul class="cluster_list">
#  <li class="cluster_item">
#  <div class="cluster_thumb">
#  <div class="cluster_thumb_inner">
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898643?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/366/2023/05/03/898643.jpg?type=ofullfill132_90" width="132"/>
#  </a>
#  </div>
#  </div>
#  <div class="cluster_text">
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898643?sid=100">박광온 “오늘 의총서 국민이 바라는 쇄신방안 마련…향후 전원토론 실시”</a>
#  <div class="cluster_text_lede">“모든 의원 대상 심층 설문조사…‘최종 쇄신 보고서’ 보고” 박광온 더불어민주당 원내대표는 3일 개최가 예정된 의원총회와 관련, “쇄신 의총의 전 과정은 …</div>
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news366,0000898643',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">조선비즈</div>
#  </div>
#  </div>
#  </li>
#  <li class="cluster_item">
#  <div class="cluster_thumb">
#  <div class="cluster_thumb_inner">
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011837599?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/05/03/11837599.jpg?type=ofullfill132_90" width="132"/>
#  </a>
#  </div>
#  </div>
#  <div class="cluster_text">
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011837599?sid=100">박광온 "집단지성 통해 국민 바라는 쇄신안 마련할 것"</a>
#  <div class="cluster_text_lede">기사내용 요약 의원 대상 심층설문조사·국민 대상 웹조사 실시 조사 결과 나온 주제들로 심층 토론 진행 예정 [서울=뉴시스] 박광온 더불어민주당 원내대표가 …</div>
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011837599',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">뉴시스</div>
#  </div>
#  </div>
#  </li>
#  </ul>
#  </div>
#  <div class="cluster_foot">
#  <div class="cluster_foot_inner">
#  <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010010_00000758&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=366&amp;aid=0000898643"><span class="cluster_foot_more_icon_num">18</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
#  </div>
#  </div>
#  </div>
#  <div class="cluster_group _cluster_content" style="display: none">
#  <div class="cluster_body">
#  <ul class="cluster_list">
#  <li class="cluster_item">
#  <div class="cluster_thumb">
#  <div class="cluster_thumb_inner">
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011477716?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/056/2023/05/03/11477716.jpg?type=ofullfill132_90" width="132"/>
#  </a>
#  </div>
#  </div>
#  <div class="cluster_text">
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011477716?sid=100">국민의힘 당원 2만여 명, 김재원 징계 반대 요구서 제출</a>
#  <div class="cluster_text_lede">국민의힘 중앙윤리위원회가 김재원 최고위원에 대한 징계 여부를 논의하는 가운데, 당원 2만여 명이 이를 반대하는 요구서를 오늘(3일) 제출했습니다. 송세달 …</div>
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news056,0011477716',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">KBS</div>
#  </div>
#  </div>
#  </li>
#  <li class="cluster_item">
#  <div class="cluster_thumb">
#  <div class="cluster_thumb_inner">
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001270417?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/214/2023/05/03/1270417.jpg?type=ofullfill132_90" width="132"/>
#  </a>
#  </div>
#  </div>
#  <div class="cluster_text">
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001270417?sid=100">국민의힘 일부 당원들, 김재원 징계 반대 요구서 제출</a>
#  <div class="cluster_text_lede">잇단 설화로 논란을 빚은 김재원 최고위원에 대한 당 윤리위의 징계 결정을 앞두고, 국민의힘 일부 당원들이 징계를 반대하는 요구서를 당에 제출했습니다. 송 …</div>
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news214,0001270417',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">MBC</div>
#  </div>
#  </div>
#  </li>
#  </ul>
#  </div>
#  <div class="cluster_foot">
#  <div class="cluster_foot_inner">
#  <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304281030_00001855&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=056&amp;aid=0011477716"><span class="cluster_foot_more_icon_num">14</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
#  </div>
#  </div>
#  </div>
#  <div class="cluster_group _cluster_content" style="display: none">
#  <div class="cluster_body">
#  <ul class="cluster_list">
#  <li class="cluster_item">
#  <div class="cluster_thumb">
#  <div class="cluster_thumb_inner">
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004186221?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/011/2023/05/03/4186221.jpg?type=ofullfill132_90" width="132"/>
#  </a>
#  </div>
#  </div>
#  <div class="cluster_text">
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004186221?sid=100">이용 국힘 의원 "尹, 김건희 여사 남편 잘못 만나 고생한다고 생각"</a>
#  <div class="cluster_text_lede">윤석열 대통령이 ‘남편을 잘못 만나 고생하고 있다’며 부인 김건희 여사를 향한 미안한 마음을 측근에게 토로한 적이 있는 것으로 전해졌다. 이는 대선후보  …</div>
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004186221',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">서울경제</div>
#  </div>
#  </div>
#  </li>
#  <li class="cluster_item">
#  <div class="cluster_thumb">
#  <div class="cluster_thumb_inner">
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/020/0003495164?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/020/2023/05/03/3495164.jpg?type=ofullfill132_90" width="132"/>
#  </a>
#  </div>
#  </div>
#  <div class="cluster_text">
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/020/0003495164?sid=100">‘尹 수행실장’ 이용 “김건희, 다소곳하고 온순…尹이 미안해 해”</a>
#  <div class="cluster_text_lede">윤석열 대통령이 대선후보 및 당선인 시절까지 수행실장을 맡으며 1년여 동안 밀착 수행했던 국민의힘 이용 의원이 윤 대통령과 아내 김건희 여사에 대해 “서 …</div>
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news020,0003495164',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">동아일보</div>
#  </div>
#  </div>
#  </li>
#  </ul>
#  </div>
#  <div class="cluster_foot">
#  <div class="cluster_foot_inner">
#  <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305022310_00000116&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=011&amp;aid=0004186221"><span class="cluster_foot_more_icon_num">23</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
#  </div>
#  </div>
#  </div>
#  <div class="cluster_group _cluster_content" style="display: none">
#  <div class="cluster_body">
#  <ul class="cluster_list">
#  <li class="cluster_item">
#  <div class="cluster_thumb">
#  <div class="cluster_thumb_inner">
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/088/0000812191?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/088/2023/05/03/812191.jpg?type=ofullfill132_90" width="132"/>
#  </a>
#  </div>
#  </div>
#  <div class="cluster_text">
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/088/0000812191?sid=100">尹 "문재인, 중국에서 8끼나 혼밥…'외교적 결례'"</a>
#  <div class="cluster_text_lede">윤석열 대통령이 전날인 2일 국민의힘 지도부와의 만찬에서 문재인 전 대통령의 2017년 중국 방문 당시 이른바 '혼밥'에 대해 언급한 것으로 전해졌다.  …</div>
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news088,0000812191',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">매일신문</div>
#  </div>
#  </div>
#  </li>
#  <li class="cluster_item">
#  <div class="cluster_thumb">
#  <div class="cluster_thumb_inner">
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013918387?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2023/05/03/13918387.jpg?type=ofullfill132_90" width="132"/>
#  </a>
#  </div>
#  </div>
#  <div class="cluster_text">
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013918387?sid=100">尹, 與지도부 만찬서 文 중국 방문 당시 '혼밥'에 "외교적 결례"</a>
#  <div class="cluster_text_lede">文정부, 친중정책 폈는데 중국에서 얻은 게 뭐 있나" 아쉬움 피력 '한미일 동맹 구축돼야 북·중이 함부로 못한다' 취지 발언도 윤석열 대통령이 국민의힘  …</div>
#  <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013918387',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#  <div class="cluster_text_press">연합뉴스</div>
#  </div>
#  </div>
#  </li>
#  </ul>
#  </div>
#  <div class="cluster_foot">
#  <div class="cluster_foot_inner">
#  <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305031000_00000379&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=088&amp;aid=0000812191"><span class="cluster_foot_more_icon_num">11</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
#  </div>
#  </div>
#  </div>
#  <div class="cluster_group _cluster_content" style="display: none">
#  <div class="cluster_body">
#  <ul class="cluster_list">
#  <li class="cluster_item">
#  <div class="cluster_thumb">
#  <div class="cluster_thumb_inner">
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002138442?sid=100">
# ...
#  </div>
#  </div>,
#  <div class="list_text_inner">
#  <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/665/0000000892?ntype=RANKING&amp;sid=001">1년 만에 론칭? 리버버스 졸속과 땜빵 사이 [視리즈]</a>
#  <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=665"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/665/2022/12/08/logo_665_56_20221208184224.png" width="16"/></span>더스쿠프</a>
#  </div>,
#  <div class="list_text_wrap">
#  <div class="list_text">
#  <div class="list_text_inner">
#  <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018643?ntype=RANKING&amp;sid=001">‘스시테러’ 정신 못 차렸나…일본 방송인 망원시장서 침 묻 …</a>
#  <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=145"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/145/2020/12/09/logo_145_56_20201209180915.png" width="16"/></span>레이디경향</a>
#  </div>
#  </div>
#  </div>,
#  <div class="list_text">
#  <div class="list_text_inner">
#  <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018643?ntype=RANKING&amp;sid=001">‘스시테러’ 정신 못 차렸나…일본 방송인 망원시장서 침 묻 …</a>
#  <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=145"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/145/2020/12/09/logo_145_56_20201209180915.png" width="16"/></span>레이디경향</a>
#  </div>
#  </div>,
#  <div class="list_text_inner">
#  <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018643?ntype=RANKING&amp;sid=001">‘스시테러’ 정신 못 차렸나…일본 방송인 망원시장서 침 묻 …</a>
#  <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=145"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/145/2020/12/09/logo_145_56_20201209180915.png" width="16"/></span>레이디경향</a>
#  </div>,
#  <div class="side_ad" id="glad_ad_sidebox"></div>,
#  <div class="section" id="right_dailyList" style="margin-bottom:20px; white-space:nowrap;">
#  <h4>분야별 주요뉴스</h4>
#  <div class="classfy sd" style="display:block">
#  <ul class="list_txt">
#  <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article
li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/422/0000596819?sid=103" title="[날씨] 중부 초여름 더위…내일 전국 '비소식'">[날씨] 중부 초여름 더위…내일 전국 '비소식'</a> </li>
#  <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/018/0005477970?sid=103" title="KG 모빌리티, '렉스턴 뉴 아레나·스포츠&amp;칸 쿨멘' 출격">KG 모빌리티, '렉스턴 뉴 아레나·스포츠&amp;칸 쿨멘' 출격</a> </li>
#  </ul>
#  </ul>
#  </ul>
#  </div>,
#  <div class="section">
#  <div class="banner">
#  <a class="nclicks(rig.banner)" href="https://media.naver.com/channel/settings"> <img alt="네이버 메인에서 바로 보는 언론사 편집뉴스 지금 바로 구독해보세요!" src="https://imgnews.pstatic.net/image/upload/item/2018/11/27/174854048_PC_%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA_%25B1%25B8%25B5%25B6%25C8%25B0%25BC%25BA%25C8%25AD.png" width="300"> </img></a>
#  </div>
#  </div>,
#  <div class="banner">
#  <a class="nclicks(rig.banner)" href="https://media.naver.com/channel/settings"> <img alt="네이버 메인에서 바로 보는 언론사 편집뉴스 지금 바로 구독해보세요!" src="https://imgnews.pstatic.net/image/upload/item/2018/11/27/174854048_PC_%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA_%25B1%25B8%25B5%25B6%25C8%25B0%25BC%25BA%25C8%25AD.png" width="300"> </img></a>
#  </div>,
#  <div class="section">
#  <a class="nclicks(rig.banner)" href="https://news.naver.com/main/assembly/index.naver" target="_blank"> <img alt="내일을 여는 국민의 국회" border="0" class="banner" height="60" src="https://imgnews.pstatic.net/image/upload/item/2021/01/08/173235779_%25B1%25B9%25C8%25B8%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA.png" width="300"> </img></a>
#  </div>,
#  <div class="section">
#  <div class="banner">
#  <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" target="_blank"> <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/183951086_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300"> </img></a>
#  </div>
#  </div>,
#  <div class="banner">
#  <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" target="_blank"> <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/183951086_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300"> </img></a>
#  </div>,
#  <div class="section">
#  <h4> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"> 서비스 안내 </a> </h4>
#  <ul class="list_txt">
#  <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb"> 고침 기사 모음 </a> </li>
#  <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb"> 정정·반론·추후 보도 기사 모음 </a> </li>
#  <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb"> 불공정 선거 보도 기사 모음 </a> </li>
#  </ul>
#  <a class="more_link nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"><span class="blind">서비스 안내</span>더보기</a>
#  </div>,
#  <div class="index">
#  <div class="index_inner">
#  <div class="floating_btn">
#  <div class="floating_inner">
#  <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
#  <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
#  </div>
#  </div>
#  <div class="index_tab" id="index.press_category">
#  <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
#  <div class="index_content is_hidden" id="index.press.area"></div>
#  <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
#  <div class="index_content02 is_hidden" id="index.category.area"></div>
#  </div>
#  </div>
#  </div>,
#  <div class="index_inner">
#  <div class="floating_btn">
#  <div class="floating_inner">
#  <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
#  <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
#  </div>
#  </div>
#  <div class="index_tab" id="index.press_category">
#  <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
#  <div class="index_content is_hidden" id="index.press.area"></div>
#  <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
#  <div class="index_content02 is_hidden" id="index.category.area"></div>
#  </div>
#  </div>,
#  <div class="floating_btn">
#  <div class="floating_inner">
#  <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
#  <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
#  </div>
#  </div>,
#  <div class="floating_inner">
#  <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
#  <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
#  </div>,
#  <div class="index_tab" id="index.press_category">
#  <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
#  <div class="index_content is_hidden" id="index.press.area"></div>
#  <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
#  <div class="index_content02 is_hidden" id="index.category.area"></div>
#  </div>,
#  <div class="index_content is_hidden" id="index.press.area"></div>,
#  <div class="index_content02 is_hidden" id="index.category.area"></div>,
#  <div id="footer">
#  <ul>
#  <li class="first"><a class="nclicks(fot.agreement)" href="http://www.naver.com/rules/service.html">이용약관</a></li>
#  <li><a class="nclicks(fot.guide)" href="/main/ombudsman/index.naver">서비스 안내</a></li>
#  <li><a class="nclicks(fot.editor)" href="/main/ombudsman/edit.naver?mid=omb">기사배열 원칙 책임자 : 유봉석</a></li>
#  <li>청소년 보호 책임자 : 이희만</li>
#  <li><strong><a class="nclicks(fot.privacy)" href="http://www.naver.com/rules/privacy.html">개인정보처리방침</a></strong></li>
#  <li><a class="nclicks(fot.disclaimer)" href="http://www.naver.com/rules/disclaimer.html">책임의 한계와 법적고지</a></li>
#  <li><a class="nclicks(fot.help)" href="#" onclick="news.external.OPS.helpNews(); return false;" title="새창">뉴스 고객센터</a></li>
#  </ul>
#  <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
#  <address class="address_nhn">
#  <a class="logo nclicks(fot.naver)" href="https://www.navercorp.com/" target="_blank"><span class="blind">NAVER</span></a>
#  <em>Copyright ©</em>
#  <a class="nclicks(fot.navercorp)" href="https://www.navercorp.com/" target="_blank">NAVER Corp.</a>
#  <span>All Rights Reserved.</span>
#  </address>
#  <!-- -->
#  </div>]

# %%
# 기본 태그를 사용해서 해당하는 첫번째 텍스트와 전체 텍스트를 출력
#1
bs.find('a').text

te = bs.find_all('a')
for i in te:
    print(i.text)

#2
bs.find('span', class_='tx').text

te = bs.findAll('span', class_='tx')
for i in te:
    print(i.text)

#3
bs.find('div')

te = bs.findAll('div')
for i in te:
    print(i.text)

#4
te = bs.find_all('span', {'class':'blind','class':"tx"})
for i in te:
    print(i.text)
    
# 5.
bs.select_one('div#u_skip a span').text

# 6.
te = bs.select('div#u_skip a span')
for i in te:
    print(i.text)
# Out:
# 메인 메뉴로 바로가기
# 본문으로 바로가기
# 검색
# NAVER
# 뉴스
# TV연예
# 스포츠
# 날씨
# 프리미엄
# 언론사별
# 정치 선택됨
# 경제
# 사회
# 생활/문화
# IT/과학
# 세계
# 랭킹
# 신문보기
# 오피니언
# TV
# 팩트체크
# 전체 언론사
# 뉴스스탠드
# 라이브러리
# 전체 언론사
# 뉴스스탠드
# 라이브러리
# 정치
# 대통령실
# 국회/정당
# 북한
# 행정
# 국방/외교
# 정치일반
#
#
# 안내헤드라인 뉴스
#
#
#
# 국회 정개특위, 선거제 개편 ‘500인 공론조사’ 실시…KBS 생중계
# `선거제 개편` 공론화 본격화…대표 시민 500인 토론
# '선거제도, 국회의원이 아닌 국민이 결정하자' 정개특위, 시민 500명 참여 토론회 연다
# 선거개편 공론화…시민참여단 500명 모여 토론한다
# 8개의 관련뉴스 더보기
#
#
#
# 野 의원 독도 방문에 日 항의…외교부 “부당한 주장 일축”
# 정부, "野 독도 방문 부당' 日항의에 "부당한 주장"
# 더불어민주당 경북도당 청년·대학생위 독도 현지서 ‘독도영유권수호 다짐’
# 韓의원 독도 방문에…日 "윤석열 정권에 대한 반발이냐"[이슈시개]
# 77개의 관련뉴스 더보기
#
#
#
# '태영호 녹취록'에 與 '산 넘어 산'…태영호 징계 수위에 영향은
# '체리따봉'부터 '태영호 녹취록'까지, 용산 '당무 개입'은 이제 시작?
# '태영호 녹취록'에 국민의힘 발칵…당내서도 "불법 공천개입"
# 대통령실 공천 개입? 태영호 녹취록 논란에 與 '선긋기'
# 82개의 관련뉴스 더보기
#
#
#
# 장예찬 "태영호 녹취록, 일벌백계해야"… 김성태 "중징계감 아니야"
# 장예찬 “용산과 더 가까운 나도 공천 부탁 들은 적 없다”
#  장예찬 "내가 태영호보다 대통령실과 더 가까운데.. 공천-부탁 들어본 적 없어" [시선집중]
# 장예찬 "내가 태영호보다 대통령실과 더 가깝지만 공천‧부탁 들어본 적 없다"
# 9개의 관련뉴스 더보기
#
#
#
# ‘돈 봉투 의혹’ 민주당 윤관석·이성만 의원 자진 탈당 결정
#
#
#
# '돈봉투' 의혹 윤관석·이성만 민주당 탈당…"선당후사 마음으로..."
# 85개의 관련뉴스 더보기
#
#
#
# '야권 원로' 유인태, 국민의힘 친윤모임 국민공감서 특강
#
#
#
# 野 원로 유인태, 與 공부모임 ‘국민공감’서 특강한다
# 11개의 관련뉴스 더보기
#
#
#
# 이재명 "尹 정권 폭력적 탄압에 노동자 죽음 선택…대통령 사과하길"
#
#
#
# 이재명, 노조원 분신 사망에 "대통령에 원천 책임…사과해야"
# 30개의 관련뉴스 더보기
#
#
#
# 상습적으로 임금 안 주는 사업주, 정부 지원사업 제한한다
#
#
#
# "임금 3개월 밀리면 신용제재"…'상습체불 근절대책'
# 36개의 관련뉴스 더보기
#
#
#
# 민주 "기시다 총리 방한, 과거사 사과부터 받아야"
#
#
# 동영상기사
#
# 대통령실 "기시다 7일 방한"…내일 안보실장 사전 회담
# 110개의 관련뉴스 더보기
#
#
# 동영상기사
#
# 北 반발 수위 고조...한미 정상 겨냥 '화형식'까지
#
#
#
# 北, 워싱턴선언 반발 수위 고조…한미 정상 겨냥 ‘화형식’ 진행
# 44개의 관련뉴스 더보기
#
#
#
# 태영호 "비서관이 녹취록 유출? 허위사실"
#
#
#
# "태영호 녹취록 유출자, 이들일 것"...유튜버들의 마녀사냥
# 14개의 관련뉴스 더보기
#
#
#
# 박광온 “오늘 의총서 국민이 바라는 쇄신방안 마련…향후 전원토론 실시”
#
#
#
# 박광온 "집단지성 통해 국민 바라는 쇄신안 마련할 것"
# 18개의 관련뉴스 더보기
#
#
#
# 국민의힘 당원 2만여 명, 김재원 징계 반대 요구서 제출
#
#
#
# 국민의힘 일부 당원들, 김재원 징계 반대 요구서 제출
# 14개의 관련뉴스 더보기
#
#
#
# 이용 국힘 의원 "尹, 김건희 여사 남편 잘못 만나 고생한다고 생각"
#
#
#
# ‘尹 수행실장’ 이용 “김건희, 다소곳하고 온순…尹이 미안해 해”
# 23개의 관련뉴스 더보기
#
#
#
# 尹 "문재인, 중국에서 8끼나 혼밥…'외교적 결례'"
#
#
#
# 尹, 與지도부 만찬서 文 중국 방문 당시 '혼밥'에 "외교적 결례"
# 11개의 관련뉴스 더보기
#
#
#
# 홍준표 “尹이 이재명 안 만나는 이유? 중대범죄 혐의자라서”
#
#
#
# 홍준표 “김재원·태영호, 어처구니 없는 자중지란…중징계 불가피”
# 16개의 관련뉴스 더보기
# 헤드라인 더보기
#
# 연재보기
# 박순찬의 장도리 카툰
#
#
#
#
#  윤윅
#  날리맨
#  온다
#  한미일 동맹
#
#
#
#
# "아줌마!" 부르다 살인난다…여성 분노케 하는 '그 말'  …
# 서울경제
#
#
#
# 어린이날 연휴 전국에 '집중호우'…수도권 사흘간 최대 12 …
# 연합뉴스
#
#
#
# "성욕만 푸는 XX취급" 前남친에 문자만 800번…20대  …
# 중앙일보
#
#
# 동영상기사
#
# "마동석 사진 쓰면 인생이 편해진다"…중국서 '프사 바꾸기 …
# JTBC
#
#
#
# 임신한 외상 손님, 이제 식구가 됐습니다 [아살세]
# 국민일보
#
#
#
# "여보세력 나야" 풍자한 유튜버에…임창정, 경고장 날렸다
# 한국경제
#
#
#
# 세계 최초 누워가는 '비행기 침대칸' 나온다…가격 얼마?
# 머니투데이
#
#
#
# 서정진 셀트리온 회장 혼외자 2명 호적에… 친모와 서 회장 …
# 조선비즈
#
#
#
# 손혜원, '목포 투기 의혹' 조선일보 상대 항소심도 패소
# TV조선
#
#
#
# 택시에 두고 내린 '40년 업무자료'…한 달간 CCTV 돌 …
# SBS
#
#
#
# “여보 세력 나야~” 임창정, 패러디에 칼 뺐다
# 매일경제
#
#
#
# “새치기 하다니”…서울대 명예교수, 구내식당서 학생 폭행
# 동아일보
#
#
#
# 신부 이어 목사 1000명 시국선언…“윤석열 운명 다했다”
# 한겨레
#
#
#
# "인어 몸매가 왜 이래" 조각상에 발칵 뒤집힌 이탈리아
# 아시아경제
#
#
# 동영상기사
#
# "10분 만에 25억 꽂혔다"‥임창정, 계좌 공개하며 '결 …
# MBC
#
#
# 동영상기사
#
# [단독] “깔렸다고” “밀지 마” 민노총 집회서 경찰 밀어 …
# 조선일보
#
#
#
# 공무원 인기 떨어졌다…완전자본잠식 빠진 에듀윌
# 이데일리
#
#
# 동영상기사
#
# 해고 당했는데 ‘자진 퇴사’라니…실업급여도 막막 [5인미만 …
# KBS
#
#
# 동영상기사
#
# [날씨] 중부 초여름 더위…내일 전국 '비소식'
# 연합뉴스TV
#
#
#
# "나도 피해자" 임창정, 주가조작단 美골프장 계약자리 동행
# 디지털타임스
#
#
#
# 국내 언론이 본 한미정상회담… "동맹은 격상, 경제 성과  …
# 기자협회보
#
#
#
# 日 유명 개그맨이 韓 시장에서 보인 돌발 행동...일본 사 …
# YTN
#
#
#
# 32년째 행방불명 아나운서...어디로 갔나
# MBN
#
#
#
# [단독]'돈세탁' 의혹 유명 유튜버 헬스장에 '수상한' 사 …
# 뉴스1
#
#
#
# 백윤식, 전 연인 ‘폭로 에세이’ 출판·판매금지 소송서 일 …
# 경향신문
#
#
#
# “한강변 49층이요? 35층 하시죠” 반포 재건축 초고층  …
# 헤럴드경제
#
#
#
# 메스 들고 허벅지 정맥 도려낸 '김 선생'... 그의 정체 …
# 한국일보
#
#
#
# 영영 못 찾을 줄 알았던 카메라가 다시 내 손에…“한국,  …
# 세계일보
#
#
#
# ‘부촌’ 명성 고개 드나… 달맞이고개 100억 빌라 들어선 …
# 부산일보
#
#
#
# [영상] 속도 감당 못한 페라리가 들이받은 닛산…하늘로 ‘ …
# 문화일보
#
#
#
# 체중 줄이고 싶은 여성, '이 기간'에 운동 해보세요
# 헬스조선
#
#
#
# 도로서 어린 남매 발견한 최초 신고자 "맨발에 속옷차림으로 …
# 파이낸셜뉴스
#
#
#
# 평택 아파트서 30대 엄마와 7세 아들 숨진 채 발견
# 서울신문
#
#
#
# 日 개그맨, 망원시장서 침 묻은 꼬치로 닭강정 '푹'
# 뉴시스
#
#
#
# 완공 5개월 앞두고 '와르르'…입주 예정자들 '분통'
# 한국경제TV
#
#
#
# 韓의원 독도 방문에…日 "윤석열 정권에 대한 반발이냐"[이 …
# 노컷뉴스
#
#
#
# 온가족 뛰어들어 월수 2천만원... 우리가 버는 돈은 특별 …
# 오마이뉴스
#
#
#
# '보복여행' 떠난 中여행객들, 욕설·몸싸움 민폐...화장실 …
# 전자신문
#
#
#
# [단독]野원로 유인태, 대통령 취임 1주년에 與 친윤 모임 …
# 채널A
#
#
#
# 어린이날 나들이 어쩌나.. 4일밤부터 호우특보 수준 쏟아진 …
# CJB청주방송
#
#
#
# 건설노동자 분신 사망에 "尹 정부, '건폭' 신조어까지 만 …
# 프레시안
#
#
#
# 양극재 판매 질주…에코프로 1분기도 날았다
# 비즈워치
#
#
#
# '여신도 성폭행' JMS 정명석 파렴치 행각 도운 정조은과 …
# 시사저널
#
#
#
# 송영길, '나는 협조? 연락처·통화내역·카톡 '초기화'…제 …
# 데일리안
#
#
#
# 일가족 3명 숨진 채 발견…아내 살해하고 한살배기 자녀 껴 …
# 강원일보
#
#
#
# 尹 "문재인, 중국에서 8끼나 혼밥…'외교적 결례'"
# 매일신문
#
#
#
# "어버이날 선물 예산 평균 33만6천원"
# ZDNet Korea
#
#
#
# 손혜원, 조선일보 '목포 투기 의혹'  정정보도 소송서 패 …
# 미디어오늘
#
#
#
# "아버지가 마약한 것 같아요"…필로폰 투약 50대, 아들  …
# 더팩트
#
#
#
# "여기서 주님 지켜며 잠 자라" 정명석 성폭행 도운 JMS …
# kbc광주방송
#
#
#
# 美연준, 마지막 '베이비스텝' 유력…동결기조 전환하나
# 블로터
#
#
#
# 멈춰버린 행정심판과 법무부의 비공개 ‘억지 주장’
# 뉴스타파
#
#
#
# “엄마 편이야, 아빠 편이야” 묻지 마세요
# 한겨레21
#
#
#
# "선배한테 밥 얻어먹기 최고"… 무지출 챌린지 해봤어? [ …
# 머니S
#
#
#
# Bear or badger? Debates continue …
# 코리아헤럴드
#
#
#
# “사는 게 행복하더라” 임영웅을 사랑하는 이들
# 시사IN
#
#
#
# 경상적자 계속, '제2 외환위기說'까지…KDI는 "가능성  …
# 조세일보
#
#
#
# [DD 퇴근길] 대기업 카카오, 아이디어 베끼기 논란
# 디지털데일리
#
#
#
# [단독]이번엔 해운대...전세사기로 27억 원 가로챈 건축 …
# 국제신문
#
#
#
# 카카오뱅크 1분기 당기순이익 1019억원... '역대 최대 …
# 한경비즈니스
#
#
#
# “美·日·中  로봇 산업 성장 비결은 정부 투자”
# 주간동아
#
#
#
# 홍준표"대통령, 범죄혐의자와 만나면 오해 받아 이재명 안  …
# 주간조선
#
#
#
# '대전 스쿨존' 승아양 친 60대 男, 음주운전 '상습범' …
# 아이뉴스24
#
#
#
# “또 오너리스크?”...셀트리온그룹주, 이번엔 서정진 회장 …
# 매경이코노미
#
#
#
# 알코올성 간질환 표적 치료 열쇠 찾았다
# 동아사이언스
#
#
#
# 엠폭스 환자 96% 남성… 대부분 20~40대
# 여성신문
#
#
#
# 서정진 혼외 자녀 호적 오르자 셀트리온 주가 ‘흔들’
# 이코노미스트
#
#
#
# 최근 혈당이 높아졌다면…‘착한’탄수화물 식품6
# 코메디닷컴
#
#
#
# 연산군의 ‘탕춘대’가 왜 세계유산감일까[이기환의 Hi-st …
# 주간경향
#
#
#
# 〈나는 신이다〉 재현은 왜 문제가 되는가?
# 일다
#
#
#
# [속보] 분신사망 건설노조 강원지부 간부, "대한민국 바로 …
# 강원도민일보
#
#
#
# [Man&Wall] 선수도 힘든 5.14급 루트 끝낸 하하 …
# 월간 산
#
#
#
# “안철수보다 윤석열이 먼저 손 내밀었다” [+영상]
# 신동아
#
#
#
# Korean victim of Japanese wartim …
# 코리아중앙데일리
#
#
#
# 콧물 주르륵 ‘OOO염’…방치 시 수술 필요
# 농민신문
#
#
#
# [영상+] "마음이 아프신가요?" 국립 김천 치유의 숲
# 대구MBC
#
#
#
# 김기현, 윤리위에 '태영호 녹취록' 병합 심사 요청… "심 …
# 대전일보
#
#
#
# '尹 호위무사' 이용 "김건희 여사 활동적이지 않고 온순. …
# JIBS
#
#
#
# 서정진 '혼외 자녀' 친모 회사 2곳 계열사로 추가… 셀트 …
# 경기일보
#
#
#
# 오물 뒤섞여 방치된 '비숑' 100마리..진안 무허가 번식 …
# 전주MBC
#
#
#
# '尹 호위무사' 이용 "김건희 여사 활동적이지 않고 온순. …
# JIBS
#
#
#
# 서정진 '혼외 자녀' 친모 회사 2곳 계열사로 추가… 셀트 …
# 경기일보
#
#
#
# 오물 뒤섞여 방치된 '비숑' 100마리..진안 무허가 번식 …
# 전주MBC
#
#
#
# 1년 만에 론칭? 리버버스 졸속과 땜빵 사이 [視리즈]
# 더스쿠프
#
#
#
# ‘스시테러’ 정신 못 차렸나…일본 방송인 망원시장서 침 묻 …
# 레이디경향
# 이재명, 윤관석·이성만 탈당 질문에 “태영호 녹취는요?”
# ‘韓의원 독도 방문’ 항의한 일본…외교부 “부당한 주장 일축”
# 임금체불 한해 1조3천억원…상습체불 사업주 신용대출 제한(종합)
# 한국서 침 묻은 꼬치로 판매 음식 푹푹 찌른 일본인?뭇매
# 美 부채가 더 걱정…백악관 “협상 불가’ 재천명, 디폴트 우려 고조
# [ADB2023] 尹 대통령 "韓, 아시아 협력 공동망 구축"
# 대한항공, 부산세계박람회 유치 기원 특별 항공기 공개
# 최저가 노트북 업체의 몰락... 뒤엔 G마켓·경쟁사 '갑질 동맹'
# 카카오게임즈, 2분기 반등 자신…'오딘' 日 보내고 '아레스' 출격(종합)
# 삼성, 올해 '월드 디제이 페스티벌'에 갤럭시 찐팬 초청
# 건설노동자 분신 사망에 "尹 정부, '건폭' 신조어까지 만들어 노조 매도하더니…"
# 엠폭스 환자 52명 중 50명이 남성…96% '성접촉' 감염(종합)
# 송영길 전 보좌관 검찰 출석…"돈 봉투 본 적도 없어"
# [날씨] 중부 초여름 더위…내일 전국 '비소식'
# KG 모빌리티, '렉스턴 뉴 아레나·스포츠&칸 쿨멘' 출격
#
#
#
#  서비스 안내
#  고침 기사 모음
#  정정·반론·추후 보도 기사 모음
#  불공정 선거 보도 기사 모음
# 서비스 안내더보기
# 이젠 페이지
# 맨위로
# 언론사 목록열기로딩 중
# 분야별 목록열기로딩 중
# 이용약관
# 서비스 안내
# 기사배열 원칙 책임자 : 유봉석
# 개인정보처리방침
# 책임의 한계와 법적고지
# 뉴스 고객센터
# NAVER
# NAVER Corp.
# 언론사별
# 정치
# 경제
# 사회
# 생활/문화
# IT/과학
# 세계
# 랭킹
# 신문보기
# 오피니언
# TV
# 팩트체크
#
#
#
#
#
#
# 메인 메뉴로 바로가기
# 본문으로 바로가기
#
#
#
#
#
#
#
#
#
#
# 검색
#
#
#
#
# NAVER
# 뉴스
#
#
# TV연예
# 스포츠
# 날씨
# 프리미엄
#
#
#
#
#
#
#
#
#
#
# 언론사별
# 정치 선택됨
# 경제
# 사회
# 생활/문화
# IT/과학
# 세계
# 랭킹
# 신문보기
# 오피니언
# TV
# 팩트체크
#
#
#
#
#
#
#
# 전체 언론사
# 뉴스스탠드
# 라이브러리
#
#
#
#
#
#
#
#
# 05.03(수)
#
# 전체 언론사
# 뉴스스탠드
# 라이브러리
#
#
#
#
#
# 기사목록
#
#
#
#
#
#
#
#
# 정치
#
# 대통령실
# 국회/정당
# 북한
# 행정
# 국방/외교
# 정치일반
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 안내헤드라인 뉴스
#
#
#                             헤드라인 뉴스와 각 기사묶음 타이틀은  기사 내용을 기반으로 자동 추출됩니다.
#
#
# 닫기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 국회 정개특위, 선거제 개편 ‘500인 공론조사’ 실시…KBS 생중계
# 국회 정치개혁특별위원회(정개특위)는 오는 6일과 13일 양일간 500명의 시민참여단을 대상으로 국회의원 선거제도 개편에 대한 공론조사를 실시하고, KBS …
#
# KBS
#
#
#
#
#
#
# 이데일리
#
# `선거제 개편` 공론화 본격화…대표 시민 500인 토론
#
#
#
#
#
# 파이낸셜뉴스
#
# '선거제도, 국회의원이 아닌 국민이 결정하자' 정개특위, 시민 500명 참여 토론회 연다
#
#
#
#
#
# 매일경제
#
# 선거개편 공론화…시민참여단 500명 모여 토론한다
#
#
#
#
#
#
# 8개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 野 의원 독도 방문에 日 항의…외교부 “부당한 주장 일축”
# 정부는 3일 전용기 더불어민주당 의원의 독도 방문에 대한 일본 측 항의에 “일본 측의 부당한 주장은 외교 채널을 통해 일축했다”고 밝혔다. 외교부 당국자 …
#
# 조선비즈
#
#
#
#
#
#
# 서울경제
#
# 정부, "野 독도 방문 부당' 日항의에 "부당한 주장"
#
#
#
#
#
# 헤럴드경제
#
# 더불어민주당 경북도당 청년·대학생위 독도 현지서 ‘독도영유권수호 다짐’
#
#
#
#
#
# 노컷뉴스
#
# 韓의원 독도 방문에…日 "윤석열 정권에 대한 반발이냐"[이슈시개]
#
#
#
#
#
#
# 77개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# '태영호 녹취록'에 與 '산 넘어 산'…태영호 징계 수위에 영향은
# 이진복 대통령실 정무수석이 22대 총선 공천 문제를 거론하며 한일 관계에 대한 옹호 발언을 해달라고 요청했다는 태영호 국민의힘 최고위원의 녹취가 공개되면 …
#
# 뉴스1
#
#
#
#
#
#
# 시사저널
#
# '체리따봉'부터 '태영호 녹취록'까지, 용산 '당무 개입'은 이제 시작?
#
#
#
#
#
# JTBC
#
# '태영호 녹취록'에 국민의힘 발칵…당내서도 "불법 공천개입"
#
#
#
#
#
# 한국경제TV
#
# 대통령실 공천 개입? 태영호 녹취록 논란에 與 '선긋기'
#
#
#
#
#
#
# 82개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 장예찬 "태영호 녹취록, 일벌백계해야"… 김성태 "중징계감 아니야"
# 이른바 '공천 녹취록' 유출과 관련해 여당 내부에서 의견이 엇갈리고 있다. 장예찬 국민의힘 최고위원은 "누구든 일벌백계 읍참마속의 기조로 엄하게 다뤄야  …
#
# 머니S
#
#
#
#
#
#
# 한겨레
#
# 장예찬 “용산과 더 가까운 나도 공천 부탁 들은 적 없다”
#
#
#
#
#
# MBC
#
#  장예찬 "내가 태영호보다 대통령실과 더 가까운데.. 공천-부탁 들어본 적 없어" [시선집중]
#
#
#
#
#
# 파이낸셜뉴스
#
# 장예찬 "내가 태영호보다 대통령실과 더 가깝지만 공천‧부탁 들어본 적 없다"
#
#
#
#
#
#
# 9개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ‘돈 봉투 의혹’ 민주당 윤관석·이성만 의원 자진 탈당 결정
# '돈 봉투 의혹'에 휩싸인 더불어민주당 윤관석, 이성만 의원이 자진 탈당을 결정했습니다. 민주당 윤관석, 이성만 의원은 오늘(3일) 국회에서 비공개 최고 …
#
# KBS
#
#
#
#
#
#
#
#
#
#
#
#
# '돈봉투' 의혹 윤관석·이성만 민주당 탈당…"선당후사 마음으로..."
# ‘전당대회 돈봉투’ 논란과 윤관석·이성만 의원이 더불어민주당을 탈당하기로 했다. 윤 의원과 이 의원은 3일 민주당 지도부와 면담을 거친 뒤 기자들에게 탈 …
#
# 아시아경제
#
#
#
#
#
#
#
# 85개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# '야권 원로' 유인태, 국민의힘 친윤모임 국민공감서 특강
# 야권 원로 인사인 유인태 전 국회 사무총장이 국민의힘 내 친윤 그룹 공부 모임인 ‘국민공감’에서 특강을 진행한다. 유인태 전 국회사무총장(사진=연합뉴스) …
#
# 이데일리
#
#
#
#
#
#
#
#
#
#
#
#
# 野 원로 유인태, 與 공부모임 ‘국민공감’서 특강한다
# 야권 원로인 유인태 전 국회 사무총장이 국민의힘 내 친윤 그룹 공부모임인 ‘국민공감’에서 특강을 한다. 국민공감에 따르면 유 전 사무총장은 오는 9일 오 …
#
# 동아일보
#
#
#
#
#
#
#
# 11개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 이재명 "尹 정권 폭력적 탄압에 노동자 죽음 선택…대통령 사과하길"
# 이재명 더불어민주당 대표가 지난 2일 분신 시도 후 끝내 사망한 노동자를 두고 “윤석열 정권의 노조 탄압이 결국 소중한 생명을 앗아갔다”고 강하게 비판했 …
#
# 이데일리
#
#
#
#
#
#
#
#
#
#
#
#
# 이재명, 노조원 분신 사망에 "대통령에 원천 책임…사과해야"
# 최근 정부에 항의하며 분신한 건설노조 간부가 숨진 것과 관련, 이재명 더불어민주당 대표가 3일 "원천적 책임은 대통령에게 있다"며 "대통령에게 진솔한 사 …
#
# 머니투데이
#
#
#
#
#
#
#
# 30개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 상습적으로 임금 안 주는 사업주, 정부 지원사업 제한한다
# 3개월분 이상 체불하는 등 상습적으로 임금을 체불하면서 적극적인 청산노력을 기울이지 않는 사업주에 대해 형사처벌 외 경제적 제재가 추가된다. 이정식 고용 …
#
# 이데일리
#
#
#
#
#
#
#
#
#
#
#
#
# "임금 3개월 밀리면 신용제재"…'상습체불 근절대책'
# 임금을 3개월분 이상 상습적으로 체불하는 등 적극적인 청산노력을 기울이지 않는 사업주에 대해 신용제재와 정부지원 제한 등 경제적 제재가 강화된다. 고용노 …
#
# 아시아경제
#
#
#
#
#
#
#
# 36개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 민주 "기시다 총리 방한, 과거사 사과부터 받아야"
# 더불어민주당은 일본 기시다 총리가 오는 7일과 8일 방한한다는 정부 발표에 대해 "과거사 사과부터 받아야 한다"고 직격했다. 권칠승 수석대변인은 2일 논 …
#
# 뉴시스
#
#
#
#
#
#
#
#
# 동영상기사
#
#
#
#
# 대통령실 "기시다 7일 방한"…내일 안보실장 사전 회담
# 기시다 일본 총리가 오는 7일부터 1박 2일 일정으로 한국을 방문합니다. 내일(3일)은 두 나라 안보실장이 먼저 만나 정상회담에서 어떤 의제를 다룰지 논 …
#
# SBS
#
#
#
#
#
#
#
# 110개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
# 동영상기사
#
#
#
#
# 北 반발 수위 고조...한미 정상 겨냥 '화형식'까지
# 북한이 확장억제 강화 방안이 담긴 워싱턴 선언에 대해 한미 정상을 겨냥한 화형식까지 열며 반발 수위를 높이고 있습니다. 김여정의 막말 담화에 이은 비난  …
#
# YTN
#
#
#
#
#
#
#
#
#
#
#
#
# 北, 워싱턴선언 반발 수위 고조…한미 정상 겨냥 ‘화형식’ 진행
# 청년학생 ‘복수결의모임’ 2일 개최 “늙다리 전쟁괴수와 특등하수인의 추악한 몰골들이 재가루로…” 북한이 ‘워싱턴 선언’을 비난하는 청년학생 집회를 열고  …
#
# 세계일보
#
#
#
#
#
#
#
# 44개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 태영호 "비서관이 녹취록 유출? 허위사실"
# 태영호 국민의힘 최고위원이 녹취록 유출자로 자신의 보좌진이 의심받는 상황에 유감을 표했다. 2일 태 최고위원은 자신의 SNS 계정에 "현재 일부 유튜버들 …
#
# YTN
#
#
#
#
#
#
#
#
#
#
#
#
# "태영호 녹취록 유출자, 이들일 것"...유튜버들의 마녀사냥
# 태영호 국민의힘 최고위원은 녹취록 파문으로 자신의 보좌진이 유출자로 의심받는 상황에 강력 반발하며 유감을 표했습니다. 태 최고위원은 전날(2일) 밤 페이 …
#
# MBN
#
#
#
#
#
#
#
# 14개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 박광온 “오늘 의총서 국민이 바라는 쇄신방안 마련…향후 전원토론 실시”
# “모든 의원 대상 심층 설문조사…‘최종 쇄신 보고서’ 보고” 박광온 더불어민주당 원내대표는 3일 개최가 예정된 의원총회와 관련, “쇄신 의총의 전 과정은 …
#
# 조선비즈
#
#
#
#
#
#
#
#
#
#
#
#
# 박광온 "집단지성 통해 국민 바라는 쇄신안 마련할 것"
# 기사내용 요약 의원 대상 심층설문조사·국민 대상 웹조사 실시 조사 결과 나온 주제들로 심층 토론 진행 예정 [서울=뉴시스] 박광온 더불어민주당 원내대표가 …
#
# 뉴시스
#
#
#
#
#
#
#
# 18개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 국민의힘 당원 2만여 명, 김재원 징계 반대 요구서 제출
# 국민의힘 중앙윤리위원회가 김재원 최고위원에 대한 징계 여부를 논의하는 가운데, 당원 2만여 명이 이를 반대하는 요구서를 오늘(3일) 제출했습니다. 송세달 …
#
# KBS
#
#
#
#
#
#
#
#
#
#
#
#
# 국민의힘 일부 당원들, 김재원 징계 반대 요구서 제출
# 잇단 설화로 논란을 빚은 김재원 최고위원에 대한 당 윤리위의 징계 결정을 앞두고, 국민의힘 일부 당원들이 징계를 반대하는 요구서를 당에 제출했습니다. 송 …
#
# MBC
#
#
#
#
#
#
#
# 14개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 이용 국힘 의원 "尹, 김건희 여사 남편 잘못 만나 고생한다고 생각"
# 윤석열 대통령이 ‘남편을 잘못 만나 고생하고 있다’며 부인 김건희 여사를 향한 미안한 마음을 측근에게 토로한 적이 있는 것으로 전해졌다. 이는 대선후보  …
#
# 서울경제
#
#
#
#
#
#
#
#
#
#
#
#
# ‘尹 수행실장’ 이용 “김건희, 다소곳하고 온순…尹이 미안해 해”
# 윤석열 대통령이 대선후보 및 당선인 시절까지 수행실장을 맡으며 1년여 동안 밀착 수행했던 국민의힘 이용 의원이 윤 대통령과 아내 김건희 여사에 대해 “서 …
#
# 동아일보
#
#
#
#
#
#
#
# 23개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 尹 "문재인, 중국에서 8끼나 혼밥…'외교적 결례'"
# 윤석열 대통령이 전날인 2일 국민의힘 지도부와의 만찬에서 문재인 전 대통령의 2017년 중국 방문 당시 이른바 '혼밥'에 대해 언급한 것으로 전해졌다.  …
#
# 매일신문
#
#
#
#
#
#
#
#
#
#
#
#
# 尹, 與지도부 만찬서 文 중국 방문 당시 '혼밥'에 "외교적 결례"
# 文정부, 친중정책 폈는데 중국에서 얻은 게 뭐 있나" 아쉬움 피력 '한미일 동맹 구축돼야 북·중이 함부로 못한다' 취지 발언도 윤석열 대통령이 국민의힘  …
#
# 연합뉴스
#
#
#
#
#
#
#
# 11개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 홍준표 “尹이 이재명 안 만나는 이유? 중대범죄 혐의자라서”
# 홍준표 대구시장은 3일 윤석열 대통령이 이재명 더불어민주당 대표와 만나지 않는 데 대해 "(이 대표가)중범죄로 기소된 피고인이기 때문"이라고 추측했다.  …
#
# 헤럴드경제
#
#
#
#
#
#
#
#
#
#
#
#
# 홍준표 “김재원·태영호, 어처구니 없는 자중지란…중징계 불가피”
# 홍준표 대구 시장은 3일 국민의힘 윤리위원회 징계 절차가 개시된 김재원·태영호 최고위원에 대해 “중징계가 불가피하다”고 말했다. 홍 시장은 이날 오전 자 …
#
# 헤럴드경제
#
#
#
#
#
#
#
# 16개의 관련뉴스 더보기
#
#
#
#
#
#
# 헤드라인 더보기
#
#
#
#
#
#
#
#
# 연재보기
# 박순찬의 장도리 카툰
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  윤윅
# 다 쓸어버린다! ⓒ 박순찬 윤석열 대통령의 미국 순방 후폭풍이 거세다. 확장억제 강화에 치중한 워싱턴 선언은 북·중·러의 반발을  …
#
# 오마이뉴스
#
#
#
#
#
#
# 오마이뉴스
#
#  날리맨
#
#
#
#
#
# 오마이뉴스
#
#  온다
#
#
#
#
#
# 오마이뉴스
#
#  한미일 동맹
#
#
#
#
#
#
#
#
#
#
# 뉴스 더보기
#
#
#
# AiRS추천으로 구성된 뉴스를 제공합니다.
#
#
#
#
#
#
#
#
#
#
# 언론사별 가장 많이 본 뉴스
# 안내
# 각 언론사의 가장 많이 본 기사 1건을 제공합니다. 닫기
# 오후 1시~오후 2시까지 집계한 결과입니다.
#
#
#
#
#
#
#
#
# "아줌마!" 부르다 살인난다…여성 분노케 하는 '그 말'  …
# 서울경제
#
#
#
#
#
#
#
#
#
#
#
# 어린이날 연휴 전국에 '집중호우'…수도권 사흘간 최대 12 …
# 연합뉴스
#
#
#
#
#
#
#
#
#
#
#
# "성욕만 푸는 XX취급" 前남친에 문자만 800번…20대  …
# 중앙일보
#
#
#
#
#
#
#
# 동영상기사
#
#
#
#
# "마동석 사진 쓰면 인생이 편해진다"…중국서 '프사 바꾸기 …
# JTBC
#
#
#
#
#
#
#
#
#
#
#
# 임신한 외상 손님, 이제 식구가 됐습니다 [아살세]
# 국민일보
#
#
#
#
#
#
#
#
#
#
#
#
#
# "여보세력 나야" 풍자한 유튜버에…임창정, 경고장 날렸다
# 한국경제
#
#
#
#
#
#
#
#
#
#
#
# 세계 최초 누워가는 '비행기 침대칸' 나온다…가격 얼마?
# 머니투데이
#
#
#
#
#
#
#
#
#
#
#
# 서정진 셀트리온 회장 혼외자 2명 호적에… 친모와 서 회장 …
# 조선비즈
#
#
#
#
#
#
#
#
#
#
#
# 손혜원, '목포 투기 의혹' 조선일보 상대 항소심도 패소
# TV조선
#
#
#
#
#
#
#
#
#
#
#
# 택시에 두고 내린 '40년 업무자료'…한 달간 CCTV 돌 …
# SBS
#
#
#
#
#
#
#
#
#
#
#
#
#
# “여보 세력 나야~” 임창정, 패러디에 칼 뺐다
# 매일경제
#
#
#
#
#
#
#
#
#
#
#
# “새치기 하다니”…서울대 명예교수, 구내식당서 학생 폭행
# 동아일보
#
#
#
#
#
#
#
#
#
#
#
# 신부 이어 목사 1000명 시국선언…“윤석열 운명 다했다”
# 한겨레
#
#
#
#
#
#
#
#
#
#
#
# "인어 몸매가 왜 이래" 조각상에 발칵 뒤집힌 이탈리아
# 아시아경제
#
#
#
#
#
#
#
# 동영상기사
#
#
#
#
# "10분 만에 25억 꽂혔다"‥임창정, 계좌 공개하며 '결 …
# MBC
#
#
#
#
#
#
#
#
#
# 동영상기사
#
#
#
#
# [단독] “깔렸다고” “밀지 마” 민노총 집회서 경찰 밀어 …
# 조선일보
#
#
#
#
#
#
#
#
#
#
#
# 공무원 인기 떨어졌다…완전자본잠식 빠진 에듀윌
# 이데일리
#
#
#
#
#
#
#
# 동영상기사
#
#
#
#
# 해고 당했는데 ‘자진 퇴사’라니…실업급여도 막막 [5인미만 …
# KBS
#
#
#
#
#
#
#
# 동영상기사
#
#
#
#
# [날씨] 중부 초여름 더위…내일 전국 '비소식'
# 연합뉴스TV
#
#
#
#
#
#
#
#
#
#
#
# "나도 피해자" 임창정, 주가조작단 美골프장 계약자리 동행
# 디지털타임스
#
#
#
#
#
#
#
#
#
#
#
#
#
# 국내 언론이 본 한미정상회담… "동맹은 격상, 경제 성과  …
# 기자협회보
#
#
#
#
#
#
#
#
#
#
#
# 日 유명 개그맨이 韓 시장에서 보인 돌발 행동...일본 사 …
# YTN
#
#
#
#
#
#
#
#
#
#
#
# 32년째 행방불명 아나운서...어디로 갔나
# MBN
#
#
#
#
#
#
#
#
#
#
#
# [단독]'돈세탁' 의혹 유명 유튜버 헬스장에 '수상한' 사 …
# 뉴스1
#
#
#
#
#
#
#
#
#
#
#
# 백윤식, 전 연인 ‘폭로 에세이’ 출판·판매금지 소송서 일 …
# 경향신문
#
#
#
#
#
#
#
#
#
#
#
#
#
# “한강변 49층이요? 35층 하시죠” 반포 재건축 초고층  …
# 헤럴드경제
#
#
#
#
#
#
#
#
#
#
#
# 메스 들고 허벅지 정맥 도려낸 '김 선생'... 그의 정체 …
# 한국일보
#
#
#
#
#
#
#
#
#
#
#
# 영영 못 찾을 줄 알았던 카메라가 다시 내 손에…“한국,  …
# 세계일보
#
#
#
#
#
#
#
#
#
#
#
# ‘부촌’ 명성 고개 드나… 달맞이고개 100억 빌라 들어선 …
# 부산일보
#
#
#
#
#
#
#
#
#
#
#
# [영상] 속도 감당 못한 페라리가 들이받은 닛산…하늘로 ‘ …
# 문화일보
#
#
#
#
#
#
#
#
#
#
#
#
#
# 체중 줄이고 싶은 여성, '이 기간'에 운동 해보세요
# 헬스조선
#
#
#
#
#
#
#
#
#
#
#
# 도로서 어린 남매 발견한 최초 신고자 "맨발에 속옷차림으로 …
# 파이낸셜뉴스
#
#
#
#
#
#
#
#
#
#
#
# 평택 아파트서 30대 엄마와 7세 아들 숨진 채 발견
# 서울신문
#
#
#
#
#
#
#
#
#
#
#
# 日 개그맨, 망원시장서 침 묻은 꼬치로 닭강정 '푹'
# 뉴시스
#
#
#
#
#
#
#
#
#
#
#
# 완공 5개월 앞두고 '와르르'…입주 예정자들 '분통'
# 한국경제TV
#
#
#
#
#
#
#
#
#
#
#
#
#
# 韓의원 독도 방문에…日 "윤석열 정권에 대한 반발이냐"[이 …
# 노컷뉴스
#
#
#
#
#
#
#
#
#
#
#
# 온가족 뛰어들어 월수 2천만원... 우리가 버는 돈은 특별 …
# 오마이뉴스
#
#
#
#
#
#
#
#
#
#
#
# '보복여행' 떠난 中여행객들, 욕설·몸싸움 민폐...화장실 …
# 전자신문
#
#
#
#
#
#
#
#
#
#
#
# [단독]野원로 유인태, 대통령 취임 1주년에 與 친윤 모임 …
# 채널A
#
#
#
#
#
#
#
#
#
#
#
# 어린이날 나들이 어쩌나.. 4일밤부터 호우특보 수준 쏟아진 …
# CJB청주방송
#
#
#
#
#
#
#
#
#
#
#
#
#
# 건설노동자 분신 사망에 "尹 정부, '건폭' 신조어까지 만 …
# 프레시안
#
#
#
#
#
#
#
#
#
#
#
# 양극재 판매 질주…에코프로 1분기도 날았다
# 비즈워치
#
#
#
#
#
#
#
#
#
#
#
# '여신도 성폭행' JMS 정명석 파렴치 행각 도운 정조은과 …
# 시사저널
#
#
#
#
#
#
#
#
#
#
#
# 송영길, '나는 협조? 연락처·통화내역·카톡 '초기화'…제 …
# 데일리안
#
#
#
#
#
#
#
#
#
#
#
# 일가족 3명 숨진 채 발견…아내 살해하고 한살배기 자녀 껴 …
# 강원일보
#
#
#
#
#
#
#
#
#
#
#
#
#
# 尹 "문재인, 중국에서 8끼나 혼밥…'외교적 결례'"
# 매일신문
#
#
#
#
#
#
#
#
#
#
#
# "어버이날 선물 예산 평균 33만6천원"
# ZDNet Korea
#
#
#
#
#
#
#
#
#
#
#
# 손혜원, 조선일보 '목포 투기 의혹'  정정보도 소송서 패 …
# 미디어오늘
#
#
#
#
#
#
#
#
#
#
#
# "아버지가 마약한 것 같아요"…필로폰 투약 50대, 아들  …
# 더팩트
#
#
#
#
#
#
#
#
#
#
#
# "여기서 주님 지켜며 잠 자라" 정명석 성폭행 도운 JMS …
# kbc광주방송
#
#
#
#
#
#
#
#
#
#
#
#
#
# 美연준, 마지막 '베이비스텝' 유력…동결기조 전환하나
# 블로터
#
#
#
#
#
#
#
#
#
#
#
# 멈춰버린 행정심판과 법무부의 비공개 ‘억지 주장’
# 뉴스타파
#
#
#
#
#
#
#
#
#
#
#
# “엄마 편이야, 아빠 편이야” 묻지 마세요
# 한겨레21
#
#
#
#
#
#
#
#
#
#
#
# "선배한테 밥 얻어먹기 최고"… 무지출 챌린지 해봤어? [ …
# 머니S
#
#
#
#
#
#
#
#
#
#
#
# Bear or badger? Debates continue …
# 코리아헤럴드
#
#
#
#
#
#
#
#
#
#
#
#
#
# “사는 게 행복하더라” 임영웅을 사랑하는 이들
# 시사IN
#
#
#
#
#
#
#
#
#
#
#
# 경상적자 계속, '제2 외환위기說'까지…KDI는 "가능성  …
# 조세일보
#
#
#
#
#
#
#
#
#
#
#
# [DD 퇴근길] 대기업 카카오, 아이디어 베끼기 논란
# 디지털데일리
#
#
#
#
#
#
#
#
#
#
#
# [단독]이번엔 해운대...전세사기로 27억 원 가로챈 건축 …
# 국제신문
#
#
#
#
#
#
#
#
#
#
#
# 카카오뱅크 1분기 당기순이익 1019억원... '역대 최대 …
# 한경비즈니스
#
#
#
#
#
#
#
#
#
#
#
#
#
# “美·日·中  로봇 산업 성장 비결은 정부 투자”
# 주간동아
#
#
#
#
#
#
#
#
#
#
#
# 홍준표"대통령, 범죄혐의자와 만나면 오해 받아 이재명 안  …
# 주간조선
#
#
#
#
#
#
#
#
#
#
#
# '대전 스쿨존' 승아양 친 60대 男, 음주운전 '상습범' …
# 아이뉴스24
#
#
#
#
#
#
#
#
#
#
#
# “또 오너리스크?”...셀트리온그룹주, 이번엔 서정진 회장 …
# 매경이코노미
#
#
#
#
#
#
#
#
#
#
#
# 알코올성 간질환 표적 치료 열쇠 찾았다
# 동아사이언스
#
#
#
#
#
#
#
#
#
#
#
#
#
# 엠폭스 환자 96% 남성… 대부분 20~40대
# 여성신문
#
#
#
#
#
#
#
#
#
#
#
# 서정진 혼외 자녀 호적 오르자 셀트리온 주가 ‘흔들’
# 이코노미스트
#
#
#
#
#
#
#
#
#
#
#
# 최근 혈당이 높아졌다면…‘착한’탄수화물 식품6
# 코메디닷컴
#
#
#
#
#
#
#
#
#
#
#
# 연산군의 ‘탕춘대’가 왜 세계유산감일까[이기환의 Hi-st …
# 주간경향
#
#
#
#
#
#
#
#
#
#
#
# 〈나는 신이다〉 재현은 왜 문제가 되는가?
# 일다
#
#
#
#
#
#
#
#
#
#
#
#
#
# [속보] 분신사망 건설노조 강원지부 간부, "대한민국 바로 …
# 강원도민일보
#
#
#
#
#
#
#
#
#
#
#
# [Man&Wall] 선수도 힘든 5.14급 루트 끝낸 하하 …
# 월간 산
#
#
#
#
#
#
#
#
#
#
#
# “안철수보다 윤석열이 먼저 손 내밀었다” [+영상]
# 신동아
#
#
#
#
#
#
#
#
#
#
#
# Korean victim of Japanese wartim …
# 코리아중앙데일리
#
#
#
#
#
#
#
#
#
#
#
# 콧물 주르륵 ‘OOO염’…방치 시 수술 필요
# 농민신문
#
#
#
#
#
#
#
#
#
#
#
#
#
# [영상+] "마음이 아프신가요?" 국립 김천 치유의 숲
# 대구MBC
#
#
#
#
#
#
#
#
#
#
#
# 김기현, 윤리위에 '태영호 녹취록' 병합 심사 요청… "심 …
# 대전일보
#
#
#
#
#
#
#
#
#
#
#
# '尹 호위무사' 이용 "김건희 여사 활동적이지 않고 온순. …
# JIBS
#
#
#
#
#
#
#
#
#
#
#
# 서정진 '혼외 자녀' 친모 회사 2곳 계열사로 추가… 셀트 …
# 경기일보
#
#
#
#
#
#
#
#
#
#
#
# 오물 뒤섞여 방치된 '비숑' 100마리..진안 무허가 번식 …
# 전주MBC
#
#
#
#
#
#
#
#
#
#
#
#
#
# '尹 호위무사' 이용 "김건희 여사 활동적이지 않고 온순. …
# JIBS
#
#
#
#
#
#
#
#
#
#
#
# 서정진 '혼외 자녀' 친모 회사 2곳 계열사로 추가… 셀트 …
# 경기일보
#
#
#
#
#
#
#
#
#
#
#
# 오물 뒤섞여 방치된 '비숑' 100마리..진안 무허가 번식 …
# 전주MBC
#
#
#
#
#
#
#
#
#
#
#
# 1년 만에 론칭? 리버버스 졸속과 땜빵 사이 [視리즈]
# 더스쿠프
#
#
#
#
#
#
#
#
#
#
#
# ‘스시테러’ 정신 못 차렸나…일본 방송인 망원시장서 침 묻 …
# 레이디경향
#
#
#
#
#
# 더보기
#
#
#
#
# 분야별 주요뉴스
#
#
#  이재명, 윤관석·이성만 탈당 질문에 “태영호 녹취는요?”
#  ‘韓의원 독도 방문’ 항의한 일본…외교부 “부당한 주장 일축”
#  임금체불 한해 1조3천억원…상습체불 사업주 신용대출 제한(종합)
#  한국서 침 묻은 꼬치로 판매 음식 푹푹 찌른 일본인?뭇매
#  美 부채가 더 걱정…백악관 “협상 불가’ 재천명, 디폴트 우려 고조
#
#
#
#  [ADB2023] 尹 대통령 "韓, 아시아 협력 공동망 구축"
#  대한항공, 부산세계박람회 유치 기원 특별 항공기 공개
#  최저가 노트북 업체의 몰락... 뒤엔 G마켓·경쟁사 '갑질 동맹'
#  카카오게임즈, 2분기 반등 자신…'오딘' 日 보내고 '아레스' 출격(종합)
#  삼성, 올해 '월드 디제이 페스티벌'에 갤럭시 찐팬 초청
#
#
#
#  건설노동자 분신 사망에 "尹 정부, '건폭' 신조어까지 만들어 노조 매도하더니…"
#  엠폭스 환자 52명 중 50명이 남성…96% '성접촉' 감염(종합)
#  송영길 전 보좌관 검찰 출석…"돈 봉투 본 적도 없어"
#  [날씨] 중부 초여름 더위…내일 전국 '비소식'
#  KG 모빌리티, '렉스턴 뉴 아레나·스포츠&칸 쿨멘' 출격
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   서비스 안내
#
#   고침 기사 모음
#   정정·반론·추후 보도 기사 모음
#   불공정 선거 보도 기사 모음
#
# 서비스 안내더보기
#
#
#
#
#
#
#
#
#
#
#
# 메인 메뉴로 바로가기
# 본문으로 바로가기
#
#
#
#
#
#
#
#
#
#
# 검색
#
#
#
#
# NAVER
# 뉴스
#
#
# TV연예
# 스포츠
# 날씨
# 프리미엄
#
#
#
#
#
#
#
#
#
#
# 언론사별
# 정치 선택됨
# 경제
# 사회
# 생활/문화
# IT/과학
# 세계
# 랭킹
# 신문보기
# 오피니언
# TV
# 팩트체크
#
#
#
#
#
#
#
# 전체 언론사
# 뉴스스탠드
# 라이브러리
#
#
#
#
#
#
#
#
# 05.03(수)
#
# 전체 언론사
# 뉴스스탠드
# 라이브러리
#
#
#
#
# 메인 메뉴로 바로가기
# 본문으로 바로가기
#
#
#
#
#
#
#
#
#
#
# 검색
#
#
#
#
# NAVER
# 뉴스
#
#
# TV연예
# 스포츠
# 날씨
# 프리미엄
#
#
#
#
#
#
#
#
#
#
#
#
# 검색
#
#
#
#
# NAVER
# 뉴스
#
#
# TV연예
# 스포츠
# 날씨
# 프리미엄
#
#
#
#
#
#
#
#
#
#
# 검색
#
#
#
#
#
#
#
#
#
# 검색
#
#
#
# NAVER
# 뉴스
#
#
# TV연예
# 스포츠
# 날씨
# 프리미엄
#
#
#
#
#
#
#
#
# 언론사별
# 정치 선택됨
# 경제
# 사회
# 생활/문화
# IT/과학
# 세계
# 랭킹
# 신문보기
# 오피니언
# TV
# 팩트체크
#
#
#
#
#
#
#
# 전체 언론사
# 뉴스스탠드
# 라이브러리
#
#
#
#
#
#
#
#
#
#
#
#
# 언론사별
# 정치 선택됨
# 경제
# 사회
# 생활/문화
# IT/과학
# 세계
# 랭킹
# 신문보기
# 오피니언
# TV
# 팩트체크
#
#
#
#
#
#
#
# 전체 언론사
# 뉴스스탠드
# 라이브러리
#
#
#
#
#
#
#
#
#
#
# 언론사별
# 정치 선택됨
# 경제
# 사회
# 생활/문화
# IT/과학
# 세계
# 랭킹
# 신문보기
# 오피니언
# TV
# 팩트체크
#
#
#
#
#
#
#
# 전체 언론사
# 뉴스스탠드
# 라이브러리
#
#
#
#
#
#
#
#
# 언론사별
# 정치 선택됨
# 경제
# 사회
# 생활/문화
# IT/과학
# 세계
# 랭킹
# 신문보기
# 오피니언
# TV
# 팩트체크
#
#
#
#
#
# 언론사별
# 정치 선택됨
# 경제
# 사회
# 생활/문화
# IT/과학
# 세계
# 랭킹
# 신문보기
# 오피니언
# TV
# 팩트체크
#
#
#
#
#
#
# 전체 언론사
# 뉴스스탠드
# 라이브러리
#
#
#
#
#
#
#
# 전체 언론사
# 뉴스스탠드
# 라이브러리
#
#
#
#
#
# 전체 언론사
# 뉴스스탠드
# 라이브러리
#
#
#
# 05.03(수)
#
# 전체 언론사
# 뉴스스탠드
# 라이브러리
#
#
#
# 정치
#
# 대통령실
# 국회/정당
# 북한
# 행정
# 국방/외교
# 정치일반
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 안내헤드라인 뉴스
#
#
#                             헤드라인 뉴스와 각 기사묶음 타이틀은  기사 내용을 기반으로 자동 추출됩니다.
#
#
# 닫기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 국회 정개특위, 선거제 개편 ‘500인 공론조사’ 실시…KBS 생중계
# 국회 정치개혁특별위원회(정개특위)는 오는 6일과 13일 양일간 500명의 시민참여단을 대상으로 국회의원 선거제도 개편에 대한 공론조사를 실시하고, KBS …
#
# KBS
#
#
#
#
#
#
# 이데일리
#
# `선거제 개편` 공론화 본격화…대표 시민 500인 토론
#
#
#
#
#
# 파이낸셜뉴스
#
# '선거제도, 국회의원이 아닌 국민이 결정하자' 정개특위, 시민 500명 참여 토론회 연다
#
#
#
#
#
# 매일경제
#
# 선거개편 공론화…시민참여단 500명 모여 토론한다
#
#
#
#
#
#
# 8개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 野 의원 독도 방문에 日 항의…외교부 “부당한 주장 일축”
# 정부는 3일 전용기 더불어민주당 의원의 독도 방문에 대한 일본 측 항의에 “일본 측의 부당한 주장은 외교 채널을 통해 일축했다”고 밝혔다. 외교부 당국자 …
#
# 조선비즈
#
#
#
#
#
#
# 서울경제
#
# 정부, "野 독도 방문 부당' 日항의에 "부당한 주장"
#
#
#
#
#
# 헤럴드경제
#
# 더불어민주당 경북도당 청년·대학생위 독도 현지서 ‘독도영유권수호 다짐’
#
#
#
#
#
# 노컷뉴스
#
# 韓의원 독도 방문에…日 "윤석열 정권에 대한 반발이냐"[이슈시개]
#
#
#
#
#
#
# 77개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# '태영호 녹취록'에 與 '산 넘어 산'…태영호 징계 수위에 영향은
# 이진복 대통령실 정무수석이 22대 총선 공천 문제를 거론하며 한일 관계에 대한 옹호 발언을 해달라고 요청했다는 태영호 국민의힘 최고위원의 녹취가 공개되면 …
#
# 뉴스1
#
#
#
#
#
#
# 시사저널
#
# '체리따봉'부터 '태영호 녹취록'까지, 용산 '당무 개입'은 이제 시작?
#
#
#
#
#
# JTBC
#
# '태영호 녹취록'에 국민의힘 발칵…당내서도 "불법 공천개입"
#
#
#
#
#
# 한국경제TV
#
# 대통령실 공천 개입? 태영호 녹취록 논란에 與 '선긋기'
#
#
#
#
#
#
# 82개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 장예찬 "태영호 녹취록, 일벌백계해야"… 김성태 "중징계감 아니야"
# 이른바 '공천 녹취록' 유출과 관련해 여당 내부에서 의견이 엇갈리고 있다. 장예찬 국민의힘 최고위원은 "누구든 일벌백계 읍참마속의 기조로 엄하게 다뤄야  …
#
# 머니S
#
#
#
#
#
#
# 한겨레
#
# 장예찬 “용산과 더 가까운 나도 공천 부탁 들은 적 없다”
#
#
#
#
#
# MBC
#
#  장예찬 "내가 태영호보다 대통령실과 더 가까운데.. 공천-부탁 들어본 적 없어" [시선집중]
#
#
#
#
#
# 파이낸셜뉴스
#
# 장예찬 "내가 태영호보다 대통령실과 더 가깝지만 공천‧부탁 들어본 적 없다"
#
#
#
#
#
#
# 9개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ‘돈 봉투 의혹’ 민주당 윤관석·이성만 의원 자진 탈당 결정
# '돈 봉투 의혹'에 휩싸인 더불어민주당 윤관석, 이성만 의원이 자진 탈당을 결정했습니다. 민주당 윤관석, 이성만 의원은 오늘(3일) 국회에서 비공개 최고 …
#
# KBS
#
#
#
#
#
#
#
#
#
#
#
#
# '돈봉투' 의혹 윤관석·이성만 민주당 탈당…"선당후사 마음으로..."
# ‘전당대회 돈봉투’ 논란과 윤관석·이성만 의원이 더불어민주당을 탈당하기로 했다. 윤 의원과 이 의원은 3일 민주당 지도부와 면담을 거친 뒤 기자들에게 탈 …
#
# 아시아경제
#
#
#
#
#
#
#
# 85개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# '야권 원로' 유인태, 국민의힘 친윤모임 국민공감서 특강
# 야권 원로 인사인 유인태 전 국회 사무총장이 국민의힘 내 친윤 그룹 공부 모임인 ‘국민공감’에서 특강을 진행한다. 유인태 전 국회사무총장(사진=연합뉴스) …
#
# 이데일리
#
#
#
#
#
#
#
#
#
#
#
#
# 野 원로 유인태, 與 공부모임 ‘국민공감’서 특강한다
# 야권 원로인 유인태 전 국회 사무총장이 국민의힘 내 친윤 그룹 공부모임인 ‘국민공감’에서 특강을 한다. 국민공감에 따르면 유 전 사무총장은 오는 9일 오 …
#
# 동아일보
#
#
#
#
#
#
#
# 11개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 이재명 "尹 정권 폭력적 탄압에 노동자 죽음 선택…대통령 사과하길"
# 이재명 더불어민주당 대표가 지난 2일 분신 시도 후 끝내 사망한 노동자를 두고 “윤석열 정권의 노조 탄압이 결국 소중한 생명을 앗아갔다”고 강하게 비판했 …
#
# 이데일리
#
#
#
#
#
#
#
#
#
#
#
#
# 이재명, 노조원 분신 사망에 "대통령에 원천 책임…사과해야"
# 최근 정부에 항의하며 분신한 건설노조 간부가 숨진 것과 관련, 이재명 더불어민주당 대표가 3일 "원천적 책임은 대통령에게 있다"며 "대통령에게 진솔한 사 …
#
# 머니투데이
#
#
#
#
#
#
#
# 30개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 상습적으로 임금 안 주는 사업주, 정부 지원사업 제한한다
# 3개월분 이상 체불하는 등 상습적으로 임금을 체불하면서 적극적인 청산노력을 기울이지 않는 사업주에 대해 형사처벌 외 경제적 제재가 추가된다. 이정식 고용 …
#
# 이데일리
#
#
#
#
#
#
#
#
#
#
#
#
# "임금 3개월 밀리면 신용제재"…'상습체불 근절대책'
# 임금을 3개월분 이상 상습적으로 체불하는 등 적극적인 청산노력을 기울이지 않는 사업주에 대해 신용제재와 정부지원 제한 등 경제적 제재가 강화된다. 고용노 …
#
# 아시아경제
#
#
#
#
#
#
#
# 36개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 민주 "기시다 총리 방한, 과거사 사과부터 받아야"
# 더불어민주당은 일본 기시다 총리가 오는 7일과 8일 방한한다는 정부 발표에 대해 "과거사 사과부터 받아야 한다"고 직격했다. 권칠승 수석대변인은 2일 논 …
#
# 뉴시스
#
#
#
#
#
#
#
#
# 동영상기사
#
#
#
#
# 대통령실 "기시다 7일 방한"…내일 안보실장 사전 회담
# 기시다 일본 총리가 오는 7일부터 1박 2일 일정으로 한국을 방문합니다. 내일(3일)은 두 나라 안보실장이 먼저 만나 정상회담에서 어떤 의제를 다룰지 논 …
#
# SBS
#
#
#
#
#
#
#
# 110개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
# 동영상기사
#
#
#
#
# 北 반발 수위 고조...한미 정상 겨냥 '화형식'까지
# 북한이 확장억제 강화 방안이 담긴 워싱턴 선언에 대해 한미 정상을 겨냥한 화형식까지 열며 반발 수위를 높이고 있습니다. 김여정의 막말 담화에 이은 비난  …
#
# YTN
#
#
#
#
#
#
#
#
#
#
#
#
# 北, 워싱턴선언 반발 수위 고조…한미 정상 겨냥 ‘화형식’ 진행
# 청년학생 ‘복수결의모임’ 2일 개최 “늙다리 전쟁괴수와 특등하수인의 추악한 몰골들이 재가루로…” 북한이 ‘워싱턴 선언’을 비난하는 청년학생 집회를 열고  …
#
# 세계일보
#
#
#
#
#
#
#
# 44개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 태영호 "비서관이 녹취록 유출? 허위사실"
# 태영호 국민의힘 최고위원이 녹취록 유출자로 자신의 보좌진이 의심받는 상황에 유감을 표했다. 2일 태 최고위원은 자신의 SNS 계정에 "현재 일부 유튜버들 …
#
# YTN
#
#
#
#
#
#
#
#
#
#
#
#
# "태영호 녹취록 유출자, 이들일 것"...유튜버들의 마녀사냥
# 태영호 국민의힘 최고위원은 녹취록 파문으로 자신의 보좌진이 유출자로 의심받는 상황에 강력 반발하며 유감을 표했습니다. 태 최고위원은 전날(2일) 밤 페이 …
#
# MBN
#
#
#
#
#
#
#
# 14개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 박광온 “오늘 의총서 국민이 바라는 쇄신방안 마련…향후 전원토론 실시”
# “모든 의원 대상 심층 설문조사…‘최종 쇄신 보고서’ 보고” 박광온 더불어민주당 원내대표는 3일 개최가 예정된 의원총회와 관련, “쇄신 의총의 전 과정은 …
#
# 조선비즈
#
#
#
#
#
#
#
#
#
#
#
#
# 박광온 "집단지성 통해 국민 바라는 쇄신안 마련할 것"
# 기사내용 요약 의원 대상 심층설문조사·국민 대상 웹조사 실시 조사 결과 나온 주제들로 심층 토론 진행 예정 [서울=뉴시스] 박광온 더불어민주당 원내대표가 …
#
# 뉴시스
#
#
#
#
#
#
#
# 18개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 국민의힘 당원 2만여 명, 김재원 징계 반대 요구서 제출
# 국민의힘 중앙윤리위원회가 김재원 최고위원에 대한 징계 여부를 논의하는 가운데, 당원 2만여 명이 이를 반대하는 요구서를 오늘(3일) 제출했습니다. 송세달 …
#
# KBS
#
#
#
#
#
#
#
#
#
#
#
#
# 국민의힘 일부 당원들, 김재원 징계 반대 요구서 제출
# 잇단 설화로 논란을 빚은 김재원 최고위원에 대한 당 윤리위의 징계 결정을 앞두고, 국민의힘 일부 당원들이 징계를 반대하는 요구서를 당에 제출했습니다. 송 …
#
# MBC
#
#
#
#
#
#
#
# 14개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 이용 국힘 의원 "尹, 김건희 여사 남편 잘못 만나 고생한다고 생각"
# 윤석열 대통령이 ‘남편을 잘못 만나 고생하고 있다’며 부인 김건희 여사를 향한 미안한 마음을 측근에게 토로한 적이 있는 것으로 전해졌다. 이는 대선후보  …
#
# 서울경제
#
#
#
#
#
#
#
#
#
#
#
#
# ‘尹 수행실장’ 이용 “김건희, 다소곳하고 온순…尹이 미안해 해”
# 윤석열 대통령이 대선후보 및 당선인 시절까지 수행실장을 맡으며 1년여 동안 밀착 수행했던 국민의힘 이용 의원이 윤 대통령과 아내 김건희 여사에 대해 “서 …
#
# 동아일보
#
#
#
#
#
#
#
# 23개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 尹 "문재인, 중국에서 8끼나 혼밥…'외교적 결례'"
# 윤석열 대통령이 전날인 2일 국민의힘 지도부와의 만찬에서 문재인 전 대통령의 2017년 중국 방문 당시 이른바 '혼밥'에 대해 언급한 것으로 전해졌다.  …
#
# 매일신문
#
#
#
#
#
#
#
#
#
#
#
#
# 尹, 與지도부 만찬서 文 중국 방문 당시 '혼밥'에 "외교적 결례"
# 文정부, 친중정책 폈는데 중국에서 얻은 게 뭐 있나" 아쉬움 피력 '한미일 동맹 구축돼야 북·중이 함부로 못한다' 취지 발언도 윤석열 대통령이 국민의힘  …
#
# 연합뉴스
#
#
#
#
#
#
#
# 11개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 홍준표 “尹이 이재명 안 만나는 이유? 중대범죄 혐의자라서”
# 홍준표 대구시장은 3일 윤석열 대통령이 이재명 더불어민주당 대표와 만나지 않는 데 대해 "(이 대표가)중범죄로 기소된 피고인이기 때문"이라고 추측했다.  …
#
# 헤럴드경제
#
#
#
#
#
#
#
#
#
#
#
#
# 홍준표 “김재원·태영호, 어처구니 없는 자중지란…중징계 불가피”
# 홍준표 대구 시장은 3일 국민의힘 윤리위원회 징계 절차가 개시된 김재원·태영호 최고위원에 대해 “중징계가 불가피하다”고 말했다. 홍 시장은 이날 오전 자 …
#
# 헤럴드경제
#
#
#
#
#
#
#
# 16개의 관련뉴스 더보기
#
#
#
#
#
#
# 헤드라인 더보기
#
#
#
#
#
#
#
#
# 연재보기
# 박순찬의 장도리 카툰
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  윤윅
# 다 쓸어버린다! ⓒ 박순찬 윤석열 대통령의 미국 순방 후폭풍이 거세다. 확장억제 강화에 치중한 워싱턴 선언은 북·중·러의 반발을  …
#
# 오마이뉴스
#
#
#
#
#
#
# 오마이뉴스
#
#  날리맨
#
#
#
#
#
# 오마이뉴스
#
#  온다
#
#
#
#
#
# 오마이뉴스
#
#  한미일 동맹
#
#
#
#
#
#
#
#
#
#
# 뉴스 더보기
#
#
#
# AiRS추천으로 구성된 뉴스를 제공합니다.
#
#
#
#
#
#
#
#
#
# 안내헤드라인 뉴스
#
#
#                             헤드라인 뉴스와 각 기사묶음 타이틀은  기사 내용을 기반으로 자동 추출됩니다.
#
#
# 닫기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 국회 정개특위, 선거제 개편 ‘500인 공론조사’ 실시…KBS 생중계
# 국회 정치개혁특별위원회(정개특위)는 오는 6일과 13일 양일간 500명의 시민참여단을 대상으로 국회의원 선거제도 개편에 대한 공론조사를 실시하고, KBS …
#
# KBS
#
#
#
#
#
#
# 이데일리
#
# `선거제 개편` 공론화 본격화…대표 시민 500인 토론
#
#
#
#
#
# 파이낸셜뉴스
#
# '선거제도, 국회의원이 아닌 국민이 결정하자' 정개특위, 시민 500명 참여 토론회 연다
#
#
#
#
#
# 매일경제
#
# 선거개편 공론화…시민참여단 500명 모여 토론한다
#
#
#
#
#
#
# 8개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 野 의원 독도 방문에 日 항의…외교부 “부당한 주장 일축”
# 정부는 3일 전용기 더불어민주당 의원의 독도 방문에 대한 일본 측 항의에 “일본 측의 부당한 주장은 외교 채널을 통해 일축했다”고 밝혔다. 외교부 당국자 …
#
# 조선비즈
#
#
#
#
#
#
# 서울경제
#
# 정부, "野 독도 방문 부당' 日항의에 "부당한 주장"
#
#
#
#
#
# 헤럴드경제
#
# 더불어민주당 경북도당 청년·대학생위 독도 현지서 ‘독도영유권수호 다짐’
#
#
#
#
#
# 노컷뉴스
#
# 韓의원 독도 방문에…日 "윤석열 정권에 대한 반발이냐"[이슈시개]
#
#
#
#
#
#
# 77개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# '태영호 녹취록'에 與 '산 넘어 산'…태영호 징계 수위에 영향은
# 이진복 대통령실 정무수석이 22대 총선 공천 문제를 거론하며 한일 관계에 대한 옹호 발언을 해달라고 요청했다는 태영호 국민의힘 최고위원의 녹취가 공개되면 …
#
# 뉴스1
#
#
#
#
#
#
# 시사저널
#
# '체리따봉'부터 '태영호 녹취록'까지, 용산 '당무 개입'은 이제 시작?
#
#
#
#
#
# JTBC
#
# '태영호 녹취록'에 국민의힘 발칵…당내서도 "불법 공천개입"
#
#
#
#
#
# 한국경제TV
#
# 대통령실 공천 개입? 태영호 녹취록 논란에 與 '선긋기'
#
#
#
#
#
#
# 82개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 장예찬 "태영호 녹취록, 일벌백계해야"… 김성태 "중징계감 아니야"
# 이른바 '공천 녹취록' 유출과 관련해 여당 내부에서 의견이 엇갈리고 있다. 장예찬 국민의힘 최고위원은 "누구든 일벌백계 읍참마속의 기조로 엄하게 다뤄야  …
#
# 머니S
#
#
#
#
#
#
# 한겨레
#
# 장예찬 “용산과 더 가까운 나도 공천 부탁 들은 적 없다”
#
#
#
#
#
# MBC
#
#  장예찬 "내가 태영호보다 대통령실과 더 가까운데.. 공천-부탁 들어본 적 없어" [시선집중]
#
#
#
#
#
# 파이낸셜뉴스
#
# 장예찬 "내가 태영호보다 대통령실과 더 가깝지만 공천‧부탁 들어본 적 없다"
#
#
#
#
#
#
# 9개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ‘돈 봉투 의혹’ 민주당 윤관석·이성만 의원 자진 탈당 결정
# '돈 봉투 의혹'에 휩싸인 더불어민주당 윤관석, 이성만 의원이 자진 탈당을 결정했습니다. 민주당 윤관석, 이성만 의원은 오늘(3일) 국회에서 비공개 최고 …
#
# KBS
#
#
#
#
#
#
#
#
#
#
#
#
# '돈봉투' 의혹 윤관석·이성만 민주당 탈당…"선당후사 마음으로..."
# ‘전당대회 돈봉투’ 논란과 윤관석·이성만 의원이 더불어민주당을 탈당하기로 했다. 윤 의원과 이 의원은 3일 민주당 지도부와 면담을 거친 뒤 기자들에게 탈 …
#
# 아시아경제
#
#
#
#
#
#
#
# 85개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# '야권 원로' 유인태, 국민의힘 친윤모임 국민공감서 특강
# 야권 원로 인사인 유인태 전 국회 사무총장이 국민의힘 내 친윤 그룹 공부 모임인 ‘국민공감’에서 특강을 진행한다. 유인태 전 국회사무총장(사진=연합뉴스) …
#
# 이데일리
#
#
#
#
#
#
#
#
#
#
#
#
# 野 원로 유인태, 與 공부모임 ‘국민공감’서 특강한다
# 야권 원로인 유인태 전 국회 사무총장이 국민의힘 내 친윤 그룹 공부모임인 ‘국민공감’에서 특강을 한다. 국민공감에 따르면 유 전 사무총장은 오는 9일 오 …
#
# 동아일보
#
#
#
#
#
#
#
# 11개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 이재명 "尹 정권 폭력적 탄압에 노동자 죽음 선택…대통령 사과하길"
# 이재명 더불어민주당 대표가 지난 2일 분신 시도 후 끝내 사망한 노동자를 두고 “윤석열 정권의 노조 탄압이 결국 소중한 생명을 앗아갔다”고 강하게 비판했 …
#
# 이데일리
#
#
#
#
#
#
#
#
#
#
#
#
# 이재명, 노조원 분신 사망에 "대통령에 원천 책임…사과해야"
# 최근 정부에 항의하며 분신한 건설노조 간부가 숨진 것과 관련, 이재명 더불어민주당 대표가 3일 "원천적 책임은 대통령에게 있다"며 "대통령에게 진솔한 사 …
#
# 머니투데이
#
#
#
#
#
#
#
# 30개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 상습적으로 임금 안 주는 사업주, 정부 지원사업 제한한다
# 3개월분 이상 체불하는 등 상습적으로 임금을 체불하면서 적극적인 청산노력을 기울이지 않는 사업주에 대해 형사처벌 외 경제적 제재가 추가된다. 이정식 고용 …
#
# 이데일리
#
#
#
#
#
#
#
#
#
#
#
#
# "임금 3개월 밀리면 신용제재"…'상습체불 근절대책'
# 임금을 3개월분 이상 상습적으로 체불하는 등 적극적인 청산노력을 기울이지 않는 사업주에 대해 신용제재와 정부지원 제한 등 경제적 제재가 강화된다. 고용노 …
#
# 아시아경제
#
#
#
#
#
#
#
# 36개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 민주 "기시다 총리 방한, 과거사 사과부터 받아야"
# 더불어민주당은 일본 기시다 총리가 오는 7일과 8일 방한한다는 정부 발표에 대해 "과거사 사과부터 받아야 한다"고 직격했다. 권칠승 수석대변인은 2일 논 …
#
# 뉴시스
#
#
#
#
#
#
#
#
# 동영상기사
#
#
#
#
# 대통령실 "기시다 7일 방한"…내일 안보실장 사전 회담
# 기시다 일본 총리가 오는 7일부터 1박 2일 일정으로 한국을 방문합니다. 내일(3일)은 두 나라 안보실장이 먼저 만나 정상회담에서 어떤 의제를 다룰지 논 …
#
# SBS
#
#
#
#
#
#
#
# 110개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
# 동영상기사
#
#
#
#
# 北 반발 수위 고조...한미 정상 겨냥 '화형식'까지
# 북한이 확장억제 강화 방안이 담긴 워싱턴 선언에 대해 한미 정상을 겨냥한 화형식까지 열며 반발 수위를 높이고 있습니다. 김여정의 막말 담화에 이은 비난  …
#
# YTN
#
#
#
#
#
#
#
#
#
#
#
#
# 北, 워싱턴선언 반발 수위 고조…한미 정상 겨냥 ‘화형식’ 진행
# 청년학생 ‘복수결의모임’ 2일 개최 “늙다리 전쟁괴수와 특등하수인의 추악한 몰골들이 재가루로…” 북한이 ‘워싱턴 선언’을 비난하는 청년학생 집회를 열고  …
#
# 세계일보
#
#
#
#
#
#
#
# 44개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 태영호 "비서관이 녹취록 유출? 허위사실"
# 태영호 국민의힘 최고위원이 녹취록 유출자로 자신의 보좌진이 의심받는 상황에 유감을 표했다. 2일 태 최고위원은 자신의 SNS 계정에 "현재 일부 유튜버들 …
#
# YTN
#
#
#
#
#
#
#
#
#
#
#
#
# "태영호 녹취록 유출자, 이들일 것"...유튜버들의 마녀사냥
# 태영호 국민의힘 최고위원은 녹취록 파문으로 자신의 보좌진이 유출자로 의심받는 상황에 강력 반발하며 유감을 표했습니다. 태 최고위원은 전날(2일) 밤 페이 …
#
# MBN
#
#
#
#
#
#
#
# 14개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 박광온 “오늘 의총서 국민이 바라는 쇄신방안 마련…향후 전원토론 실시”
# “모든 의원 대상 심층 설문조사…‘최종 쇄신 보고서’ 보고” 박광온 더불어민주당 원내대표는 3일 개최가 예정된 의원총회와 관련, “쇄신 의총의 전 과정은 …
#
# 조선비즈
#
#
#
#
#
#
#
#
#
#
#
#
# 박광온 "집단지성 통해 국민 바라는 쇄신안 마련할 것"
# 기사내용 요약 의원 대상 심층설문조사·국민 대상 웹조사 실시 조사 결과 나온 주제들로 심층 토론 진행 예정 [서울=뉴시스] 박광온 더불어민주당 원내대표가 …
#
# 뉴시스
#
#
#
#
#
#
#
# 18개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 국민의힘 당원 2만여 명, 김재원 징계 반대 요구서 제출
# 국민의힘 중앙윤리위원회가 김재원 최고위원에 대한 징계 여부를 논의하는 가운데, 당원 2만여 명이 이를 반대하는 요구서를 오늘(3일) 제출했습니다. 송세달 …
#
# KBS
#
#
#
#
#
#
#
#
#
#
#
#
# 국민의힘 일부 당원들, 김재원 징계 반대 요구서 제출
# 잇단 설화로 논란을 빚은 김재원 최고위원에 대한 당 윤리위의 징계 결정을 앞두고, 국민의힘 일부 당원들이 징계를 반대하는 요구서를 당에 제출했습니다. 송 …
#
# MBC
#
#
#
#
#
#
#
# 14개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 이용 국힘 의원 "尹, 김건희 여사 남편 잘못 만나 고생한다고 생각"
# 윤석열 대통령이 ‘남편을 잘못 만나 고생하고 있다’며 부인 김건희 여사를 향한 미안한 마음을 측근에게 토로한 적이 있는 것으로 전해졌다. 이는 대선후보  …
#
# 서울경제
#
#
#
#
#
#
#
#
#
#
#
#
# ‘尹 수행실장’ 이용 “김건희, 다소곳하고 온순…尹이 미안해 해”
# 윤석열 대통령이 대선후보 및 당선인 시절까지 수행실장을 맡으며 1년여 동안 밀착 수행했던 국민의힘 이용 의원이 윤 대통령과 아내 김건희 여사에 대해 “서 …
#
# 동아일보
#
#
#
#
#
#
#
# 23개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 尹 "문재인, 중국에서 8끼나 혼밥…'외교적 결례'"
# 윤석열 대통령이 전날인 2일 국민의힘 지도부와의 만찬에서 문재인 전 대통령의 2017년 중국 방문 당시 이른바 '혼밥'에 대해 언급한 것으로 전해졌다.  …
#
# 매일신문
#
#
#
#
#
#
#
#
#
#
#
#
# 尹, 與지도부 만찬서 文 중국 방문 당시 '혼밥'에 "외교적 결례"
# 文정부, 친중정책 폈는데 중국에서 얻은 게 뭐 있나" 아쉬움 피력 '한미일 동맹 구축돼야 북·중이 함부로 못한다' 취지 발언도 윤석열 대통령이 국민의힘  …
#
# 연합뉴스
#
#
#
#
#
#
#
# 11개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 홍준표 “尹이 이재명 안 만나는 이유? 중대범죄 혐의자라서”
# 홍준표 대구시장은 3일 윤석열 대통령이 이재명 더불어민주당 대표와 만나지 않는 데 대해 "(이 대표가)중범죄로 기소된 피고인이기 때문"이라고 추측했다.  …
#
# 헤럴드경제
#
#
#
#
#
#
#
#
#
#
#
#
# 홍준표 “김재원·태영호, 어처구니 없는 자중지란…중징계 불가피”
# 홍준표 대구 시장은 3일 국민의힘 윤리위원회 징계 절차가 개시된 김재원·태영호 최고위원에 대해 “중징계가 불가피하다”고 말했다. 홍 시장은 이날 오전 자 …
#
# 헤럴드경제
#
#
#
#
#
#
#
# 16개의 관련뉴스 더보기
#
#
#
#
#
#
# 헤드라인 더보기
#
#
#
#
#
#
#
#
# 연재보기
# 박순찬의 장도리 카툰
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  윤윅
# 다 쓸어버린다! ⓒ 박순찬 윤석열 대통령의 미국 순방 후폭풍이 거세다. 확장억제 강화에 치중한 워싱턴 선언은 북·중·러의 반발을  …
#
# 오마이뉴스
#
#
#
#
#
#
# 오마이뉴스
#
#  날리맨
#
#
#
#
#
# 오마이뉴스
#
#  온다
#
#
#
#
#
# 오마이뉴스
#
#  한미일 동맹
#
#
#
#
#
#
#
#
#
#
# 뉴스 더보기
#
#
#
# AiRS추천으로 구성된 뉴스를 제공합니다.
#
#
#
#
#
#
# 안내헤드라인 뉴스
#
#
#                             헤드라인 뉴스와 각 기사묶음 타이틀은  기사 내용을 기반으로 자동 추출됩니다.
#
#
# 닫기
#
#
#
#
# 안내헤드라인 뉴스
#
#
#                             헤드라인 뉴스와 각 기사묶음 타이틀은  기사 내용을 기반으로 자동 추출됩니다.
#
#
# 닫기
#
#
#
#
#                             헤드라인 뉴스와 각 기사묶음 타이틀은  기사 내용을 기반으로 자동 추출됩니다.
#
#
# 닫기
#
#
#                             헤드라인 뉴스와 각 기사묶음 타이틀은  기사 내용을 기반으로 자동 추출됩니다.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 국회 정개특위, 선거제 개편 ‘500인 공론조사’ 실시…KBS 생중계
# 국회 정치개혁특별위원회(정개특위)는 오는 6일과 13일 양일간 500명의 시민참여단을 대상으로 국회의원 선거제도 개편에 대한 공론조사를 실시하고, KBS …
#
# KBS
#
#
#
#
#
#
# 이데일리
#
# `선거제 개편` 공론화 본격화…대표 시민 500인 토론
#
#
#
#
#
# 파이낸셜뉴스
#
# '선거제도, 국회의원이 아닌 국민이 결정하자' 정개특위, 시민 500명 참여 토론회 연다
#
#
#
#
#
# 매일경제
#
# 선거개편 공론화…시민참여단 500명 모여 토론한다
#
#
#
#
#
#
# 8개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 野 의원 독도 방문에 日 항의…외교부 “부당한 주장 일축”
# 정부는 3일 전용기 더불어민주당 의원의 독도 방문에 대한 일본 측 항의에 “일본 측의 부당한 주장은 외교 채널을 통해 일축했다”고 밝혔다. 외교부 당국자 …
#
# 조선비즈
#
#
#
#
#
#
# 서울경제
#
# 정부, "野 독도 방문 부당' 日항의에 "부당한 주장"
#
#
#
#
#
# 헤럴드경제
#
# 더불어민주당 경북도당 청년·대학생위 독도 현지서 ‘독도영유권수호 다짐’
#
#
#
#
#
# 노컷뉴스
#
# 韓의원 독도 방문에…日 "윤석열 정권에 대한 반발이냐"[이슈시개]
#
#
#
#
#
#
# 77개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# '태영호 녹취록'에 與 '산 넘어 산'…태영호 징계 수위에 영향은
# 이진복 대통령실 정무수석이 22대 총선 공천 문제를 거론하며 한일 관계에 대한 옹호 발언을 해달라고 요청했다는 태영호 국민의힘 최고위원의 녹취가 공개되면 …
#
# 뉴스1
#
#
#
#
#
#
# 시사저널
#
# '체리따봉'부터 '태영호 녹취록'까지, 용산 '당무 개입'은 이제 시작?
#
#
#
#
#
# JTBC
#
# '태영호 녹취록'에 국민의힘 발칵…당내서도 "불법 공천개입"
#
#
#
#
#
# 한국경제TV
#
# 대통령실 공천 개입? 태영호 녹취록 논란에 與 '선긋기'
#
#
#
#
#
#
# 82개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 장예찬 "태영호 녹취록, 일벌백계해야"… 김성태 "중징계감 아니야"
# 이른바 '공천 녹취록' 유출과 관련해 여당 내부에서 의견이 엇갈리고 있다. 장예찬 국민의힘 최고위원은 "누구든 일벌백계 읍참마속의 기조로 엄하게 다뤄야  …
#
# 머니S
#
#
#
#
#
#
# 한겨레
#
# 장예찬 “용산과 더 가까운 나도 공천 부탁 들은 적 없다”
#
#
#
#
#
# MBC
#
#  장예찬 "내가 태영호보다 대통령실과 더 가까운데.. 공천-부탁 들어본 적 없어" [시선집중]
#
#
#
#
#
# 파이낸셜뉴스
#
# 장예찬 "내가 태영호보다 대통령실과 더 가깝지만 공천‧부탁 들어본 적 없다"
#
#
#
#
#
#
# 9개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ‘돈 봉투 의혹’ 민주당 윤관석·이성만 의원 자진 탈당 결정
# '돈 봉투 의혹'에 휩싸인 더불어민주당 윤관석, 이성만 의원이 자진 탈당을 결정했습니다. 민주당 윤관석, 이성만 의원은 오늘(3일) 국회에서 비공개 최고 …
#
# KBS
#
#
#
#
#
#
#
#
#
#
#
#
# '돈봉투' 의혹 윤관석·이성만 민주당 탈당…"선당후사 마음으로..."
# ‘전당대회 돈봉투’ 논란과 윤관석·이성만 의원이 더불어민주당을 탈당하기로 했다. 윤 의원과 이 의원은 3일 민주당 지도부와 면담을 거친 뒤 기자들에게 탈 …
#
# 아시아경제
#
#
#
#
#
#
#
# 85개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# '야권 원로' 유인태, 국민의힘 친윤모임 국민공감서 특강
# 야권 원로 인사인 유인태 전 국회 사무총장이 국민의힘 내 친윤 그룹 공부 모임인 ‘국민공감’에서 특강을 진행한다. 유인태 전 국회사무총장(사진=연합뉴스) …
#
# 이데일리
#
#
#
#
#
#
#
#
#
#
#
#
# 野 원로 유인태, 與 공부모임 ‘국민공감’서 특강한다
# 야권 원로인 유인태 전 국회 사무총장이 국민의힘 내 친윤 그룹 공부모임인 ‘국민공감’에서 특강을 한다. 국민공감에 따르면 유 전 사무총장은 오는 9일 오 …
#
# 동아일보
#
#
#
#
#
#
#
# 11개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 이재명 "尹 정권 폭력적 탄압에 노동자 죽음 선택…대통령 사과하길"
# 이재명 더불어민주당 대표가 지난 2일 분신 시도 후 끝내 사망한 노동자를 두고 “윤석열 정권의 노조 탄압이 결국 소중한 생명을 앗아갔다”고 강하게 비판했 …
#
# 이데일리
#
#
#
#
#
#
#
#
#
#
#
#
# 이재명, 노조원 분신 사망에 "대통령에 원천 책임…사과해야"
# 최근 정부에 항의하며 분신한 건설노조 간부가 숨진 것과 관련, 이재명 더불어민주당 대표가 3일 "원천적 책임은 대통령에게 있다"며 "대통령에게 진솔한 사 …
#
# 머니투데이
#
#
#
#
#
#
#
# 30개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 상습적으로 임금 안 주는 사업주, 정부 지원사업 제한한다
# 3개월분 이상 체불하는 등 상습적으로 임금을 체불하면서 적극적인 청산노력을 기울이지 않는 사업주에 대해 형사처벌 외 경제적 제재가 추가된다. 이정식 고용 …
#
# 이데일리
#
#
#
#
#
#
#
#
#
#
#
#
# "임금 3개월 밀리면 신용제재"…'상습체불 근절대책'
# 임금을 3개월분 이상 상습적으로 체불하는 등 적극적인 청산노력을 기울이지 않는 사업주에 대해 신용제재와 정부지원 제한 등 경제적 제재가 강화된다. 고용노 …
#
# 아시아경제
#
#
#
#
#
#
#
# 36개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 민주 "기시다 총리 방한, 과거사 사과부터 받아야"
# 더불어민주당은 일본 기시다 총리가 오는 7일과 8일 방한한다는 정부 발표에 대해 "과거사 사과부터 받아야 한다"고 직격했다. 권칠승 수석대변인은 2일 논 …
#
# 뉴시스
#
#
#
#
#
#
#
#
# 동영상기사
#
#
#
#
# 대통령실 "기시다 7일 방한"…내일 안보실장 사전 회담
# 기시다 일본 총리가 오는 7일부터 1박 2일 일정으로 한국을 방문합니다. 내일(3일)은 두 나라 안보실장이 먼저 만나 정상회담에서 어떤 의제를 다룰지 논 …
#
# SBS
#
#
#
#
#
#
#
# 110개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
# 동영상기사
#
#
#
#
# 北 반발 수위 고조...한미 정상 겨냥 '화형식'까지
# 북한이 확장억제 강화 방안이 담긴 워싱턴 선언에 대해 한미 정상을 겨냥한 화형식까지 열며 반발 수위를 높이고 있습니다. 김여정의 막말 담화에 이은 비난  …
#
# YTN
#
#
#
#
#
#
#
#
#
#
#
#
# 北, 워싱턴선언 반발 수위 고조…한미 정상 겨냥 ‘화형식’ 진행
# 청년학생 ‘복수결의모임’ 2일 개최 “늙다리 전쟁괴수와 특등하수인의 추악한 몰골들이 재가루로…” 북한이 ‘워싱턴 선언’을 비난하는 청년학생 집회를 열고  …
#
# 세계일보
#
#
#
#
#
#
#
# 44개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 태영호 "비서관이 녹취록 유출? 허위사실"
# 태영호 국민의힘 최고위원이 녹취록 유출자로 자신의 보좌진이 의심받는 상황에 유감을 표했다. 2일 태 최고위원은 자신의 SNS 계정에 "현재 일부 유튜버들 …
#
# YTN
#
#
#
#
#
#
#
#
#
#
#
#
# "태영호 녹취록 유출자, 이들일 것"...유튜버들의 마녀사냥
# 태영호 국민의힘 최고위원은 녹취록 파문으로 자신의 보좌진이 유출자로 의심받는 상황에 강력 반발하며 유감을 표했습니다. 태 최고위원은 전날(2일) 밤 페이 …
#
# MBN
#
#
#
#
#
#
#
# 14개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 박광온 “오늘 의총서 국민이 바라는 쇄신방안 마련…향후 전원토론 실시”
# “모든 의원 대상 심층 설문조사…‘최종 쇄신 보고서’ 보고” 박광온 더불어민주당 원내대표는 3일 개최가 예정된 의원총회와 관련, “쇄신 의총의 전 과정은 …
#
# 조선비즈
#
#
#
#
#
#
#
#
#
#
#
#
# 박광온 "집단지성 통해 국민 바라는 쇄신안 마련할 것"
# 기사내용 요약 의원 대상 심층설문조사·국민 대상 웹조사 실시 조사 결과 나온 주제들로 심층 토론 진행 예정 [서울=뉴시스] 박광온 더불어민주당 원내대표가 …
#
# 뉴시스
#
#
#
#
#
#
#
# 18개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 국민의힘 당원 2만여 명, 김재원 징계 반대 요구서 제출
# 국민의힘 중앙윤리위원회가 김재원 최고위원에 대한 징계 여부를 논의하는 가운데, 당원 2만여 명이 이를 반대하는 요구서를 오늘(3일) 제출했습니다. 송세달 …
#
# KBS
#
#
#
#
#
#
#
#
#
#
#
#
# 국민의힘 일부 당원들, 김재원 징계 반대 요구서 제출
# 잇단 설화로 논란을 빚은 김재원 최고위원에 대한 당 윤리위의 징계 결정을 앞두고, 국민의힘 일부 당원들이 징계를 반대하는 요구서를 당에 제출했습니다. 송 …
#
# MBC
#
#
#
#
#
#
#
# 14개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 이용 국힘 의원 "尹, 김건희 여사 남편 잘못 만나 고생한다고 생각"
# 윤석열 대통령이 ‘남편을 잘못 만나 고생하고 있다’며 부인 김건희 여사를 향한 미안한 마음을 측근에게 토로한 적이 있는 것으로 전해졌다. 이는 대선후보  …
#
# 서울경제
#
#
#
#
#
#
#
#
#
#
#
#
# ‘尹 수행실장’ 이용 “김건희, 다소곳하고 온순…尹이 미안해 해”
# 윤석열 대통령이 대선후보 및 당선인 시절까지 수행실장을 맡으며 1년여 동안 밀착 수행했던 국민의힘 이용 의원이 윤 대통령과 아내 김건희 여사에 대해 “서 …
#
# 동아일보
#
#
#
#
#
#
#
# 23개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 尹 "문재인, 중국에서 8끼나 혼밥…'외교적 결례'"
# 윤석열 대통령이 전날인 2일 국민의힘 지도부와의 만찬에서 문재인 전 대통령의 2017년 중국 방문 당시 이른바 '혼밥'에 대해 언급한 것으로 전해졌다.  …
#
# 매일신문
#
#
#
#
#
#
#
#
#
#
#
#
# 尹, 與지도부 만찬서 文 중국 방문 당시 '혼밥'에 "외교적 결례"
# 文정부, 친중정책 폈는데 중국에서 얻은 게 뭐 있나" 아쉬움 피력 '한미일 동맹 구축돼야 북·중이 함부로 못한다' 취지 발언도 윤석열 대통령이 국민의힘  …
#
# 연합뉴스
#
#
#
#
#
#
#
# 11개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 홍준표 “尹이 이재명 안 만나는 이유? 중대범죄 혐의자라서”
# 홍준표 대구시장은 3일 윤석열 대통령이 이재명 더불어민주당 대표와 만나지 않는 데 대해 "(이 대표가)중범죄로 기소된 피고인이기 때문"이라고 추측했다.  …
#
# 헤럴드경제
#
#
#
#
#
#
#
#
#
#
#
#
# 홍준표 “김재원·태영호, 어처구니 없는 자중지란…중징계 불가피”
# 홍준표 대구 시장은 3일 국민의힘 윤리위원회 징계 절차가 개시된 김재원·태영호 최고위원에 대해 “중징계가 불가피하다”고 말했다. 홍 시장은 이날 오전 자 …
#
# 헤럴드경제
#
#
#
#
#
#
#
# 16개의 관련뉴스 더보기
#
#
#
#
#
#
# 헤드라인 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 국회 정개특위, 선거제 개편 ‘500인 공론조사’ 실시…KBS 생중계
# 국회 정치개혁특별위원회(정개특위)는 오는 6일과 13일 양일간 500명의 시민참여단을 대상으로 국회의원 선거제도 개편에 대한 공론조사를 실시하고, KBS …
#
# KBS
#
#
#
#
#
#
# 이데일리
#
# `선거제 개편` 공론화 본격화…대표 시민 500인 토론
#
#
#
#
#
# 파이낸셜뉴스
#
# '선거제도, 국회의원이 아닌 국민이 결정하자' 정개특위, 시민 500명 참여 토론회 연다
#
#
#
#
#
# 매일경제
#
# 선거개편 공론화…시민참여단 500명 모여 토론한다
#
#
#
#
#
#
# 8개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 野 의원 독도 방문에 日 항의…외교부 “부당한 주장 일축”
# 정부는 3일 전용기 더불어민주당 의원의 독도 방문에 대한 일본 측 항의에 “일본 측의 부당한 주장은 외교 채널을 통해 일축했다”고 밝혔다. 외교부 당국자 …
#
# 조선비즈
#
#
#
#
#
#
# 서울경제
#
# 정부, "野 독도 방문 부당' 日항의에 "부당한 주장"
#
#
#
#
#
# 헤럴드경제
#
# 더불어민주당 경북도당 청년·대학생위 독도 현지서 ‘독도영유권수호 다짐’
#
#
#
#
#
# 노컷뉴스
#
# 韓의원 독도 방문에…日 "윤석열 정권에 대한 반발이냐"[이슈시개]
#
#
#
#
#
#
# 77개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# '태영호 녹취록'에 與 '산 넘어 산'…태영호 징계 수위에 영향은
# 이진복 대통령실 정무수석이 22대 총선 공천 문제를 거론하며 한일 관계에 대한 옹호 발언을 해달라고 요청했다는 태영호 국민의힘 최고위원의 녹취가 공개되면 …
#
# 뉴스1
#
#
#
#
#
#
# 시사저널
#
# '체리따봉'부터 '태영호 녹취록'까지, 용산 '당무 개입'은 이제 시작?
#
#
#
#
#
# JTBC
#
# '태영호 녹취록'에 국민의힘 발칵…당내서도 "불법 공천개입"
#
#
#
#
#
# 한국경제TV
#
# 대통령실 공천 개입? 태영호 녹취록 논란에 與 '선긋기'
#
#
#
#
#
#
# 82개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 장예찬 "태영호 녹취록, 일벌백계해야"… 김성태 "중징계감 아니야"
# 이른바 '공천 녹취록' 유출과 관련해 여당 내부에서 의견이 엇갈리고 있다. 장예찬 국민의힘 최고위원은 "누구든 일벌백계 읍참마속의 기조로 엄하게 다뤄야  …
#
# 머니S
#
#
#
#
#
#
# 한겨레
#
# 장예찬 “용산과 더 가까운 나도 공천 부탁 들은 적 없다”
#
#
#
#
#
# MBC
#
#  장예찬 "내가 태영호보다 대통령실과 더 가까운데.. 공천-부탁 들어본 적 없어" [시선집중]
#
#
#
#
#
# 파이낸셜뉴스
#
# 장예찬 "내가 태영호보다 대통령실과 더 가깝지만 공천‧부탁 들어본 적 없다"
#
#
#
#
#
#
# 9개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ‘돈 봉투 의혹’ 민주당 윤관석·이성만 의원 자진 탈당 결정
# '돈 봉투 의혹'에 휩싸인 더불어민주당 윤관석, 이성만 의원이 자진 탈당을 결정했습니다. 민주당 윤관석, 이성만 의원은 오늘(3일) 국회에서 비공개 최고 …
#
# KBS
#
#
#
#
#
#
#
#
#
#
#
#
# '돈봉투' 의혹 윤관석·이성만 민주당 탈당…"선당후사 마음으로..."
# ‘전당대회 돈봉투’ 논란과 윤관석·이성만 의원이 더불어민주당을 탈당하기로 했다. 윤 의원과 이 의원은 3일 민주당 지도부와 면담을 거친 뒤 기자들에게 탈 …
#
# 아시아경제
#
#
#
#
#
#
#
# 85개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# '야권 원로' 유인태, 국민의힘 친윤모임 국민공감서 특강
# 야권 원로 인사인 유인태 전 국회 사무총장이 국민의힘 내 친윤 그룹 공부 모임인 ‘국민공감’에서 특강을 진행한다. 유인태 전 국회사무총장(사진=연합뉴스) …
#
# 이데일리
#
#
#
#
#
#
#
#
#
#
#
#
# 野 원로 유인태, 與 공부모임 ‘국민공감’서 특강한다
# 야권 원로인 유인태 전 국회 사무총장이 국민의힘 내 친윤 그룹 공부모임인 ‘국민공감’에서 특강을 한다. 국민공감에 따르면 유 전 사무총장은 오는 9일 오 …
#
# 동아일보
#
#
#
#
#
#
#
# 11개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 이재명 "尹 정권 폭력적 탄압에 노동자 죽음 선택…대통령 사과하길"
# 이재명 더불어민주당 대표가 지난 2일 분신 시도 후 끝내 사망한 노동자를 두고 “윤석열 정권의 노조 탄압이 결국 소중한 생명을 앗아갔다”고 강하게 비판했 …
#
# 이데일리
#
#
#
#
#
#
#
#
#
#
#
#
# 이재명, 노조원 분신 사망에 "대통령에 원천 책임…사과해야"
# 최근 정부에 항의하며 분신한 건설노조 간부가 숨진 것과 관련, 이재명 더불어민주당 대표가 3일 "원천적 책임은 대통령에게 있다"며 "대통령에게 진솔한 사 …
#
# 머니투데이
#
#
#
#
#
#
#
# 30개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 상습적으로 임금 안 주는 사업주, 정부 지원사업 제한한다
# 3개월분 이상 체불하는 등 상습적으로 임금을 체불하면서 적극적인 청산노력을 기울이지 않는 사업주에 대해 형사처벌 외 경제적 제재가 추가된다. 이정식 고용 …
#
# 이데일리
#
#
#
#
#
#
#
#
#
#
#
#
# "임금 3개월 밀리면 신용제재"…'상습체불 근절대책'
# 임금을 3개월분 이상 상습적으로 체불하는 등 적극적인 청산노력을 기울이지 않는 사업주에 대해 신용제재와 정부지원 제한 등 경제적 제재가 강화된다. 고용노 …
#
# 아시아경제
#
#
#
#
#
#
#
# 36개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 민주 "기시다 총리 방한, 과거사 사과부터 받아야"
# 더불어민주당은 일본 기시다 총리가 오는 7일과 8일 방한한다는 정부 발표에 대해 "과거사 사과부터 받아야 한다"고 직격했다. 권칠승 수석대변인은 2일 논 …
#
# 뉴시스
#
#
#
#
#
#
#
#
# 동영상기사
#
#
#
#
# 대통령실 "기시다 7일 방한"…내일 안보실장 사전 회담
# 기시다 일본 총리가 오는 7일부터 1박 2일 일정으로 한국을 방문합니다. 내일(3일)은 두 나라 안보실장이 먼저 만나 정상회담에서 어떤 의제를 다룰지 논 …
#
# SBS
#
#
#
#
#
#
#
# 110개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
# 동영상기사
#
#
#
#
# 北 반발 수위 고조...한미 정상 겨냥 '화형식'까지
# 북한이 확장억제 강화 방안이 담긴 워싱턴 선언에 대해 한미 정상을 겨냥한 화형식까지 열며 반발 수위를 높이고 있습니다. 김여정의 막말 담화에 이은 비난  …
#
# YTN
#
#
#
#
#
#
#
#
#
#
#
#
# 北, 워싱턴선언 반발 수위 고조…한미 정상 겨냥 ‘화형식’ 진행
# 청년학생 ‘복수결의모임’ 2일 개최 “늙다리 전쟁괴수와 특등하수인의 추악한 몰골들이 재가루로…” 북한이 ‘워싱턴 선언’을 비난하는 청년학생 집회를 열고  …
#
# 세계일보
#
#
#
#
#
#
#
# 44개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 태영호 "비서관이 녹취록 유출? 허위사실"
# 태영호 국민의힘 최고위원이 녹취록 유출자로 자신의 보좌진이 의심받는 상황에 유감을 표했다. 2일 태 최고위원은 자신의 SNS 계정에 "현재 일부 유튜버들 …
#
# YTN
#
#
#
#
#
#
#
#
#
#
#
#
# "태영호 녹취록 유출자, 이들일 것"...유튜버들의 마녀사냥
# 태영호 국민의힘 최고위원은 녹취록 파문으로 자신의 보좌진이 유출자로 의심받는 상황에 강력 반발하며 유감을 표했습니다. 태 최고위원은 전날(2일) 밤 페이 …
#
# MBN
#
#
#
#
#
#
#
# 14개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 박광온 “오늘 의총서 국민이 바라는 쇄신방안 마련…향후 전원토론 실시”
# “모든 의원 대상 심층 설문조사…‘최종 쇄신 보고서’ 보고” 박광온 더불어민주당 원내대표는 3일 개최가 예정된 의원총회와 관련, “쇄신 의총의 전 과정은 …
#
# 조선비즈
#
#
#
#
#
#
#
#
#
#
#
#
# 박광온 "집단지성 통해 국민 바라는 쇄신안 마련할 것"
# 기사내용 요약 의원 대상 심층설문조사·국민 대상 웹조사 실시 조사 결과 나온 주제들로 심층 토론 진행 예정 [서울=뉴시스] 박광온 더불어민주당 원내대표가 …
#
# 뉴시스
#
#
#
#
#
#
#
# 18개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 국민의힘 당원 2만여 명, 김재원 징계 반대 요구서 제출
# 국민의힘 중앙윤리위원회가 김재원 최고위원에 대한 징계 여부를 논의하는 가운데, 당원 2만여 명이 이를 반대하는 요구서를 오늘(3일) 제출했습니다. 송세달 …
#
# KBS
#
#
#
#
#
#
#
#
#
#
#
#
# 국민의힘 일부 당원들, 김재원 징계 반대 요구서 제출
# 잇단 설화로 논란을 빚은 김재원 최고위원에 대한 당 윤리위의 징계 결정을 앞두고, 국민의힘 일부 당원들이 징계를 반대하는 요구서를 당에 제출했습니다. 송 …
#
# MBC
#
#
#
#
#
#
#
# 14개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 이용 국힘 의원 "尹, 김건희 여사 남편 잘못 만나 고생한다고 생각"
# 윤석열 대통령이 ‘남편을 잘못 만나 고생하고 있다’며 부인 김건희 여사를 향한 미안한 마음을 측근에게 토로한 적이 있는 것으로 전해졌다. 이는 대선후보  …
#
# 서울경제
#
#
#
#
#
#
#
#
#
#
#
#
# ‘尹 수행실장’ 이용 “김건희, 다소곳하고 온순…尹이 미안해 해”
# 윤석열 대통령이 대선후보 및 당선인 시절까지 수행실장을 맡으며 1년여 동안 밀착 수행했던 국민의힘 이용 의원이 윤 대통령과 아내 김건희 여사에 대해 “서 …
#
# 동아일보
#
#
#
#
#
#
#
# 23개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 尹 "문재인, 중국에서 8끼나 혼밥…'외교적 결례'"
# 윤석열 대통령이 전날인 2일 국민의힘 지도부와의 만찬에서 문재인 전 대통령의 2017년 중국 방문 당시 이른바 '혼밥'에 대해 언급한 것으로 전해졌다.  …
#
# 매일신문
#
#
#
#
#
#
#
#
#
#
#
#
# 尹, 與지도부 만찬서 文 중국 방문 당시 '혼밥'에 "외교적 결례"
# 文정부, 친중정책 폈는데 중국에서 얻은 게 뭐 있나" 아쉬움 피력 '한미일 동맹 구축돼야 북·중이 함부로 못한다' 취지 발언도 윤석열 대통령이 국민의힘  …
#
# 연합뉴스
#
#
#
#
#
#
#
# 11개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 홍준표 “尹이 이재명 안 만나는 이유? 중대범죄 혐의자라서”
# 홍준표 대구시장은 3일 윤석열 대통령이 이재명 더불어민주당 대표와 만나지 않는 데 대해 "(이 대표가)중범죄로 기소된 피고인이기 때문"이라고 추측했다.  …
#
# 헤럴드경제
#
#
#
#
#
#
#
#
#
#
#
#
# 홍준표 “김재원·태영호, 어처구니 없는 자중지란…중징계 불가피”
# 홍준표 대구 시장은 3일 국민의힘 윤리위원회 징계 절차가 개시된 김재원·태영호 최고위원에 대해 “중징계가 불가피하다”고 말했다. 홍 시장은 이날 오전 자 …
#
# 헤럴드경제
#
#
#
#
#
#
#
# 16개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 국회 정개특위, 선거제 개편 ‘500인 공론조사’ 실시…KBS 생중계
# 국회 정치개혁특별위원회(정개특위)는 오는 6일과 13일 양일간 500명의 시민참여단을 대상으로 국회의원 선거제도 개편에 대한 공론조사를 실시하고, KBS …
#
# KBS
#
#
#
#
#
#
# 이데일리
#
# `선거제 개편` 공론화 본격화…대표 시민 500인 토론
#
#
#
#
#
# 파이낸셜뉴스
#
# '선거제도, 국회의원이 아닌 국민이 결정하자' 정개특위, 시민 500명 참여 토론회 연다
#
#
#
#
#
# 매일경제
#
# 선거개편 공론화…시민참여단 500명 모여 토론한다
#
#
#
#
#
#
# 8개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 국회 정개특위, 선거제 개편 ‘500인 공론조사’ 실시…KBS 생중계
# 국회 정치개혁특별위원회(정개특위)는 오는 6일과 13일 양일간 500명의 시민참여단을 대상으로 국회의원 선거제도 개편에 대한 공론조사를 실시하고, KBS …
#
# KBS
#
#
#
#
#
#
# 이데일리
#
# `선거제 개편` 공론화 본격화…대표 시민 500인 토론
#
#
#
#
#
# 파이낸셜뉴스
#
# '선거제도, 국회의원이 아닌 국민이 결정하자' 정개특위, 시민 500명 참여 토론회 연다
#
#
#
#
#
# 매일경제
#
# 선거개편 공론화…시민참여단 500명 모여 토론한다
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 국회 정개특위, 선거제 개편 ‘500인 공론조사’ 실시…KBS 생중계
# 국회 정치개혁특별위원회(정개특위)는 오는 6일과 13일 양일간 500명의 시민참여단을 대상으로 국회의원 선거제도 개편에 대한 공론조사를 실시하고, KBS …
#
# KBS
#
#
# 국회 정치개혁특별위원회(정개특위)는 오는 6일과 13일 양일간 500명의 시민참여단을 대상으로 국회의원 선거제도 개편에 대한 공론조사를 실시하고, KBS …
#
# KBS
#
# KBS
#
#
# 이데일리
#
# `선거제 개편` 공론화 본격화…대표 시민 500인 토론
#
#
# 이데일리
#
# 이데일리
#
#
# 파이낸셜뉴스
#
# '선거제도, 국회의원이 아닌 국민이 결정하자' 정개특위, 시민 500명 참여 토론회 연다
#
#
# 파이낸셜뉴스
#
# 파이낸셜뉴스
#
#
# 매일경제
#
# 선거개편 공론화…시민참여단 500명 모여 토론한다
#
#
# 매일경제
#
# 매일경제
#
#
# 8개의 관련뉴스 더보기
#
#
#
# 8개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
# 野 의원 독도 방문에 日 항의…외교부 “부당한 주장 일축”
# 정부는 3일 전용기 더불어민주당 의원의 독도 방문에 대한 일본 측 항의에 “일본 측의 부당한 주장은 외교 채널을 통해 일축했다”고 밝혔다. 외교부 당국자 …
#
# 조선비즈
#
#
#
#
#
#
# 서울경제
#
# 정부, "野 독도 방문 부당' 日항의에 "부당한 주장"
#
#
#
#
#
# 헤럴드경제
#
# 더불어민주당 경북도당 청년·대학생위 독도 현지서 ‘독도영유권수호 다짐’
#
#
#
#
#
# 노컷뉴스
#
# 韓의원 독도 방문에…日 "윤석열 정권에 대한 반발이냐"[이슈시개]
#
#
#
#
#
#
# 77개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 野 의원 독도 방문에 日 항의…외교부 “부당한 주장 일축”
# 정부는 3일 전용기 더불어민주당 의원의 독도 방문에 대한 일본 측 항의에 “일본 측의 부당한 주장은 외교 채널을 통해 일축했다”고 밝혔다. 외교부 당국자 …
#
# 조선비즈
#
#
#
#
#
#
# 서울경제
#
# 정부, "野 독도 방문 부당' 日항의에 "부당한 주장"
#
#
#
#
#
# 헤럴드경제
#
# 더불어민주당 경북도당 청년·대학생위 독도 현지서 ‘독도영유권수호 다짐’
#
#
#
#
#
# 노컷뉴스
#
# 韓의원 독도 방문에…日 "윤석열 정권에 대한 반발이냐"[이슈시개]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 野 의원 독도 방문에 日 항의…외교부 “부당한 주장 일축”
# 정부는 3일 전용기 더불어민주당 의원의 독도 방문에 대한 일본 측 항의에 “일본 측의 부당한 주장은 외교 채널을 통해 일축했다”고 밝혔다. 외교부 당국자 …
#
# 조선비즈
#
#
# 정부는 3일 전용기 더불어민주당 의원의 독도 방문에 대한 일본 측 항의에 “일본 측의 부당한 주장은 외교 채널을 통해 일축했다”고 밝혔다. 외교부 당국자 …
#
# 조선비즈
#
# 조선비즈
#
#
# 서울경제
#
# 정부, "野 독도 방문 부당' 日항의에 "부당한 주장"
#
#
# 서울경제
#
# 서울경제
#
#
# 헤럴드경제
#
# 더불어민주당 경북도당 청년·대학생위 독도 현지서 ‘독도영유권수호 다짐’
#
#
# 헤럴드경제
#
# 헤럴드경제
#
#
# 노컷뉴스
#
# 韓의원 독도 방문에…日 "윤석열 정권에 대한 반발이냐"[이슈시개]
#
#
# 노컷뉴스
#
# 노컷뉴스
#
#
# 77개의 관련뉴스 더보기
#
#
#
# 77개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
# '태영호 녹취록'에 與 '산 넘어 산'…태영호 징계 수위에 영향은
# 이진복 대통령실 정무수석이 22대 총선 공천 문제를 거론하며 한일 관계에 대한 옹호 발언을 해달라고 요청했다는 태영호 국민의힘 최고위원의 녹취가 공개되면 …
#
# 뉴스1
#
#
#
#
#
#
# 시사저널
#
# '체리따봉'부터 '태영호 녹취록'까지, 용산 '당무 개입'은 이제 시작?
#
#
#
#
#
# JTBC
#
# '태영호 녹취록'에 국민의힘 발칵…당내서도 "불법 공천개입"
#
#
#
#
#
# 한국경제TV
#
# 대통령실 공천 개입? 태영호 녹취록 논란에 與 '선긋기'
#
#
#
#
#
#
# 82개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# '태영호 녹취록'에 與 '산 넘어 산'…태영호 징계 수위에 영향은
# 이진복 대통령실 정무수석이 22대 총선 공천 문제를 거론하며 한일 관계에 대한 옹호 발언을 해달라고 요청했다는 태영호 국민의힘 최고위원의 녹취가 공개되면 …
#
# 뉴스1
#
#
#
#
#
#
# 시사저널
#
# '체리따봉'부터 '태영호 녹취록'까지, 용산 '당무 개입'은 이제 시작?
#
#
#
#
#
# JTBC
#
# '태영호 녹취록'에 국민의힘 발칵…당내서도 "불법 공천개입"
#
#
#
#
#
# 한국경제TV
#
# 대통령실 공천 개입? 태영호 녹취록 논란에 與 '선긋기'
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# '태영호 녹취록'에 與 '산 넘어 산'…태영호 징계 수위에 영향은
# 이진복 대통령실 정무수석이 22대 총선 공천 문제를 거론하며 한일 관계에 대한 옹호 발언을 해달라고 요청했다는 태영호 국민의힘 최고위원의 녹취가 공개되면 …
#
# 뉴스1
#
#
# 이진복 대통령실 정무수석이 22대 총선 공천 문제를 거론하며 한일 관계에 대한 옹호 발언을 해달라고 요청했다는 태영호 국민의힘 최고위원의 녹취가 공개되면 …
#
# 뉴스1
#
# 뉴스1
#
#
# 시사저널
#
# '체리따봉'부터 '태영호 녹취록'까지, 용산 '당무 개입'은 이제 시작?
#
#
# 시사저널
#
# 시사저널
#
#
# JTBC
#
# '태영호 녹취록'에 국민의힘 발칵…당내서도 "불법 공천개입"
#
#
# JTBC
#
# JTBC
#
#
# 한국경제TV
#
# 대통령실 공천 개입? 태영호 녹취록 논란에 與 '선긋기'
#
#
# 한국경제TV
#
# 한국경제TV
#
#
# 82개의 관련뉴스 더보기
#
#
#
# 82개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
# 장예찬 "태영호 녹취록, 일벌백계해야"… 김성태 "중징계감 아니야"
# 이른바 '공천 녹취록' 유출과 관련해 여당 내부에서 의견이 엇갈리고 있다. 장예찬 국민의힘 최고위원은 "누구든 일벌백계 읍참마속의 기조로 엄하게 다뤄야  …
#
# 머니S
#
#
#
#
#
#
# 한겨레
#
# 장예찬 “용산과 더 가까운 나도 공천 부탁 들은 적 없다”
#
#
#
#
#
# MBC
#
#  장예찬 "내가 태영호보다 대통령실과 더 가까운데.. 공천-부탁 들어본 적 없어" [시선집중]
#
#
#
#
#
# 파이낸셜뉴스
#
# 장예찬 "내가 태영호보다 대통령실과 더 가깝지만 공천‧부탁 들어본 적 없다"
#
#
#
#
#
#
# 9개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 장예찬 "태영호 녹취록, 일벌백계해야"… 김성태 "중징계감 아니야"
# 이른바 '공천 녹취록' 유출과 관련해 여당 내부에서 의견이 엇갈리고 있다. 장예찬 국민의힘 최고위원은 "누구든 일벌백계 읍참마속의 기조로 엄하게 다뤄야  …
#
# 머니S
#
#
#
#
#
#
# 한겨레
#
# 장예찬 “용산과 더 가까운 나도 공천 부탁 들은 적 없다”
#
#
#
#
#
# MBC
#
#  장예찬 "내가 태영호보다 대통령실과 더 가까운데.. 공천-부탁 들어본 적 없어" [시선집중]
#
#
#
#
#
# 파이낸셜뉴스
#
# 장예찬 "내가 태영호보다 대통령실과 더 가깝지만 공천‧부탁 들어본 적 없다"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 장예찬 "태영호 녹취록, 일벌백계해야"… 김성태 "중징계감 아니야"
# 이른바 '공천 녹취록' 유출과 관련해 여당 내부에서 의견이 엇갈리고 있다. 장예찬 국민의힘 최고위원은 "누구든 일벌백계 읍참마속의 기조로 엄하게 다뤄야  …
#
# 머니S
#
#
# 이른바 '공천 녹취록' 유출과 관련해 여당 내부에서 의견이 엇갈리고 있다. 장예찬 국민의힘 최고위원은 "누구든 일벌백계 읍참마속의 기조로 엄하게 다뤄야  …
#
# 머니S
#
# 머니S
#
#
# 한겨레
#
# 장예찬 “용산과 더 가까운 나도 공천 부탁 들은 적 없다”
#
#
# 한겨레
#
# 한겨레
#
#
# MBC
#
#  장예찬 "내가 태영호보다 대통령실과 더 가까운데.. 공천-부탁 들어본 적 없어" [시선집중]
#
#
# MBC
#
# MBC
#
#
# 파이낸셜뉴스
#
# 장예찬 "내가 태영호보다 대통령실과 더 가깝지만 공천‧부탁 들어본 적 없다"
#
#
# 파이낸셜뉴스
#
# 파이낸셜뉴스
#
#
# 9개의 관련뉴스 더보기
#
#
#
# 9개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
# ‘돈 봉투 의혹’ 민주당 윤관석·이성만 의원 자진 탈당 결정
# '돈 봉투 의혹'에 휩싸인 더불어민주당 윤관석, 이성만 의원이 자진 탈당을 결정했습니다. 민주당 윤관석, 이성만 의원은 오늘(3일) 국회에서 비공개 최고 …
#
# KBS
#
#
#
#
#
#
#
#
#
#
#
#
# '돈봉투' 의혹 윤관석·이성만 민주당 탈당…"선당후사 마음으로..."
# ‘전당대회 돈봉투’ 논란과 윤관석·이성만 의원이 더불어민주당을 탈당하기로 했다. 윤 의원과 이 의원은 3일 민주당 지도부와 면담을 거친 뒤 기자들에게 탈 …
#
# 아시아경제
#
#
#
#
#
#
#
# 85개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ‘돈 봉투 의혹’ 민주당 윤관석·이성만 의원 자진 탈당 결정
# '돈 봉투 의혹'에 휩싸인 더불어민주당 윤관석, 이성만 의원이 자진 탈당을 결정했습니다. 민주당 윤관석, 이성만 의원은 오늘(3일) 국회에서 비공개 최고 …
#
# KBS
#
#
#
#
#
#
#
#
#
#
#
#
# '돈봉투' 의혹 윤관석·이성만 민주당 탈당…"선당후사 마음으로..."
# ‘전당대회 돈봉투’ 논란과 윤관석·이성만 의원이 더불어민주당을 탈당하기로 했다. 윤 의원과 이 의원은 3일 민주당 지도부와 면담을 거친 뒤 기자들에게 탈 …
#
# 아시아경제
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ‘돈 봉투 의혹’ 민주당 윤관석·이성만 의원 자진 탈당 결정
# '돈 봉투 의혹'에 휩싸인 더불어민주당 윤관석, 이성만 의원이 자진 탈당을 결정했습니다. 민주당 윤관석, 이성만 의원은 오늘(3일) 국회에서 비공개 최고 …
#
# KBS
#
#
# '돈 봉투 의혹'에 휩싸인 더불어민주당 윤관석, 이성만 의원이 자진 탈당을 결정했습니다. 민주당 윤관석, 이성만 의원은 오늘(3일) 국회에서 비공개 최고 …
#
# KBS
#
# KBS
#
#
#
#
#
#
#
#
#
#
#
#
#
# '돈봉투' 의혹 윤관석·이성만 민주당 탈당…"선당후사 마음으로..."
# ‘전당대회 돈봉투’ 논란과 윤관석·이성만 의원이 더불어민주당을 탈당하기로 했다. 윤 의원과 이 의원은 3일 민주당 지도부와 면담을 거친 뒤 기자들에게 탈 …
#
# 아시아경제
#
#
# ‘전당대회 돈봉투’ 논란과 윤관석·이성만 의원이 더불어민주당을 탈당하기로 했다. 윤 의원과 이 의원은 3일 민주당 지도부와 면담을 거친 뒤 기자들에게 탈 …
#
# 아시아경제
#
# 아시아경제
#
#
# 85개의 관련뉴스 더보기
#
#
#
# 85개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
# '야권 원로' 유인태, 국민의힘 친윤모임 국민공감서 특강
# 야권 원로 인사인 유인태 전 국회 사무총장이 국민의힘 내 친윤 그룹 공부 모임인 ‘국민공감’에서 특강을 진행한다. 유인태 전 국회사무총장(사진=연합뉴스) …
#
# 이데일리
#
#
#
#
#
#
#
#
#
#
#
#
# 野 원로 유인태, 與 공부모임 ‘국민공감’서 특강한다
# 야권 원로인 유인태 전 국회 사무총장이 국민의힘 내 친윤 그룹 공부모임인 ‘국민공감’에서 특강을 한다. 국민공감에 따르면 유 전 사무총장은 오는 9일 오 …
#
# 동아일보
#
#
#
#
#
#
#
# 11개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# '야권 원로' 유인태, 국민의힘 친윤모임 국민공감서 특강
# 야권 원로 인사인 유인태 전 국회 사무총장이 국민의힘 내 친윤 그룹 공부 모임인 ‘국민공감’에서 특강을 진행한다. 유인태 전 국회사무총장(사진=연합뉴스) …
#
# 이데일리
#
#
#
#
#
#
#
#
#
#
#
#
# 野 원로 유인태, 與 공부모임 ‘국민공감’서 특강한다
# 야권 원로인 유인태 전 국회 사무총장이 국민의힘 내 친윤 그룹 공부모임인 ‘국민공감’에서 특강을 한다. 국민공감에 따르면 유 전 사무총장은 오는 9일 오 …
#
# 동아일보
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# '야권 원로' 유인태, 국민의힘 친윤모임 국민공감서 특강
# 야권 원로 인사인 유인태 전 국회 사무총장이 국민의힘 내 친윤 그룹 공부 모임인 ‘국민공감’에서 특강을 진행한다. 유인태 전 국회사무총장(사진=연합뉴스) …
#
# 이데일리
#
#
# 야권 원로 인사인 유인태 전 국회 사무총장이 국민의힘 내 친윤 그룹 공부 모임인 ‘국민공감’에서 특강을 진행한다. 유인태 전 국회사무총장(사진=연합뉴스) …
#
# 이데일리
#
# 이데일리
#
#
#
#
#
#
#
#
#
#
#
#
#
# 野 원로 유인태, 與 공부모임 ‘국민공감’서 특강한다
# 야권 원로인 유인태 전 국회 사무총장이 국민의힘 내 친윤 그룹 공부모임인 ‘국민공감’에서 특강을 한다. 국민공감에 따르면 유 전 사무총장은 오는 9일 오 …
#
# 동아일보
#
#
# 야권 원로인 유인태 전 국회 사무총장이 국민의힘 내 친윤 그룹 공부모임인 ‘국민공감’에서 특강을 한다. 국민공감에 따르면 유 전 사무총장은 오는 9일 오 …
#
# 동아일보
#
# 동아일보
#
#
# 11개의 관련뉴스 더보기
#
#
#
# 11개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
# 이재명 "尹 정권 폭력적 탄압에 노동자 죽음 선택…대통령 사과하길"
# 이재명 더불어민주당 대표가 지난 2일 분신 시도 후 끝내 사망한 노동자를 두고 “윤석열 정권의 노조 탄압이 결국 소중한 생명을 앗아갔다”고 강하게 비판했 …
#
# 이데일리
#
#
#
#
#
#
#
#
#
#
#
#
# 이재명, 노조원 분신 사망에 "대통령에 원천 책임…사과해야"
# 최근 정부에 항의하며 분신한 건설노조 간부가 숨진 것과 관련, 이재명 더불어민주당 대표가 3일 "원천적 책임은 대통령에게 있다"며 "대통령에게 진솔한 사 …
#
# 머니투데이
#
#
#
#
#
#
#
# 30개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 이재명 "尹 정권 폭력적 탄압에 노동자 죽음 선택…대통령 사과하길"
# 이재명 더불어민주당 대표가 지난 2일 분신 시도 후 끝내 사망한 노동자를 두고 “윤석열 정권의 노조 탄압이 결국 소중한 생명을 앗아갔다”고 강하게 비판했 …
#
# 이데일리
#
#
#
#
#
#
#
#
#
#
#
#
# 이재명, 노조원 분신 사망에 "대통령에 원천 책임…사과해야"
# 최근 정부에 항의하며 분신한 건설노조 간부가 숨진 것과 관련, 이재명 더불어민주당 대표가 3일 "원천적 책임은 대통령에게 있다"며 "대통령에게 진솔한 사 …
#
# 머니투데이
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 이재명 "尹 정권 폭력적 탄압에 노동자 죽음 선택…대통령 사과하길"
# 이재명 더불어민주당 대표가 지난 2일 분신 시도 후 끝내 사망한 노동자를 두고 “윤석열 정권의 노조 탄압이 결국 소중한 생명을 앗아갔다”고 강하게 비판했 …
#
# 이데일리
#
#
# 이재명 더불어민주당 대표가 지난 2일 분신 시도 후 끝내 사망한 노동자를 두고 “윤석열 정권의 노조 탄압이 결국 소중한 생명을 앗아갔다”고 강하게 비판했 …
#
# 이데일리
#
# 이데일리
#
#
#
#
#
#
#
#
#
#
#
#
#
# 이재명, 노조원 분신 사망에 "대통령에 원천 책임…사과해야"
# 최근 정부에 항의하며 분신한 건설노조 간부가 숨진 것과 관련, 이재명 더불어민주당 대표가 3일 "원천적 책임은 대통령에게 있다"며 "대통령에게 진솔한 사 …
#
# 머니투데이
#
#
# 최근 정부에 항의하며 분신한 건설노조 간부가 숨진 것과 관련, 이재명 더불어민주당 대표가 3일 "원천적 책임은 대통령에게 있다"며 "대통령에게 진솔한 사 …
#
# 머니투데이
#
# 머니투데이
#
#
# 30개의 관련뉴스 더보기
#
#
#
# 30개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
# 상습적으로 임금 안 주는 사업주, 정부 지원사업 제한한다
# 3개월분 이상 체불하는 등 상습적으로 임금을 체불하면서 적극적인 청산노력을 기울이지 않는 사업주에 대해 형사처벌 외 경제적 제재가 추가된다. 이정식 고용 …
#
# 이데일리
#
#
#
#
#
#
#
#
#
#
#
#
# "임금 3개월 밀리면 신용제재"…'상습체불 근절대책'
# 임금을 3개월분 이상 상습적으로 체불하는 등 적극적인 청산노력을 기울이지 않는 사업주에 대해 신용제재와 정부지원 제한 등 경제적 제재가 강화된다. 고용노 …
#
# 아시아경제
#
#
#
#
#
#
#
# 36개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 상습적으로 임금 안 주는 사업주, 정부 지원사업 제한한다
# 3개월분 이상 체불하는 등 상습적으로 임금을 체불하면서 적극적인 청산노력을 기울이지 않는 사업주에 대해 형사처벌 외 경제적 제재가 추가된다. 이정식 고용 …
#
# 이데일리
#
#
#
#
#
#
#
#
#
#
#
#
# "임금 3개월 밀리면 신용제재"…'상습체불 근절대책'
# 임금을 3개월분 이상 상습적으로 체불하는 등 적극적인 청산노력을 기울이지 않는 사업주에 대해 신용제재와 정부지원 제한 등 경제적 제재가 강화된다. 고용노 …
#
# 아시아경제
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 상습적으로 임금 안 주는 사업주, 정부 지원사업 제한한다
# 3개월분 이상 체불하는 등 상습적으로 임금을 체불하면서 적극적인 청산노력을 기울이지 않는 사업주에 대해 형사처벌 외 경제적 제재가 추가된다. 이정식 고용 …
#
# 이데일리
#
#
# 3개월분 이상 체불하는 등 상습적으로 임금을 체불하면서 적극적인 청산노력을 기울이지 않는 사업주에 대해 형사처벌 외 경제적 제재가 추가된다. 이정식 고용 …
#
# 이데일리
#
# 이데일리
#
#
#
#
#
#
#
#
#
#
#
#
#
# "임금 3개월 밀리면 신용제재"…'상습체불 근절대책'
# 임금을 3개월분 이상 상습적으로 체불하는 등 적극적인 청산노력을 기울이지 않는 사업주에 대해 신용제재와 정부지원 제한 등 경제적 제재가 강화된다. 고용노 …
#
# 아시아경제
#
#
# 임금을 3개월분 이상 상습적으로 체불하는 등 적극적인 청산노력을 기울이지 않는 사업주에 대해 신용제재와 정부지원 제한 등 경제적 제재가 강화된다. 고용노 …
#
# 아시아경제
#
# 아시아경제
#
#
# 36개의 관련뉴스 더보기
#
#
#
# 36개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
# 민주 "기시다 총리 방한, 과거사 사과부터 받아야"
# 더불어민주당은 일본 기시다 총리가 오는 7일과 8일 방한한다는 정부 발표에 대해 "과거사 사과부터 받아야 한다"고 직격했다. 권칠승 수석대변인은 2일 논 …
#
# 뉴시스
#
#
#
#
#
#
#
#
# 동영상기사
#
#
#
#
# 대통령실 "기시다 7일 방한"…내일 안보실장 사전 회담
# 기시다 일본 총리가 오는 7일부터 1박 2일 일정으로 한국을 방문합니다. 내일(3일)은 두 나라 안보실장이 먼저 만나 정상회담에서 어떤 의제를 다룰지 논 …
#
# SBS
#
#
#
#
#
#
#
# 110개의 관련뉴스 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 민주 "기시다 총리 방한, 과거사 사과부터 받아야"
# 더불어민주당은 일본 기시다 총리가 오는 7일과 8일 방한한다는 정부 발표에 대해 "과거사 사과부터 받아야 한다"고 직격했다. 권칠승 수석대변인은 2일 논 …
#
# 뉴시스
#
#
#
#
#
#
#
#
# 동영상기사
#
#
#
#
# 대통령실 "기시다 7일 방한"…내일 안보실장 사전 회담
# 기시다 일본 총리가 오는 7일부터 1박 2일 일정으로 한국을 방문합니다. 내일(3일)은 두 나라 안보실장이 먼저 만나 정상회담에서 어떤 의제를 다룰지 논 …
#
# SBS
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 민주 "기시다 총리 방한, 과거사 사과부터 받아야"
# 더불어민주당은 일본 기시다 총리가 오는 7일과 8일 방한한다는 정부 발표에 대해 "과거사 사과부터 받아야 한다"고 직격했다. 권칠승 수석대변인은 2일 논 …
#
# 뉴시스
#
#
# 더불어민주당은 일본 기시다 총리가 오는 7일과 8일 방한한다는 정부 발표에 대해 "과거사 사과부터 받아야 한다"고 직격했다. 권칠승 수석대변인은 2일 논 …
#
# 뉴시스
#
# 뉴시스
#
#
#
#
# ...
#
#
#
#
#
#
#
#
#
#
#
# 신부 이어 목사 1000명 시국선언…“윤석열 운명 다했다”
# 한겨레
#
#
#
#
#
#
#
#
#
#
#
# "인어 몸매가 왜 이래" 조각상에 발칵 뒤집힌 이탈리아
# 아시아경제
#
#
#
#
#
#
#
# 동영상기사
#
#
#
#
# "10분 만에 25억 꽂혔다"‥임창정, 계좌 공개하며 '결 …
# MBC
#
#
#
#
#
#
#
#
#
# 동영상기사
#
#
#
#
# [단독] “깔렸다고” “밀지 마” 민노총 집회서 경찰 밀어 …
# 조선일보
#
#
#
#
#
#
#
#
#
#
#
# 공무원 인기 떨어졌다…완전자본잠식 빠진 에듀윌
# 이데일리
#
#
#
#
#
#
#
# 동영상기사
#
#
#
#
# 해고 당했는데 ‘자진 퇴사’라니…실업급여도 막막 [5인미만 …
# KBS
#
#
#
#
#
#
#
# 동영상기사
#
#
#
#
# [날씨] 중부 초여름 더위…내일 전국 '비소식'
# 연합뉴스TV
#
#
#
#
#
#
#
#
#
#
#
# "나도 피해자" 임창정, 주가조작단 美골프장 계약자리 동행
# 디지털타임스
#
#
#
#
#
#
#
#
#
#
#
#
#
# 국내 언론이 본 한미정상회담… "동맹은 격상, 경제 성과  …
# 기자협회보
#
#
#
#
#
#
#
#
#
#
#
# 日 유명 개그맨이 韓 시장에서 보인 돌발 행동...일본 사 …
# YTN
#
#
#
#
#
#
#
#
#
#
#
# 32년째 행방불명 아나운서...어디로 갔나
# MBN
#
#
#
#
#
#
#
#
#
#
#
# [단독]'돈세탁' 의혹 유명 유튜버 헬스장에 '수상한' 사 …
# 뉴스1
#
#
#
#
#
#
#
#
#
#
#
# 백윤식, 전 연인 ‘폭로 에세이’ 출판·판매금지 소송서 일 …
# 경향신문
#
#
#
#
#
#
#
#
#
#
#
#
#
# “한강변 49층이요? 35층 하시죠” 반포 재건축 초고층  …
# 헤럴드경제
#
#
#
#
#
#
#
#
#
#
#
# 메스 들고 허벅지 정맥 도려낸 '김 선생'... 그의 정체 …
# 한국일보
#
#
#
#
#
#
#
#
#
#
#
# 영영 못 찾을 줄 알았던 카메라가 다시 내 손에…“한국,  …
# 세계일보
#
#
#
#
#
#
#
#
#
#
#
# ‘부촌’ 명성 고개 드나… 달맞이고개 100억 빌라 들어선 …
# 부산일보
#
#
#
#
#
#
#
#
#
#
#
# [영상] 속도 감당 못한 페라리가 들이받은 닛산…하늘로 ‘ …
# 문화일보
#
#
#
#
#
#
#
#
#
#
#
#
#
# 체중 줄이고 싶은 여성, '이 기간'에 운동 해보세요
# 헬스조선
#
#
#
#
#
#
#
#
#
#
#
# 도로서 어린 남매 발견한 최초 신고자 "맨발에 속옷차림으로 …
# 파이낸셜뉴스
#
#
#
#
#
#
#
#
#
#
#
# 평택 아파트서 30대 엄마와 7세 아들 숨진 채 발견
# 서울신문
#
#
#
#
#
#
#
#
#
#
#
# 日 개그맨, 망원시장서 침 묻은 꼬치로 닭강정 '푹'
# 뉴시스
#
#
#
#
#
#
#
#
#
#
#
# 완공 5개월 앞두고 '와르르'…입주 예정자들 '분통'
# 한국경제TV
#
#
#
#
#
#
#
#
#
#
#
#
#
# 韓의원 독도 방문에…日 "윤석열 정권에 대한 반발이냐"[이 …
# 노컷뉴스
#
#
#
#
#
#
#
#
#
#
#
# 온가족 뛰어들어 월수 2천만원... 우리가 버는 돈은 특별 …
# 오마이뉴스
#
#
#
#
#
#
#
#
#
#
#
# '보복여행' 떠난 中여행객들, 욕설·몸싸움 민폐...화장실 …
# 전자신문
#
#
#
#
#
#
#
#
#
#
#
# [단독]野원로 유인태, 대통령 취임 1주년에 與 친윤 모임 …
# 채널A
#
#
#
#
#
#
#
#
#
#
#
# 어린이날 나들이 어쩌나.. 4일밤부터 호우특보 수준 쏟아진 …
# CJB청주방송
#
#
#
#
#
#
#
#
#
#
#
#
#
# 건설노동자 분신 사망에 "尹 정부, '건폭' 신조어까지 만 …
# 프레시안
#
#
#
#
#
#
#
#
#
#
#
# 양극재 판매 질주…에코프로 1분기도 날았다
# 비즈워치
#
#
#
#
#
#
#
#
#
#
#
# '여신도 성폭행' JMS 정명석 파렴치 행각 도운 정조은과 …
# 시사저널
#
#
#
#
#
#
#
#
#
#
#
# 송영길, '나는 협조? 연락처·통화내역·카톡 '초기화'…제 …
# 데일리안
#
#
#
#
#
#
#
#
#
#
#
# 일가족 3명 숨진 채 발견…아내 살해하고 한살배기 자녀 껴 …
# 강원일보
#
#
#
#
#
#
#
#
#
#
#
#
#
# 尹 "문재인, 중국에서 8끼나 혼밥…'외교적 결례'"
# 매일신문
#
#
#
#
#
#
#
#
#
#
#
# "어버이날 선물 예산 평균 33만6천원"
# ZDNet Korea
#
#
#
#
#
#
#
#
#
#
#
# 손혜원, 조선일보 '목포 투기 의혹'  정정보도 소송서 패 …
# 미디어오늘
#
#
#
#
#
#
#
#
#
#
#
# "아버지가 마약한 것 같아요"…필로폰 투약 50대, 아들  …
# 더팩트
#
#
#
#
#
#
#
#
#
#
#
# "여기서 주님 지켜며 잠 자라" 정명석 성폭행 도운 JMS …
# kbc광주방송
#
#
#
#
#
#
#
#
#
#
#
#
#
# 美연준, 마지막 '베이비스텝' 유력…동결기조 전환하나
# 블로터
#
#
#
#
#
#
#
#
#
#
#
# 멈춰버린 행정심판과 법무부의 비공개 ‘억지 주장’
# 뉴스타파
#
#
#
#
#
#
#
#
#
#
#
# “엄마 편이야, 아빠 편이야” 묻지 마세요
# 한겨레21
#
#
#
#
#
#
#
#
#
#
#
# "선배한테 밥 얻어먹기 최고"… 무지출 챌린지 해봤어? [ …
# 머니S
#
#
#
#
#
#
#
#
#
#
#
# Bear or badger? Debates continue …
# 코리아헤럴드
#
#
#
#
#
#
#
#
#
#
#
#
#
# “사는 게 행복하더라” 임영웅을 사랑하는 이들
# 시사IN
#
#
#
#
#
#
#
#
#
#
#
# 경상적자 계속, '제2 외환위기說'까지…KDI는 "가능성  …
# 조세일보
#
#
#
#
#
#
#
#
#
#
#
# [DD 퇴근길] 대기업 카카오, 아이디어 베끼기 논란
# 디지털데일리
#
#
#
#
#
#
#
#
#
#
#
# [단독]이번엔 해운대...전세사기로 27억 원 가로챈 건축 …
# 국제신문
#
#
#
#
#
#
#
#
#
#
#
# 카카오뱅크 1분기 당기순이익 1019억원... '역대 최대 …
# 한경비즈니스
#
#
#
#
#
#
#
#
#
#
#
#
#
# “美·日·中  로봇 산업 성장 비결은 정부 투자”
# 주간동아
#
#
#
#
#
#
#
#
#
#
#
# 홍준표"대통령, 범죄혐의자와 만나면 오해 받아 이재명 안  …
# 주간조선
#
#
#
#
#
#
#
#
#
#
#
# '대전 스쿨존' 승아양 친 60대 男, 음주운전 '상습범' …
# 아이뉴스24
#
#
#
#
#
#
#
#
#
#
#
# “또 오너리스크?”...셀트리온그룹주, 이번엔 서정진 회장 …
# 매경이코노미
#
#
#
#
#
#
#
#
#
#
#
# 알코올성 간질환 표적 치료 열쇠 찾았다
# 동아사이언스
#
#
#
#
#
#
#
#
#
#
#
#
#
# 엠폭스 환자 96% 남성… 대부분 20~40대
# 여성신문
#
#
#
#
#
#
#
#
#
#
#
# 서정진 혼외 자녀 호적 오르자 셀트리온 주가 ‘흔들’
# 이코노미스트
#
#
#
#
#
#
#
#
#
#
#
# 최근 혈당이 높아졌다면…‘착한’탄수화물 식품6
# 코메디닷컴
#
#
#
#
#
#
#
#
#
#
#
# 연산군의 ‘탕춘대’가 왜 세계유산감일까[이기환의 Hi-st …
# 주간경향
#
#
#
#
#
#
#
#
#
#
#
# 〈나는 신이다〉 재현은 왜 문제가 되는가?
# 일다
#
#
#
#
#
#
#
#
#
#
#
#
#
# [속보] 분신사망 건설노조 강원지부 간부, "대한민국 바로 …
# 강원도민일보
#
#
#
#
#
#
#
#
#
#
#
# [Man&Wall] 선수도 힘든 5.14급 루트 끝낸 하하 …
# 월간 산
#
#
#
#
#
#
#
#
#
#
#
# “안철수보다 윤석열이 먼저 손 내밀었다” [+영상]
# 신동아
#
#
#
#
#
#
#
#
#
#
#
# Korean victim of Japanese wartim …
# 코리아중앙데일리
#
#
#
#
#
#
#
#
#
#
#
# 콧물 주르륵 ‘OOO염’…방치 시 수술 필요
# 농민신문
#
#
#
#
#
#
#
#
#
#
#
#
#
# [영상+] "마음이 아프신가요?" 국립 김천 치유의 숲
# 대구MBC
#
#
#
#
#
#
#
#
#
#
#
# 김기현, 윤리위에 '태영호 녹취록' 병합 심사 요청… "심 …
# 대전일보
#
#
#
#
#
#
#
#
#
#
#
# '尹 호위무사' 이용 "김건희 여사 활동적이지 않고 온순. …
# JIBS
#
#
#
#
#
#
#
#
#
#
#
# 서정진 '혼외 자녀' 친모 회사 2곳 계열사로 추가… 셀트 …
# 경기일보
#
#
#
#
#
#
#
#
#
#
#
# 오물 뒤섞여 방치된 '비숑' 100마리..진안 무허가 번식 …
# 전주MBC
#
#
#
#
#
#
#
#
#
#
#
#
#
# '尹 호위무사' 이용 "김건희 여사 활동적이지 않고 온순. …
# JIBS
#
#
#
#
#
#
#
#
#
#
#
# 서정진 '혼외 자녀' 친모 회사 2곳 계열사로 추가… 셀트 …
# 경기일보
#
#
#
#
#
#
#
#
#
#
#
# 오물 뒤섞여 방치된 '비숑' 100마리..진안 무허가 번식 …
# 전주MBC
#
#
#
#
#
#
#
#
#
#
#
# 1년 만에 론칭? 리버버스 졸속과 땜빵 사이 [視리즈]
# 더스쿠프
#
#
#
#
#
#
#
#
#
#
#
# ‘스시테러’ 정신 못 차렸나…일본 방송인 망원시장서 침 묻 …
# 레이디경향
#
#
#
#
#
# 더보기
#
# 각 언론사의 가장 많이 본 기사 1건을 제공합니다. 닫기
#
#
#
# "아줌마!" 부르다 살인난다…여성 분노케 하는 '그 말'  …
# 서울경제
#
#
#
#
#
# "아줌마!" 부르다 살인난다…여성 분노케 하는 '그 말'  …
# 서울경제
#
#
#
# "아줌마!" 부르다 살인난다…여성 분노케 하는 '그 말'  …
# 서울경제
#
#
#
#
# 어린이날 연휴 전국에 '집중호우'…수도권 사흘간 최대 12 …
# 연합뉴스
#
#
#
#
#
# 어린이날 연휴 전국에 '집중호우'…수도권 사흘간 최대 12 …
# 연합뉴스
#
#
#
# 어린이날 연휴 전국에 '집중호우'…수도권 사흘간 최대 12 …
# 연합뉴스
#
#
#
#
# "성욕만 푸는 XX취급" 前남친에 문자만 800번…20대  …
# 중앙일보
#
#
#
#
#
# "성욕만 푸는 XX취급" 前남친에 문자만 800번…20대  …
# 중앙일보
#
#
#
# "성욕만 푸는 XX취급" 前남친에 문자만 800번…20대  …
# 중앙일보
#
#
#
#
# "마동석 사진 쓰면 인생이 편해진다"…중국서 '프사 바꾸기 …
# JTBC
#
#
#
#
#
# "마동석 사진 쓰면 인생이 편해진다"…중국서 '프사 바꾸기 …
# JTBC
#
#
#
# "마동석 사진 쓰면 인생이 편해진다"…중국서 '프사 바꾸기 …
# JTBC
#
#
#
#
# 임신한 외상 손님, 이제 식구가 됐습니다 [아살세]
# 국민일보
#
#
#
#
#
# 임신한 외상 손님, 이제 식구가 됐습니다 [아살세]
# 국민일보
#
#
#
# 임신한 외상 손님, 이제 식구가 됐습니다 [아살세]
# 국민일보
#
#
#
#
# "여보세력 나야" 풍자한 유튜버에…임창정, 경고장 날렸다
# 한국경제
#
#
#
#
#
# "여보세력 나야" 풍자한 유튜버에…임창정, 경고장 날렸다
# 한국경제
#
#
#
# "여보세력 나야" 풍자한 유튜버에…임창정, 경고장 날렸다
# 한국경제
#
#
#
#
# 세계 최초 누워가는 '비행기 침대칸' 나온다…가격 얼마?
# 머니투데이
#
#
#
#
#
# 세계 최초 누워가는 '비행기 침대칸' 나온다…가격 얼마?
# 머니투데이
#
#
#
# 세계 최초 누워가는 '비행기 침대칸' 나온다…가격 얼마?
# 머니투데이
#
#
#
#
# 서정진 셀트리온 회장 혼외자 2명 호적에… 친모와 서 회장 …
# 조선비즈
#
#
#
#
#
# 서정진 셀트리온 회장 혼외자 2명 호적에… 친모와 서 회장 …
# 조선비즈
#
#
#
# 서정진 셀트리온 회장 혼외자 2명 호적에… 친모와 서 회장 …
# 조선비즈
#
#
#
#
# 손혜원, '목포 투기 의혹' 조선일보 상대 항소심도 패소
# TV조선
#
#
#
#
#
# 손혜원, '목포 투기 의혹' 조선일보 상대 항소심도 패소
# TV조선
#
#
#
# 손혜원, '목포 투기 의혹' 조선일보 상대 항소심도 패소
# TV조선
#
#
#
#
# 택시에 두고 내린 '40년 업무자료'…한 달간 CCTV 돌 …
# SBS
#
#
#
#
#
# 택시에 두고 내린 '40년 업무자료'…한 달간 CCTV 돌 …
# SBS
#
#
#
# 택시에 두고 내린 '40년 업무자료'…한 달간 CCTV 돌 …
# SBS
#
#
#
#
# “여보 세력 나야~” 임창정, 패러디에 칼 뺐다
# 매일경제
#
#
#
#
#
# “여보 세력 나야~” 임창정, 패러디에 칼 뺐다
# 매일경제
#
#
#
# “여보 세력 나야~” 임창정, 패러디에 칼 뺐다
# 매일경제
#
#
#
#
# “새치기 하다니”…서울대 명예교수, 구내식당서 학생 폭행
# 동아일보
#
#
#
#
#
# “새치기 하다니”…서울대 명예교수, 구내식당서 학생 폭행
# 동아일보
#
#
#
# “새치기 하다니”…서울대 명예교수, 구내식당서 학생 폭행
# 동아일보
#
#
#
#
# 신부 이어 목사 1000명 시국선언…“윤석열 운명 다했다”
# 한겨레
#
#
#
#
#
# 신부 이어 목사 1000명 시국선언…“윤석열 운명 다했다”
# 한겨레
#
#
#
# 신부 이어 목사 1000명 시국선언…“윤석열 운명 다했다”
# 한겨레
#
#
#
#
# "인어 몸매가 왜 이래" 조각상에 발칵 뒤집힌 이탈리아
# 아시아경제
#
#
#
#
#
# "인어 몸매가 왜 이래" 조각상에 발칵 뒤집힌 이탈리아
# 아시아경제
#
#
#
# "인어 몸매가 왜 이래" 조각상에 발칵 뒤집힌 이탈리아
# 아시아경제
#
#
#
#
# "10분 만에 25억 꽂혔다"‥임창정, 계좌 공개하며 '결 …
# MBC
#
#
#
#
#
# "10분 만에 25억 꽂혔다"‥임창정, 계좌 공개하며 '결 …
# MBC
#
#
#
# "10분 만에 25억 꽂혔다"‥임창정, 계좌 공개하며 '결 …
# MBC
#
#
#
#
# [단독] “깔렸다고” “밀지 마” 민노총 집회서 경찰 밀어 …
# 조선일보
#
#
#
#
#
# [단독] “깔렸다고” “밀지 마” 민노총 집회서 경찰 밀어 …
# 조선일보
#
#
#
# [단독] “깔렸다고” “밀지 마” 민노총 집회서 경찰 밀어 …
# 조선일보
#
#
#
#
# 공무원 인기 떨어졌다…완전자본잠식 빠진 에듀윌
# 이데일리
#
#
#
#
#
# 공무원 인기 떨어졌다…완전자본잠식 빠진 에듀윌
# 이데일리
#
#
#
# 공무원 인기 떨어졌다…완전자본잠식 빠진 에듀윌
# 이데일리
#
#
#
#
# 해고 당했는데 ‘자진 퇴사’라니…실업급여도 막막 [5인미만 …
# KBS
#
#
#
#
#
# 해고 당했는데 ‘자진 퇴사’라니…실업급여도 막막 [5인미만 …
# KBS
#
#
#
# 해고 당했는데 ‘자진 퇴사’라니…실업급여도 막막 [5인미만 …
# KBS
#
#
#
#
# [날씨] 중부 초여름 더위…내일 전국 '비소식'
# 연합뉴스TV
#
#
#
#
#
# [날씨] 중부 초여름 더위…내일 전국 '비소식'
# 연합뉴스TV
#
#
#
# [날씨] 중부 초여름 더위…내일 전국 '비소식'
# 연합뉴스TV
#
#
#
#
# "나도 피해자" 임창정, 주가조작단 美골프장 계약자리 동행
# 디지털타임스
#
#
#
#
#
# "나도 피해자" 임창정, 주가조작단 美골프장 계약자리 동행
# 디지털타임스
#
#
#
# "나도 피해자" 임창정, 주가조작단 美골프장 계약자리 동행
# 디지털타임스
#
#
#
#
# 국내 언론이 본 한미정상회담… "동맹은 격상, 경제 성과  …
# 기자협회보
#
#
#
#
#
# 국내 언론이 본 한미정상회담… "동맹은 격상, 경제 성과  …
# 기자협회보
#
#
#
# 국내 언론이 본 한미정상회담… "동맹은 격상, 경제 성과  …
# 기자협회보
#
#
#
#
# 日 유명 개그맨이 韓 시장에서 보인 돌발 행동...일본 사 …
# YTN
#
#
#
#
#
# 日 유명 개그맨이 韓 시장에서 보인 돌발 행동...일본 사 …
# YTN
#
#
#
# 日 유명 개그맨이 韓 시장에서 보인 돌발 행동...일본 사 …
# YTN
#
#
#
#
# 32년째 행방불명 아나운서...어디로 갔나
# MBN
#
#
#
#
#
# 32년째 행방불명 아나운서...어디로 갔나
# MBN
#
#
#
# 32년째 행방불명 아나운서...어디로 갔나
# MBN
#
#
#
#
# [단독]'돈세탁' 의혹 유명 유튜버 헬스장에 '수상한' 사 …
# 뉴스1
#
#
#
#
#
# [단독]'돈세탁' 의혹 유명 유튜버 헬스장에 '수상한' 사 …
# 뉴스1
#
#
#
# [단독]'돈세탁' 의혹 유명 유튜버 헬스장에 '수상한' 사 …
# 뉴스1
#
#
#
#
# 백윤식, 전 연인 ‘폭로 에세이’ 출판·판매금지 소송서 일 …
# 경향신문
#
#
#
#
#
# 백윤식, 전 연인 ‘폭로 에세이’ 출판·판매금지 소송서 일 …
# 경향신문
#
#
#
# 백윤식, 전 연인 ‘폭로 에세이’ 출판·판매금지 소송서 일 …
# 경향신문
#
#
#
#
# “한강변 49층이요? 35층 하시죠” 반포 재건축 초고층  …
# 헤럴드경제
#
#
#
#
#
# “한강변 49층이요? 35층 하시죠” 반포 재건축 초고층  …
# 헤럴드경제
#
#
#
# “한강변 49층이요? 35층 하시죠” 반포 재건축 초고층  …
# 헤럴드경제
#
#
#
#
# 메스 들고 허벅지 정맥 도려낸 '김 선생'... 그의 정체 …
# 한국일보
#
#
#
#
#
# 메스 들고 허벅지 정맥 도려낸 '김 선생'... 그의 정체 …
# 한국일보
#
#
#
# 메스 들고 허벅지 정맥 도려낸 '김 선생'... 그의 정체 …
# 한국일보
#
#
#
#
# 영영 못 찾을 줄 알았던 카메라가 다시 내 손에…“한국,  …
# 세계일보
#
#
#
#
#
# 영영 못 찾을 줄 알았던 카메라가 다시 내 손에…“한국,  …
# 세계일보
#
#
#
# 영영 못 찾을 줄 알았던 카메라가 다시 내 손에…“한국,  …
# 세계일보
#
#
#
#
# ‘부촌’ 명성 고개 드나… 달맞이고개 100억 빌라 들어선 …
# 부산일보
#
#
#
#
#
# ‘부촌’ 명성 고개 드나… 달맞이고개 100억 빌라 들어선 …
# 부산일보
#
#
#
# ‘부촌’ 명성 고개 드나… 달맞이고개 100억 빌라 들어선 …
# 부산일보
#
#
#
#
# [영상] 속도 감당 못한 페라리가 들이받은 닛산…하늘로 ‘ …
# 문화일보
#
#
#
#
#
# [영상] 속도 감당 못한 페라리가 들이받은 닛산…하늘로 ‘ …
# 문화일보
#
#
#
# [영상] 속도 감당 못한 페라리가 들이받은 닛산…하늘로 ‘ …
# 문화일보
#
#
#
#
# 체중 줄이고 싶은 여성, '이 기간'에 운동 해보세요
# 헬스조선
#
#
#
#
#
# 체중 줄이고 싶은 여성, '이 기간'에 운동 해보세요
# 헬스조선
#
#
#
# 체중 줄이고 싶은 여성, '이 기간'에 운동 해보세요
# 헬스조선
#
#
#
#
# 도로서 어린 남매 발견한 최초 신고자 "맨발에 속옷차림으로 …
# 파이낸셜뉴스
#
#
#
#
#
# 도로서 어린 남매 발견한 최초 신고자 "맨발에 속옷차림으로 …
# 파이낸셜뉴스
#
#
#
# 도로서 어린 남매 발견한 최초 신고자 "맨발에 속옷차림으로 …
# 파이낸셜뉴스
#
#
#
#
# 평택 아파트서 30대 엄마와 7세 아들 숨진 채 발견
# 서울신문
#
#
#
#
#
# 평택 아파트서 30대 엄마와 7세 아들 숨진 채 발견
# 서울신문
#
#
#
# 평택 아파트서 30대 엄마와 7세 아들 숨진 채 발견
# 서울신문
#
#
#
#
# 日 개그맨, 망원시장서 침 묻은 꼬치로 닭강정 '푹'
# 뉴시스
#
#
#
#
#
# 日 개그맨, 망원시장서 침 묻은 꼬치로 닭강정 '푹'
# 뉴시스
#
#
#
# 日 개그맨, 망원시장서 침 묻은 꼬치로 닭강정 '푹'
# 뉴시스
#
#
#
#
# 완공 5개월 앞두고 '와르르'…입주 예정자들 '분통'
# 한국경제TV
#
#
#
#
#
# 완공 5개월 앞두고 '와르르'…입주 예정자들 '분통'
# 한국경제TV
#
#
#
# 완공 5개월 앞두고 '와르르'…입주 예정자들 '분통'
# 한국경제TV
#
#
#
#
# 韓의원 독도 방문에…日 "윤석열 정권에 대한 반발이냐"[이 …
# 노컷뉴스
#
#
#
#
#
# 韓의원 독도 방문에…日 "윤석열 정권에 대한 반발이냐"[이 …
# 노컷뉴스
#
#
#
# 韓의원 독도 방문에…日 "윤석열 정권에 대한 반발이냐"[이 …
# 노컷뉴스
#
#
#
#
# 온가족 뛰어들어 월수 2천만원... 우리가 버는 돈은 특별 …
# 오마이뉴스
#
#
#
#
#
# 온가족 뛰어들어 월수 2천만원... 우리가 버는 돈은 특별 …
# 오마이뉴스
#
#
#
# 온가족 뛰어들어 월수 2천만원... 우리가 버는 돈은 특별 …
# 오마이뉴스
#
#
#
#
# '보복여행' 떠난 中여행객들, 욕설·몸싸움 민폐...화장실 …
# 전자신문
#
#
#
#
#
# '보복여행' 떠난 中여행객들, 욕설·몸싸움 민폐...화장실 …
# 전자신문
#
#
#
# '보복여행' 떠난 中여행객들, 욕설·몸싸움 민폐...화장실 …
# 전자신문
#
#
#
#
# [단독]野원로 유인태, 대통령 취임 1주년에 與 친윤 모임 …
# 채널A
#
#
#
#
#
# [단독]野원로 유인태, 대통령 취임 1주년에 與 친윤 모임 …
# 채널A
#
#
#
# [단독]野원로 유인태, 대통령 취임 1주년에 與 친윤 모임 …
# 채널A
#
#
#
#
# 어린이날 나들이 어쩌나.. 4일밤부터 호우특보 수준 쏟아진 …
# CJB청주방송
#
#
#
#
#
# 어린이날 나들이 어쩌나.. 4일밤부터 호우특보 수준 쏟아진 …
# CJB청주방송
#
#
#
# 어린이날 나들이 어쩌나.. 4일밤부터 호우특보 수준 쏟아진 …
# CJB청주방송
#
#
#
#
# 건설노동자 분신 사망에 "尹 정부, '건폭' 신조어까지 만 …
# 프레시안
#
#
#
#
#
# 건설노동자 분신 사망에 "尹 정부, '건폭' 신조어까지 만 …
# 프레시안
#
#
#
# 건설노동자 분신 사망에 "尹 정부, '건폭' 신조어까지 만 …
# 프레시안
#
#
#
#
# 양극재 판매 질주…에코프로 1분기도 날았다
# 비즈워치
#
#
#
#
#
# 양극재 판매 질주…에코프로 1분기도 날았다
# 비즈워치
#
#
#
# 양극재 판매 질주…에코프로 1분기도 날았다
# 비즈워치
#
#
#
#
# '여신도 성폭행' JMS 정명석 파렴치 행각 도운 정조은과 …
# 시사저널
#
#
#
#
#
# '여신도 성폭행' JMS 정명석 파렴치 행각 도운 정조은과 …
# 시사저널
#
#
#
# '여신도 성폭행' JMS 정명석 파렴치 행각 도운 정조은과 …
# 시사저널
#
#
#
#
# 송영길, '나는 협조? 연락처·통화내역·카톡 '초기화'…제 …
# 데일리안
#
#
#
#
#
# 송영길, '나는 협조? 연락처·통화내역·카톡 '초기화'…제 …
# 데일리안
#
#
#
# 송영길, '나는 협조? 연락처·통화내역·카톡 '초기화'…제 …
# 데일리안
#
#
#
#
# 일가족 3명 숨진 채 발견…아내 살해하고 한살배기 자녀 껴 …
# 강원일보
#
#
#
#
#
# 일가족 3명 숨진 채 발견…아내 살해하고 한살배기 자녀 껴 …
# 강원일보
#
#
#
# 일가족 3명 숨진 채 발견…아내 살해하고 한살배기 자녀 껴 …
# 강원일보
#
#
#
#
# 尹 "문재인, 중국에서 8끼나 혼밥…'외교적 결례'"
# 매일신문
#
#
#
#
#
# 尹 "문재인, 중국에서 8끼나 혼밥…'외교적 결례'"
# 매일신문
#
#
#
# 尹 "문재인, 중국에서 8끼나 혼밥…'외교적 결례'"
# 매일신문
#
#
#
#
# "어버이날 선물 예산 평균 33만6천원"
# ZDNet Korea
#
#
#
#
#
# "어버이날 선물 예산 평균 33만6천원"
# ZDNet Korea
#
#
#
# "어버이날 선물 예산 평균 33만6천원"
# ZDNet Korea
#
#
#
#
# 손혜원, 조선일보 '목포 투기 의혹'  정정보도 소송서 패 …
# 미디어오늘
#
#
#
#
#
# 손혜원, 조선일보 '목포 투기 의혹'  정정보도 소송서 패 …
# 미디어오늘
#
#
#
# 손혜원, 조선일보 '목포 투기 의혹'  정정보도 소송서 패 …
# 미디어오늘
#
#
#
#
# "아버지가 마약한 것 같아요"…필로폰 투약 50대, 아들  …
# 더팩트
#
#
#
#
#
# "아버지가 마약한 것 같아요"…필로폰 투약 50대, 아들  …
# 더팩트
#
#
#
# "아버지가 마약한 것 같아요"…필로폰 투약 50대, 아들  …
# 더팩트
#
#
#
#
# "여기서 주님 지켜며 잠 자라" 정명석 성폭행 도운 JMS …
# kbc광주방송
#
#
#
#
#
# "여기서 주님 지켜며 잠 자라" 정명석 성폭행 도운 JMS …
# kbc광주방송
#
#
#
# "여기서 주님 지켜며 잠 자라" 정명석 성폭행 도운 JMS …
# kbc광주방송
#
#
#
#
# 美연준, 마지막 '베이비스텝' 유력…동결기조 전환하나
# 블로터
#
#
#
#
#
# 美연준, 마지막 '베이비스텝' 유력…동결기조 전환하나
# 블로터
#
#
#
# 美연준, 마지막 '베이비스텝' 유력…동결기조 전환하나
# 블로터
#
#
#
#
# 멈춰버린 행정심판과 법무부의 비공개 ‘억지 주장’
# 뉴스타파
#
#
#
#
#
# 멈춰버린 행정심판과 법무부의 비공개 ‘억지 주장’
# 뉴스타파
#
#
#
# 멈춰버린 행정심판과 법무부의 비공개 ‘억지 주장’
# 뉴스타파
#
#
#
#
# “엄마 편이야, 아빠 편이야” 묻지 마세요
# 한겨레21
#
#
#
#
#
# “엄마 편이야, 아빠 편이야” 묻지 마세요
# 한겨레21
#
#
#
# “엄마 편이야, 아빠 편이야” 묻지 마세요
# 한겨레21
#
#
#
#
# "선배한테 밥 얻어먹기 최고"… 무지출 챌린지 해봤어? [ …
# 머니S
#
#
#
#
#
# "선배한테 밥 얻어먹기 최고"… 무지출 챌린지 해봤어? [ …
# 머니S
#
#
#
# "선배한테 밥 얻어먹기 최고"… 무지출 챌린지 해봤어? [ …
# 머니S
#
#
#
#
# Bear or badger? Debates continue …
# 코리아헤럴드
#
#
#
#
#
# Bear or badger? Debates continue …
# 코리아헤럴드
#
#
#
# Bear or badger? Debates continue …
# 코리아헤럴드
#
#
#
#
# “사는 게 행복하더라” 임영웅을 사랑하는 이들
# 시사IN
#
#
#
#
#
# “사는 게 행복하더라” 임영웅을 사랑하는 이들
# 시사IN
#
#
#
# “사는 게 행복하더라” 임영웅을 사랑하는 이들
# 시사IN
#
#
#
#
# 경상적자 계속, '제2 외환위기說'까지…KDI는 "가능성  …
# 조세일보
#
#
#
#
#
# 경상적자 계속, '제2 외환위기說'까지…KDI는 "가능성  …
# 조세일보
#
#
#
# 경상적자 계속, '제2 외환위기說'까지…KDI는 "가능성  …
# 조세일보
#
#
#
#
# [DD 퇴근길] 대기업 카카오, 아이디어 베끼기 논란
# 디지털데일리
#
#
#
#
#
# [DD 퇴근길] 대기업 카카오, 아이디어 베끼기 논란
# 디지털데일리
#
#
#
# [DD 퇴근길] 대기업 카카오, 아이디어 베끼기 논란
# 디지털데일리
#
#
#
#
# [단독]이번엔 해운대...전세사기로 27억 원 가로챈 건축 …
# 국제신문
#
#
#
#
#
# [단독]이번엔 해운대...전세사기로 27억 원 가로챈 건축 …
# 국제신문
#
#
#
# [단독]이번엔 해운대...전세사기로 27억 원 가로챈 건축 …
# 국제신문
#
#
#
#
# 카카오뱅크 1분기 당기순이익 1019억원... '역대 최대 …
# 한경비즈니스
#
#
#
#
#
# 카카오뱅크 1분기 당기순이익 1019억원... '역대 최대 …
# 한경비즈니스
#
#
#
# 카카오뱅크 1분기 당기순이익 1019억원... '역대 최대 …
# 한경비즈니스
#
#
#
#
# “美·日·中  로봇 산업 성장 비결은 정부 투자”
# 주간동아
#
#
#
#
#
# “美·日·中  로봇 산업 성장 비결은 정부 투자”
# 주간동아
#
#
#
# “美·日·中  로봇 산업 성장 비결은 정부 투자”
# 주간동아
#
#
#
#
# 홍준표"대통령, 범죄혐의자와 만나면 오해 받아 이재명 안  …
# 주간조선
#
#
#
#
#
# 홍준표"대통령, 범죄혐의자와 만나면 오해 받아 이재명 안  …
# 주간조선
#
#
#
# 홍준표"대통령, 범죄혐의자와 만나면 오해 받아 이재명 안  …
# 주간조선
#
#
#
#
# '대전 스쿨존' 승아양 친 60대 男, 음주운전 '상습범' …
# 아이뉴스24
#
#
#
#
#
# '대전 스쿨존' 승아양 친 60대 男, 음주운전 '상습범' …
# 아이뉴스24
#
#
#
# '대전 스쿨존' 승아양 친 60대 男, 음주운전 '상습범' …
# 아이뉴스24
#
#
#
#
# “또 오너리스크?”...셀트리온그룹주, 이번엔 서정진 회장 …
# 매경이코노미
#
#
#
#
#
# “또 오너리스크?”...셀트리온그룹주, 이번엔 서정진 회장 …
# 매경이코노미
#
#
#
# “또 오너리스크?”...셀트리온그룹주, 이번엔 서정진 회장 …
# 매경이코노미
#
#
#
#
# 알코올성 간질환 표적 치료 열쇠 찾았다
# 동아사이언스
#
#
#
#
#
# 알코올성 간질환 표적 치료 열쇠 찾았다
# 동아사이언스
#
#
#
# 알코올성 간질환 표적 치료 열쇠 찾았다
# 동아사이언스
#
#
#
#
# 엠폭스 환자 96% 남성… 대부분 20~40대
# 여성신문
#
#
#
#
#
# 엠폭스 환자 96% 남성… 대부분 20~40대
# 여성신문
#
#
#
# 엠폭스 환자 96% 남성… 대부분 20~40대
# 여성신문
#
#
#
#
# 서정진 혼외 자녀 호적 오르자 셀트리온 주가 ‘흔들’
# 이코노미스트
#
#
#
#
#
# 서정진 혼외 자녀 호적 오르자 셀트리온 주가 ‘흔들’
# 이코노미스트
#
#
#
# 서정진 혼외 자녀 호적 오르자 셀트리온 주가 ‘흔들’
# 이코노미스트
#
#
#
#
# 최근 혈당이 높아졌다면…‘착한’탄수화물 식품6
# 코메디닷컴
#
#
#
#
#
# 최근 혈당이 높아졌다면…‘착한’탄수화물 식품6
# 코메디닷컴
#
#
#
# 최근 혈당이 높아졌다면…‘착한’탄수화물 식품6
# 코메디닷컴
#
#
#
#
# 연산군의 ‘탕춘대’가 왜 세계유산감일까[이기환의 Hi-st …
# 주간경향
#
#
#
#
#
# 연산군의 ‘탕춘대’가 왜 세계유산감일까[이기환의 Hi-st …
# 주간경향
#
#
#
# 연산군의 ‘탕춘대’가 왜 세계유산감일까[이기환의 Hi-st …
# 주간경향
#
#
#
#
# 〈나는 신이다〉 재현은 왜 문제가 되는가?
# 일다
#
#
#
#
#
# 〈나는 신이다〉 재현은 왜 문제가 되는가?
# 일다
#
#
#
# 〈나는 신이다〉 재현은 왜 문제가 되는가?
# 일다
#
#
#
#
# [속보] 분신사망 건설노조 강원지부 간부, "대한민국 바로 …
# 강원도민일보
#
#
#
#
#
# [속보] 분신사망 건설노조 강원지부 간부, "대한민국 바로 …
# 강원도민일보
#
#
#
# [속보] 분신사망 건설노조 강원지부 간부, "대한민국 바로 …
# 강원도민일보
#
#
#
#
# [Man&Wall] 선수도 힘든 5.14급 루트 끝낸 하하 …
# 월간 산
#
#
#
#
#
# [Man&Wall] 선수도 힘든 5.14급 루트 끝낸 하하 …
# 월간 산
#
#
#
# [Man&Wall] 선수도 힘든 5.14급 루트 끝낸 하하 …
# 월간 산
#
#
#
#
# “안철수보다 윤석열이 먼저 손 내밀었다” [+영상]
# 신동아
#
#
#
#
#
# “안철수보다 윤석열이 먼저 손 내밀었다” [+영상]
# 신동아
#
#
#
# “안철수보다 윤석열이 먼저 손 내밀었다” [+영상]
# 신동아
#
#
#
#
# Korean victim of Japanese wartim …
# 코리아중앙데일리
#
#
#
#
#
# Korean victim of Japanese wartim …
# 코리아중앙데일리
#
#
#
# Korean victim of Japanese wartim …
# 코리아중앙데일리
#
#
#
#
# 콧물 주르륵 ‘OOO염’…방치 시 수술 필요
# 농민신문
#
#
#
#
#
# 콧물 주르륵 ‘OOO염’…방치 시 수술 필요
# 농민신문
#
#
#
# 콧물 주르륵 ‘OOO염’…방치 시 수술 필요
# 농민신문
#
#
#
#
# [영상+] "마음이 아프신가요?" 국립 김천 치유의 숲
# 대구MBC
#
#
#
#
#
# [영상+] "마음이 아프신가요?" 국립 김천 치유의 숲
# 대구MBC
#
#
#
# [영상+] "마음이 아프신가요?" 국립 김천 치유의 숲
# 대구MBC
#
#
#
#
# 김기현, 윤리위에 '태영호 녹취록' 병합 심사 요청… "심 …
# 대전일보
#
#
#
#
#
# 김기현, 윤리위에 '태영호 녹취록' 병합 심사 요청… "심 …
# 대전일보
#
#
#
# 김기현, 윤리위에 '태영호 녹취록' 병합 심사 요청… "심 …
# 대전일보
#
#
#
#
# '尹 호위무사' 이용 "김건희 여사 활동적이지 않고 온순. …
# JIBS
#
#
#
#
#
# '尹 호위무사' 이용 "김건희 여사 활동적이지 않고 온순. …
# JIBS
#
#
#
# '尹 호위무사' 이용 "김건희 여사 활동적이지 않고 온순. …
# JIBS
#
#
#
#
# 서정진 '혼외 자녀' 친모 회사 2곳 계열사로 추가… 셀트 …
# 경기일보
#
#
#
#
#
# 서정진 '혼외 자녀' 친모 회사 2곳 계열사로 추가… 셀트 …
# 경기일보
#
#
#
# 서정진 '혼외 자녀' 친모 회사 2곳 계열사로 추가… 셀트 …
# 경기일보
#
#
#
#
# 오물 뒤섞여 방치된 '비숑' 100마리..진안 무허가 번식 …
# 전주MBC
#
#
#
#
#
# 오물 뒤섞여 방치된 '비숑' 100마리..진안 무허가 번식 …
# 전주MBC
#
#
#
# 오물 뒤섞여 방치된 '비숑' 100마리..진안 무허가 번식 …
# 전주MBC
#
#
#
#
# '尹 호위무사' 이용 "김건희 여사 활동적이지 않고 온순. …
# JIBS
#
#
#
#
#
# '尹 호위무사' 이용 "김건희 여사 활동적이지 않고 온순. …
# JIBS
#
#
#
# '尹 호위무사' 이용 "김건희 여사 활동적이지 않고 온순. …
# JIBS
#
#
#
#
# 서정진 '혼외 자녀' 친모 회사 2곳 계열사로 추가… 셀트 …
# 경기일보
#
#
#
#
#
# 서정진 '혼외 자녀' 친모 회사 2곳 계열사로 추가… 셀트 …
# 경기일보
#
#
#
# 서정진 '혼외 자녀' 친모 회사 2곳 계열사로 추가… 셀트 …
# 경기일보
#
#
#
#
# 오물 뒤섞여 방치된 '비숑' 100마리..진안 무허가 번식 …
# 전주MBC
#
#
#
#
#
# 오물 뒤섞여 방치된 '비숑' 100마리..진안 무허가 번식 …
# 전주MBC
#
#
#
# 오물 뒤섞여 방치된 '비숑' 100마리..진안 무허가 번식 …
# 전주MBC
#
#
#
#
# 1년 만에 론칭? 리버버스 졸속과 땜빵 사이 [視리즈]
# 더스쿠프
#
#
#
#
#
# 1년 만에 론칭? 리버버스 졸속과 땜빵 사이 [視리즈]
# 더스쿠프
#
#
#
# 1년 만에 론칭? 리버버스 졸속과 땜빵 사이 [視리즈]
# 더스쿠프
#
#
#
#
# ‘스시테러’ 정신 못 차렸나…일본 방송인 망원시장서 침 묻 …
# 레이디경향
#
#
#
#
#
# ‘스시테러’ 정신 못 차렸나…일본 방송인 망원시장서 침 묻 …
# 레이디경향
#
#
#
# ‘스시테러’ 정신 못 차렸나…일본 방송인 망원시장서 침 묻 …
# 레이디경향
#
#
#
# 분야별 주요뉴스
#
#
#  이재명, 윤관석·이성만 탈당 질문에 “태영호 녹취는요?”
#  ‘韓의원 독도 방문’ 항의한 일본…외교부 “부당한 주장 일축”
#  임금체불 한해 1조3천억원…상습체불 사업주 신용대출 제한(종합)
#  한국서 침 묻은 꼬치로 판매 음식 푹푹 찌른 일본인?뭇매
#  美 부채가 더 걱정…백악관 “협상 불가’ 재천명, 디폴트 우려 고조
#
#
#
#  [ADB2023] 尹 대통령 "韓, 아시아 협력 공동망 구축"
#  대한항공, 부산세계박람회 유치 기원 특별 항공기 공개
#  최저가 노트북 업체의 몰락... 뒤엔 G마켓·경쟁사 '갑질 동맹'
#  카카오게임즈, 2분기 반등 자신…'오딘' 日 보내고 '아레스' 출격(종합)
#  삼성, 올해 '월드 디제이 페스티벌'에 갤럭시 찐팬 초청
#
#
#
#  건설노동자 분신 사망에 "尹 정부, '건폭' 신조어까지 만들어 노조 매도하더니…"
#  엠폭스 환자 52명 중 50명이 남성…96% '성접촉' 감염(종합)
#  송영길 전 보좌관 검찰 출석…"돈 봉투 본 적도 없어"
#  [날씨] 중부 초여름 더위…내일 전국 '비소식'
#  KG 모빌리티, '렉스턴 뉴 아레나·스포츠&칸 쿨멘' 출격
#
#
#
#
#
#
#
#  이재명, 윤관석·이성만 탈당 질문에 “태영호 녹취는요?”
#  ‘韓의원 독도 방문’ 항의한 일본…외교부 “부당한 주장 일축”
#  임금체불 한해 1조3천억원…상습체불 사업주 신용대출 제한(종합)
#  한국서 침 묻은 꼬치로 판매 음식 푹푹 찌른 일본인?뭇매
#  美 부채가 더 걱정…백악관 “협상 불가’ 재천명, 디폴트 우려 고조
#
#
#
#  [ADB2023] 尹 대통령 "韓, 아시아 협력 공동망 구축"
#  대한항공, 부산세계박람회 유치 기원 특별 항공기 공개
#  최저가 노트북 업체의 몰락... 뒤엔 G마켓·경쟁사 '갑질 동맹'
#  카카오게임즈, 2분기 반등 자신…'오딘' 日 보내고 '아레스' 출격(종합)
#  삼성, 올해 '월드 디제이 페스티벌'에 갤럭시 찐팬 초청
#
#
#
#  건설노동자 분신 사망에 "尹 정부, '건폭' 신조어까지 만들어 노조 매도하더니…"
#  엠폭스 환자 52명 중 50명이 남성…96% '성접촉' 감염(종합)
#  송영길 전 보좌관 검찰 출석…"돈 봉투 본 적도 없어"
#  [날씨] 중부 초여름 더위…내일 전국 '비소식'
#  KG 모빌리티, '렉스턴 뉴 아레나·스포츠&칸 쿨멘' 출격
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   서비스 안내
#
#   고침 기사 모음
#   정정·반론·추후 보도 기사 모음
#   불공정 선거 보도 기사 모음
#
# 서비스 안내더보기
#
#
#
#
#
# 이젠 페이지
# 맨위로
#
#
#
# 언론사 목록열기로딩 중
#
# 분야별 목록열기로딩 중
#
#
#
#
#
#
#
# 이젠 페이지
# 맨위로
#
#
#
# 언론사 목록열기로딩 중
#
# 분야별 목록열기로딩 중
#
#
#
#
#
# 이젠 페이지
# 맨위로
#
#
#
# 이젠 페이지
# 맨위로
#
#
# 언론사 목록열기로딩 중
#
# 분야별 목록열기로딩 중
#
#
#
#
#
#
# 이용약관
# 서비스 안내
# 기사배열 원칙 책임자 : 유봉석
# 청소년 보호 책임자 : 이희만
# 개인정보처리방침
# 책임의 한계와 법적고지
# 뉴스 고객센터
#
# 본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.
#
# NAVER
# Copyright ©
# NAVER Corp.
# All Rights Reserved.
#
#
#
# 언론사별
# 정치
# 경제
# 사회
# 생활/문화
# IT/과학
# 세계
# 랭킹
# 신문보기
# 오피니언
# TV
# 팩트체크
# 메인 메뉴로 바로가기
# 본문으로 바로가기

# %%
# div 태그를 모두 가져와서 문자와 숫자만 스페이스로 연결해서 출력하세요
import re
for i in bs.find_all('div'):
    print(' '.join(re.findall('[\w]+', i.text)))
# Out:
# 메인 메뉴로 바로가기 본문으로 바로가기 검색 NAVER 뉴스 TV연예 스포츠 날씨 프리미엄 언론사별 정치 선택됨 경제 사회 생활 문화 IT 과학 세계 랭킹 신문보기 오피니언 TV 팩트체크 전체 언론사 뉴스스탠드 라이브러리 05 03 수 전체 언론사 뉴스스탠드 라이브러리 기사목록 정치 대통령실 국회 정당 북한 행정 국방 외교 정치일반 안내헤드라인 뉴스 헤드라인 뉴스와 각 기사묶음 타이틀은 기사 내용을 기반으로 자동 추출됩니다 닫기 국회 정개특위 선거제 개편 500인 공론조사 실시 KBS 생중계 국회 정치개혁특별위원회 정개특위 는 오는 6일과 13일 양일간 500명의 시민참여단을 대상으로 국회의원 선거제도 개편에 대한 공론조사를 실시하고 KBS KBS 이데일리 선거제 개편 공론화 본격화 대표 시민 500인 토론 파이낸셜뉴스 선거제도 국회의원이 아닌 국민이 결정하자 정개특위 시민 500명 참여 토론회 연다 매일경제 선거개편 공론화 시민참여단 500명 모여 토론한다 8개의 관련뉴스 더보기 野 의원 독도 방문에 日 항의 외교부 부당한 주장 일축 정부는 3일 전용기 더불어민주당 의원의 독도 방문에 대한 일본 측 항의에 일본 측의 부당한 주장은 외교 채널을 통해 일축했다 고 밝혔다 외교부 당국자 조선비즈 서울경제 정부 野 독도 방문 부당 日항의에 부당한 주장 헤럴드경제 더불어민주당 경북도당 청년 대학생위 독도 현지서 독도영유권수호 다짐 노컷뉴스 韓의원 독도 방문에 日 윤석열 정권에 대한 반발이냐 이슈시개 77개의 관련뉴스 더보기 태영호 녹취록 에 與 산 넘어 산 태영호 징계 수위에 영향은 이진복 대통령실 정무수석이 22대 총선 공천 문제를 거론하며 한일 관계에 대한 옹호 발언을 해달라고 요청했다는 태영호 국민의힘 최고위원의 녹취가 공개되면 뉴스1 시사저널 체리따봉 부터 태영호 녹취록 까지 용산 당무 개입 은 이제 시작 JTBC 태영호 녹취록 에 국민의힘 발칵 당내서도 불법 공천개입 한국경제TV 대통령실 공천 개입 태영호 녹취록 논란에 與 선긋기 82개의 관련뉴스 더보기 장예찬 태영호 녹취록 일벌백계해야 김성태 중징계감 아니야 이른바 공천 녹취록 유출과 관련해 여당 내부에서 의견이 엇갈리고 있다 장예찬 국민의힘 최고위원은 누구든 일벌백계 읍참마속의 기조로 엄하게 다뤄야 머니S 한겨레 장예찬 용산과 더 가까운 나도 공천 부탁 들은 적 없다 MBC 장예찬 내가 태영호보다 대통령실과 더 가까운데 공천 부탁 들어본 적 없어 시선집중 파이낸셜뉴스 장예찬 내가 태영호보다 대통령실과 더 가깝지만 공천 부탁 들어본 적 없다 9개의 관련뉴스 더보기 
# 메인 메뉴로 바로가기 본문으로 바로가기
# 검색 NAVER 뉴스 TV연예 스포츠 날씨 프리미엄
# 검색 NAVER 뉴스 TV연예 스포츠 날씨 프리미엄
# 검색
#
#
#
# 검색
# NAVER 뉴스 TV연예 스포츠 날씨 프리미엄
# 언론사별 정치 선택됨 경제 사회 생활 문화 IT 과학 세계 랭킹 신문보기 오피니언 TV 팩트체크 전체 언론사 뉴스스탠드 라이브러리
# 언론사별 정치 선택됨 경제 사회 생활 문화 IT 과학 세계 랭킹 신문보기 오피니언 TV 팩트체크 전체 언론사 뉴스스탠드 라이브러리
# 언론사별 정치 선택됨 경제 사회 생활 문화 IT 과학 세계 랭킹 신문보기 오피니언 TV 팩트체크 전체 언론사 뉴스스탠드 라이브러리
# 언론사별 정치 선택됨 경제 사회 생활 문화 IT 과학 세계 랭킹 신문보기 오피니언 TV 팩트체크
# 언론사별 정치 선택됨 경제 사회 생활 문화 IT 과학 세계 랭킹 신문보기 오피니언 TV 팩트체크
# 전체 언론사 뉴스스탠드 라이브러리
# 전체 언론사 뉴스스탠드 라이브러리
# 전체 언론사 뉴스스탠드 라이브러리
# 05 03 수 전체 언론사 뉴스스탠드 라이브러리
# 정치 대통령실 국회 정당 북한 행정 국방 외교 정치일반
#
#
# 안내헤드라인 뉴스 헤드라인 뉴스와 각 기사묶음 타이틀은 기사 내용을 기반으로 자동 추출됩니다 닫기 국회 정개특위 선거제 개편 500인 공론조사 실시 KBS 생중계 국회 정치개혁특별위원회 정개특위 는 오는 6일과 13일 양일간 500명의 시민참여단을 대상으로 국회의원 선거제도 개편에 대한 공론조사를 실시하고 KBS KBS 이데일리 선거제 개편 공론화 본격화 대표 시민 500인 토론 파이낸셜뉴스 선거제도 국회의원이 아닌 국민이 결정하자 정개특위 시민 500명 참여 토론회 연다 매일경제 선거개편 공론화 시민참여단 500명 모여 토론한다 8개의 관련뉴스 더보기 野 의원 독도 방문에 日 항의 외교부 부당한 주장 일축 정부는 3일 전용기 더불어민주당 의원의 독도 방문에 대한 일본 측 항의에 일본 측의 부당한 주장은 외교 채널을 통해 일축했다 고 밝혔다 외교부 당국자 조선비즈 서울경제 정부 野 독도 방문 부당 日항의에 부당한 주장 헤럴드경제 더불어민주당 경북도당 청년 대학생위 독도 현지서 독도영유권수호 다짐 노컷뉴스 韓의원 독도 방문에 日 윤석열 정권에 대한 반발이냐 이슈시개 77개의 관련뉴스 더보기 태영호 녹취록 에 與 산 넘어 산 태영호 징계 수위에 영향은 이진복 대통령실 정무수석이 22대 총선 공천 문제를 거론하며 한일 관계에 대한 옹호 발언을 해달라고 요청했다는 태영호 국민의힘 최고위원의 녹취가 공개되면 뉴스1 시사저널 체리따봉 부터 태영호 녹취록 까지 용산 당무 개입 은 이제 시작 JTBC 태영호 녹취록 에 국민의힘 발칵 당내서도 불법 공천개입 한국경제TV 대통령실 공천 개입 태영호 녹취록 논란에 與 선긋기 82개의 관련뉴스 더보기 장예찬 태영호 녹취록 일벌백계해야 김성태 
# 국회 정개특위 선거제 개편 500인 공론조사 실시 KBS 생중계 국회 정치개혁특별위원회 정개특위 는 오는 6일과 13일 양일간 500명의 시민참여단을 대상으로 국회의원 선거제도 개편에 대한 공론조사를 실시하고 KBS KBS
# 국회 정치개혁특별위원회 정개특위 는 오는 6일과 13일 양일간 500명의 시민참여단을 대상으로 국회의원 선거제도 개편에 대한 공론조사를 실시하고 KBS
# KBS
# KBS
# 이데일리 선거제 개편 공론화 본격화 대표 시민 500인 토론
# 이데일리
# 이데일리
# 파이낸셜뉴스 선거제도 국회의원이 아닌 국민이 결정하자 정개특위 시민 500명 참여 토론회 연다
# 파이낸셜뉴스
# 파이낸셜뉴스
# 매일경제 선거개편 공론화 시민참여단 500명 모여 토론한다
# 매일경제
# 매일경제
# 8개의 관련뉴스 더보기
# 8개의 관련뉴스 더보기
# 野 의원 독도 방문에 日 항의 외교부 부당한 주장 일축 정부는 3일 전용기 더불어민주당 의원의 독도 방문에 대한 일본 측 항의에 일본 측의 부당한 주장은 외교 채널을 통해 일축했다 고 밝혔다 외교부 당국자 조선비즈 서울경제 정부 野 독도 방문 부당 日항의에 부당한 주장 헤럴드경제 더불어민주당 경북도당 청년 대학생위 독도 현지서 독도영유권수호 다짐 노컷뉴스 韓의원 독도 방문에 日 윤석열 정권에 대한 반발이냐 이슈시개 77개의 관련뉴스 더보기
# 野 의원 독도 방문에 日 항의 외교부 부당한 주장 일축 정부는 3일 전용기 더불어민주당 의원의 독도 방문에 대한 일본 측 항의에 일본 측의 부당한 주장은 외교 채널을 통해 일축했다 고 밝혔다 외교부 당국자 조선비즈 서울경제 정부 野 독도 방문 부당 日항의에 부당한 주장 헤럴드경제 더불어민주당 경북도당 청년 대학생위 독도 현지서 독도영유권수호 다짐 노컷뉴스 韓의원 독도 방문에 日 윤석열 정권에 대한 반발이냐 이슈시개
#
#
# 野 의원 독도 방문에 日 항의 외교부 부당한 주장 일축 정부는 3일 전용기 더불어민주당 의원의 독도 방문에 대한 일본 측 항의에 일본 측의 부당한 주장은 외교 채널을 통해 일축했다 고 밝혔다 외교부 당국자 조선비즈
# 정부는 3일 전용기 더불어민주당 의원의 독도 방문에 대한 일본 측 항의에 일본 측의 부당한 주장은 외교 채널을 통해 일축했다 고 밝혔다 외교부 당국자
# 조선비즈
# 조선비즈
# 서울경제 정부 野 독도 방문 부당 日항의에 부당한 주장
# 서울경제
# 서울경제
# 헤럴드경제 더불어민주당 경북도당 청년 대학생위 독도 현지서 독도영유권수호 다짐
# 헤럴드경제
# 헤럴드경제
# 노컷뉴스 韓의원 독도 방문에 日 윤석열 정권에 대한 반발이냐 이슈시개
# 노컷뉴스
# 노컷뉴스
# 77개의 관련뉴스 더보기
# 77개의 관련뉴스 더보기
# 태영호 녹취록 에 與 산 넘어 산 태영호 징계 수위에 영향은 이진복 대통령실 정무수석이 22대 총선 공천 문제를 거론하며 한일 관계에 대한 옹호 발언을 해달라고 요청했다는 태영호 국민의힘 최고위원의 녹취가 공개되면 뉴스1 시사저널 체리따봉 부터 태영호 녹취록 까지 용산 당무 개입 은 이제 시작 JTBC 태영호 녹취록 에 국민의힘 발칵 당내서도 불법 공천개입 한국경제TV 대통령실 공천 개입 태영호 녹취록 논란에 與 선긋기 82개의 관련뉴스 더보기
# 태영호 녹취록 에 與 산 넘어 산 태영호 징계 수위에 영향은 이진복 대통령실 정무수석이 22대 총선 공천 문제를 거론하며 한일 관계에 대한 옹호 발언을 해달라고 요청했다는 태영호 국민의힘 최고위원의 녹취가 공개되면 뉴스1 시사저널 체리따봉 부터 태영호 녹취록 까지 용산 당무 개입 은 이제 시작 JTBC 태영호 녹취록 에 국민의힘 발칵 당내서도 불법 공천개입 한국경제TV 대통령실 공천 개입 태영호 녹취록 논란에 與 선긋기
#
#
# 태영호 녹취록 에 與 산 넘어 산 태영호 징계 수위에 영향은 이진복 대통령실 정무수석이 22대 총선 공천 문제를 거론하며 한일 관계에 대한 옹호 발언을 해달라고 요청했다는 태영호 국민의힘 최고위원의 녹취가 공개되면 뉴스1
# 이진복 대통령실 정무수석이 22대 총선 공천 문제를 거론하며 한일 관계에 대한 옹호 발언을 해달라고 요청했다는 태영호 국민의힘 최고위원의 녹취가 공개되면
# 뉴스1
# 뉴스1
# 시사저널 체리따봉 부터 태영호 녹취록 까지 용산 당무 개입 은 이제 시작
# 시사저널
# 시사저널
# JTBC 태영호 녹취록 에 국민의힘 발칵 당내서도 불법 공천개입
# JTBC
# JTBC
# 한국경제TV 대통령실 공천 개입 태영호 녹취록 논란에 與 선긋기
# 한국경제TV
# 한국경제TV
# 82개의 관련뉴스 더보기
# 82개의 관련뉴스 더보기
# 장예찬 태영호 녹취록 일벌백계해야 김성태 중징계감 아니야 이른바 공천 녹취록 유출과 관련해 여당 내부에서 의견이 엇갈리고 있다 장예찬 국민의힘 최고위원은 누구든 일벌백계 읍참마속의 기조로 엄하게 다뤄야 머니S 한겨레 장예찬 용산과 더 가까운 나도 공천 부탁 들은 적 없다 MBC 장예찬 내가 태영호보다 대통령실과 더 가까운데 공천 부탁 들어본 적 없어 시선집중 파이낸셜뉴스 장예찬 내가 태영호보다 대통령실과 더 가깝지만 공천 부탁 들어본 적 없다 9개의 관련뉴스 더보기
# 장예찬 태영호 녹취록 일벌백계해야 김성태 중징계감 아니야 이른바 공천 녹취록 유출과 관련해 여당 내부에서 의견이 엇갈리고 있다 장예찬 국민의힘 최고위원은 누구든 일벌백계 읍참마속의 기조로 엄하게 다뤄야 머니S 한겨레 장예찬 용산과 더 가까운 나도 공천 부탁 들은 적 없다 MBC 장예찬 내가 태영호보다 대통령실과 더 가까운데 공천 부탁 들어본 적 없어 시선집중 파이낸셜뉴스 장예찬 내가 태영호보다 대통령실과 더 가깝지만 공천 부탁 들어본 적 없다
#
#
# 장예찬 태영호 녹취록 일벌백계해야 김성태 중징계감 아니야 이른바 공천 녹취록 유출과 관련해 여당 내부에서 의견이 엇갈리고 있다 장예찬 국민의힘 최고위원은 누구든 일벌백계 읍참마속의 기조로 엄하게 다뤄야 머니S
# 이재명 더불어민주당 대표가 지난 2일 분신 시도 후 끝내 사망한 노동자를 두고 윤석열 정권의 노조 탄압이 결국 소중한 생명을 앗아갔다 고 강하게 비판했
# 이데일리
# 이데일리
#
#
# 이재명 노조원 분신 사망에 대통령에 원천 책임 사과해야 최근 정부에 항의하며 분신한 건설노조 간부가 숨진 것과 관련 이재명 더불어민주당 대표가 3일 원천적 책임은 대통령에게 있다 며 대통령에게 진솔한 사 머니투데이
# 최근 정부에 항의하며 분신한 건설노조 간부가 숨진 것과 관련 이재명 더불어민주당 대표가 3일 원천적 책임은 대통령에게 있다 며 대통령에게 진솔한 사
# 머니투데이
# 머니투데이
# 30개의 관련뉴스 더보기
# 30개의 관련뉴스 더보기
# 상습적으로 임금 안 주는 사업주 정부 지원사업 제한한다 3개월분 이상 체불하는 등 상습적으로 임금을 체불하면서 적극적인 청산노력을 기울이지 않는 사업주에 대해 형사처벌 외 경제적 제재가 추가된다 이정식 고용 이데일리 임금 3개월 밀리면 신용제재 상습체불 근절대책 임금을 3개월분 이상 상습적으로 체불하는 등 적극적인 청산노력을 기울이지 않는 사업주에 대해 신용제재와 정부지원 제한 등 경제적 제재가 강화된다 고용노 아시아경제 36개의 관련뉴스 더보기
# 상습적으로 임금 안 주는 사업주 정부 지원사업 제한한다 3개월분 이상 체불하는 등 상습적으로 임금을 체불하면서 적극적인 청산노력을 기울이지 않는 사업주에 대해 형사처벌 외 경제적 제재가 추가된다 이정식 고용 이데일리 임금 3개월 밀리면 신용제재 상습체불 근절대책 임금을 3개월분 이상 상습적으로 체불하는 등 적극적인 청산노력을 기울이지 않는 사업주에 대해 신용제재와 정부지원 제한 등 경제적 제재가 강화된다 고용노 아시아경제
#
#
# 상습적으로 임금 안 주는 사업주 정부 지원사업 제한한다 3개월분 이상 체불하는 등 상습적으로 임금을 체불하면서 적극적인 청산노력을 기울이지 않는 사업주에 대해 형사처벌 외 경제적 제재가 추가된다 이정식 고용 이데일리
# 3개월분 이상 체불하는 등 상습적으로 임금을 체불하면서 적극적인 청산노력을 기울이지 않는 사업주에 대해 형사처벌 외 경제적 제재가 추가된다 이정식 고용
# 이데일리
# 이데일리
#
#
# 임금 3개월 밀리면 신용제재 상습체불 근절대책 임금을 3개월분 이상 상습적으로 체불하는 등 적극적인 청산노력을 기울이지 않는 사업주에 대해 신용제재와 정부지원 제한 등 경제적 제재가 강화된다 고용노 아시아경제
# 임금을 3개월분 이상 상습적으로 체불하는 등 적극적인 청산노력을 기울이지 않는 사업주에 대해 신용제재와 정부지원 제한 등 경제적 제재가 강화된다 고용노
# 아시아경제
# 아시아경제
# 36개의 관련뉴스 더보기
# 36개의 관련뉴스 더보기
# 민주 기시다 총리 방한 과거사 사과부터 받아야 더불어민주당은 일본 기시다 총리가 오는 7일과 8일 방한한다는 정부 발표에 대해 과거사 사과부터 받아야 한다 고 직격했다 권칠승 수석대변인은 2일 논 뉴시스 동영상기사 대통령실 기시다 7일 방한 내일 안보실장 사전 회담 기시다 일본 총리가 오는 7일부터 1박 2일 일정으로 한국을 방문합니다 내일 3일 은 두 나라 안보실장이 먼저 만나 정상회담에서 어떤 의제를 다룰지 논 SBS 110개의 관련뉴스 더보기
# 북한이 확장억제 강화 방안이 담긴 워싱턴 선언에 대해 한미 정상을 겨냥한 화형식까지 열며 반발 수위를 높이고 있습니다 김여정의 막말 담화에 이은 비난
# YTN
# YTN
#
#
# 北 워싱턴선언 반발 수위 고조 한미 정상 겨냥 화형식 진행 청년학생 복수결의모임 2일 개최 늙다리 전쟁괴수와 특등하수인의 추악한 몰골들이 재가루로 북한이 워싱턴 선언 을 비난하는 청년학생 집회를 열고 세계일보
# 청년학생 복수결의모임 2일 개최 늙다리 전쟁괴수와 특등하수인의 추악한 몰골들이 재가루로 북한이 워싱턴 선언 을 비난하는 청년학생 집회를 열고
# 세계일보
# 세계일보
# 44개의 관련뉴스 더보기
# 44개의 관련뉴스 더보기
# 태영호 비서관이 녹취록 유출 허위사실 태영호 국민의힘 최고위원이 녹취록 유출자로 자신의 보좌진이 의심받는 상황에 유감을 표했다 2일 태 최고위원은 자신의 SNS 계정에 현재 일부 유튜버들 YTN 태영호 녹취록 유출자 이들일 것 유튜버들의 마녀사냥 태영호 국민의힘 최고위원은 녹취록 파문으로 자신의 보좌진이 유출자로 의심받는 상황에 강력 반발하며 유감을 표했습니다 태 최고위원은 전날 2일 밤 페이 MBN 14개의 관련뉴스 더보기
# 태영호 비서관이 녹취록 유출 허위사실 태영호 국민의힘 최고위원이 녹취록 유출자로 자신의 보좌진이 의심받는 상황에 유감을 표했다 2일 태 최고위원은 자신의 SNS 계정에 현재 일부 유튜버들 YTN 태영호 녹취록 유출자 이들일 것 유튜버들의 마녀사냥 태영호 국민의힘 최고위원은 녹취록 파문으로 자신의 보좌진이 유출자로 의심받는 상황에 강력 반발하며 유감을 표했습니다 태 최고위원은 전날 2일 밤 페이 MBN
#
#
# 태영호 비서관이 녹취록 유출 허위사실 태영호 국민의힘 최고위원이 녹취록 유출자로 자신의 보좌진이 의심받는 상황에 유감을 표했다 2일 태 최고위원은 자신의 SNS 계정에 현재 일부 유튜버들 YTN
# 태영호 국민의힘 최고위원이 녹취록 유출자로 자신의 보좌진이 의심받는 상황에 유감을 표했다 2일 태 최고위원은 자신의 SNS 계정에 현재 일부 유튜버들
# YTN
# YTN
#
#
# 태영호 녹취록 유출자 이들일 것 유튜버들의 마녀사냥 태영호 국민의힘 최고위원은 녹취록 파문으로 자신의 보좌진이 유출자로 의심받는 상황에 강력 반발하며 유감을 표했습니다 태 최고위원은 전날 2일 밤 페이 MBN
# 태영호 국민의힘 최고위원은 녹취록 파문으로 자신의 보좌진이 유출자로 의심받는 상황에 강력 반발하며 유감을 표했습니다 태 최고위원은 전날 2일 밤 페이
# MBN
# MBN
# 14개의 관련뉴스 더보기
# 14개의 관련뉴스 더보기
# 박광온 오늘 의총서 국민이 바라는 쇄신방안 마련 향후 전원토론 실시 모든 의원 대상 심층 설문조사 최종 쇄신 보고서 보고 박광온 더불어민주당 원내대표는 3일 개최가 예정된 의원총회와 관련 쇄신 의총의 전 과정은 조선비즈 박광온 집단지성 통해 국민 바라는 쇄신안 마련할 것 기사내용 요약 의원 대상 심층설문조사 국민 대상 웹조사 실시 조사 결과 나온 주제들로 심층 토론 진행 예정 서울 뉴시스 박광온 더불어민주당 원내대표가 뉴시스 18개의 관련뉴스 더보기
# 손혜원 목포 투기 의혹 조선일보 상대 항소심도 패소 TV조선
# 택시에 두고 내린 40년 업무자료 한 달간 CCTV 돌 SBS
# 택시에 두고 내린 40년 업무자료 한 달간 CCTV 돌 SBS
# 택시에 두고 내린 40년 업무자료 한 달간 CCTV 돌 SBS
# 여보 세력 나야 임창정 패러디에 칼 뺐다 매일경제
# 여보 세력 나야 임창정 패러디에 칼 뺐다 매일경제
# 여보 세력 나야 임창정 패러디에 칼 뺐다 매일경제
# 새치기 하다니 서울대 명예교수 구내식당서 학생 폭행 동아일보
# 새치기 하다니 서울대 명예교수 구내식당서 학생 폭행 동아일보
# 새치기 하다니 서울대 명예교수 구내식당서 학생 폭행 동아일보
# 신부 이어 목사 1000명 시국선언 윤석열 운명 다했다 한겨레
# 신부 이어 목사 1000명 시국선언 윤석열 운명 다했다 한겨레
# 신부 이어 목사 1000명 시국선언 윤석열 운명 다했다 한겨레
# 인어 몸매가 왜 이래 조각상에 발칵 뒤집힌 이탈리아 아시아경제
# 인어 몸매가 왜 이래 조각상에 발칵 뒤집힌 이탈리아 아시아경제
# 인어 몸매가 왜 이래 조각상에 발칵 뒤집힌 이탈리아 아시아경제
# 10분 만에 25억 꽂혔다 임창정 계좌 공개하며 결 MBC
# 10분 만에 25억 꽂혔다 임창정 계좌 공개하며 결 MBC
# 10분 만에 25억 꽂혔다 임창정 계좌 공개하며 결 MBC
# 단독 깔렸다고 밀지 마 민노총 집회서 경찰 밀어 조선일보
# 단독 깔렸다고 밀지 마 민노총 집회서 경찰 밀어 조선일보
# 단독 깔렸다고 밀지 마 민노총 집회서 경찰 밀어 조선일보
# 공무원 인기 떨어졌다 완전자본잠식 빠진 에듀윌 이데일리
# 공무원 인기 떨어졌다 완전자본잠식 빠진 에듀윌 이데일리
# 공무원 인기 떨어졌다 완전자본잠식 빠진 에듀윌 이데일리
# 해고 당했는데 자진 퇴사 라니 실업급여도 막막 5인미만 KBS
# 해고 당했는데 자진 퇴사 라니 실업급여도 막막 5인미만 KBS
# 해고 당했는데 자진 퇴사 라니 실업급여도 막막 5인미만 KBS
# 날씨 중부 초여름 더위 내일 전국 비소식 연합뉴스TV
# 날씨 중부 초여름 더위 내일 전국 비소식 연합뉴스TV
# 날씨 중부 초여름 더위 내일 전국 비소식 연합뉴스TV
# 나도 피해자 임창정 주가조작단 美골프장 계약자리 동행 디지털타임스
# 나도 피해자 임창정 주가조작단 美골프장 계약자리 동행 디지털타임스
# 나도 피해자 임창정 주가조작단 美골프장 계약자리 동행 디지털타임스
# 국내 언론이 본 한미정상회담 동맹은 격상 경제 성과 기자협회보
# 국내 언론이 본 한미정상회담 동맹은 격상 경제 성과 기자협회보
# 국내 언론이 본 한미정상회담 동맹은 격상 경제 성과 기자협회보
# 日 유명 개그맨이 韓 시장에서 보인 돌발 행동 일본 사 YTN
# 日 유명 개그맨이 韓 시장에서 보인 돌발 행동 일본 사 YTN
# 日 유명 개그맨이 韓 시장에서 보인 돌발 행동 일본 사 YTN
# 32년째 행방불명 아나운서 어디로 갔나 MBN
# 32년째 행방불명 아나운서 어디로 갔나 MBN
# 32년째 행방불명 아나운서 어디로 갔나 MBN
# 단독 돈세탁 의혹 유명 유튜버 헬스장에 수상한 사 뉴스1
# 단독 돈세탁 의혹 유명 유튜버 헬스장에 수상한 사 뉴스1
# 단독 돈세탁 의혹 유명 유튜버 헬스장에 수상한 사 뉴스1
# 백윤식 전 연인 폭로 에세이 출판 판매금지 소송서 일 경향신문
# 백윤식 전 연인 폭로 에세이 출판 판매금지 소송서 일 경향신문
# 백윤식 전 연인 폭로 에세이 출판 판매금지 소송서 일 경향신문
# 한강변 49층이요 35층 하시죠 반포 재건축 초고층 헤럴드경제
# 한강변 49층이요 35층 하시죠 반포 재건축 초고층 헤럴드경제
# 한강변 49층이요 35층 하시죠 반포 재건축 초고층 헤럴드경제
# 메스 들고 허벅지 정맥 도려낸 김 선생 그의 정체 한국일보
# 메스 들고 허벅지 정맥 도려낸 김 선생 그의 정체 한국일보
# 메스 들고 허벅지 정맥 도려낸 김 선생 그의 정체 한국일보
# 영영 못 찾을 줄 알았던 카메라가 다시 내 손에 한국 세계일보
# 영영 못 찾을 줄 알았던 카메라가 다시 내 손에 한국 세계일보
# 영영 못 찾을 줄 알았던 카메라가 다시 내 손에 한국 세계일보
# 부촌 명성 고개 드나 달맞이고개 100억 빌라 들어선 부산일보
# 부촌 명성 고개 드나 달맞이고개 100억 빌라 들어선 부산일보
# 부촌 명성 고개 드나 달맞이고개 100억 빌라 들어선 부산일보
# 영상 속도 감당 못한 페라리가 들이받은 닛산 하늘로 문화일보
# 영상 속도 감당 못한 페라리가 들이받은 닛산 하늘로 문화일보
# 영상 속도 감당 못한 페라리가 들이받은 닛산 하늘로 문화일보
# 체중 줄이고 싶은 여성 이 기간 에 운동 해보세요 헬스조선
# 체중 줄이고 싶은 여성 이 기간 에 운동 해보세요 헬스조선
# 체중 줄이고 싶은 여성 이 기간 에 운동 해보세요 헬스조선
# 도로서 어린 남매 발견한 최초 신고자 맨발에 속옷차림으로 파이낸셜뉴스
# 도로서 어린 남매 발견한 최초 신고자 맨발에 속옷차림으로 파이낸셜뉴스
# 도로서 어린 남매 발견한 최초 신고자 맨발에 속옷차림으로 파이낸셜뉴스
# 평택 아파트서 30대 엄마와 7세 아들 숨진 채 발견 서울신문
# 평택 아파트서 30대 엄마와 7세 아들 숨진 채 발견 서울신문
# 평택 아파트서 30대 엄마와 7세 아들 숨진 채 발견 서울신문
# 日 개그맨 망원시장서 침 묻은 꼬치로 닭강정 푹 뉴시스
# 日 개그맨 망원시장서 침 묻은 꼬치로 닭강정 푹 뉴시스
# 日 개그맨 망원시장서 침 묻은 꼬치로 닭강정 푹 뉴시스
# 완공 5개월 앞두고 와르르 입주 예정자들 분통 한국경제TV
# 완공 5개월 앞두고 와르르 입주 예정자들 분통 한국경제TV
# 완공 5개월 앞두고 와르르 입주 예정자들 분통 한국경제TV
# 韓의원 독도 방문에 日 윤석열 정권에 대한 반발이냐 이 노컷뉴스
# 또 오너리스크 셀트리온그룹주 이번엔 서정진 회장 매경이코노미
# 또 오너리스크 셀트리온그룹주 이번엔 서정진 회장 매경이코노미
# 또 오너리스크 셀트리온그룹주 이번엔 서정진 회장 매경이코노미
# 알코올성 간질환 표적 치료 열쇠 찾았다 동아사이언스
# 알코올성 간질환 표적 치료 열쇠 찾았다 동아사이언스
# 알코올성 간질환 표적 치료 열쇠 찾았다 동아사이언스
# 엠폭스 환자 96 남성 대부분 20 40대 여성신문
# 엠폭스 환자 96 남성 대부분 20 40대 여성신문
# 엠폭스 환자 96 남성 대부분 20 40대 여성신문
# 서정진 혼외 자녀 호적 오르자 셀트리온 주가 흔들 이코노미스트
# 서정진 혼외 자녀 호적 오르자 셀트리온 주가 흔들 이코노미스트
# 서정진 혼외 자녀 호적 오르자 셀트리온 주가 흔들 이코노미스트
# 최근 혈당이 높아졌다면 착한 탄수화물 식품6 코메디닷컴
# 최근 혈당이 높아졌다면 착한 탄수화물 식품6 코메디닷컴
# 최근 혈당이 높아졌다면 착한 탄수화물 식품6 코메디닷컴
# 연산군의 탕춘대 가 왜 세계유산감일까 이기환의 Hi st 주간경향
# 연산군의 탕춘대 가 왜 세계유산감일까 이기환의 Hi st 주간경향
# 연산군의 탕춘대 가 왜 세계유산감일까 이기환의 Hi st 주간경향
# 나는 신이다 재현은 왜 문제가 되는가 일다
# 나는 신이다 재현은 왜 문제가 되는가 일다
# 나는 신이다 재현은 왜 문제가 되는가 일다
# 속보 분신사망 건설노조 강원지부 간부 대한민국 바로 강원도민일보
# 속보 분신사망 건설노조 강원지부 간부 대한민국 바로 강원도민일보
# 속보 분신사망 건설노조 강원지부 간부 대한민국 바로 강원도민일보
# Man Wall 선수도 힘든 5 14급 루트 끝낸 하하 월간 산
# Man Wall 선수도 힘든 5 14급 루트 끝낸 하하 월간 산
# Man Wall 선수도 힘든 5 14급 루트 끝낸 하하 월간 산
# 안철수보다 윤석열이 먼저 손 내밀었다 영상 신동아
# 안철수보다 윤석열이 먼저 손 내밀었다 영상 신동아
# 안철수보다 윤석열이 먼저 손 내밀었다 영상 신동아
# Korean victim of Japanese wartim 코리아중앙데일리
# Korean victim of Japanese wartim 코리아중앙데일리
# Korean victim of Japanese wartim 코리아중앙데일리
# 콧물 주르륵 OOO염 방치 시 수술 필요 농민신문
# 콧물 주르륵 OOO염 방치 시 수술 필요 농민신문
# 콧물 주르륵 OOO염 방치 시 수술 필요 농민신문
# 영상 마음이 아프신가요 국립 김천 치유의 숲 대구MBC
# 영상 마음이 아프신가요 국립 김천 치유의 숲 대구MBC
# 영상 마음이 아프신가요 국립 김천 치유의 숲 대구MBC
# 김기현 윤리위에 태영호 녹취록 병합 심사 요청 심 대전일보
# 김기현 윤리위에 태영호 녹취록 병합 심사 요청 심 대전일보
# 김기현 윤리위에 태영호 녹취록 병합 심사 요청 심 대전일보
# 尹 호위무사 이용 김건희 여사 활동적이지 않고 온순 JIBS
# 尹 호위무사 이용 김건희 여사 활동적이지 않고 온순 JIBS
# 이재명 윤관석 이성만 탈당 질문에 태영호 녹취는요 韓의원 독도 방문 항의한 일본 외교부 부당한 주장 일축 임금체불 한해 1조3천억원 상습체불 사업주 신용대출 제한 종합 한국서 침 묻은 꼬치로 판매 음식 푹푹 찌른 일본인 뭇매 美 부채가 더 걱정 백악관 협상 불가 재천명 디폴트 우려 고조 ADB2023 尹 대통령 韓 아시아 협력 공동망 구축 대한항공 부산세계박람회 유치 기원 특별 항공기 공개 최저가 노트북 업체의 몰락 뒤엔 G마켓 경쟁사 갑질 동맹 카카오게임즈 2분기 반등 자신 오딘 日 보내고 아레스 출격 종합 삼성 올해 월드 디제이 페스티벌 에 갤럭시 찐팬 초청 건설노동자 분신 사망에 尹 정부 건폭 신조어까지 만들어 노조 매도하더니 엠폭스 환자 52명 중 50명이 남성 96 성접촉 감염 종합 송영길 전 보좌관 검찰 출석 돈 봉투 본 적도 없어 날씨 중부 초여름 더위 내일 전국 비소식 KG 모빌리티 렉스턴 뉴 아레나 스포츠 칸 쿨멘 출격
#
#
#
#
#
# 서비스 안내 고침 기사 모음 정정 반론 추후 보도 기사 모음 불공정 선거 보도 기사 모음 서비스 안내더보기
# 이젠 페이지 맨위로 언론사 목록열기로딩 중 분야별 목록열기로딩 중
# 이젠 페이지 맨위로 언론사 목록열기로딩 중 분야별 목록열기로딩 중
# 이젠 페이지 맨위로
# 이젠 페이지 맨위로
# 언론사 목록열기로딩 중 분야별 목록열기로딩 중
#
#
# 이용약관 서비스 안내 기사배열 원칙 책임자 유봉석 청소년 보호 책임자 이희만 개인정보처리방침 책임의 한계와 법적고지 뉴스 고객센터 본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다 NAVER Copyright NAVER Corp All Rights Reserved

# %% [markdown]
# #### 과제2_0503,
# url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100' 사이트에서
# id가 'footer'인 한글만 출력하세요.

# %% [markdown]
# #### 과제3_0503.
# url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100' 사이트에서
# p태그가 있는 데이터를 5개만 출력하세요

# %% [markdown]
# #### 과제4_0503.
# url = 'https://news.daum.net/politics' 사이트에서 '정치'를 출력하세요.

# %%
# url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100' 사이트에서 
# id가 있는 데이터를 모두 출력하세요
from bs4 import BeautifulSoup
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100'

r = rq.get(url,headers=headers)
html = r.text
bs = BeautifulSoup(html,'html.parser')
print(bs.find_all(id=True))
# Out:
# [<div id="wrap">
# <!-- 광고적용 태그 추가 -->
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
# <li><span class="snb_bdr"></span><a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">스포츠</a></li>
# <li><span class="snb_bdr"></span><a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">날씨</a></li>
# <li><span class="snb_bdr"></span><a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">프리미엄</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_both">
# <div class="lnb_left">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li><a class="nclicks(lnb.pcmedia)" href="/"><span class="tx">언론사별</span> </a></li>
# <li class="on"><a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
# <li><a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a></li>
# <li><a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹</span> </a></li>
# <li><a class="nclicks(lnb.paper)" href="/newspaper/home"><span class="tx">신문보기</span> </a></li>
# <li><a class="nclicks(lnb.opi)" href="/opinion/home"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(lnb.fact)" href="/main/factcheck/main.naver"><span class="tx">팩트체크</span> </a></li>
# </ul>
# </div>
# </div>
# <div class="lnb_right">
# <div class="lnb_extra">
# <div class="lnb_extra_menu">
# <ul class="lnb_extra_menu_list">
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(STA.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb">
# <span class="lnb_date"><strong>05</strong>.<strong>03</strong><span class="day">(수)</span></span>
# <ul class="lnb_side" tabindex="0">
# <li><a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li><a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li><a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# <hr/>
# <table cellpadding="0" cellspacing="0" class="container">
# <caption class="blind">기사목록</caption>
# <colgroup>
# <col class="col_snb"/>
# <col class="col_content"/>
# <col class="col_aside"/>
# </colgroup>
# <tr>
# <td class="snb">
# <div class="snb" id="snb">
# <h2 class="h2"><a class="nclicks(lmn_pol.home)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100">정치</a></h2>
# <ul class="nav">
# <li><a class="snb_s11 nclicks(lmn_pol.mnl,,1)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=264">대통령실 </a></li>
# <li><a class="snb_s12 nclicks(lmn_pol.mnl,,2)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=265">국회/정당 </a></li>
# <li><a class="snb_s13 nclicks(lmn_pol.mnl,,3)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=268">북한 </a></li>
# <li><a class="snb_s14 nclicks(lmn_pol.mnl,,4)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=266">행정 </a></li>
# <li><a class="snb_s15 nclicks(lmn_pol.mnl,,5)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=267">국방/외교 </a></li>
# <li><a class="snb_s16 nclicks(lmn_pol.mnl,,6)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=269">정치일반 </a></li>
# </ul>
# <div class="snb_banner">
# <a class="nclicks(lmn_pol.pmb,,1)" href="https://media.naver.com/channel/setting?back=main"><img alt="언론사 구독하기" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/01/14/142956425_144518244_%2525B8%2525F0%2525B9%2525D9%2525C0%2525CF%2525B8%2525DE%2525C0%2525CE.png" width="71"/></a>
# </div>
# <div class="snb_banner">
# <a class="nclicks(lmn_pol.pmb,,1)" href="https://contents.premium.naver.com/"><img alt="네이버 프리미엄콘텐츠" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71"/></a>
# </div>
# </div>
# </td>
# <td class="content">
# <div class="content" id="main_content">
# <div class="list_body section_index">
# <div class="cluster">
# <div class="cluster_title">
# <span class="cluster_title_inner"><a class="cluster_title_icon_link _news_cluster_layer_btn" href="#biF7L"><i class="cluster_title_icon">안내</i>헤드라인 뉴스</a></span>
# <div class="cluster_title_layer _news_cluster_layer is_hidden">
# <div class="cluster_title_layer_text">
#                             헤드라인 뉴스와 각 기사묶음 타이틀은 <br/> 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.
#                         </div>
# <div class="cluster_title_layer_image"></div>
# <button class="cluster_title_layer_close _news_cluster_layer_close_btn" type="button">닫기</button>
# </div>
# </div>
# </div>
# <div class="_persist">
# <div class="cluster">
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011477736?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/056/2023/05/03/11477736.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011477736?sid=100">국회 JMS 토론회 열려…“변호인 접견권 제한 근거 마련해야”</a>
# <div class="cluster_text_lede">JMS 총재 정명석 씨의 ‘황제 접견’ 논란과 관련해 변호인 접견권을 제한해야 할지를 두고 국회에서 토론회가 열렸습니다. 더불어민주당 박범계 의원은 오늘 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news056,0011477736',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">KBS</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news016,0002138715',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">헤럴드경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002138715?sid=100">“JMS 신도, 교도관·법조계·대학·국정원까지 퍼져 있다”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004186288',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004186288?sid=100">“교도관·법조계·대학·정부기관까지 JMS 신도 퍼져”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news079,0003765805',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">노컷뉴스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/079/0003765805?sid=100">'JMS 황제접견' 방지…국회서 접견남용 방지 토론회 연다</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305021810_00000913&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=056&amp;aid=0011477736"><span class="cluster_foot_more_icon_num">6</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004186064?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/011/2023/05/03/4186064.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004186064?sid=100">日 정부, 민주당 의원 독도 방문에 항의·유감표명</a>
# <div class="cluster_text_lede">일본 정부가 더불어민주당 전용기 의원이 독도를 방문한 데 대해 외교 경로를 통해 항의했다. 3일 교도통신 등 일본 언론에 따르면 후나코시 다케히로 일본  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004186064',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004186276',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004186276?sid=100">정부, "野 독도 방문 부당' 日항의에 "부당한 주장"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news437,0000341569',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">JTBC</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/437/0000341569?sid=100">전용기 의원, 독도 관련 일본 항의에 "내정간섭, 외교부가 강력 대응해야"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news008,0004882635',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">머니투데이</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/008/0004882635?sid=100">"韓 의원, 다케시마 상륙" 日 외무성, 韓에 재발 방지 요구</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305021530_00000499&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=011&amp;aid=0004186064"><span class="cluster_foot_more_icon_num">81</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011837498?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/05/03/11837498.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011837498?sid=100">홍준표 "尹, 이재명 안 만나는건 '딜'오해 때문…불통 아냐"</a>
# <div class="cluster_text_lede">기사내용 요약 김재원·태영호에 "중징계 불가피해 보여" 간호법 제정안 "대통령 거부권 행사해야" [서울=뉴홍준표 대구시장은 3일 윤석열 대통령이 이재명  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011837498',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news008,0004882753',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">머니투데이</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/008/0004882753?sid=100">홍준표 "尹대통령 불통 아냐, 이재명 안 만나는 이유는…"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news025,0003277520',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">중앙일보</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277520?sid=100">홍준표 "尹, 이재명 안 만나는 건 '딜' 오해 때문…불통 아니다"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news014,0005006498',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">파이낸셜뉴스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/014/0005006498?sid=100">홍준표 "尹, 이재명과 안 만나는 이유?  '딜' 오해 때문"</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305030940_00000034&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=003&amp;aid=0011837498"><span class="cluster_foot_more_icon_num">17</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/079/0003765874?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/079/2023/05/03/3765874.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/079/0003765874?sid=100">'돈봉투' 밤샘의총 두고 당내 갑론을박…시기 미뤄지나</a>
# <div class="cluster_text_lede">더불어민주당이 전당대회 돈 봉투 의혹 수습을 위한 '쇄신 의원총회'에 대해 본격 논의에 들어갔다. 당내에선 탈당, 자체조사 등 당 차원의 결단이 필요하다 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news079,0003765874',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">노컷뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011837599',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011837599?sid=100">박광온 "집단지성 통해 국민 바라는 쇄신안 마련할 것"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news008,0004882746',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">머니투데이</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/008/0004882746?sid=100">박광온 "집단지성 통해 국민 원하는 쇄신안 마련할 것"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006783752',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006783752?sid=100">민주, 오늘 의원총회…전대 '돈봉투 의혹' 쇄신 본격화</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010010_00000758&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=079&amp;aid=0003765874"><span class="cluster_foot_more_icon_num">18</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/079/0003765927?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/079/2023/05/03/3765927.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/079/0003765927?sid=100">한미 워싱턴선언에 北 '화형식' 개최 반발…신천박물관 청년복수결의 진행</a>
# <div class="cluster_text_lede">핵심요약 "美 늙다리 전쟁괴수와 괴뢰역도의 추악한 몰골들 재가루로" 북한이 반미 정신을 상징하는 신천박물관에서 워싱턴선언을 채택한 한미정상에 대한 청년들 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news079,0003765927',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">노컷뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002138529?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/016/2023/05/03/2138529.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002138529?sid=100">北, ‘워싱턴선언’ 채택 후 ‘막말에 화형식’ 연일 민감 반응</a>
# <div class="cluster_text_lede">윤석열 대통령과 조 바이든 미국 대통령이 한미정상회담 후 확장억제 강화 방안을 골자로 한 ‘워싱턴 선언’을 채택하면서 이에 대한 북한의 강도 높은 반발이 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news016,0002138529',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">헤럴드경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305030700_00000006&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=079&amp;aid=0003765927"><span class="cluster_foot_more_icon_num">44</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/079/0003765959?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/079/2023/05/03/3765959.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/079/0003765959?sid=100">상습 임금 체불 사업주 경제적 제재 강화</a>
# <div class="cluster_text_lede">상습적으로 임금을 체불하면서 적극적인 청산 노력을 기울이지 않는 사업주에 대한 경제적 제재가 강화된다. 고용노동부는 3일 이런 내용을 담은 '상습체불 근 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news079,0003765959',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">노컷뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898624?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/366/2023/05/03/898624.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898624?sid=100">임금 체불 1.3조, 근로자 24만명 생계 위협…악의적 체불, 구속수사한다</a>
# <div class="cluster_text_lede">고용부·국민의힘, 상습체불 근절대책 발표 “사회적 인식 문제도…한국이 日보다 18배 많다” “재산은닉·출석거부 악의적 체불 사업주, 구속수사·체포영장 신 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news366,0000898624',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선비즈</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305030930_00000008&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=079&amp;aid=0003765959"><span class="cluster_foot_more_icon_num">46</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/629/0000214897?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/629/2023/05/02/214897.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/629/0000214897?sid=100">대통령실 "日 기시다 총리 방한 핵심 의제는 '안보·경제협력'"</a>
# <div class="cluster_text_lede">한일관계 전반, 북한 및 지역, 국제정세, 상호관심사 등 의제" 기시다 후미오 일본 총리 내외가 오는 7~8일 한국을 실무 방문할 예정인 가운데 대통령실 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news629,0000214897',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">더팩트</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/449/0000248834?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/449/2023/05/02/248834.jpg?type=ofullfill132_90" width="132"/>
# <strong class="r_ico r_vod_medium">동영상기사</strong>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/449/0000248834?sid=100">日 총리 부부, 14년 만에 방한…첫날 한일 정상회담 예정</a>
# <div class="cluster_text_lede">뉴스에이 시작합니다. 저는 동정민입니다. 한일, 한미 외교에 이어 한중일 3국 외교 정상화에도 시동이 걸렸습니다. 한중일 3국 정상회의 협의가 곧 시작되 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news449,0000248834',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">채널A</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304290110_00000004&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=629&amp;aid=0000214897"><span class="cluster_foot_more_icon_num">109</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277556?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/025/2023/05/03/3277556.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277556?sid=100">'바이든 깜짝선물' 성김 은퇴할 듯…美 한반도라인 세대 교체</a>
# <div class="cluster_text_lede">미 국무부에서 북핵 문제를 총괄해온 성김 대북특별대표 겸 주인도네시아가 올해를 끝으로 은퇴할 가능성이 제기됐다. 최근 한ㆍ미 정상회담의 실무를 총괄한 에 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news025,0003277556',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">중앙일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/021/0002569943?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/021/2023/05/03/2569943.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/021/0002569943?sid=100">성김 대북대표 은퇴 검토… 미국 한반도라인 세대 교체</a>
# <div class="cluster_text_lede">“핵공유 아니다” 발언 케이건 말레이시아 대사에 지명돼 워싱턴 = 김남석 특파원 namdol@munhwa.com 한·미 정상회담이 마무리된 가운데 미국의 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news021,0002569943',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">문화일보</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305030930_00000174&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=025&amp;aid=0003277556"><span class="cluster_foot_more_icon_num">6</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003761470?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/023/2023/05/03/3761470.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003761470?sid=100">‘전대 돈봉투 의혹’ 민주 윤관석·이성만 의원 탈당</a>
# <div class="cluster_text_lede">윤관석·이성만 의원이 3일 더불어민주당을 자진 탈당했다. 두 의원은 지난 2021년 민주당 전당 대회 때 내부에 돈 봉투를 돌린 의혹에 연루돼 검찰 압수 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news023,0003761470',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006784688?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/421/2023/05/03/6784688.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006784688?sid=100">'돈 봉투 의혹' 윤관석·이성만 전격 탈당…당내 압박에 "선당후사"</a>
# <div class="cluster_text_lede">2021년 전당대회 당시 금품 공여 혐의를 받고 있는 윤관석·이성만 더불어민주당 의원이 3일 전격 탈당했다. 일명 '돈 봉투' 의혹과 관련한 부담을 덜어 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006784688',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305021920_00000080&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=023&amp;aid=0003761470"><span class="cluster_foot_more_icon_num">87</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013919382?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2023/05/03/13919382.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013919382?sid=100">'태영호 녹취' 與설왕설래…"태의원이 과장" "터질게 터졌다"</a>
# <div class="cluster_text_lede">일각선 국민의힘 전신 새누리·미래통합당 '공천 파동' 소환도 국민의힘 내에서 '태영호 녹취'를 놓고 설왕설래가 이어지고 있다. MBC가 지난 1일 보도한 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013919382',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/422/0000596738?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/422/2023/05/02/596738.jpg?type=ofullfill132_90" width="132"/>
# <strong class="r_ico r_vod_medium">동영상기사</strong>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/422/0000596738?sid=100">'태영호 녹취' 여파…여, 진화 노력 속 내부 비판도</a>
# <div class="cluster_text_lede">이진복 대통령실 정무수석이 태영호 국민의힘 최고위원에게 공천 문제를 거론했다는 의혹이 제기되면서 당 내부로 여파가 미치고 있습니다. 당 지도부는 해명된  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news422,0000596738',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스TV</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305012010_00000017&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0013919382"><span class="cluster_foot_more_icon_num">73</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277507?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/025/2023/05/03/3277507.jpg?type=ofullfill132_90" width="132"/>
# <strong class="r_ico r_vod_medium">동영상기사</strong>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277507?sid=100">"태영호 녹취록 유출자, 이들 의심"…극우 유튜버 마녀사냥</a>
# <div class="cluster_text_lede">태영호 국민의힘 최고위원은 녹취록 파문으로 자신의 보좌진이 유출자로 의심받는 상황에 강력 반발하며 유감을 표했다. 태 최고위원은 전날(2일) 밤 페이스북 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news025,0003277507',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">중앙일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/082/0001210447?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/082/2023/05/03/1210447.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/082/0001210447?sid=100">'태영호 녹취록' 일파만파…여권에서도 "무거운 정치적 책임져야"</a>
# <div class="cluster_text_lede">국민의힘 태영호 최고위원의 이른바 '태영호 녹취록'이 정치권에 퍼진 이후 여당 강성 지지층이 녹취 파일 유출자를 색출하는 ‘신상 털기’를 시작하는 등 파 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news082,0001210447',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">부산일보</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305030800_00000037&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=025&amp;aid=0003277507"><span class="cluster_foot_more_icon_num">14</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002138754?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/016/2023/05/03/2138754.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002138754?sid=100">이준석 “난 양두구육 썼다고 징계 1년…김재원·태영호, 더 강한 징계 나와야”</a>
# <div class="cluster_text_lede">이준석 전 국민의힘 대표가 당 윤리위원회에서 징계 절차가 시작된 김재원·태영호 최고위원에게 당원권 정지 1년보다 더 강한 징계가 나와야 한다고 주장했다. …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news016,0002138754',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">헤럴드경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001270370?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/214/2023/05/03/1270370.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001270370?sid=100">이준석 "'양두구육'은 징계 1년‥김재원·태영호, 더 강한 징계 나와야"</a>
# <div class="cluster_text_lede">이준석 전 국민의힘 대표가 잇단 설화로 당 윤리위원회에서 징계 절차가 시작된 김재원·태영호 최고위원에게 당원권 정지 1년보다 더 강한 징계가 나와야 한다 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news214,0001270370',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">MBC</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304281030_00001855&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=016&amp;aid=0002138754"><span class="cluster_foot_more_icon_num">16</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/119/0002709072?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/119/2023/05/03/2709072.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/119/0002709072?sid=100">윤석열 대통령, ADB총회 참석…금융그룹 CEO '총출동'(종합)</a>
# <div class="cluster_text_lede">윤석열 대통령을 포함해 국내 금융그룹 최고경영진들이 인천 송도서 열리는 아시아개발은행(ADB) 연차총회를 찾았다. 윤 대통령은 3일 오전 11시 인천 송 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news119,0002709072',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">데일리안</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/008/0004882278?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/008/2023/05/02/4882278.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/008/0004882278?sid=100">ADB 총재 "새 기후금융프로그램 '이프캡' 출범…韓경제, 낙관적"</a>
# <div class="cluster_text_lede">아시아개발은행(ADB)이 아시아·태평양 지역의 기후변화 대응 금융지원을 대폭 늘리기 위해 '아시아 태평양 혁신 기후 금융 기구(이프캡·Innovative …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news008,0004882278',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">머니투데이</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305031120_00000012&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=119&amp;aid=0002709072"><span class="cluster_foot_more_icon_num">58</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011477677?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/056/2023/05/03/11477677.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011477677?sid=100">국회 정개특위, 선거제 개편 ‘500인 공론조사’ 실시…KBS 생중계</a>
# <div class="cluster_text_lede">국회 정치개혁특별위원회(정개특위)는 오는 6일과 13일 양일간 500명의 시민참여단을 대상으로 국회의원 선거제도 개편에 대한 공론조사를 실시하고, KBS …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news056,0011477677',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">KBS</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011837780?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/05/03/11837780.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011837780?sid=100">정개특위, 500인 시민참여단 대상 선거제 개편 공론화</a>
# <div class="cluster_text_lede">기사내용 요약 총 4개 의제 이틀 간 토의…주요일정 생중계 국회 정치개혁 특별위원회(국회 정개특위)는 오는 6일과 13일 양일간 500인의 시민참여단을  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011837780',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305031050_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=056&amp;aid=0011477677"><span class="cluster_foot_more_icon_num">9</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/028/0002638333?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/028/2023/05/03/2638333.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/028/0002638333?sid=100">윤 대통령 “중국, 문 전 대통령 초청해 혼밥 먹게 하지 않았나”</a>
# <div class="cluster_text_lede">윤석열 대통령이 지난 2일 여당 지도부와 한 만찬에서 2017년 12월 문재인 당시 대통령이 중국을 방문했을 때 10끼 중 2끼만 중국 지도부와 식사한  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news028,0002638333',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">한겨레</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001880493?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/052/2023/05/03/1880493.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001880493?sid=100">尹 "文 중국 방문 때 '혼밥'하게 한 건 외교적 결례"</a>
# <div class="cluster_text_lede">윤석열 대통령이 어제(2일) 국민의힘 지도부와 만찬에서 문재인 전 대통령이 지난 2017년 중국 방문 당시 혼자서 밥을 먹은 이른바 '혼밥'을 언급한 것 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001880493',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305031000_00000379&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=028&amp;aid=0002638333"><span class="cluster_foot_more_icon_num">14</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277562?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/025/2023/05/03/3277562.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277562?sid=100">서영교 "박근혜 공천 개입 기소한 게 尹…대통령실 정치 개입"</a>
# <div class="cluster_text_lede">더불어민주당은 3일 이진복 대통령실 정무수석이 국민의힘 태영호 최고위원에게 공천 문제를 거론하며 한일 관계 옹호 발언을 요청했다는 의혹에 대해 "대통령실 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news025,0003277562',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">중앙일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# ...
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/659/0000011201?ntype=RANKING&amp;sid=001">[전북날씨] 일교차 크고.. 내일부터 강풍 동반 비</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=659"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/659/2022/01/19/logo_659_56_20220119141438.png" width="16"/></span>전주MBC</a>
# </div>
# </div>
# </div>
# </li>
# </ul>, <ul class="section_list_ranking_press _rankingList" id="_rankingList75" style="display: none">
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/657/0000014527?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/657/2023/05/03/14527.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/657/0000014527?ntype=RANKING&amp;sid=001">[영상+] "마음이 아프신가요?" 국립 김천 치유의 숲</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=657"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/657/2022/01/19/logo_657_56_20220119135625.png" width="16"/></span>대구MBC</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/666/0000010331?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/666/2023/05/03/10331.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/666/0000010331?ntype=RANKING&amp;sid=001">서정진 '혼외 자녀' 친모 회사 2곳 계열사로 추가… 셀트 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=666"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/666/2023/01/03/logo_666_56_20230103174615.png" width="16"/></span>경기일보</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/658/0000039942?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/658/2023/05/03/39942.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/658/0000039942?ntype=RANKING&amp;sid=001">민주당 ‘돈 봉투 의혹’ 윤관석 이성만 자진 탈당</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=658"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/658/2022/01/20/logo_658_56_20220120164828.png" width="16"/></span>국제신문</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/656/0000049887?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/656/2023/05/03/49887.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/656/0000049887?ntype=RANKING&amp;sid=001">"그것이 하나님의 극적인 사랑" JMS 2인자 등 간부 8 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=656"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/656/2022/01/19/logo_656_56_20220119134936.png" width="16"/></span>대전일보</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/661/0000024456?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/661/2023/05/03/24456.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/661/0000024456?ntype=RANKING&amp;sid=001">'尹 호위무사' 이용 "김건희 여사 활동적이지 않고 온순. …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=661"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/661/2022/01/19/logo_661_56_20220119142145.png" width="16"/></span>JIBS</a>
# </div>
# </div>
# </div>
# </li>
# </ul>, <ul class="section_list_ranking_press _rankingList" id="_rankingList80" style="display: none">
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/656/0000049887?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/656/2023/05/03/49887.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/656/0000049887?ntype=RANKING&amp;sid=001">"그것이 하나님의 극적인 사랑" JMS 2인자 등 간부 8 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=656"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/656/2022/01/19/logo_656_56_20220119134936.png" width="16"/></span>대전일보</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/661/0000024456?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/661/2023/05/03/24456.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/661/0000024456?ntype=RANKING&amp;sid=001">'尹 호위무사' 이용 "김건희 여사 활동적이지 않고 온순. …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=661"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/661/2022/01/19/logo_661_56_20220119142145.png" width="16"/></span>JIBS</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/655/0000009635?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/655/2023/05/02/9635.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/655/0000009635?ntype=RANKING&amp;sid=001">어린이날 나들이 어쩌나.. 4일밤부터 호우특보 수준 쏟아진 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=655"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/655/2022/01/20/logo_655_56_20220120164501.png" width="16"/></span>CJB청주방송</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/665/0000000892?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/665/2023/05/03/892.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/665/0000000892?ntype=RANKING&amp;sid=001">1년 만에 론칭? 리버버스 졸속과 땜빵 사이 [視리즈]</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=665"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/665/2022/12/08/logo_665_56_20221208184224.png" width="16"/></span>더스쿠프</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018643?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/145/2023/05/03/18643.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/145/0000018643?ntype=RANKING&amp;sid=001">‘스시테러’ 정신 못 차렸나…일본 방송인 망원시장서 침 묻 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=145"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/145/2020/12/09/logo_145_56_20201209180915.png" width="16"/></span>레이디경향</a>
# </div>
# </div>
# </div>
# </li>
# </ul>, <div class="side_ad" id="glad_ad_sidebox"></div>, <div class="section" id="right_dailyList" style="margin-bottom:20px; white-space:nowrap;">
# <h4>분야별 주요뉴스</h4>
# <div class="classfy sd" style="display:block">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/031/0000744368?sid=100" title="민주 윤관석·이성만, '돈봉투 의혹'에 탈당 결정">민주 윤관석·이성만, '돈봉투 의혹'에 탈당 결정</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/629/0000215015?sid=100" title="尹대통령 &quot;ADB 회원국과 함께 세계 공동 번영 '연대의 길' 걷겠다&quot;">尹대통령 "ADB 회원국과 함께 세계 공동 번영 '연대의 길' 걷겠다"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/047/0002391021?sid=100" title='"독도 방문에 일본 정부 허락 필요? 윤 정부의 비겁한 침묵"'>"독도 방문에 일본 정부 허락 필요? 윤 정부의 비겁한 침묵"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/023/0003761517?sid=104" title="사용한 꼬치로 매대 음식 ‘푹’… 망원시장 간 日방송인, 위생 논란">사용한 꼬치로 매대 음식 ‘푹’… 망원시장 간 日방송인, 위생 논란</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/277/0005254219?sid=104" title="외로움, 하루 담배 15개피 만큼 해롭다">외로움, 하루 담배 15개피 만큼 해롭다</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/421/0006785038?sid=101" title="[뉴스1 PICK]부산 엑스포 유치 위해 ‘블랙핑크’ 비행기 뜬다…  대한항공 특별기 등장">[뉴스1 PICK]부산 엑스포 유치 위해 ‘블랙핑크’ 비행기 뜬다… 대한항공 특별기 등장</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/030/0003096150?sid=101" title="성장 가속도 내는 대웅제약…보톡스 수출·신약 2종 확대">성장 가속도 내는 대웅제약…보톡스 수출·신약 2종 확대</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/079/0003766110?sid=101" title="산업은행 '부산 이전 공공기관' 지정…부산시 &quot;끝까지 협조 당부&quot;">산업은행 '부산 이전 공공기관' 지정…부산시 "끝까지 협조 당부"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/293/0000043860?sid=105" title="카카오게임즈, 2분기 아닌 3분기가 진짜인 이유 [오~컬쳐]">카카오게임즈, 2분기 아닌 3분기가 진짜인 이유 [오~컬쳐]</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/020/0003495217?sid=105" title="AWS코리아, 코로나 딛고 4년 만에 'AWS 서밋 서울' 개최">AWS코리아, 코로나 딛고 4년 만에 'AWS 서밋 서울' 개최</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/584/0000022917?sid=102" title='국내 엠폭스 확진 대다수 20~40대 남성…"대부분 익명인과 성접촉"'>국내 엠폭스 확진 대다수 20~40대 남성…"대부분 익명인과 성접촉"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/079/0003766099?sid=102" title="&quot;분신 사망 건설노조 간부 '건폭몰이' 희생자…尹 정권, 노조탄압 중단하라&quot;">"분신 사망 건설노조 간부 '건폭몰이' 희생자…尹 정권, 노조탄압 중단하라"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/032/0003221243?sid=102" title="“주님을 지키며 잠을 자라” JMS 정명석 성폭행 도운 2인자 등 구속기소">“주님을 지키며 잠을 자라” JMS 정명석 성폭행 도운 2인자 등 구속기소</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/417/0000918086?sid=103" title="토레스 흥행 이을까… KG모빌리티, '렉스턴 뉴 아레나·스포츠&amp;칸 쿨멘' 출시">토레스 흥행 이을까… KG모빌리티, '렉스턴 뉴 아레나·스포츠&amp;칸 쿨멘' 출시</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/422/0000596819?sid=103" title="[날씨] 중부 초여름 더위…내일 전국 '비소식'">[날씨] 중부 초여름 더위…내일 전국 '비소식'</a> </li>
# </ul>
# </ul>
# </ul>
# </div>
# </div>, <div class="index_tab" id="index.press_category">
# <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content is_hidden" id="index.press.area"></div>
# <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content02 is_hidden" id="index.category.area"></div>
# </div>, <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>, <div class="index_content is_hidden" id="index.press.area"></div>, <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>, <div class="index_content02 is_hidden" id="index.category.area"></div>, <div id="footer">
# <ul>
# <li class="first"><a class="nclicks(fot.agreement)" href="http://www.naver.com/rules/service.html">이용약관</a></li>
# <li><a class="nclicks(fot.guide)" href="/main/ombudsman/index.naver">서비스 안내</a></li>
# <li><a class="nclicks(fot.editor)" href="/main/ombudsman/edit.naver?mid=omb">기사배열 원칙 책임자 : 유봉석</a></li>
# <li>청소년 보호 책임자 : 이희만</li>
# <li><strong><a class="nclicks(fot.privacy)" href="http://www.naver.com/rules/privacy.html">개인정보처리방침</a></strong></li>
# <li><a class="nclicks(fot.disclaimer)" href="http://www.naver.com/rules/disclaimer.html">책임의 한계와 법적고지</a></li>
# <li><a class="nclicks(fot.help)" href="#" onclick="news.external.OPS.helpNews(); return false;" title="새창">뉴스 고객센터</a></li>
# </ul>
# <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
# <address class="address_nhn">
# <a class="logo nclicks(fot.naver)" href="https://www.navercorp.com/" target="_blank"><span class="blind">NAVER</span></a>
# <em>Copyright ©</em>
# <a class="nclicks(fot.navercorp)" href="https://www.navercorp.com/" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# <!-- -->
# </div>]

# %%
bs.select_one('div#u_skip>a>span').text
# Out:
# '메인 메뉴로 바로가기'

# %%
bs.find('div', id='header').find('a').text
# Out:
# '메인 메뉴로 바로가기'

# %%
# https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100' 사이트에서 
# class_='cluster_text'에 있는 모든 한글 text 10개를 출력하세요.

for i in bs.find_all(class_='cluster_text')[:10]:
    print(' '.join(re.findall('[^\n]+',i.text)))
# Out:
# 국회 JMS 토론회 열려…“변호인 접견권 제한 근거 마련해야” JMS 총재 정명석 씨의 ‘황제 접견’ 논란과 관련해 변호인 접견권을 제한해야 할지를 두고 국회에서 토론회가 열렸습니다. 더불어민주당 박범계 의원은 오늘 … KBS
# 헤럴드경제 “JMS 신도, 교도관·법조계·대학·국정원까지 퍼져 있다”
# 서울경제 “교도관·법조계·대학·정부기관까지 JMS 신도 퍼져”
# 노컷뉴스 'JMS 황제접견' 방지…국회서 접견남용 방지 토론회 연다
# 日 정부, 민주당 의원 독도 방문에 항의·유감표명 일본 정부가 더불어민주당 전용기 의원이 독도를 방문한 데 대해 외교 경로를 통해 항의했다. 3일 교도통신 등 일본 언론에 따르면 후나코시 다케히로 일본  … 서울경제
# 서울경제 정부, "野 독도 방문 부당' 日항의에 "부당한 주장"
# JTBC 전용기 의원, 독도 관련 일본 항의에 "내정간섭, 외교부가 강력 대응해야"
# 머니투데이 "韓 의원, 다케시마 상륙" 日 외무성, 韓에 재발 방지 요구
# 홍준표 "尹, 이재명 안 만나는건 '딜'오해 때문…불통 아냐" 기사내용 요약 김재원·태영호에 "중징계 불가피해 보여" 간호법 제정안 "대통령 거부권 행사해야" [서울=뉴홍준표 대구시장은 3일 윤석열 대통령이 이재명  … 뉴시스
# 머니투데이 홍준표 "尹대통령 불통 아냐, 이재명 안 만나는 이유는…"

# %% [markdown]
# #### 과제5_0503.
# 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100'에서 뉴스 제목 10개를 가져오세요
# (사이트의 뉴스와 일치)

# %% [markdown]
# #### 과제6_0503.
# 상기에서 출력된 데이터를 news.txt 파일로 저장하세요.

# %% [markdown]
# #### 과제7_0503.
# 네이버 등 자주 사용하는 웹페이지에서 가치있다고 생각할 수 있는 데이터를 가져와서 활용할 수 있는 형태로 출력하세요.(최소 1000개 이상)

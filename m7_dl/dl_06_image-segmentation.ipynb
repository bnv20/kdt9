# %% [markdown]
# # 컴퓨터 비전을 위한 고급 딥러닝

# %% [markdown]
# ## 세 가지 주요 컴퓨터 비전 작업

# %% [markdown]
# ## 이미지 분할 예제

# %%
#  웹에서 데이터를 다운로드하고 압축을 푸는 과정
# !wget http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
# !wget http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz
# !tar -xf images.tar.gz
# !tar -xf annotations.tar.gz
# Out:
# --2023-07-11 02:06:41--  http://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
# Resolving www.robots.ox.ac.uk (www.robots.ox.ac.uk)... 129.67.94.2
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz [following]
# --2023-07-11 02:06:41--  https://www.robots.ox.ac.uk/~vgg/data/pets/data/images.tar.gz
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://thor.robots.ox.ac.uk/~vgg/data/pets/images.tar.gz [following]
# --2023-07-11 02:06:41--  https://thor.robots.ox.ac.uk/~vgg/data/pets/images.tar.gz
# Resolving thor.robots.ox.ac.uk (thor.robots.ox.ac.uk)... 129.67.95.98
# Connecting to thor.robots.ox.ac.uk (thor.robots.ox.ac.uk)|129.67.95.98|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://thor.robots.ox.ac.uk/datasets/pets/images.tar.gz [following]
# --2023-07-11 02:06:41--  https://thor.robots.ox.ac.uk/datasets/pets/images.tar.gz
# Reusing existing connection to thor.robots.ox.ac.uk:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 791918971 (755M) [application/octet-stream]
# Saving to: ‘images.tar.gz’
#
# images.tar.gz       100%[===================>] 755.23M   212MB/s    in 3.7s
#
# 2023-07-11 02:06:45 (206 MB/s) - ‘images.tar.gz’ saved [791918971/791918971]
#
# --2023-07-11 02:06:45--  http://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz
# Resolving www.robots.ox.ac.uk (www.robots.ox.ac.uk)... 129.67.94.2
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz [following]
# --2023-07-11 02:06:45--  https://www.robots.ox.ac.uk/~vgg/data/pets/data/annotations.tar.gz
# Connecting to www.robots.ox.ac.uk (www.robots.ox.ac.uk)|129.67.94.2|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://thor.robots.ox.ac.uk/~vgg/data/pets/annotations.tar.gz [following]
# --2023-07-11 02:06:45--  https://thor.robots.ox.ac.uk/~vgg/data/pets/annotations.tar.gz
# Resolving thor.robots.ox.ac.uk (thor.robots.ox.ac.uk)... 129.67.95.98
# Connecting to thor.robots.ox.ac.uk (thor.robots.ox.ac.uk)|129.67.95.98|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://thor.robots.ox.ac.uk/datasets/pets/annotations.tar.gz [following]
# --2023-07-11 02:06:45--  https://thor.robots.ox.ac.uk/datasets/pets/annotations.tar.gz
# Reusing existing connection to thor.robots.ox.ac.uk:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 19173078 (18M) [application/octet-stream]
# Saving to: ‘annotations.tar.gz’
#
# annotations.tar.gz  100%[===================>]  18.28M   108MB/s    in 0.2s
#
# 2023-07-11 02:06:45 (108 MB/s) - ‘annotations.tar.gz’ saved [19173078/19173078]

# %%
! ls
# Out:
# annotations  annotations.tar.gz  images  images.tar.gz	sample_data

# %%
# ! ls annotations/trimaps
! ls annotations/trimaps

# %%
import os

input_dir = "images/"
target_dir = "annotations/trimaps/"

input_img_paths = sorted(
    [os.path.join(input_dir, fname)
     for fname in os.listdir(input_dir)
     if fname.endswith(".jpg")])
target_paths = sorted(
    [os.path.join(target_dir, fname)
     for fname in os.listdir(target_dir)
     if fname.endswith(".png") and not fname.startswith(".")])

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img, img_to_array

plt.axis("off")
plt.imshow(load_img(input_img_paths[9]))

# %%
def display_target(target_array):
    # 원래 레이블은 1,2,3이며 여기서 1을 빼서 0 ~ 2범위로 변경. 127을 곱해서 레이블 값은 0(검은색), 127(회색), 254(흰색)로 변경
    normalized_array = (target_array.astype("uint8") - 1) * 127 #
    plt.axis("off")
    plt.imshow(normalized_array[:, :, 0])
    # plt.imshow(normalized_array[:, :, 0], cmap='gray')
img = img_to_array(load_img(target_paths[9], color_mode="grayscale"))
display_target(img)

# %%
# 이미지 데이터를 로드하고, 이를 학습과 검증 데이터로 분할
import numpy as np
import random

img_size = (200, 200)
num_imgs = len(input_img_paths)

random.Random(1337).shuffle(input_img_paths)
random.Random(1337).shuffle(target_paths)

def path_to_input_image(path):
    return img_to_array(load_img(path, target_size=img_size))

def path_to_target(path):
    img = img_to_array(
        load_img(path, target_size=img_size, color_mode="grayscale"))
    img = img.astype("uint8") - 1 # 레이블이 0,1,2가 되도록 1을 뺌
    return img

input_imgs = np.zeros((num_imgs,) + img_size + (3,), dtype="float32") # (num_imgs, img_height, img_width, 3) 모양의 4차원 배열을 생성
targets = np.zeros((num_imgs,) + img_size + (1,), dtype="uint8") # (num_imgs, img_height, img_width, 1) 모양의 4차원 배열을 생성
for i in range(num_imgs):
    input_imgs[i] = path_to_input_image(input_img_paths[i])
    targets[i] = path_to_target(target_paths[i])

num_val_samples = 1000
train_input_imgs = input_imgs[:-num_val_samples]
train_targets = targets[:-num_val_samples]
val_input_imgs = input_imgs[-num_val_samples:]
val_targets = targets[-num_val_samples:]

# %%
from tensorflow import keras
from tensorflow.keras import layers

def get_model(img_size, num_classes):
    inputs = keras.Input(shape=img_size + (3,))
    x = layers.Rescaling(1./255)(inputs)

    x = layers.Conv2D(64, 3, strides=2, activation="relu", padding="same")(x)
    x = layers.Conv2D(64, 3, activation="relu", padding="same")(x)
    x = layers.Conv2D(128, 3, strides=2, activation="relu", padding="same")(x)
    x = layers.Conv2D(128, 3, activation="relu", padding="same")(x)
    x = layers.Conv2D(256, 3, strides=2, padding="same", activation="relu")(x)
    x = layers.Conv2D(256, 3, activation="relu", padding="same")(x)
    # 특성맵을 업샘플링
    x = layers.Conv2DTranspose(256, 3, activation="relu", padding="same")(x)
    x = layers.Conv2DTranspose(256, 3, activation="relu", padding="same", strides=2)(x)
    x = layers.Conv2DTranspose(128, 3, activation="relu", padding="same")(x)
    x = layers.Conv2DTranspose(128, 3, activation="relu", padding="same", strides=2)(x)
    x = layers.Conv2DTranspose(64, 3, activation="relu", padding="same")(x)
    x = layers.Conv2DTranspose(64, 3, activation="relu", padding="same", strides=2)(x)

    outputs = layers.Conv2D(num_classes, 3, activation="softmax", padding="same")(x)

    model = keras.Model(inputs, outputs)
    return model

model = get_model(img_size=img_size, num_classes=3)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 200, 200, 3)]     0
#
#  rescaling (Rescaling)       (None, 200, 200, 3)       0
#
#  conv2d (Conv2D)             (None, 100, 100, 64)      1792
#
#  conv2d_1 (Conv2D)           (None, 100, 100, 64)      36928
#
#  conv2d_2 (Conv2D)           (None, 50, 50, 128)       73856
#
#  conv2d_3 (Conv2D)           (None, 50, 50, 128)       147584
#
#  conv2d_4 (Conv2D)           (None, 25, 25, 256)       295168
#
#  conv2d_5 (Conv2D)           (None, 25, 25, 256)       590080
#
#  conv2d_transpose (Conv2DTra  (None, 25, 25, 256)      590080
#  nspose)
#
#  conv2d_transpose_1 (Conv2DT  (None, 50, 50, 256)      590080
#  ranspose)
#
#  conv2d_transpose_2 (Conv2DT  (None, 50, 50, 128)      295040
#  ranspose)
#
#  conv2d_transpose_3 (Conv2DT  (None, 100, 100, 128)    147584
#  ranspose)
#
#  conv2d_transpose_4 (Conv2DT  (None, 100, 100, 64)     73792
#  ranspose)
#
#  conv2d_transpose_5 (Conv2DT  (None, 200, 200, 64)     36928
#  ranspose)
#
#  conv2d_6 (Conv2D)           (None, 200, 200, 3)       1731
#
# =================================================================
# Total params: 2,880,643
# Trainable params: 2,880,643
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="rmsprop", loss="sparse_categorical_crossentropy")

callbacks = [
    keras.callbacks.ModelCheckpoint("oxford_segmentation.keras",
                                    save_best_only=True)
]

history = model.fit(train_input_imgs, train_targets,
                    epochs=50,
                    callbacks=callbacks,
                    batch_size=64,
                    validation_data=(val_input_imgs, val_targets))
# Out:
# Epoch 1/50
# 100/100 [==============================] - 98s 737ms/step - loss: 0.9452 - val_loss: 0.9284
# Epoch 2/50
# 100/100 [==============================] - 64s 636ms/step - loss: 0.8988 - val_loss: 0.8385
# Epoch 3/50
# 100/100 [==============================] - 63s 631ms/step - loss: 0.8354 - val_loss: 0.8334
# Epoch 4/50
# 100/100 [==============================] - 63s 631ms/step - loss: 0.8092 - val_loss: 0.7501
# Epoch 5/50
# 100/100 [==============================] - 63s 632ms/step - loss: 0.7759 - val_loss: 0.7722
# Epoch 6/50
# 100/100 [==============================] - 63s 631ms/step - loss: 0.7630 - val_loss: 0.7393
# Epoch 7/50
# 100/100 [==============================] - 64s 638ms/step - loss: 0.7543 - val_loss: 0.7511
# Epoch 8/50
# 100/100 [==============================] - 64s 637ms/step - loss: 0.7463 - val_loss: 0.7144
# Epoch 9/50
# 100/100 [==============================] - 64s 643ms/step - loss: 0.7251 - val_loss: 0.6954
# Epoch 10/50
# 100/100 [==============================] - 64s 639ms/step - loss: 0.7007 - val_loss: 0.6392
# Epoch 11/50
# 100/100 [==============================] - 64s 642ms/step - loss: 0.6725 - val_loss: 0.7129
# Epoch 12/50
# 100/100 [==============================] - 64s 642ms/step - loss: 0.6480 - val_loss: 0.6075
# Epoch 13/50
# 100/100 [==============================] - 64s 641ms/step - loss: 0.6256 - val_loss: 0.6963
# Epoch 14/50
# 100/100 [==============================] - 64s 645ms/step - loss: 0.6073 - val_loss: 0.5780
# Epoch 15/50
# 100/100 [==============================] - 64s 644ms/step - loss: 0.5849 - val_loss: 0.5854
# Epoch 16/50
# 100/100 [==============================] - 64s 645ms/step - loss: 0.5790 - val_loss: 0.5375
# Epoch 17/50
# 100/100 [==============================] - 64s 643ms/step - loss: 0.5621 - val_loss: 0.5740
# Epoch 18/50
# 100/100 [==============================] - 64s 643ms/step - loss: 0.5497 - val_loss: 0.5878
# Epoch 19/50
# 100/100 [==============================] - 64s 644ms/step - loss: 0.5387 - val_loss: 0.5028
# Epoch 20/50
# 100/100 [==============================] - 64s 642ms/step - loss: 0.5290 - val_loss: 0.4851
# Epoch 21/50
# 100/100 [==============================] - 64s 642ms/step - loss: 0.5189 - val_loss: 0.5004
# Epoch 22/50
# 100/100 [==============================] - 64s 641ms/step - loss: 0.5079 - val_loss: 0.5677
# Epoch 23/50
# 100/100 [==============================] - 64s 642ms/step - loss: 0.4928 - val_loss: 0.4719
# Epoch 24/50
# 100/100 [==============================] - 64s 642ms/step - loss: 0.4894 - val_loss: 0.4766
# Epoch 25/50
# 100/100 [==============================] - 64s 642ms/step - loss: 0.4790 - val_loss: 0.5071
# Epoch 26/50
# 100/100 [==============================] - 64s 642ms/step - loss: 0.4724 - val_loss: 0.4582
# Epoch 27/50
# 100/100 [==============================] - 64s 641ms/step - loss: 0.4684 - val_loss: 0.4287
# Epoch 28/50
# 100/100 [==============================] - 64s 641ms/step - loss: 0.4681 - val_loss: 0.4955
# Epoch 29/50
# 100/100 [==============================] - 64s 643ms/step - loss: 0.4443 - val_loss: 0.4232
# Epoch 30/50
# 100/100 [==============================] - 64s 641ms/step - loss: 0.4432 - val_loss: 0.4422
# Epoch 31/50
# 100/100 [==============================] - 64s 643ms/step - loss: 0.4368 - val_loss: 0.4095
# Epoch 32/50
# 100/100 [==============================] - 64s 644ms/step - loss: 0.4293 - val_loss: 0.4064
# Epoch 33/50
# 100/100 [==============================] - 64s 644ms/step - loss: 0.4207 - val_loss: 0.4412
# Epoch 34/50
# 100/100 [==============================] - 64s 643ms/step - loss: 0.4199 - val_loss: 0.4209
# Epoch 35/50
# 100/100 [==============================] - 64s 643ms/step - loss: 0.4136 - val_loss: 0.3889
# Epoch 36/50
# 100/100 [==============================] - 64s 641ms/step - loss: 0.4130 - val_loss: 0.4180
# Epoch 37/50
# 100/100 [==============================] - 64s 643ms/step - loss: 0.4036 - val_loss: 0.3819
# Epoch 38/50
# 100/100 [==============================] - 64s 640ms/step - loss: 0.3946 - val_loss: 0.4002
# Epoch 39/50
# 100/100 [==============================] - 64s 641ms/step - loss: 0.3872 - val_loss: 0.4274
# Epoch 40/50
# 100/100 [==============================] - 64s 641ms/step - loss: 0.3806 - val_loss: 0.4216
# Epoch 41/50
# 100/100 [==============================] - 64s 640ms/step - loss: 0.3770 - val_loss: 0.4285
# Epoch 42/50
# 100/100 [==============================] - 64s 642ms/step - loss: 0.3716 - val_loss: 0.3747
# Epoch 43/50
# 100/100 [==============================] - 64s 641ms/step - loss: 0.3689 - val_loss: 0.3948
# Epoch 44/50
# 100/100 [==============================] - 64s 643ms/step - loss: 0.3580 - val_loss: 0.4230
# Epoch 45/50
# 100/100 [==============================] - 64s 642ms/step - loss: 0.3529 - val_loss: 0.5015
# Epoch 46/50
# 100/100 [==============================] - 64s 644ms/step - loss: 0.3461 - val_loss: 0.4649
# Epoch 47/50
# 100/100 [==============================] - 64s 644ms/step - loss: 0.3398 - val_loss: 0.3995
# Epoch 48/50
# 100/100 [==============================] - 64s 644ms/step - loss: 0.3362 - val_loss: 0.4011
# Epoch 49/50
# 100/100 [==============================] - 64s 645ms/step - loss: 0.3350 - val_loss: 0.3582
# Epoch 50/50
# 100/100 [==============================] - 64s 643ms/step - loss: 0.3251 - val_loss: 0.3614

# %%
epochs = range(1, len(history.history["loss"]) + 1)
loss = history.history["loss"]
val_loss = history.history["val_loss"]
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-82cda2500fba> in <cell line: 1>()
# ----> 1 epochs = range(1, len(history.history["loss"]) + 1)
#       2 loss = history.history["loss"]
#       3 val_loss = history.history["val_loss"]
#       4 plt.figure()
#       5 plt.plot(epochs, loss, "bo", label="Training loss")
#
# NameError: name 'history' is not defined

# %%
from tensorflow.keras.utils import array_to_img

model = keras.models.load_model("oxford_segmentation.keras")

i = 4
test_image = val_input_imgs[i]
plt.axis("off")
plt.imshow(array_to_img(test_image))

mask = model.predict(np.expand_dims(test_image, 0))[0]

def display_mask(pred):
    mask = np.argmax(pred, axis=-1)
    mask *= 127
    plt.axis("off")
    plt.imshow(mask)

display_mask(mask)
# Out:
# 1/1 [==============================] - 1s 532ms/step
